# %%
library(dplyr)
library(readr)
install.packages("caret")
library(caret)
install.packages("survminer")
library(survminer)
install.packages("survival")
library(survival)
install.packages("ggplot2")
library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘listenv’, ‘parallelly’, ‘future’, ‘globals’, ‘shape’, ‘future.apply’, ‘numDeriv’, ‘progressr’, ‘SQUAREM’, ‘diagram’, ‘lava’, ‘prodlim’, ‘proxy’, ‘iterators’, ‘Rcpp’, ‘clock’, ‘gower’, ‘hardhat’, ‘ipred’, ‘timeDate’, ‘e1071’, ‘foreach’, ‘ModelMetrics’, ‘plyr’, ‘pROC’, ‘recipes’, ‘reshape2’
#
#
# Loading required package: ggplot2
#
# Loading required package: lattice
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘Deriv’, ‘microbenchmark’, ‘doBy’, ‘SparseM’, ‘MatrixModels’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘carData’, ‘abind’, ‘pbkrtest’, ‘quantreg’, ‘lme4’, ‘corrplot’, ‘car’, ‘markdown’, ‘png’, ‘jpeg’, ‘ggrepel’, ‘ggsci’, ‘cowplot’, ‘ggsignif’, ‘polynom’, ‘rstatix’, ‘exactRankTests’, ‘mvtnorm’, ‘KMsurv’, ‘zoo’, ‘km.ci’, ‘xtable’, ‘gridtext’, ‘ggpubr’, ‘gridExtra’, ‘maxstat’, ‘survMisc’, ‘ggtext’
#
#
# Loading required package: ggpubr
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘survival’
#
#
# The following object is masked from ‘package:survminer’:
#
#     myeloma
#
#
# The following object is masked from ‘package:caret’:
#
#     cluster
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Instalar y cargar las bibliotecas necesarias
install.packages("googledrive")
library(googledrive)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Autenticarse con Google Drive
drive_auth()
# Out:
# Is it OK to cache OAuth access credentials in the folder ~/.cache/gargle
# between R sessions?
# 1: Yes
# 2: No
# Selection: 1
# Please point your browser to the following url:
#
# https://accounts.google.com/o/oauth2/v2/auth?client_id=603366585132-frjlouoa3s2ono25d2l9ukvhlsrlnr7k.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&redirect_uri=https%3A%2F%2Fwww.tidyverse.org%2Fgoogle-callback%2F&response_type=code&state=920fdd968965bad77c654882a5008a73&access_type=offline&prompt=consent
# Enter authorization code: eyJjb2RlIjoiNC8wQVR4M0xZNHI5WG15VHBINHVzN2lhOF9VdThpYVh0MW9Jb3Y5cWhRT05oeEVyMHAzU1d1Z2N3cS12My1nZGM1SUpTRlkydyIsInN0YXRlIjoiOTIwZmRkOTY4OTY1YmFkNzdjNjU0ODgyYTUwMDhhNzMifQ==

# %%
# Especificar el ID del archivo y la ruta de destino
file_id <- "https://drive.google.com/file/d/1WDRKvrZrvSlQa8qNgUCoGwEyepYNm3dz/view?usp=drivesdk"  # Reemplaza este ID con el ID de tu archivo
drive_download(as_id(file_id), path = "archivo.csv", overwrite = TRUE)
# Out:
# File downloaded:
#
# • Documento de César García <id: 1WDRKvrZrvSlQa8qNgUCoGwEyepYNm3dz>
#
# Saved locally as:
#
# • archivo.csv

# %%
# Leer el archivo CSV desde la URL
urlAge <- "https://raw.githubusercontent.com/cesargar1507/DatasetsUB/main/machine_age.csv"
urlMechanic <- "https://raw.githubusercontent.com/cesargar1507/DatasetsUB/main/mechanic_antiquity.csv"
df <- read_csv("archivo.csv", show_col_types = FALSE)
df_age <- read_csv(urlAge, show_col_types = FALSE)
df_mechanic <- read_csv(urlMechanic, show_col_types = FALSE)

# %%
summary(df)
# Out:
#    equipment        operation           wo_type           base_model
#  Min.   : 100268   Length:149066      Length:149066      Length:149066
#  1st Qu.:1023935   Class :character   Class :character   Class :character
#  Median :1078773   Mode  :character   Mode  :character   Mode  :character
#  Mean   :1017279
#  3rd Qu.:1149220
#  Max.   :1169630
#  problem_code       problem_desc       failure_code       failure_desc
#  Length:149066      Length:149066      Length:149066      Length:149066
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#   cause_code         cause_desc        action_code        action_desc
#  Length:149066      Length:149066      Length:149066      Length:149066
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#    mechanic             date           downtime_gross     pit_coverage
#  Length:149066      Length:149066      Min.   :-6.3833   Min.   : 0.0000
#  Class :character   Class :character   1st Qu.: 0.4167   1st Qu.: 0.0000
#  Mode  :character   Mode  :character   Median : 0.8333   Median : 0.1700
#                                        Mean   : 1.4810   Mean   : 0.8333
#                                        3rd Qu.: 1.8333   3rd Qu.: 1.0000
#                                        Max.   :13.9167   Max.   :20.0000
#  real_downtime         parts_cost         repair_hours     waiting_hours
#  Min.   :-18.166667   Length:149066      Min.   :-7.4333   Min.   :-14.0000
#  1st Qu.:  0.003333   Class :character   1st Qu.: 0.3333   1st Qu.:  0.0000
#  Median :  0.216667   Mode  :character   Median : 0.5000   Median :  0.0000
#  Mean   :  0.647710                      Mean   : 0.9847   Mean   :  0.4963
#  3rd Qu.:  0.666667                      3rd Qu.: 1.0000   3rd Qu.:  0.3333
#  Max.   : 13.916667                      Max.   :13.9167   Max.   : 10.0000
#   changed_pcs
#  Min.   :-7.000
#  1st Qu.: 0.000
#  Median : 1.000
#  Mean   : 1.011
#  3rd Qu.: 1.000
#  Max.   :14.000

# %%
head(df,5)
# Out:
#   equipment operation wo_type                base_model problem_code
# 1 100268    BIND LEG  Calibration            VF2500     SEWP001
# 2 100268    BIND LEG  Corrective Maintenance VF2500     SEWP002
# 3 100268    BIND LEG  Corrective Maintenance VF2500     SEWP002
# 4 100268    BIND LEG  Corrective Maintenance VF2500     SEWP002
# 5 100312    BARTACK   Corrective Maintenance LT2-B872   SEWP001
#   problem_desc                           failure_code
# 1 It does not sew / No cose              SEWF001
# 2 It sews with defect / Cose con defecto SEWF001
# 3 It sews with defect / Cose con defecto SEWF001
# 4 It sews with defect / Cose con defecto SEWF001
# 5 It does not sew / No cose              SEWF001
#   failure_desc
# 1 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 2 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 3 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 4 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 5 Machine head failure stopping sewing  / Falla cabezal dejando de coser
#   cause_code
# 1 SEWC001
# 2 SEWC017
# 3 SEWC017
# 4 SEWC012
# 5 SEWC005
#   cause_desc                                                                  ⋯
# 1 Misadjusted machine head needle guard / Guarda aguja de cabezal desajustada ⋯
# 2 Misadjusted machine head teeth / Dientes de cabezal desajustados            ⋯
# 3 Misadjusted machine head teeth / Dientes de cabezal desajustados            ⋯
# 4 Misadjusted machine head needle bar / Barra de aguja de cabezal desajustada ⋯
# 5 Broken machine head ball joint / Rotura de biela de cabezal                 ⋯
#   action_desc
# 1 Adjust machine head needle guard / Ajustar guarda aguja de cabezal
# 2 Adjust machine head teeth / Ajustar dientes de cabezal
# 3 Adjust machine head teeth / Ajustar dientes de cabezal
# 4 Adjust machine head teeth / Ajustar dientes de cabezal
# 5 Replace machine head ball joint / Reemplazar biela de cabezal
#   mechanic          date      downtime_gross pit_coverage real_downtime
# 1 Erick Garcia Lima 7/14/2023 0.08333333     0.08         0.003333333
# 2 Jaime Rivera      10/3/2023 1.25000000     0.00         1.250000000
# 3 Jaime Rivera      10/3/2023 1.25000000     0.00         1.250000000
# 4 Jaime Rivera      1/17/2024 3.00000000     3.00         0.000000000
# 5 JERONIMO FUNEZ    3/18/2023 0.25000000     0.00         0.250000000
#   parts_cost repair_hours waiting_hours changed_pcs
# 1 $0.74      0.08333333   0             0
# 2 $16.81     1.25000000   0             1
# 3 $16.81     1.25000000   0             1
# 4 $12.50     2.00000000   1             2
# 5 $2.67      0.25000000   0             0

# %% [markdown]
# **ANALISIS DE VARIABLES**

# %%
dim(df)
# Out:
# [1] 149066     21

# %%
# Calcular la frecuencia de cada operación
operation_freq <- df %>%
  group_by(operation) %>%
  summarise(count = n()) %>%
  arrange(desc(count))

# Calcular el porcentaje acumulado
operation_freq <- operation_freq %>%
  mutate(cum_count = cumsum(count),
         cum_perc = cum_count / sum(count))

operation_freq
# Out:
#    operation                  count cum_count cum_perc
# 1  HEM SLEEVE                 26821  26821    0.1799270
# 2  HEM BOTTOM                 17016  43837    0.2940778
# 3  SET SLEEVE                  8557  52394    0.3514819
# 4  JOIN PANEL                  8537  60931    0.4087518
# 5  TAPE SHOULDER               8017  68948    0.4625334
# 6  HEM AROUND                  5749  74697    0.5011002
# 7  FLAT SEAM                   5521  80218    0.5381375
# 8  JOIN SHOULDER               5227  85445    0.5732025
# 9  ATTACH ELASTIC              4947  90392    0.6063891
# 10 SET COLLAR                  4817  95209    0.6387037
# 11 CLOSE SLEEVE                4633  99842    0.6697839
# 12 FLAT LOCK                   4563 104405    0.7003945
# 13 SEW ELASTIC                 4381 108786    0.7297841
# 14 BIND LEG                    4086 112872    0.7571948
# 15 TOP STITCH                  3755 116627    0.7823850
# 16 HEM SLEEVE MAN              2835 119462    0.8014034
# 17 SET POCKET                  1953 121415    0.8145050
# 18 TOP STITCH COLLAR           1747 123162    0.8262246
# 19 TOP STITCH WAIST BAND       1631 124793    0.8371661
# 20 HEM LEG                     1629 126422    0.8480941
# 21 SET CUFF                    1608 128030    0.8588813
# 22 BARTACK                     1560 129590    0.8693465
# 23 PRECLOSE ELASTIC            1496 131086    0.8793823
# 24 BIND ARM                    1353 132439    0.8884588
# 25 BIND NECK                   1265 133704    0.8969450
# 26 TUBE FLY                    1187 134891    0.9049079
# 27 TOP STITCH SLEEVE AND BAND  1155 136046    0.9126561
# 28 JOIN LEG                     933 136979    0.9189151
# 29 SET BAND                     830 137809    0.9244831
# 30 BIND ARMHOLE                 811 138620    0.9299237
# 31 COVER STITCH WAIST           583 139203    0.9338347
# 32 CLOSE NECK                   579 139782    0.9377189
# 33 SET HOOD                     577 140359    0.9415896
# 34 GROMMET                      485 140844    0.9448432
# 35 SEW ELASTIC WAIST            484 141328    0.9480901
# 36 SIDE SEAM                    481 141809    0.9513169
# 37 COVER STITCH                 464 142273    0.9544296
# 38 HEM POCKET                   436 142709    0.9573545
# 39 BUTTON                       435 143144    0.9602726
# 40 P. LABEL                     432 143576    0.9631707
# 41 TOP STITCH HOOD              398 143974    0.9658406
# 42 TOP STITCH SEAM CROTCH       372 144346    0.9683362
# 43 TOP STITCH BAND              370 144716    0.9708183
# 44 FIRST SIDE                   347 145063    0.9731461
# 45 HEM SLEEVE AUTO              346 145409    0.9754672
# 46 BUTTON HOLE                  312 145721    0.9775603
# 47 TOP STITCH SLEEVE            309 146030    0.9796332
# 48 SECOND SIDE                  300 146330    0.9816457
# 49 SERGE ELASTIC                277 146607    0.9835040
# 50 CLOSE CUFF                   264 146871    0.9852750
# 51 CLOSE POCKET                 264 147135    0.9870460
# 52 HEM HOOD                     256 147391    0.9887634
# 53 LOCK STITCH                  253 147644    0.9904606
# 54 PLACKET TOPSTITCH            249 147893    0.9921310
# 55 TOP STITCH POCKET            244 148137    0.9937679
# 56 CUT AND CLOSE ELASTIC        238 148375    0.9953645
# 57 ANKLE                        237 148612    0.9969544
# 58 SEW PANEL                    228 148840    0.9984839
# 59 CLOSE INSEAM                 226 149066    1.0000000

# %%
# Crear el gráfico de barras
ggplot(df, aes(y = problem_desc)) +
  geom_bar(fill = 'skyblue', color = 'black') +
  labs(title = 'Frecuencia de Variables Categóricas',
       x = 'Frecuencia',
       y = 'Categoria') +
  theme_minimal()
#Ordenar, es util frecuencia acumulada top 3
# Out:
# plot without title

# %%
# Crear el gráfico de barras
ggplot(df, aes(y = failure_desc)) +
  geom_bar(fill = 'skyblue', color = 'black') +
  labs(title = 'Frecuencia de Variables Categóricas',
       x = 'Frecuencia',
       y = 'Categoria') +
  theme_minimal()
#Ordenar, es util frecuencia acumulada top 3
#Colocar porcentaje a la derecha
# Out:
# plot without title

# %%
# Calcular la frecuencia de causas de fallo
cause_freq <- df %>%
  group_by(cause_desc) %>%
  summarise(count = n()) %>%
  arrange(desc(count))

# Calcular el porcentaje acumulado
cause_freq <- cause_freq %>%
  mutate(cum_count = cumsum(count),
         cum_perc = cum_count / sum(count))
cause_freq
# Out:
#     cause_desc
# 1   Misadjusted machine head looper / Enlazador de cabezal desajustado
# 2   Damaged trim off system knife / Cuchilla de corta desperdicio en mal estado
# 3   Misadjusted machine head needle guard / Guarda aguja de cabezal desajustada
# 4   Broken machine head ball joint / Rotura de biela de cabezal
# 5   Misadjusted machine head presser foot / Prensatela de cabezal desajustado
# 6   Misadjusted machine head teeth / Dientes de cabezal desajustados
# 7   Misadjusted machine head chopper / Cuchilla de cabezal desajustada
# 8   Misadjusted machine head needle bar / Barra de aguja de cabezal desajustada
# 9   Oil leak in machine head / Fuga de aceite lubricante en cabezal
# 10  Misadjusted hook set / Conjunto de garfios mal ajustados
# 11  Broken machine head needle plate / Rotura de placa de aguja de cabezal
# 12  Excessive dirt in machine head / Suciedad excesiva en cabezal
# 13  Broken machine head presser foot  / Rotura de prensatela de cabezal
# 14  Misadjusted thread cutting knife / Cuchillas corta hilo mal ajustadas
# 15  Worn-out machine head looper / Enlazador de cabezal desgastado
# 16  Damaged  moving knife shaft /Eje cuchilla móvil corta desperdicio en mal estado
# 17  Damaged machine head looper / Enlazador de cabezal en mal estado
# 18  Broken knife of machine head / Rotura de cuchilla de cabezal
# 19  Damaged machine head thread take up / Leva de cabezal en mal estado
# 20  Misadjusted folder guide / Guía de doblillador desajustadas
# 21  Damaged bobbin / Bobina en mal estado
# 22  Misadjusted Sensor for cloth detection / Sensor detector de tela mal calibrado
# 23  Damaged thread cutting knife / Cuchillas corta hilo en mal estado
# 24  Blunt trim off knife / Cuchilla de corta tela desafilada
# 25  Broken machine head looper / Rotura de enlazador de cabezal
# 26  Misadjusted chain cutter knife / Cuchilla de corta cadeneta desajustada
# 27  Damaged burner resistance / Resistencia de quemador en mal estado
# 28  Loose machine head teeth / Soltura de dientes de cabezal
# 29  Damaged control box / Caja de control en mal estado
# 30  Needle plate finger with rough edge / Lengueta placa de aguja con rebaba
# ⋮   ⋮
# 251 Damaged table painting / coating / Pintura/revestimiento de mesa en mal estado
# 252 Damaged differential feeding box / Caja reductora de alimentación en mal estado
# 253 Damaged trim off knife position sensor/Sensor posic de corta tela en mal estado
# 254 Pedal dañado / Damaged pedal
# 255 Misadjusted printing head (switch S2-S3) / Cabezal desajustado (inter. S2-S3)
# 256 Caja de quemador dañada / Damaged burner box
# 257 Pad doesn't pick up ink correctly/Almohad. de impresión no recoge tinta correct.
# 258 Printing pad run is too fast / Carrera de almohadilla de impresión es muy rápida
# 259 Blunt spindle die / Dado de corte sin filo
# 260 Damaged machine head painting / Pintura de cabezal en mal estado
# 261 Damaged timer / Temporizador en mal estado
# 262 Incorrect ink formula / Fórmula de tinta incorrecta
# 263 Trancador de tapadera desajustado / Cover locker out of adjustment
# 264 Válvula de pedal desajustada / Pedal valve out of adjustment
# 265 Brazo de prensatela dañado / Damaged presser foot arm
# 266 Incorrdistance spindle die and cap/Dado corte&tapa sujeción a distincorrecta
# 267 Loose thread cone holder / Porta conos flojo
# 268 Misadjusted temperature / Temperatura desajustada
# 269 Damaged surface of printing plate / Placa impresión con superficie en mal estado
# 270 Motor del dispensador de etiquetas dañado / Damaged label dispenser engine
# 271 Palanca de prensatela dañada / Damaged presser lever
# 272 Printing plate with ink residues / Placa de impresión con residuos de tinta seca
# 273 Riel de maquina Grommet dañado / Damaged Grommet machine Rail
# 274 Stucked ink cup transporter / Transportador de copa de tinta atascado
# 275 Cilindro de maquina Grommet dañado / Damaged Grommet machine cylinder
# 276 Componente del sistema de aire comprimido dañado / Compressed air system compone
# 277 Grommet de mala calidad / Poor quality Grommet
# 278 Pedal sin lubricar / Pedal not lubricated
# 279 Printing pad with ink residue/Almohadilla de impresión tiene residuos de tinta
# 280 Resistencia de maquina Transfer dañada / Damaged Transfer machine resistance
#     count cum_count cum_perc
# 1   25580  25580    0.1716018
# 2   13394  38974    0.2614547
# 3   12673  51647    0.3464707
# 4   10551  62198    0.4172514
# 5    6571  68769    0.4613326
# 6    5966  74735    0.5013551
# 7    5586  80321    0.5388284
# 8    4890  85211    0.5716327
# 9    3802  89013    0.5971382
# 10   2099  91112    0.6112192
# 11   2095  93207    0.6252734
# 12   1953  95160    0.6383749
# 13   1943  97103    0.6514094
# 14   1911  99014    0.6642293
# 15   1732 100746    0.6758483
# 16   1572 102318    0.6863939
# 17   1564 103882    0.6968859
# 18   1561 105443    0.7073578
# 19   1504 106947    0.7174473
# 20   1433 108380    0.7270605
# 21   1363 109743    0.7362041
# 22   1142 110885    0.7438651
# 23   1110 111995    0.7513115
# 24   1092 113087    0.7586371
# 25   1037 114124    0.7655938
# 26   1021 115145    0.7724431
# 27   1014 116159    0.7792454
# 28   1014 117173    0.7860478
# 29    999 118172    0.7927495
# 30    789 118961    0.7980425
# ⋮   ⋮     ⋮         ⋮
# 251 9     148964    0.9993157
# 252 8     148972    0.9993694
# 253 8     148980    0.9994231
# 254 8     148988    0.9994767
# 255 7     148995    0.9995237
# 256 6     149001    0.9995640
# 257 6     149007    0.9996042
# 258 5     149012    0.9996377
# 259 4     149016    0.9996646
# 260 4     149020    0.9996914
# 261 4     149024    0.9997182
# 262 4     149028    0.9997451
# 263 4     149032    0.9997719
# 264 4     149036    0.9997987
# 265 3     149039    0.9998189
# 266 3     149042    0.9998390
# 267 3     149045    0.9998591
# 268 3     149048    0.9998792
# 269 2     149050    0.9998927
# 270 2     149052    0.9999061
# 271 2     149054    0.9999195
# 272 2     149056    0.9999329
# 273 2     149058    0.9999463
# 274 2     149060    0.9999597
# 275 1     149061    0.9999665
# 276 1     149062    0.9999732
# 277 1     149063    0.9999799
# 278 1     149064    0.9999866
# 279 1     149065    0.9999933
# 280 1     149066    1.0000000

# %%
# Calcular la frecuencia de acciones correctivas
action_freq <- df %>%
  group_by(action_desc) %>%
  summarise(count = n()) %>%
  arrange(desc(count))

# Calcular el porcentaje acumulado
action_freq <- action_freq %>%
  mutate(cum_count = cumsum(count),
         cum_perc = cum_count / sum(count))
action_freq
#Grafica de distribución
# Out:
#     action_desc
# 1   Adjust machine head looper / Ajustar enlazador de cabezal
# 2   Adjust machine head needle guard / Ajustar guarda aguja de cabezal
# 3   Replace machine head ball joint / Reemplazar biela de cabezal
# 4   Adjust machine head teeth / Ajustar dientes de cabezal
# 5   Sharpen knife / Afilar cuchillas
# 6   Replace machine head looper / Reemplazar enlazador de cabezal
# 7   Adjusted machine head presser foot / Ajustar prensatela de cabezal
# 8   Replace trim off knife / Reemplazar cuchilla de corta desperdicio
# 9   Adjust machine head knife / Ajustar cuchilla de cabezal
# 10  Fix machine head oil leak / Corregir fuga de aceite en cabezal
# 11  Adjust hook set / Ajustar conjunto de el garfio
# 12  Replace machine head needle plate / Reemplazar placa de aguja de cabezal
# 13  Adjust thread cutting knife / Ajustar cuchillas corta hilo
# 14  Adjusted machine head needle bar / Ajustar barra de aguja de cabezal
# 15  Adjust folder guide / Ajustar guía de doblillador
# 16  Replace machine head knife / Reemplazar cuchilla de cabezal
# 17  Replace bobbin / Reemplazar bobina
# 18  Replace machine head presser foot / Reemplazar prensatela de cabezal
# 19  Adjust machine head sensor / Ajustar sensor de cabezal
# 20  Replace machine head teeth / Reemplazar dientes de cabezal
# 21  Clean machine head / Limpiar cabezal
# 22  Polish thread take up / Pulir leva
# 23  Fasten machine head pedal brace / Asegurar soporte de pedal de coser de cabezal
# 24  Adjust chain cutter knife / Ajustar cuchilla de corta cadenetas
# 25  Replace thread cutting knife / Reemplazar cuchillas corta hilo
# 26  Replace machine head needle guard / Reemplazar guarda aguja de cabezal
# 27  Replace burner resistance / Reemplazar resistencia de quemador
# 28  Replace thread tension assembly / Reemplazar tensor auxiliar de largo de hebra
# 29  Replace machine head needle / Reemplazar aguja de cabezal
# 30  Replace control box / Reemplazar caja de control
# ⋮   ⋮
# 250 Replace neumatic engine / Reemplazar motor neumático
# 251 Verify ink consistency according to formula/Verificar tinta de acuerdo a fórmula
# 252 Adjust switch S1,S2,S3,S4 reg. speed/Ajustar inter. S1,S2,S3,S4 regular veloc.
# 253 Replace switch contact / Reemplazar contacto de interruptor
# 254 Adjust chain position / Ajustar posición de cadena
# 255 Ajustar válvula de pedal / Adjust pedal valve
# 256 Pulir guia hilo de cabezal/ Polish head thread guide
# 257 Reemplazar brazo de prensatela / Replace presser foot arm
# 258 Reemplazar caja de quemador / Replace burner box
# 259 Ajustar trancador de tapadera / Adjust cover locker
# 260 Inspect transf. isn't in short circuit/Verif. transf. no esté en corto circuito
# 261 Reemplazar Termo-Cupla de maquina Transfer / Replace transfer machine thermo-cup
# 262 Reemplazar motor del dispensador de etiquetas / Replace labels dispenser motor
# 263 Replace timer / Reemplazar temporizador
# 264 Close machine's side covers correctly/Cerrar cobertores lat. de manera correcta
# 265 Prepare ink according to standard formula /Preparar tinta segun fórmula estándar
# 266 Replace S2 and S3 switches / Reemplazar interruptores S2 y S3
# 267 Replace brush / Reemplazar carbones
# 268 Ajustar cilindro de maquina Grommet / Adjust grommet machine cylinder
# 269 Readjust distance spindle die&cap/Regular distancia entre tapa sujeción y dado
# 270 Reemplazar riel de maquina Grommet / Replace grommet machine Rail
# 271 Sharpen spindle die /Afilar dado de corte
# 272 Adjust temp. according to spec./Ajustar temp. segun especificación
# 273 Clean printing plate / Limpiar placa de impresión
# 274 Lubricar Pedal / Lubricate Pedal
# 275 Reemplazar Grommet / Replace Grommet
# 276 Reemplazar cilindro de maquina Grommet / Replace grommet machine cylinder
# 277 Reemplazar resistencia de maquina Transfer / Replace transfer machine resistance
# 278 Replace printing plate / Reemplazar placa de impresión
# 279 Replace vacuum arm / Reemplazar bracito succionador
#     count cum_count cum_perc
# 1   19202  19202    0.1288154
# 2   12738  31940    0.2142675
# 3   10595  42535    0.2853434
# 4   10218  52753    0.3538902
# 5    9449  62202    0.4172783
# 6    8360  70562    0.4733608
# 7    7286  77848    0.5222385
# 8    6334  84182    0.5647297
# 9    4311  88493    0.5936498
# 10   3627  92120    0.6179813
# 11   2586  94706    0.6353293
# 12   2038  96744    0.6490011
# 13   1910  98654    0.6618142
# 14   1831 100485    0.6740974
# 15   1494 101979    0.6841198
# 16   1494 103473    0.6941422
# 17   1430 104903    0.7037353
# 18   1413 106316    0.7132143
# 19   1329 107645    0.7221298
# 20   1230 108875    0.7303812
# 21   1192 110067    0.7383776
# 22   1183 111250    0.7463137
# 23   1146 112396    0.7540016
# 24   1078 113474    0.7612333
# 25   1071 114545    0.7684180
# 26   1004 115549    0.7751533
# 27    990 116539    0.7817946
# 28    957 117496    0.7882146
# 29    954 118450    0.7946145
# 30    928 119378    0.8008399
# ⋮   ⋮     ⋮         ⋮
# 250 7     148974    0.9993828
# 251 7     148981    0.9994298
# 252 6     148987    0.9994700
# 253 6     148993    0.9995103
# 254 5     148998    0.9995438
# 255 5     149003    0.9995774
# 256 5     149008    0.9996109
# 257 5     149013    0.9996445
# 258 5     149018    0.9996780
# 259 4     149022    0.9997048
# 260 4     149026    0.9997317
# 261 4     149030    0.9997585
# 262 4     149034    0.9997853
# 263 4     149038    0.9998122
# 264 3     149041    0.9998323
# 265 3     149044    0.9998524
# 266 3     149047    0.9998725
# 267 3     149050    0.9998927
# 268 2     149052    0.9999061
# 269 2     149054    0.9999195
# 270 2     149056    0.9999329
# 271 2     149058    0.9999463
# 272 1     149059    0.9999530
# 273 1     149060    0.9999597
# 274 1     149061    0.9999665
# 275 1     149062    0.9999732
# 276 1     149063    0.9999799
# 277 1     149064    0.9999866
# 278 1     149065    0.9999933
# 279 1     149066    1.0000000

# %%
# Calcular la frecuencia de acciones correctivas
mechanic_freq <- df %>%
  group_by(mechanic) %>%
  summarise(count = n()) %>%
  arrange(desc(count))

# Calcular el porcentaje acumulado
mechanic_freq <- mechanic_freq %>%
  mutate(cum_count = cumsum(count),
         cum_perc = cum_count / sum(count))
mechanic_freq
# Out:
#     mechanic                            count cum_count cum_perc
# 1   Antony Ulloa                        3301   3301     0.02214455
# 2   Omar Maldonado                      3231   6532     0.04381952
# 3   Jose Manuel Perez Zepeda            3168   9700     0.06507185
# 4   Erick Garcia Lima                   2845  12545     0.08415735
# 5   DIEGO CUELLAR                       2579  15124     0.10145841
# 6   Ronald Antonio Herrera              2566  17690     0.11867227
# 7   Carlos Alberto Alfaro Salamanca     2556  20246     0.13581903
# 8   Edwin Colindres                     2460  22706     0.15232179
# 9   DENY RAYMUNDO PUCH POOL             2171  24877     0.16688581
# 10  Kenneth Emerson Clavel Flores       2162  27039     0.18138945
# 11  Eduardo Antonio Flores Campos       1995  29034     0.19477279
# 12  Carlos De Leon                      1943  30977     0.20780728
# 13  Willian Tejada                      1859  32836     0.22027827
# 14  Cesar Edgardo Ruedas Mendoza        1857  34693     0.23273584
# 15  Immer Sanchez                       1829  36522     0.24500557
# 16  Luis Ernesto de la Rosa Garcia      1800  38322     0.25708076
# 17  Edgar Arevalo                       1795  40117     0.26912240
# 18  Juan Carlos Lemus                   1742  41859     0.28080850
# 19  JOSE PEDRO DZUL PECH                1724  43583     0.29237385
# 20  NOE CONTRERAS                       1722  45305     0.30392578
# 21  ROMAN IGNACIO AYALA PUC             1681  46986     0.31520266
# 22  Melvin Galeano                      1610  48596     0.32600325
# 23  EDWIN ALEXANDER CAMPOS              1568  50164     0.33652208
# 24  Edwin Edgardo Castillo Giron        1540  51704     0.34685307
# 25  Edwin Rogelio Galeas Perez          1508  53212     0.35696940
# 26  Cain Alfredo Ramirez                1458  54670     0.36675030
# 27  SAUL ALFARO                         1423  56093     0.37629641
# 28  Leonardo Cortez                     1389  57482     0.38561443
# 29  NERY MENA RODRIGUEZ                 1379  58861     0.39486536
# 30  Adalberto Jeremias Rodriguez Zometa 1364  60225     0.40401567
# ⋮   ⋮                                   ⋮     ⋮         ⋮
# 157 Xavier Jose Mendoza                 184   145326    0.9749104
# 158 Jorge Ramos                         182   145508    0.9761314
# 159 Juan Huezo                          180   145688    0.9773389
# 160 Solmar Elias Hernandez Mezquita     178   145866    0.9785330
# 161 Ronald Fabricio Hernandez Rivas     176   146042    0.9797137
# 162 Jonathan Ceceres                    170   146212    0.9808541
# 163 Juan Antonio Leiva                  168   146380    0.9819811
# 164 GARCIA GOMEZ FRANQUI ALIRIO         166   146546    0.9830947
# 165 Jony Bladimir Dominguez Alvarado    150   146696    0.9841010
# 166 Erlin Sabillon                      149   146845    0.9851006
# 167 Nelson Delgado                      139   146984    0.9860330
# 168 Jose Luis Rodriguez                 136   147120    0.9869454
# 169 Jaime Armando Campos                131   147251    0.9878242
# 170 Marvin Pineda                       131   147382    0.9887030
# 171 Abidail Alexander Garcia            130   147512    0.9895751
# 172 Richard Steven                      127   147639    0.9904271
# 173 GUILLERMO CASTRO                    120   147759    0.9912321
# 174 Marvin Betancourth                  119   147878    0.9920304
# 175 Fabit Aranda                        109   147987    0.9927616
# 176 Edra Alvarado                       107   148094    0.9934794
# 177 Kevin Gomez                         107   148201    0.9941972
# 178 Solmar Elias Mezquita               107   148308    0.9949150
# 179 Marvin Ernesto Melara Figueroa      106   148414    0.9956261
# 180 Wilmer Zamora                       105   148519    0.9963305
# 181 Carlos Enrique Rodriguez            101   148620    0.9970080
# 182 Jose Luis Hernandez                 100   148720    0.9976789
# 183 Marco Anthonio                       94   148814    0.9983095
# 184 JOSE ALVARENGA                       93   148907    0.9989334
# 185 ALLAN RIVERA                         89   148996    0.9995304
# 186 Julio Oswaldo Rosales                70   149066    1.0000000

# %%
# Crear el boxplot de repair_hours
ggplot(df, aes(y = repair_hours)) +
  geom_boxplot(fill = 'skyblue', color = 'black') +
  labs(title = 'Boxplot de repair hours',
       y = 'Costo de partes') +
  theme_minimal()
#Replicar gráfico con y sin outliers, analizar la frecuencia por rangos, medir con desviación típica, intentar medir cada cuanto ocurre el outlier, recomendación a añadir
# Out:
# plot without title

# %% [markdown]
# **LIMPIEZA DE DATOS**

# %%
sapply(df, function(x) sum(is.na(x)))
#Fiabilidad suficiente para continuar con el trabajo
# Out:
#      equipment      operation        wo_type     base_model   problem_code
#              0              0              0              0              0
#   problem_desc   failure_code   failure_desc     cause_code     cause_desc
#              0              0              0              0              0
#    action_code    action_desc       mechanic           date downtime_gross
#              0              0              0              0              0
#   pit_coverage  real_downtime     parts_cost   repair_hours  waiting_hours
#              0              0              0              0              0
#    changed_pcs
#              0

# %%
# Remover el símbolo de dólar y las comas, y convertir a float
df$parts_cost <- as.numeric(gsub("[\\$,()]", "", df$parts_cost))

# %%
# Crear el boxplot de parts_cost
ggplot(df, aes(y = parts_cost)) +
  geom_boxplot(fill = 'skyblue', color = 'black') +
  labs(title = 'Boxplot de parts cost',
       y = 'Costo de partes') +
  theme_minimal()
#Hacer rangos, 1 desv tip, 2 desp tipica, etc...
# Out:
# plot without title

# %%
# Convertir la columna 'Date' al formato adecuado
df$date <- as.Date(df$date, format="%m/%d/%Y")  # Ajusta el formato según tus datos
# Ordenar el DataFrame por fecha
df <- df %>%
  arrange(date)

# %%
# Histograma de 'downtimeGross'
hist_downtimeGross <- ggplot(df, aes(x = downtime_gross)) +
  geom_histogram(binwidth = 0.1, fill = "green", color = "black", alpha = 0.7) +
  labs(title = "Histograma de Downtime Bruto",
       x = "Downtime Bruto (horas)",
       y = "Frecuencia") +
  theme_minimal()

# Mostrar histogramas
print(hist_downtimeGross)
# Out:
# plot without title

# %%
mean(df$downtime_gross < 0)
# Out:
# [1] 2.683375e-05

# %%
# Filtrar registros donde downtimeGross no sea negativo
df_filtered <- df %>%
  filter(downtime_gross >= 0)

# %%
mean(df$repair_hours < 0)
# Out:
# [1] 1.341688e-05

# %%
# Calcular valor absoluto de repair hours
df$repair_hours <- abs(df$repair_hours)
#Quitarlo poco porcentaje de datos

# %%
#Eliminar columnas que no seran utilizadas
df <- select(df, -problem_code, -failure_code, -cause_code, -action_code, -pit_coverage, -real_downtime, -waiting_hours)
#Se han eliminado codigos y variables calculadas

# %%
# Filtrar el DataFrame por 'WO Type' igual a 'Corrective Maintenance'
df <- df %>%
  filter(`wo_type` == "Corrective Maintenance")
#Colocar comentario de por qué el filtro, colocar que tecnicas pueden aplicarse y cuales no, colocar en apartado diferente

# %%
# Calcular la diferencia en días entre fechas consecutivas
df <- df %>%
  group_by(equipment) %>%
  mutate(Days_Between_Failures = difftime(date, lag(date), units = "days"))

# Reemplazar los valores NA en Days_Between_Failures
df$Days_Between_Failures[is.na(df$Days_Between_Failures)] <- as.numeric(difftime(df$date[is.na(df$Days_Between_Failures)], as.Date("2023-01-01"), units = "days"))

# %%
# Convertir 'Days_Between_Failures' a numeric
df$Days_Between_Failures <- as.numeric(df$Days_Between_Failures, units = "days")

# %%
#Cambio de nombre de mecánico cuyo nombre está escrito de dos formas
df <- df %>%
  mutate(mechanic = ifelse(mechanic == "GALEAS PEREZ EDWIN ROGELIO", "Edwin Rogelio Galeas Perez", mechanic))

# %% [markdown]
# **ANALISIS DE VARIABLE OBJETIVO "DOWNTIME GROSS"**

# %%
# Histograma de 'downtimeGross'
hist_downtimeGross <- ggplot(df, aes(x = downtime_gross)) +
  geom_histogram(binwidth = 0.1, fill = "green", color = "black", alpha = 0.7) +
  labs(title = "Histograma de Downtime Bruto",
       x = "Downtime Bruto (horas)",
       y = "Frecuencia") +
  theme_minimal()

# Mostrar histogramas
print(hist_downtimeGross)
#Hacerlo más grande
# Out:
# plot without title

# %%
# Crear el boxplot de daysbetween_failures
ggplot(df, aes(y = downtime_gross)) +
  geom_boxplot(fill = 'skyblue', color = 'black') +
  labs(title = 'Boxplot de Days Between Failures',
       y = 'Días entre Fallas') +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# **MODELO DE REGRESION LINEAL INICIAL PARA PREDECIR DOWNTIME**

# %%
df <- select(df, -wo_type)
#Comparar con un glm

# %%
head(df,5)
# Out:
#   equipment operation  base_model
# 1 1011144   HEM SLEEVE VC2700
# 2 1013453   TOP STITCH VC2713
# 3 1013453   TOP STITCH VC2713
# 4 1027243   SET SLEEVE VC2700
# 5 1027243   SET SLEEVE VC2700
#   problem_desc
# 1 It does not cut the trim off / No corta el desperdicio
# 2 It sews with defect / Cose con defecto
# 3 It sews with defect / Cose con defecto
# 4 It sews with defect / Cose con defecto
# 5 It sews with defect / Cose con defecto
#   failure_desc
# 1 Trim off device failure / Falla dispositivo corta desperdicio
# 2 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 3 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 4 Machine head failure sewing with defect / Falla cabezal cosiendo con defecto
# 5 Machine head failure sewing with defect / Falla cabezal cosiendo con defecto
#   cause_desc
# 1 Damaged trim off system knife / Cuchilla de corta desperdicio en mal estado
# 2 Misadjusted machine head needle guard / Guarda aguja de cabezal desajustada
# 3 Misadjusted machine head needle guard / Guarda aguja de cabezal desajustada
# 4 Oil leak in machine head / Fuga de aceite lubricante en cabezal
# 5 Oil leak in machine head / Fuga de aceite lubricante en cabezal
#   action_desc
# 1 Sharpen knife / Afilar cuchillas
# 2 Adjust machine head needle guard / Ajustar guarda aguja de cabezal
# 3 Adjust machine head needle guard / Ajustar guarda aguja de cabezal
# 4 Fix machine head oil leak / Corregir fuga de aceite en cabezal
# 5 Fix machine head oil leak / Corregir fuga de aceite en cabezal
#   mechanic                            date       downtime_gross parts_cost
# 1 DIEGO CUELLAR                       2023-01-03 0.1666667      51.00
# 2 Adalberto Jeremias Rodriguez Zometa 2023-01-03 1.0000000      19.20
# 3 Adalberto Jeremias Rodriguez Zometa 2023-01-03 1.0000000      19.20
# 4 RAMON VILLANUEVA                    2023-01-03 0.5000000      60.69
# 5 RAMON VILLANUEVA                    2023-01-03 0.5000000      60.69
#   repair_hours changed_pcs Days_Between_Failures
# 1 0.1666667    0           2
# 2 1.0000000    1           2
# 3 1.0000000    1           0
# 4 0.5000000    1           2
# 5 0.5000000    1           0

# %%
# Inicializar y ajustar el modelo de regresión lineal
#Dividir en entrenamiento, test, validación por ejemplo 70,20,10
model1 <- lm(downtime_gross~. -equipment -downtime_gross -repair_hours -Days_Between_Failures -date -changed_pcs, data = df)
# Resumen del modelo
summary(model1)
# Out:
# Call:
# lm(formula = downtime_gross ~ . - equipment - downtime_gross -
#     repair_hours - Days_Between_Failures - date - changed_pcs,
#     data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.8166 -0.8235 -0.2693  0.2893 13.0468
#
# Coefficients: (9 not defined because of singularities)
#                                                                                                Estimate
# (Intercept)                                                                                  -0.4549411
# operationATTACH ELASTIC                                                                      -0.0100376
# operationBARTACK                                                                              0.1171701
# operationBIND ARM                                                                            -0.4315389
# operationBIND ARMHOLE                                                                        -0.1788684
# operationBIND LEG                                                                            -0.1357542
# operationBIND NECK                                                                           -0.5345471
# operationBUTTON                                                                               0.2751085
# operationBUTTON HOLE                                                                          0.8076390
# operationCLOSE CUFF                                                                          -0.0118010
# operationCLOSE INSEAM                                                                         0.0354678
# operationCLOSE NECK                                                                          -0.0604433
# operationCLOSE POCKET                                                                        -0.1428490
# operationCLOSE SLEEVE                                                                         0.4873940
# operationCOVER STITCH                                                                        -0.1089053
# operationCOVER STITCH WAIST                                                                   0.8152102
# operationCUT AND CLOSE ELASTIC                                                               -0.0095195
# operationFIRST SIDE                                                                           0.2229144
# operationFLAT LOCK                                                                           -0.2330144
# operationFLAT SEAM                                                                           -0.0979272
# operationGROMMET                                                                              0.2088463
# operationHEM AROUND                                                                           0.2308174
# operationHEM BOTTOM                                                                          -0.0625543
# operationHEM HOOD                                                                            -0.2275038
# operationHEM LEG                                                                              0.1132954
# operationHEM POCKET                                                                          -0.1720380
# operationHEM SLEEVE                                                                           0.7425987
# operationHEM SLEEVE AUTO                                                                      0.6512050
# operationHEM SLEEVE MAN                                                                       0.5151284
# operationJOIN LEG                                                                            -0.1622385
# operationJOIN PANEL                                                                          -0.0484089
# operationJOIN SHOULDER                                                                       -0.0093645
# operationLOCK STITCH                                                                          0.0680470
# operationP. LABEL                                                                            -1.5942123
# operationPLACKET TOPSTITCH                                                                    0.0614780
# operationPRECLOSE ELASTIC                                                                     0.0848471
# operationSECOND SIDE                                                                          0.1256555
# operationSERGE ELASTIC                                                                        0.3645667
# operationSET BAND                                                                             0.1715743
# operationSET COLLAR                                                                          -0.0197861
# operationSET CUFF                                                                             0.0691801
# operationSET HOOD                                                                            -0.0207152
# operationSET POCKET                                                                          -0.0106947
# operationSET SLEEVE                                                                          -0.1195851
# operationSEW ELASTIC                                                                         -0.1174806
# operationSEW ELASTIC WAIST                                                                   -0.2114793
# operationSEW PANEL                                                                           -0.0563837
# operationSIDE SEAM                                                                            0.2644686
# operationTAPE SHOULDER                                                                       -0.1071422
# operationTOP STITCH                                                                          -0.0508833
# operationTOP STITCH BAND                                                                     -0.1887154
# operationTOP STITCH COLLAR                                                                   -0.0142786
# operationTOP STITCH HOOD                                                                     -0.2607150
# operationTOP STITCH POCKET                                                                    0.1208038
# operationTOP STITCH SEAM CROTCH                                                              -0.2771876
# operationTOP STITCH SLEEVE                                                                   -0.0863968
# operationTOP STITCH SLEEVE AND BAND                                                          -0.2220068
# operationTOP STITCH WAIST BAND                                                               -0.1127163
# operationTUBE FLY                                                                            -0.3373953
# base_model504-E256                                                                           -0.1567229
# base_model504-E51                                                                             0.0249816
# base_model504-ETS51                                                                          -0.4051453
# base_model83SP                                                                               -0.1072106
# base_modelA4                                                                                 -0.0816677
# base_modelAZ8003                                                                             -0.0391409
# base_modelAZ8203                                                                             -0.0101463
# base_modelAZ8403                                                                             -0.2358483
# base_modelAZ8412                                                                              0.1683616
# base_modelAZ8420                                                                             -0.2003442
# base_modelAZ8451                                                                             -0.7502878
# base_modelAZF8420                                                                            -1.3465834
# base_modelB-100                                                                              -0.2254033
# base_modelBE-438D                                                                             0.3093888
# base_modelBE-438FX                                                                           -0.0870468
# base_modelC5                                                                                 -0.0711525
# base_modelC5-3-02/233                                                                        -0.2713621
# base_modelC5-4-M03                                                                           -0.2031504
# base_modelC5S-4-M03                                                                          -0.2638834
# base_modelCSA-2516D-03                                                                        0.8416661
# base_modelCSA-2604                                                                            0.1073875
# base_modelCSA-2604-02                                                                        -0.0315997
# base_modelCSC-2614                                                                           -0.2169953
# base_modelCSC-2614-M03                                                                       -0.2441445
# base_modelCW522AN                                                                            -1.7327842
# base_modelDB2-B737                                                                            0.6609228
# base_modelDDL-5550                                                                           -0.1197796
# base_modelDDL5550                                                                            -0.0181312
# base_modelDDL8500                                                                             0.1677284
# base_modelDDL8700                                                                            -0.1170374
# base_modelDLN-5410                                                                           -0.1429728
# base_modelDLN5410                                                                             0.2565861
# base_modelDT6L2512                                                                           -0.0239755
# base_modelE256                                                                                0.0900681
# base_modelE51-141                                                                            -0.1341348
# base_modelEX5104                                                                             -0.0640175
# base_modelEX5114                                                                             -0.1985989
# base_modelEX5204                                                                              1.2400734
# base_modelEX5214                                                                             -0.0936907
# base_modelEXT5114                                                                            -0.2375573
# base_modelFD-62                                                                              -0.0338314
# base_modelFD62                                                                                0.1991929
# base_modelICN B-100                                                                           1.2503122
# base_modelICN-2200                                                                            0.7272539
# base_modelJ-261                                                                               0.2718287
# base_modelJK-797DI                                                                           -0.2270001
# base_modelJK-798DI                                                                           -0.1737079
# base_modelJK-798DIII                                                                         -0.2893820
# base_modelJK-8670BDII                                                                        -0.0801121
# base_modelJK-SHIRLEY-IIE                                                                     -0.1366535
# base_modelJK-T1790BK                                                                         -0.0649513
# base_modelJK-T1790BS                                                                         -1.9667341
# base_modelJK-T1903BR                                                                          0.0568361
# base_modelJK-T1903GR                                                                                 NA
# base_modelJK-T1904                                                                           -0.1837063
# base_modelJK-T1904A                                                                           0.4687752
# base_modelJK-T1904BS                                                                          0.0103209
# base_modelJKT1904A                                                                            0.3368635
# base_modelJS-2261                                                                             0.1434377
# base_modelKE-430D                                                                            -0.1657858
# base_modelKE430F                                                                              0.4450613
# base_modelLBH1790                                                                             0.1302228
# base_modelLC62D                                                                               0.0728525
# base_modelLC62D-12                                                                           -0.1221914
# base_modelLDA-L26                                                                             0.0228252
# base_modelLK1900                                                                              0.0801780
# base_modelLK1910                                                                             -0.6833990
# base_modelLK1920                                                                             -0.0428241
# base_modelLT2-B842                                                                           -0.0986668
# base_modelLT2-B872                                                                           -0.0340129
# base_modelMH380                                                                              -0.2631027
# base_modelMJ2600                                                                              0.0064309
# base_modelMJ2600SD                                                                            0.8742190
# base_modelS7200                                                                               0.2829910
# base_modelSP161                                                                               0.1916118
# base_modelSP172                                                                               0.1849014
# base_modelT-8422A                                                                             0.1002154
# base_modelT-8722B                                                                            -0.0905115
# base_modelUS39500                                                                            -0.1049486
# base_modelVC1700                                                                             -0.0413283
# base_modelVC2700                                                                             -0.0656042
# base_modelVC2711                                                                             -0.0524528
# base_modelVC2713                                                                             -0.0471089
# base_modelVC2735                                                                              0.1472058
# base_modelVC2785                                                                             -0.3655286
# base_modelVC3845                                                                              0.1843665
# base_modelVC3845P                                                                             0.0942150
# base_modelVE2700                                                                             -0.0070975
# base_modelVE2711                                                                              0.0976722
# base_modelVE2713                                                                             -0.0337050
# base_modelVEU2703                                                                             0.4410857
# base_modelVF2400                                                                             -0.0447118
# base_modelVF2403                                                                              0.2364268
# base_modelVF2439                                                                              0.3588511
# base_modelVF2500                                                                             -0.0310532
# base_modelVF2503                                                                              0.4222203
# base_modelVF2529                                                                              0.9813433
# base_modelVF2529G                                                                             0.4452006
# base_modelVF2539                                                                              0.5242245
# base_modelVF2560                                                                              0.2563227
# base_modelVF64228                                                                             0.2688146
# base_modelVFF2503                                                                             0.2010578
# base_modelVG2700                                                                              0.0085346
# base_modelVG2711                                                                              0.2057018
# base_modelVG2713                                                                              0.0380168
# base_modelVG2735                                                                              0.1033310
# base_modelVM1804                                                                              0.3998630
# base_modelW1500                                                                               0.5013022
# base_modelW1562                                                                               0.1303756
# base_modelW264                                                                                0.2668947
# base_modelW3522P                                                                              0.7835895
# base_modelW4-D                                                                                0.6533928
# base_modelW500                                                                                0.1127870
# base_modelW542                                                                                2.5039585
# base_modelW562                                                                                0.1946919
# base_modelW600                                                                                0.1082867
# base_modelW664                                                                                0.1344406
# base_modelWT500                                                                              -0.4520492
# base_modelWT542                                                                               0.1798980
# base_modelWT562                                                                               0.2087136
# problem_descFruncido/ Pucker                                                                  1.8921816
# problem_descFuga de aire comprimido detectada/Compressed air leak detected                   -0.8299697
# problem_descIt cuts the cloth with defect / Corta tela con defecto                            0.8567026
# problem_descIt does not coil / No enrolla                                                     0.6305937
# problem_descIt does not cut the cloth / No corta la tela                                      0.6749495
# problem_descIt does not cut the thread / No corta el hilo                                     0.8410343
# problem_descIt does not cut the trim off / No corta el desperdicio                            0.7878491
# problem_descIt does not feed cloth / No alimenta tela                                         0.9098647
# problem_descIt does not guarantee safety / No garantiza la seguridad                          0.8077983
# problem_descIt does not label / No etiqueta                                                   0.6730338
# problem_descIt does not light / No alumbra                                                    2.8171768
# problem_descIt does not look properly / No luce adecuadamente                                 1.0070455
# problem_descIt does not lubricate / No lubrica                                                0.7124756
# problem_descIt does not pile up / No apila                                                    1.0910312
# problem_descIt does not sew / No cose                                                         0.7370064
# problem_descIt labels with defect / Etiqueta con defecto                                      1.1243206
# problem_descIt piles up with defect / Apila con defecto                                       0.8049109
# problem_descIt sews with defect / Cose con defecto                                            0.8554766
# problem_descNo acciona el Rodo / Dont activate Roll                                           0.7431167
# problem_descNo pega Grommet/Not set grommet                                                   0.8878801
# problem_descPedal no Acciona Motor / Pedal not activates motor                                1.0610629
# problem_descRemacha Grommet con defecto/ Rivet Grommet with defect                            1.3415254
# problem_descSellado Debil/ Weak Sealed                                                        1.7828736
# failure_descBurner failure / Falla quemador                                                   1.5909078
# failure_descButton spiral failure/Falla de espiral de botón                                   1.5528946
# failure_descChain cutter failure / Falla corta cadenetas                                      1.5432546
# failure_descDesajuste Pattern Wheel y Circular plate / Patter Wheel misadjustment             3.5560229
# failure_descDesgaste de Pattern Wheel / Pattern Wheel worn                                    0.3625254
# failure_descElectric panel failure / Falla pánel eléctrico                                    1.5949182
# failure_descEngine failure / Falla motor                                                      1.6982121
# failure_descFalla cabezal remachando Grommet con defecto / Head failure riveting grommet wit -0.0254254
# failure_descFalla sistema de aire comprimido / Compressed air supply system failure           1.4673444
# failure_descFeeding device failure / Falla dispositivo de alimentación                        1.4701479
# failure_descFolder failure / Falla doblillador                                                1.8035778
# failure_descLighting lamp failure / Falla lámpara de iluminación                              1.6240966
# failure_descLubrication system failure / Falla sistema de lubricación                         1.7873438
# failure_descMachine head failure it does not look properly / Falla cabezal en su apariencia   2.0430826
# failure_descMachine head failure it stops labeling / Falla cabezal dejando de etiquetar       1.5492886
# failure_descMachine head failure not riveting/Falla cabezal no remachando                    -5.1845129
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defecto      1.4558093
# failure_descMachine head failure stopping sewing  / Falla cabezal dejando de coser            1.5386841
# failure_descMachine head labeling with defect / Falla cabezal etiquetando con defecto         1.7525857
# failure_descMonitoring and control failure / Falla monitoreo y control                        1.7183480
# failure_descPneumatic engine failure / Falla motor neumático                                  1.7923500
# failure_descRoll holder failure / Falla porta rollo                                           1.5325390
# failure_descSafety guard failure / Falla protectores                                          1.4413689
# failure_descServomotor failure / Falla servomotor                                             1.4601177
# failure_descSpindle cap failure /Falla tapa de sujeción del pin                               3.3791827
# failure_descSpindle die failure not punching out/Falla dado de corte no perforando            0.9012479
# failure_descStacker  piling up with defect / Falla apilador dejando de apilar con defecto     1.8975090
# failure_descStacker failure it stops piling up / Falla apilador dejando de apilar             1.3654046
# failure_descSwitch failure / Falla interruptor                                                1.0821054
# failure_descTable failure generating defect / Falla mesa generando defecto                    1.5824504
# failure_descTable failure in its safety / Falla mesa en su seguridad                          1.4032157
# failure_descTable failure it does not look properly / Falla mesa en su apariencia             0.8813425
# failure_descThread holder failure / Falla torre de hilo                                       1.8329906
# failure_descThread winder failure / Falla devanador de hilo                                   2.2323314
# failure_descTrim off device cutting with defect /Dispositivo corta tela cortando con defecto  2.4438789
# failure_descTrim off device failure / Falla dispositivo corta desperdicio                     1.3268964
# failure_descTrim off device stops cutting/Falla dispositivo corta tela deja de cortar         1.4657135
# cause_descBanda motor-volante de maquina Grommet dañada / Damaged Grommet machine steering    7.0641872
# cause_descBase de quemador desajustada / Burner base out of adjustment                        0.1337472
# cause_descBlocked button spiral /Espiral de botón obstruida                                   2.2678505
# cause_descBlunt spindle die / Dado de corte sin filo                                         -1.2531996
# cause_descBlunt trim off knife / Cuchilla de corta tela desafilada                           -0.0281234
# cause_descBobbin case placed incorrectly / Caja de bobina mal colocada                       -0.6150618
# cause_descBrazo de prensatela dañado / Damaged presser foot arm                               0.0080431
# cause_descBroken feeding belt / Rotura de banda de alimentación                               0.3387201
# cause_descBroken fuse / Rotura de fusible                                                     1.1469751
# cause_descBroken knife of machine head / Rotura de cuchilla de cabezal                        0.3507275
# cause_descBroken lubr. system spatter  / Rotura de salpicadores en sistema de lubricación    -1.1281027
# cause_descBroken machine head ball joint / Rotura de biela de cabezal                         0.7478937
# cause_descBroken machine head feeding bar / Rotura de barra de alimentación de cabezal        1.3123369
# cause_descBroken machine head looper / Rotura de enlazador de cabezal                         0.2450759
# cause_descBroken machine head needle / Rotura de aguja de cabezal                             0.2223077
# cause_descBroken machine head needle guard / Rotura de guarda aguja de cabezal                0.2536361
# cause_descBroken machine head needle plate / Rotura de placa de aguja de cabezal              0.0136110
# cause_descBroken machine head presser foot  / Rotura de prensatela de cabezal                 0.0008472
# cause_descBroken machine head timing belt / Rotura de banda de tiempo de cabezal              0.0100300
# cause_descBroken motor v-belt/Banda de motor en mal estado o rota                             0.3025376
# cause_descBroken needle plate finger / Rotura de lengueta placa de aguja de cabezal           0.4491124
# cause_descBroken or splintered table edges / Bordes de mesa quebrados o astillados           -0.1210940
# cause_descBroken solenoid valve / Rotura de válvula del solenoide                             0.8416399
# cause_descBroken teeth of machine head / Rotura de dientes de cabezal                         0.5468530
# cause_descBurner transformer in poor condition / Transformador de quemador en mal estado      0.4368819
# cause_descCaja de quemador dañada / Damaged burner box                                       -2.5185730
# cause_descClogged lubrication system hose / Manguera de sistema de lubricación atascada       0.6260236
# cause_descComponente del sistema de aire comprimido dañado / Compressed air system compone   -0.7175261
# cause_descContamination water in pneumatic engine / Contaminación agua en motor neumático     0.9651186
# cause_descCtrol table param out of specs/Parámetros de ctrol de mesa fuera de especif.       -0.2036774
# cause_descCup hook in poor condition / Canastilla en mal estado                               0.0843103
# cause_descDamaged  chain cutter fixed knife / Cuchilla fija corta cadenetas en mal estado     0.7957183
# cause_descDamaged  moving knife shaft /Eje cuchilla móvil corta desperdicio en mal estado     0.3304883
# cause_descDamaged bobbin / Bobina en mal estado                                               0.4902951
# cause_descDamaged bobbin case brake / Freno de caja de bobina en mal estado                   0.4511375
# cause_descDamaged bobbin case thd tensor / Tensor de hilo de caja de bobina en mal estado     0.1253806
# cause_descDamaged burner resistance / Resistencia de quemador en mal estado                   0.3197896
# cause_descDamaged burner thermostat / Termostato de quemador en mal estado                    0.8705428
# cause_descDamaged chain cutter collar / Collarin de corta cadenetas en mal estado            -1.7674764
# cause_descDamaged chain cutter cylinder  / Cilindro de corta cadenetas en mal estado          0.6366671
# cause_descDamaged chain cutter humphrey clevis /Horquilla de corta cadenetas en mal estado    0.3810893
# cause_descDamaged chain cutter knife / Cuchilla de corta cadeneta en mal estado               0.8252065
# cause_descDamaged chain cutter mov knife axle/Eje cuchilla móv corta cadenetas mal estado    -0.6900815
# cause_descDamaged chain cutter screw / Tornillo de corta cadenetas en mal estado             -0.2276923
# cause_descDamaged circuit card / Tarjeta de circuito en mal estado                            0.8044201
# cause_descDamaged control box / Caja de control en mal estado                                 0.4087287
# cause_descDamaged conveyor belt / Banda transportadora de mesa en mal estado                  0.4461324
# cause_descDamaged detachment plate / Placa de desprendimeinto de cabezal en mal estado       -0.1875926
# cause_descDamaged differential feeding box / Caja reductora de alimentación en mal estado     0.1720757
# cause_descDamaged electrical panel cable / Cable de panel eléctrico en mal estado             0.8975600
# cause_descDamaged electrical panel contactor / Contactor de panel eléctrico en mal estado     0.8580180
# cause_descDamaged electrical panel drive / Variador de panel eléctrico en mal estado          1.4040476
# cause_descDamaged electrical panel fuse / Fusible de panel eléctrico en mal estado            0.4821555
# cause_descDamaged electrical panel terminal / Terminal de panel eléctrico en mal estado       0.8683218
# cause_descDamaged engine bearing / Rodamiento de motor en mal estado                          0.1350543
# cause_descDamaged engine belt guard / Protector de banda de motor en mal estado               0.1312169
# cause_descDamaged engine bobbin / Bobina de motor en mal estado                               0.2039575
# cause_descDamaged engine clutch / Embrague de motor en mal estado                             1.3071895
# cause_descDamaged Engine for trim off system / Motor corta desperdicio en mal estado          0.2156215
# cause_descDamaged engine rotor / Rotor de motor en mal estado                                -0.1794102
# cause_descDamaged eye guard / Protector de ojo en mal estado                                 -0.7942019
# cause_descDamaged feeding axis / Eje de alimentación en mal estado                            0.2588100
# cause_descDamaged feeding roll / Rodo de alimentación en mal estado                           0.6760110
# cause_descDamaged feeding transmis. cable/Cable transmisión de alimentación en mal estado     1.8982132
# cause_descDamaged finger guard / Protector de dedo en mal estado                             -0.1674861
# cause_descDamaged folder guide / Guía de doblillador en mal estado                           -0.2009009
# cause_descDamaged folder guide base / Base de doblillador en mal estado                      -0.1068624
# cause_descDamaged lubr syst hose connector/Conector manguera de sist. lubr. en mal estado     0.8093168
# cause_descDamaged lubr syst worm wheel/Engranaje acople de sistema de lubr en mal estado      1.4691165
# cause_descDamaged lubr Syst. oil filter screen/Filtro retorno de sist de lubr. mal estado    -0.0362531
# cause_descDamaged lubric. syst. main filter / Filtro princ. de sist. lubr. en mal estado     -1.0150170
# cause_descDamaged lubricant / Lubricante en mal estado                                       -0.4047328
# cause_descDamaged lubrication system hose/Manguera sistema de lubricación en mal estado       0.7359479
# cause_descDamaged lubrication system pump / Bomba de sistema de lubricación en mal estado     0.9520868
# cause_descDamaged machine head axle casings / Buje de cabezal en mal estado                   0.9404246
# cause_descDamaged machine head bearings / Rodamiento de cabezal en mal estado                 0.6161056
# cause_descDamaged machine head cup hook / Canastilla de cabezal en mal estado                 0.4745667
# cause_descDamaged machine head looper / Enlazador de cabezal en mal estado                    0.0448128
# cause_descDamaged machine head needle / Aguja de cabezal en mal estado                       -0.2859932
# cause_descDamaged machine head painting / Pintura de cabezal en mal estado                    3.2708352
# cause_descDamaged machine head teeth / Dientes de cabezal en mal estado                       0.5010508
# cause_descDamaged machine head tension disc / Disco de tensión de cabezal en mal estado       0.4816510
# cause_descDamaged machine head thread guide / Guía hilo de cabezal en mal estado              0.0106834
# cause_descDamaged machine head thread take up / Leva de cabezal en mal estado                -0.0314318
# cause_descDamaged maintenance unit / Unidad de mantenimiento en mal estado                    0.1726511
# cause_descDamaged monitor and control screen /Pantalla de monitoreo y ctrol en mal estado    -0.0156636
# cause_descDamaged movement changer main tooth/Cambiador movimto diente princ en mal estado    0.5102516
# cause_descDamaged movmt changer differ tooth /Cambiador de movmto diente difer. mal estado   -0.2211154
# cause_descDamaged needle thread guide / Deflector de hilo de cabezal en mal estado            0.4138719
# cause_descDamaged needle thread guide / Deflector de hilo en mal estado                       0.9278381
# cause_descDamaged PLC of electrical panel / PLC de panel eléctrico en mal estado              1.1019098
# cause_descDamaged presser foot's tin filling  /Relleno de prensatela en mal estado            1.0234689
# cause_descDamaged proximity switch / Interruptor de proximidad en mal estado                  0.5812581
# cause_descDamaged pulley / Polea en mal estado                                                0.9221259
# cause_descDamaged roll holder base / Base de porta rollos en mal estado                       0.4480471
# cause_descDamaged roll tensor / Tensor de rollos en mal estado                               -0.2878172
# cause_descDamaged rotation detector unit /Posicionador en mal estado                          0.2395137
# cause_descDamaged sensor  / Sensor en mal estado                                              0.0755291
# cause_descDamaged Sensor for cloth detection / Sensor detector de tela en mal estado          0.2633106
# cause_descDamaged servomotor bearing / Rodamiento de servomotor en mal estado                 0.5245345
# cause_descDamaged servomotor control card / Tarjeta de control de servomotor en mal estado    0.5263690
# cause_descDamaged servomotor rotor / Rotor de servomotor en mal estado                       -0.8768349
# cause_descDamaged servomotor sensor / Sensor de servomotor en mal estado                     -0.2825396
# cause_descDamaged servomotor sensor cable / Cable de sensor de servomotor en mal estado       0.6121283
# cause_descDamaged servomotor terminal / Terminal de servomotor en mal estado                  0.9441312
# cause_descDamaged solenoid / Solenoide en mal estado                                         -0.4621305
# cause_descDamaged stacker cylinder / Cilindro de apilador en mal estado                      -0.1676766
# cause_descDamaged stacker hose / Manguera de apilador en mal estado                          -0.6974698
# cause_descDamaged stacker humphrey clevis / Horquilla de apilador en mal estado               0.5496326
# cause_descDamaged stacker regulating valve / Válvula reguladora de apilador en mal estado     0.9822061
# cause_descDamaged stacker solenoid valve / Electroválvula de apilador en mal estado           0.4701478
# cause_descDamaged stitch regulator / Regulador de puntada de cabezal en mal estado            0.0889692
# cause_descDamaged surface of printing plate / Placa impresión con superficie en mal estado    0.0587995
# cause_descDamaged switch box / Caja de interruptor en mal estado                              0.4771996
# cause_descDamaged switch button / Botón de interruptor en mal estado                          0.2888342
# cause_descDamaged switch cable / Cable de interruptor en mal estado                          -1.2189423
# cause_descDamaged switch contact / Contacto de interruptor en mal estado                      1.3252636
# cause_descDamaged switch terminal / Terminal de interruptor en mal estado                     1.4799472
# cause_descDamaged table painting / coating / Pintura/revestimiento de mesa en mal estado      0.3269957
# cause_descDamaged thread cone holder / Porta conos en mal estado                             -1.2667843
# cause_descDamaged thread cutting knife / Cuchillas corta hilo en mal estado                   0.5052527
# cause_descDamaged thread guide / Guía hilo en mal estado                                      0.8306493
# cause_descDamaged thread guide base / Base de guía hilo en mal estado                        -0.3968024
# cause_descDamaged thread length tensor / Tensor auxiliar de largo de hebra en mal estado     -0.7757254
# cause_descDamaged thread winder tensor / Tensor del devanador en mal estado                  -0.7258371
# cause_descDamaged thread wiper / Saca hebra en mal estado                                     0.0945225
# cause_descDamaged timer / Temporizador en mal estado                                         -0.4769400
# cause_descDamaged trim off engine / Motor de corta desperdicio en mal estado                 -0.5077864
# cause_descDamaged trim off knife / Cuchilla de corta tela en mal estado                      -0.6034531
# cause_descDamaged trim off knife ball joint / Biela de corta desperdicio en mal estado        0.6443197
# cause_descDamaged trim off knife base /Base de cuchilla de corta desperdicio en mal estado    0.9398744
# cause_descDamaged trim off knife cylinder / Cilindro de corta tela en mal estado             -0.2922286
# cause_descDamaged trim off knife hose / Manguera de corta tela en mal estado                  0.7310647
# cause_descDamaged trim off knife position sensor/Sensor posic de corta tela en mal estado     0.6427877
# cause_descDamaged trim off knife regulat. valve/Válv. reguladora corta tela en mal estado    -0.0637482
# cause_descDamaged trim off knife solenoid valve/Electroválvula de corta tela en mal estado   -0.3356077
# cause_descDamaged trim off system bearing / Rodamiento de corta desperdicio en mal estado     0.5854401
# cause_descDamaged trim off system knife / Cuchilla de corta desperdicio en mal estado         0.2534003
# cause_descDamaged U-joint with shaft / Cardan de alimentación en mal estado                   0.0461756
# cause_descDeprogrammed electrical panel drive / Variador de panel eléctrico desprogramado    -0.1450384
# cause_descDirty machine head / Cabezal sucio                                                  0.3684321
# cause_descDirty table / Mesa sucia                                                            2.0563145
# cause_descDoblillador desajustado / Folder out of adjustment                                 -0.5687532
# cause_descExcess dirt in servomotor casting/ Suciedad excesiva en la carcasa de servomotor    0.7553800
# cause_descExcessive dirt in chain cutter / Suciedad excesiva en corta cadenetas              -0.9115335
# cause_descExcessive dirt in electrical panel / Suciedad excesiva en panel eléctrico           0.8184920
# cause_descExcessive dirt in machine head / Suciedad excesiva en cabezal                       0.4624581
# cause_descExcessive dirt in switch contact / Contacto de interruptor sucio                    0.9449121
# cause_descFaulty connection in burner / Falso contacto en quemador                            0.4743976
# cause_descFaulty connection in electrical panel / Falso contacto en panel eléctrico           0.1570955
# cause_descFaulty connection in main switch / Falso contacto en interruptor principal         -0.3907057
# cause_descFaulty connection in switch / Falso contacto en interruptor                         0.2997438
# cause_descHigh air pressure in pneumatic engine / Alta presión de aire en motor neumático    -0.0921699
# cause_descHigh air pressure in stacker / Alta presión de aire en apilador                    -0.0832716
# cause_descHigh air pressure in trim off guide / Alta presión de aire en corta tela            0.7847514
# cause_descIncorrdistance spindle die and cap/Dado corte&tapa sujeción a distincorrecta       -1.8254593
# cause_descIncorrect bobbin / Bobina incorrecta                                               -1.1323317
# cause_descIncorrect bobbin case / Caja de bobina incorrecta                                  -0.4063755
# cause_descIncorrect ink formula / Fórmula de tinta incorrecta                                -0.6514181
# cause_descIncorrect machine head  tension spring /Resorte de tensión de cabezal incorrecto    0.3248163
# cause_descIncorrect machine head needle / Aguja de cabezal incorrecta                         0.3831465
# cause_descIncorrect machine head threading / Enhebrado incorrecto en cabezal                  0.1832113
# cause_descIncorrect size button spiral /Tamaño de espiral de botón  incorrecto                0.4834039
# cause_descIncorrect threading / Enhebrado incorrecto                                         -0.1737553
# cause_descIncorrectly installed guard / Protector mal instalado                              -0.9504091
# cause_descKnife does not cut needle&looper thread/Cuchillla no corta hilo aguja/enlazador     0.2736871
# cause_descLack of bobbin case brake / Freno de caja de bobina faltante                        0.7700607
# cause_descLack of ventilation in Engine / Falta de ventilación en motor                       0.9520708
# cause_descLooper with rough edges / Superficie de enlazador de cabezal con asperezas          0.0176978
# cause_descLoose chain cutter collar / Collarin de corta cadenetas flojo                      -3.6311959
# cause_descLoose condense cylinder base screw/Tornillos base cilindro condensado flojos        1.0169100
# cause_descLoose condensed plug wires /Conector de condensado suelto                           0.1011431
# cause_descLoose electr. devices in electr. panel / Disp. Eléctr. sueltos en panel eléctr.     0.2758516
# cause_descLoose engine belt guard / Protector de banda de motor flojo                         0.2366723
# cause_descLoose eye guard / Protector de ojo flojo                                            0.6144865
# cause_descLoose finger guard / Protector de dedo flojo                                        0.6365628
# cause_descLoose folder subjection screw  / Tornillo de sujeción de doblillador flojo          0.6639462
# cause_descLoose lubrication system hose / Manguera de sistema de lubricación suelta          -0.1531052
# cause_descLoose machine head Support for pedal  / Soporte de pedal de cabezal suelto          0.4331115
# cause_descLoose machine head teeth / Soltura de dientes de cabezal                            0.2108831
# cause_descLoose roll holder guide / Guía de porta rollos floja                               -0.9334540
# cause_descLoose table / Mesa floja                                                            0.1838946
# cause_descLoose thread cone holder / Porta conos flojo                                        0.6579596
# cause_descLow air pressure in burner / Baja presión de aire en quemador                       0.1758658
# cause_descLow air pressure in chain cutter / Baja presión de aire en corta cadenetas         -0.6246423
# cause_descLow air pressure in pneumatic engine / Baja presión de aire en motor neumático      0.0495305
# cause_descLow air pressure in stacker / Baja presión de aire en apilador                      0.2153792
# cause_descLow air pressure in trim off knife / Baja presión de aire en corta tela             1.4939179
# cause_descLow oil level in lubr. system / Nivel de aceite bajo en sistema de lubricación      0.1839974
# cause_descMisadjusted bobbin case thd tensor/ Tensor de hilo de caja de bobina desajustado   -0.1409720
# cause_descMisadjusted chain cutter knife / Cuchilla de corta cadeneta desajustada             0.3046478
# cause_descMisadjusted chain cutter moving knife/Cuchilla móvil corta cadeneta mal estado      0.4517366
# cause_descMisadjusted compressed air pressure / Presión de aire comprimido desajustado        1.3063468
# cause_descMisadjusted control box / Caja de control desajustada                               0.1301215
# cause_descMisadjusted feeding and ndl movement/Movmto de alimentación y aguja desajustado    -0.0504531
# cause_descMisadjusted feeding roll / Rodo de alimentación desajustado                         0.1569451
# cause_descMisadjusted finger guard / Dedo posicionador de cabezal en mal ajustado            -0.0324286
# cause_descMisadjusted finger guard / Dedo posicionador mal ajustado                          -0.1482465
# cause_descMisadjusted folder guide / Guía de doblillador desajustadas                        -0.0791726
# cause_descMisadjusted guide / Guía desajustada                                                3.0650856
# cause_descMisadjusted hook set / Conjunto de el garfio mal ajustados                          0.3114979
# cause_descMisadjusted hook set / Conjunto de garfios mal ajustados                            0.4047518
# cause_descMisadjusted machine head chopper / Cuchilla de cabezal desajustada                  0.1933225
# cause_descMisadjusted machine head looper / Enlazador de cabezal desajustado                  0.2990853
# cause_descMisadjusted machine head needle bar / Barra de aguja de cabezal desajustada         0.3488776
# cause_descMisadjusted machine head needle guard / Guarda aguja de cabezal desajustada         0.3916062
# cause_descMisadjusted machine head presser foot / Prensatela de cabezal desajustado           0.3084466
# cause_descMisadjusted machine head teeth / Dientes de cabezal desajustados                    0.2398354
# cause_descMisadjusted machine head thd frame guide/ Marco guía hilo de cabezal desajustado    0.2019089
# cause_descMisadjusted presser foot bar /Barra de prensatela desajustada                       0.9493482
# cause_descMisadjusted printing head (switch S2-S3) / Cabezal desajustado (inter. S2-S3)       0.0245438
# cause_descMisadjusted roll tensor / Tensor de rollos desajustado                             -0.1013559
# cause_descMisadjusted rotation detector unit /Posicionador desajustado                       -0.2681782
# cause_descMisadjusted sensor / Sensor desajustado                                            -0.4062288
# cause_descMisadjusted Sensor for cloth detection / Sensor detector de tela mal calibrado     -0.2071810
# cause_descMisadjusted servomotor magnet brake / Imán de freno de servomotor desajustado       0.6937380
# cause_descMisadjusted servomotor sensor / Sensor de servomotor en mal calibrado               0.1101535
# cause_descMisadjusted servomotor thermal relay  / Relé térmico de servomotor mal calibrado    0.1266070
# ...
# mechanicCesar Edgardo Ruedas Mendoza                                                         **
# mechanicCesar Edwin Maradiaga                                                                ***
# mechanicCristian Vladimir Cartagena Ortiz                                                    ***
# mechanicDaniel Arevalo                                                                       .
# mechanicDaniel Edgardo Sandoval
# mechanicDENY RAYMUNDO PUCH POOL                                                              ***
# mechanicDIEGO CUELLAR                                                                        .
# mechanicDouglas Alonso Bonilla Soriano                                                       ***
# mechanicDouglas del Cid                                                                      ***
# mechanicDOUGLAS LEONEL CHAVEZ                                                                ***
# mechanicDouglas Leonel Chavez Bonilla                                                        .
# mechanicEdgar Arevalo                                                                        ***
# mechanicEDIL BERRIOS                                                                         ***
# mechanicEDIS MAREL RODRIGUEZ                                                                 ***
# mechanicEdra Alvarado                                                                        ***
# mechanicEduardo Antonio Flores Campos                                                        ***
# mechanicEDWIN ALEXANDER CAMPOS                                                               ***
# mechanicEdwin Colindres                                                                      ***
# mechanicEdwin Edgardo Castillo Giron                                                         **
# mechanicEdwin Froylan Turcios                                                                ***
# mechanicEdwin Rogelio Galeas Perez                                                           ***
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                          ***
# mechanicEmilio Zeledon Lopez                                                                 ***
# mechanicEnrique Pech Canul                                                                   ***
# mechanicErick Garcia Lima                                                                    ***
# mechanicErick Salazar                                                                        ***
# mechanicErlin Sabillon                                                                       ***
# mechanicEver Alfredo Flores Molina                                                           ***
# mechanicFABIAN POSADAS                                                                       ***
# mechanicFabit Aranda                                                                         ***
# mechanicFAULO VICENTE TEC TORRES                                                             ***
# mechanicFernando Alexander Pubill Quintanilla                                                *
# mechanicFLORES CAMPOS EDUARDO ANTONIO
# mechanicFrancisco Antonio Hernandez                                                          ***
# mechanicFranqui Garcia                                                                       ***
# mechanicFUENTES LIMA NESTOR MAURICIO                                                         ***
# mechanicGabriel Sanchez                                                                      ***
# mechanicGARCIA GOMEZ FRANQUI ALIRIO                                                          ***
# mechanicGeovanny  Felipe Rivera                                                              ***
# mechanicGerardo Arturo de la Cruz Lemus                                                      ***
# mechanicGilberto Antonio Flores                                                              ***
# mechanicGiovanny Alexander Rivas                                                             ***
# mechanicGuillermo Alfonso Ramirez Landaverde                                                 ***
# mechanicGUILLERMO CASTRO                                                                     **
# mechanicGuillermo Josue Lara Ferman                                                          ***
# mechanicHarley Antonio Valiente                                                              ***
# mechanicHector Antonio Alfaro                                                                .
# mechanicHector Montoya                                                                       ***
# mechanicHenry Valdez                                                                         ***
# mechanicHerbert Amilcar Montiel Sosa                                                         ***
# mechanicHERIBERTO GARCIA                                                                     ***
# mechanicHugo Hernandez                                                                       ***
# mechanicIGNACIO COB                                                                          ***
# mechanicImmer Sanchez                                                                        ***
# mechanicIsaias Santiago Hernandez                                                            ***
# mechanicJaime Armando Campos                                                                 **
# mechanicJaime Juarez                                                                         ***
# mechanicJaime Rivera                                                                         ***
# mechanicJAIRO NATAEL CALIX                                                                   ***
# mechanicJarim Martinez                                                                       ***
# mechanicJeffrey Velasquez                                                                    ***
# mechanicJERONIMO FUNEZ                                                                       ***
# mechanicJimmy Bardales                                                                       ***
# mechanicJoel Elias Chica Bran                                                                ***
# mechanicJoel Ernesto Cuellar Vanegas                                                         ***
# mechanicJonathan Ceceres
# mechanicJony Bladimir Dominguez Alvarado                                                     ***
# mechanicJordy Cedillos                                                                       ***
# mechanicJorge Lopez                                                                          ***
# mechanicJorge Ramos                                                                          ***
# mechanicJOSE AGUILAR                                                                         ***
# mechanicJOSE ALVARENGA                                                                       .
# mechanicJose Luis Hernandez                                                                  ***
# mechanicJose Luis Rodriguez                                                                  ***
# mechanicJose Manuel Perez Zepeda                                                             *
# mechanicJose Maria Canul Tec                                                                 ***
# mechanicJOSE MAURICIO VELASQUEZ ASCENCIO                                                     ***
# mechanicJose Max Reyes Flores                                                                ***
# mechanicJOSE MENDOZA                                                                         ***
# mechanicJOSE PEDRO DZUL PECH                                                                 ***
# mechanicJose Valencia                                                                        ***
# mechanicJosue Zalmeron                                                                       ***
# mechanicJuan Absalon Portillo Lemus                                                          ***
# mechanicJuan Antonio Leiva
# mechanicJuan Carlos Lemus
# mechanicJuan Francisco Cardona Hernandez                                                     ***
# mechanicJUAN GONZALEZ                                                                        ***
# mechanicJuan Huezo                                                                           ***
# mechanicJuan Leiva                                                                           ***
# mechanicJuan Manuel Interiano Zaldana
# mechanicJulia Margarita Chicas Diaz
# mechanicJulio Oswaldo Rosales                                                                ***
# mechanicKenneth Emerson Clavel Flores                                                        ***
# mechanicKevin Gomez                                                                          ***
# mechanicLadislao Monterrosa Torres                                                           ***
# mechanicLeonardo Cortez                                                                      ***
# mechanicLeonardo Villanueva                                                                  ***
# mechanicLEONEL CHAVEZ                                                                        ***
# mechanicLucas Mejia                                                                          ***
# mechanicLuis Duran
# mechanicLuis Ernesto de la Rosa Garcia                                                       ***
# mechanicLuis Manuel Garcia Rosales                                                           *
# mechanicLUIS PECH                                                                            ***
# mechanicMarco Anthonio                                                                       ***
# mechanicMarco Enmanuel Osorio Palacios
# mechanicMarcos Emmanuel Osorio Palacios                                                      ***
# mechanicMARCOS MOGUEL                                                                        ***
# mechanicMarvin Betancourth                                                                   ***
# mechanicMarvin Ernesto Melara Figueroa                                                       ***
# mechanicMarvin Pineda                                                                        ***
# mechanicMAURICIO DAVILA SANCHEZ                                                              ***
# mechanicMauricio Ernesto Valencia                                                            ***
# mechanicMelvin Galeano                                                                       ***
# mechanicMiguel Angel Fajardo Ortiz                                                           ***
# mechanicMONTOYA HECTOR AMERICO                                                               ***
# mechanicNelson Amilcar Rodriguez Salazar                                                     ***
# mechanicNelson Delgado
# mechanicNELSON GUILLEN                                                                       ***
# mechanicNERY MENA RODRIGUEZ                                                                  ***
# mechanicNestor Mauricio Carpio Salas                                                         ***
# mechanicNestor Mauricio Fuentes Lima                                                         ***
# mechanicNoe Alexander Caballero Flores                                                       ***
# mechanicNOE CONTRERAS                                                                        ***
# mechanicOdil Alfredo Guzman Saget
# mechanicOdil Alfredo Saget Guzman
# mechanicOmar Maldonado                                                                       ***
# mechanicOscar Argumedo                                                                       ***
# mechanicOscar Hurtado                                                                        ***
# mechanicPedro Miguel Martinez Linares
# mechanicRafael Esquivel                                                                      ***
# mechanicRAMIREZ RIVERA ABEL ALBERTO
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                          ***
# mechanicRAMON VILLANUEVA                                                                     ***
# mechanicRaul Coto
# mechanicREYES JAVIER CORTEZ CANTE                                                            ***
# mechanicReynaldo Chavez Guerra
# mechanicRichard Lara                                                                         ***
# mechanicRichard Steven                                                                       ***
# mechanicRIVAS TORRES CARLOS ANTONIO                                                          .
# mechanicRoberto Reyes
# mechanicROMAN IGNACIO AYALA PUC                                                              ***
# mechanicRonald Antonio Herrera                                                               ***
# mechanicRonald Fabricio Hernandez Rivas
# mechanicSalvador Roberto Palacios Alvarado                                                   *
# mechanicSalvador Rodriguez                                                                   ***
# mechanicSANCHEZ IMMER ALBERTO                                                                ***
# mechanicSAUL ALFARO                                                                          ***
# mechanicSaul Nolberto Alfaro                                                                 *
# mechanicSolmar Elias Hernandez Mezquita                                                      ***
# mechanicSolmar Elias Mezquita                                                                ***
# mechanicVictor Alfonzo Ardon Monteros                                                        ***
# mechanicVladimir Enrique Aguilar Hernandez                                                   ***
# mechanicWalter Anibal Belloso Hernandez                                                      ***
# mechanicWalter Bladimir Garcia Patino
# mechanicWalter Patino                                                                        ***
# mechanicWALTER RENE SIERRA VARGAS                                                            ***
# mechanicWilliam Alexander Arevalo Leiva                                                      ***
# mechanicWillian Tejada
# mechanicWILMER CRUZ                                                                          ***
# mechanicWilmer Zamora                                                                        ***
# mechanicXavier Jose Mendoza                                                                  ***
# parts_cost                                                                                   ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.506 on 134905 degrees of freedom
# Multiple R-squared:  0.2176,	Adjusted R-squared:  0.2121
# F-statistic: 39.33 on 954 and 134905 DF,  p-value: < 2.2e-16

# %% [markdown]
# **CALCULO DE VARIABLES PARA MEJORA DEL AJUSTE**

# %%
#Calcular los fallos acumulativos
df <- df %>%
  group_by(equipment) %>%
  mutate(Cumulative_Failure_Count = row_number())

# %%
# Calcular la mediana de tiempo de reparación
df <- df %>%
  group_by(equipment) %>%
  mutate(Median_Repair_Time = median(repair_hours, na.rm = TRUE))

# %%
# Calcular el costo acumulado de mantenimiento
df <- df %>%
  group_by(equipment) %>%
  mutate(Cumulative_Maintenance_Cost = cumsum(parts_cost))

# %% [markdown]
# **MODELO DE REGRESION LINEAL PARA PREDECIR DOWNTIME CON MAS VARIABLES**

# %%
# Inicializar y ajustar el modelo de regresión lineal
model2 <- lm(downtime_gross~. -equipment -downtime_gross -repair_hours -date -changed_pcs, data = df)
# Resumen del modelo
summary(model2)
# Out:
# Call:
# lm(formula = downtime_gross ~ . - equipment - downtime_gross -
#     repair_hours - date - changed_pcs, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -9.4696 -0.7989 -0.2564  0.2797 12.8656
#
# Coefficients: (9 not defined because of singularities)
#                                                                                                Estimate
# (Intercept)                                                                                  -1.073e+00
# operationATTACH ELASTIC                                                                       1.263e-01
# operationBARTACK                                                                              1.776e-01
# operationBIND ARM                                                                            -1.859e-01
# operationBIND ARMHOLE                                                                        -2.209e-03
# operationBIND LEG                                                                            -7.170e-03
# operationBIND NECK                                                                           -2.503e-01
# operationBUTTON                                                                               2.739e-02
# operationBUTTON HOLE                                                                          2.238e-01
# operationCLOSE CUFF                                                                           1.615e-01
# operationCLOSE INSEAM                                                                         1.208e-01
# operationCLOSE NECK                                                                           3.320e-02
# operationCLOSE POCKET                                                                         2.018e-02
# operationCLOSE SLEEVE                                                                         5.695e-01
# operationCOVER STITCH                                                                         1.003e-01
# operationCOVER STITCH WAIST                                                                   7.743e-01
# operationCUT AND CLOSE ELASTIC                                                                1.216e-01
# operationFIRST SIDE                                                                           3.056e-01
# operationFLAT LOCK                                                                           -4.965e-02
# operationFLAT SEAM                                                                           -2.400e-03
# operationGROMMET                                                                              2.661e-01
# operationHEM AROUND                                                                           3.723e-01
# operationHEM BOTTOM                                                                           7.856e-02
# operationHEM HOOD                                                                            -1.146e-01
# operationHEM LEG                                                                              1.433e-01
# operationHEM POCKET                                                                          -2.470e-02
# operationHEM SLEEVE                                                                           7.942e-01
# operationHEM SLEEVE AUTO                                                                      8.901e-01
# operationHEM SLEEVE MAN                                                                       4.263e-01
# operationJOIN LEG                                                                            -2.549e-03
# operationJOIN PANEL                                                                           5.992e-02
# operationJOIN SHOULDER                                                                        9.848e-02
# operationLOCK STITCH                                                                          2.186e-01
# operationP. LABEL                                                                            -1.038e+00
# operationPLACKET TOPSTITCH                                                                    3.133e-01
# operationPRECLOSE ELASTIC                                                                     3.543e-01
# operationSECOND SIDE                                                                          2.488e-01
# operationSERGE ELASTIC                                                                        4.029e-01
# operationSET BAND                                                                             3.075e-01
# operationSET COLLAR                                                                           1.530e-01
# operationSET CUFF                                                                             2.834e-01
# operationSET HOOD                                                                             1.208e-01
# operationSET POCKET                                                                           1.160e-01
# operationSET SLEEVE                                                                           1.327e-02
# operationSEW ELASTIC                                                                         -2.468e-02
# operationSEW ELASTIC WAIST                                                                   -6.988e-02
# operationSEW PANEL                                                                            1.604e-02
# operationSIDE SEAM                                                                            1.202e-01
# operationTAPE SHOULDER                                                                        1.639e-02
# operationTOP STITCH                                                                           3.438e-02
# operationTOP STITCH BAND                                                                     -3.195e-02
# operationTOP STITCH COLLAR                                                                    1.527e-01
# operationTOP STITCH HOOD                                                                     -6.057e-02
# operationTOP STITCH POCKET                                                                    2.661e-01
# operationTOP STITCH SEAM CROTCH                                                              -7.244e-02
# operationTOP STITCH SLEEVE                                                                    1.772e-01
# operationTOP STITCH SLEEVE AND BAND                                                          -7.398e-02
# operationTOP STITCH WAIST BAND                                                                7.030e-02
# operationTUBE FLY                                                                            -1.794e-01
# base_model504-E256                                                                           -3.535e-01
# base_model504-E51                                                                            -9.761e-02
# base_model504-ETS51                                                                          -4.108e-01
# base_model83SP                                                                               -1.238e-01
# base_modelA4                                                                                 -8.582e-02
# base_modelAZ8003                                                                             -2.103e-01
# base_modelAZ8203                                                                              2.137e-01
# base_modelAZ8403                                                                             -2.931e-01
# base_modelAZ8412                                                                             -6.086e-01
# base_modelAZ8420                                                                             -1.607e-01
# base_modelAZ8451                                                                             -6.647e-01
# base_modelAZF8420                                                                            -8.407e-01
# base_modelB-100                                                                              -5.244e-01
# base_modelBE-438D                                                                            -2.508e-01
# base_modelBE-438FX                                                                            2.249e-01
# base_modelC5                                                                                 -1.072e-01
# base_modelC5-3-02/233                                                                        -2.752e-01
# base_modelC5-4-M03                                                                           -1.946e-01
# base_modelC5S-4-M03                                                                          -2.127e-01
# base_modelCSA-2516D-03                                                                       -3.765e-01
# base_modelCSA-2604                                                                            4.947e-02
# base_modelCSA-2604-02                                                                        -2.364e-01
# base_modelCSC-2614                                                                           -3.308e-01
# base_modelCSC-2614-M03                                                                       -4.534e-01
# base_modelCW522AN                                                                            -8.909e-01
# base_modelDB2-B737                                                                            2.432e-01
# base_modelDDL-5550                                                                           -1.748e-01
# base_modelDDL5550                                                                            -1.666e-01
# base_modelDDL8500                                                                            -9.580e-02
# base_modelDDL8700                                                                            -2.441e-01
# base_modelDLN-5410                                                                           -1.585e-01
# base_modelDLN5410                                                                            -8.179e-02
# base_modelDT6L2512                                                                           -1.243e-01
# base_modelE256                                                                                1.298e-01
# base_modelE51-141                                                                            -1.731e-01
# base_modelEX5104                                                                             -1.381e-01
# base_modelEX5114                                                                             -3.084e-01
# base_modelEX5204                                                                             -2.495e-01
# base_modelEX5214                                                                             -1.509e-01
# base_modelEXT5114                                                                            -3.019e-01
# base_modelFD-62                                                                              -1.993e-01
# base_modelFD62                                                                                1.117e-01
# base_modelICN B-100                                                                           7.140e-01
# base_modelICN-2200                                                                            3.971e-01
# base_modelJ-261                                                                               1.093e-01
# base_modelJK-797DI                                                                           -3.133e-01
# base_modelJK-798DI                                                                           -2.512e-01
# base_modelJK-798DIII                                                                         -3.063e-01
# base_modelJK-8670BDII                                                                        -1.265e-01
# base_modelJK-SHIRLEY-IIE                                                                     -1.510e-01
# base_modelJK-T1790BK                                                                         -1.130e-01
# base_modelJK-T1790BS                                                                         -6.531e-01
# base_modelJK-T1903BR                                                                          3.705e-01
# base_modelJK-T1903GR                                                                                 NA
# base_modelJK-T1904                                                                           -3.259e-01
# base_modelJK-T1904A                                                                          -1.085e-01
# base_modelJK-T1904BS                                                                         -2.172e-01
# base_modelJKT1904A                                                                           -2.231e-01
# base_modelJS-2261                                                                             3.999e-02
# base_modelKE-430D                                                                            -2.701e-01
# base_modelKE430F                                                                             -1.223e-01
# base_modelLBH1790                                                                             8.817e-02
# base_modelLC62D                                                                               2.420e-02
# base_modelLC62D-12                                                                           -1.663e-01
# base_modelLDA-L26                                                                            -5.091e-02
# base_modelLK1900                                                                             -1.850e-01
# base_modelLK1910                                                                             -1.004e+00
# base_modelLK1920                                                                             -3.747e-01
# base_modelLT2-B842                                                                           -1.834e-01
# base_modelLT2-B872                                                                           -1.332e-01
# base_modelMH380                                                                              -2.078e-01
# base_modelMJ2600                                                                             -7.912e-02
# base_modelMJ2600SD                                                                            3.512e-01
# base_modelS7200                                                                               1.612e-01
# base_modelSP161                                                                               3.047e-01
# base_modelSP172                                                                               7.121e-02
# base_modelT-8422A                                                                            -1.202e-01
# base_modelT-8722B                                                                            -1.643e-01
# base_modelUS39500                                                                            -7.215e-02
# base_modelVC1700                                                                             -9.337e-02
# base_modelVC2700                                                                             -1.180e-01
# base_modelVC2711                                                                             -1.246e-01
# base_modelVC2713                                                                             -1.450e-01
# base_modelVC2735                                                                              5.099e-02
# base_modelVC2785                                                                             -5.495e-01
# base_modelVC3845                                                                             -7.064e-02
# base_modelVC3845P                                                                            -5.637e-02
# base_modelVE2700                                                                             -1.410e-01
# base_modelVE2711                                                                              2.206e-02
# base_modelVE2713                                                                             -1.366e-01
# base_modelVEU2703                                                                             2.569e-01
# base_modelVF2400                                                                             -1.891e-01
# base_modelVF2403                                                                              9.212e-02
# base_modelVF2439                                                                              2.421e-01
# base_modelVF2500                                                                             -2.367e-01
# base_modelVF2503                                                                              1.865e-01
# base_modelVF2529                                                                              9.956e-01
# base_modelVF2529G                                                                             4.031e-01
# base_modelVF2539                                                                              2.589e-01
# base_modelVF2560                                                                             -2.057e-03
# base_modelVF64228                                                                             8.747e-02
# base_modelVFF2503                                                                             2.689e-02
# base_modelVG2700                                                                             -8.136e-02
# base_modelVG2711                                                                              1.293e-01
# base_modelVG2713                                                                             -8.201e-02
# base_modelVG2735                                                                              1.343e-02
# base_modelVM1804                                                                              2.817e-01
# base_modelW1500                                                                               2.782e-01
# base_modelW1562                                                                              -5.216e-02
# base_modelW264                                                                                1.892e-01
# base_modelW3522P                                                                             -1.347e-01
# base_modelW4-D                                                                                4.749e-01
# base_modelW500                                                                               -6.790e-02
# base_modelW542                                                                               -2.135e-01
# base_modelW562                                                                                3.829e-02
# base_modelW600                                                                               -2.388e-02
# base_modelW664                                                                                1.613e-03
# base_modelWT500                                                                              -4.610e-01
# base_modelWT542                                                                               3.175e-02
# base_modelWT562                                                                              -7.918e-03
# problem_descFruncido/ Pucker                                                                  1.629e+00
# problem_descFuga de aire comprimido detectada/Compressed air leak detected                   -5.421e-01
# problem_descIt cuts the cloth with defect / Corta tela con defecto                            6.529e-01
# problem_descIt does not coil / No enrolla                                                     4.362e-01
# problem_descIt does not cut the cloth / No corta la tela                                      4.467e-01
# problem_descIt does not cut the thread / No corta el hilo                                     6.323e-01
# problem_descIt does not cut the trim off / No corta el desperdicio                            5.579e-01
# problem_descIt does not feed cloth / No alimenta tela                                         6.688e-01
# problem_descIt does not guarantee safety / No garantiza la seguridad                          5.564e-01
# problem_descIt does not label / No etiqueta                                                   3.399e-01
# problem_descIt does not light / No alumbra                                                    2.573e+00
# problem_descIt does not look properly / No luce adecuadamente                                 7.290e-01
# problem_descIt does not lubricate / No lubrica                                                5.166e-01
# problem_descIt does not pile up / No apila                                                    8.756e-01
# problem_descIt does not sew / No cose                                                         5.252e-01
# problem_descIt labels with defect / Etiqueta con defecto                                      9.478e-01
# problem_descIt piles up with defect / Apila con defecto                                       6.208e-01
# problem_descIt sews with defect / Cose con defecto                                            6.401e-01
# problem_descNo acciona el Rodo / Dont activate Roll                                           6.827e-01
# problem_descNo pega Grommet/Not set grommet                                                   6.449e-01
# problem_descPedal no Acciona Motor / Pedal not activates motor                                8.561e-01
# problem_descRemacha Grommet con defecto/ Rivet Grommet with defect                            4.498e-01
# problem_descSellado Debil/ Weak Sealed                                                        1.533e+00
# failure_descBurner failure / Falla quemador                                                   1.868e+00
# failure_descButton spiral failure/Falla de espiral de botón                                   1.652e+00
# failure_descChain cutter failure / Falla corta cadenetas                                      1.791e+00
# failure_descDesajuste Pattern Wheel y Circular plate / Patter Wheel misadjustment             3.792e+00
# failure_descDesgaste de Pattern Wheel / Pattern Wheel worn                                    6.615e-01
# failure_descElectric panel failure / Falla pánel eléctrico                                    1.819e+00
# failure_descEngine failure / Falla motor                                                      1.891e+00
# failure_descFalla cabezal remachando Grommet con defecto / Head failure riveting grommet wit  2.194e-01
# failure_descFalla sistema de aire comprimido / Compressed air supply system failure           1.486e+00
# failure_descFeeding device failure / Falla dispositivo de alimentación                        1.704e+00
# failure_descFolder failure / Falla doblillador                                                2.029e+00
# failure_descLighting lamp failure / Falla lámpara de iluminación                              1.939e+00
# failure_descLubrication system failure / Falla sistema de lubricación                         1.967e+00
# failure_descMachine head failure it does not look properly / Falla cabezal en su apariencia   2.338e+00
# failure_descMachine head failure it stops labeling / Falla cabezal dejando de etiquetar       1.828e+00
# failure_descMachine head failure not riveting/Falla cabezal no remachando                    -4.949e+00
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defecto      1.684e+00
# failure_descMachine head failure stopping sewing  / Falla cabezal dejando de coser            1.761e+00
# failure_descMachine head labeling with defect / Falla cabezal etiquetando con defecto         1.986e+00
# failure_descMonitoring and control failure / Falla monitoreo y control                        1.940e+00
# failure_descPneumatic engine failure / Falla motor neumático                                  1.969e+00
# failure_descRoll holder failure / Falla porta rollo                                           1.736e+00
# failure_descSafety guard failure / Falla protectores                                          1.666e+00
# failure_descServomotor failure / Falla servomotor                                             1.656e+00
# failure_descSpindle cap failure /Falla tapa de sujeción del pin                               3.488e+00
# failure_descSpindle die failure not punching out/Falla dado de corte no perforando            1.229e+00
# failure_descStacker  piling up with defect / Falla apilador dejando de apilar con defecto     2.137e+00
# failure_descStacker failure it stops piling up / Falla apilador dejando de apilar             1.580e+00
# failure_descSwitch failure / Falla interruptor                                                1.311e+00
# failure_descTable failure generating defect / Falla mesa generando defecto                    1.838e+00
# failure_descTable failure in its safety / Falla mesa en su seguridad                          1.884e+00
# failure_descTable failure it does not look properly / Falla mesa en su apariencia             1.228e+00
# failure_descThread holder failure / Falla torre de hilo                                       2.022e+00
# failure_descThread winder failure / Falla devanador de hilo                                   2.460e+00
# failure_descTrim off device cutting with defect /Dispositivo corta tela cortando con defecto  2.695e+00
# failure_descTrim off device failure / Falla dispositivo corta desperdicio                     1.562e+00
# failure_descTrim off device stops cutting/Falla dispositivo corta tela deja de cortar         1.690e+00
# cause_descBanda motor-volante de maquina Grommet dañada / Damaged Grommet machine steering    6.917e+00
# cause_descBase de quemador desajustada / Burner base out of adjustment                        1.284e-01
# cause_descBlocked button spiral /Espiral de botón obstruida                                   2.373e+00
# cause_descBlunt spindle die / Dado de corte sin filo                                         -1.262e+00
# cause_descBlunt trim off knife / Cuchilla de corta tela desafilada                           -6.840e-02
# cause_descBobbin case placed incorrectly / Caja de bobina mal colocada                       -7.622e-01
# cause_descBrazo de prensatela dañado / Damaged presser foot arm                               4.652e-02
# cause_descBroken feeding belt / Rotura de banda de alimentación                               2.750e-01
# cause_descBroken fuse / Rotura de fusible                                                     1.137e+00
# cause_descBroken knife of machine head / Rotura de cuchilla de cabezal                        2.597e-01
# cause_descBroken lubr. system spatter  / Rotura de salpicadores en sistema de lubricación    -1.356e+00
# cause_descBroken machine head ball joint / Rotura de biela de cabezal                         6.469e-01
# cause_descBroken machine head feeding bar / Rotura de barra de alimentación de cabezal        1.137e+00
# cause_descBroken machine head looper / Rotura de enlazador de cabezal                         1.679e-01
# cause_descBroken machine head needle / Rotura de aguja de cabezal                             1.413e-01
# cause_descBroken machine head needle guard / Rotura de guarda aguja de cabezal                1.253e-01
# cause_descBroken machine head needle plate / Rotura de placa de aguja de cabezal             -9.514e-02
# cause_descBroken machine head presser foot  / Rotura de prensatela de cabezal                -6.723e-02
# cause_descBroken machine head timing belt / Rotura de banda de tiempo de cabezal             -1.123e-01
# cause_descBroken motor v-belt/Banda de motor en mal estado o rota                             1.961e-01
# cause_descBroken needle plate finger / Rotura de lengueta placa de aguja de cabezal           3.381e-01
# cause_descBroken or splintered table edges / Bordes de mesa quebrados o astillados           -1.411e-01
# cause_descBroken solenoid valve / Rotura de válvula del solenoide                             8.901e-01
# cause_descBroken teeth of machine head / Rotura de dientes de cabezal                         4.234e-01
# cause_descBurner transformer in poor condition / Transformador de quemador en mal estado      4.533e-01
# cause_descCaja de quemador dañada / Damaged burner box                                       -3.014e+00
# cause_descClogged lubrication system hose / Manguera de sistema de lubricación atascada       5.681e-01
# cause_descComponente del sistema de aire comprimido dañado / Compressed air system compone   -7.930e-01
# cause_descContamination water in pneumatic engine / Contaminación agua en motor neumático     7.951e-01
# cause_descCtrol table param out of specs/Parámetros de ctrol de mesa fuera de especif.       -3.269e-01
# cause_descCup hook in poor condition / Canastilla en mal estado                               1.053e-01
# cause_descDamaged  chain cutter fixed knife / Cuchilla fija corta cadenetas en mal estado     6.986e-01
# cause_descDamaged  moving knife shaft /Eje cuchilla móvil corta desperdicio en mal estado     2.215e-01
# cause_descDamaged bobbin / Bobina en mal estado                                               3.455e-01
# cause_descDamaged bobbin case brake / Freno de caja de bobina en mal estado                   3.138e-01
# cause_descDamaged bobbin case thd tensor / Tensor de hilo de caja de bobina en mal estado    -1.286e-02
# cause_descDamaged burner resistance / Resistencia de quemador en mal estado                   1.665e-01
# cause_descDamaged burner thermostat / Termostato de quemador en mal estado                    1.163e+00
# cause_descDamaged chain cutter collar / Collarin de corta cadenetas en mal estado            -1.823e+00
# cause_descDamaged chain cutter cylinder  / Cilindro de corta cadenetas en mal estado          5.599e-01
# cause_descDamaged chain cutter humphrey clevis /Horquilla de corta cadenetas en mal estado    2.605e-01
# cause_descDamaged chain cutter knife / Cuchilla de corta cadeneta en mal estado               6.914e-01
# cause_descDamaged chain cutter mov knife axle/Eje cuchilla móv corta cadenetas mal estado    -6.983e-01
# cause_descDamaged chain cutter screw / Tornillo de corta cadenetas en mal estado             -3.634e-01
# cause_descDamaged circuit card / Tarjeta de circuito en mal estado                            7.444e-01
# cause_descDamaged control box / Caja de control en mal estado                                 3.286e-01
# cause_descDamaged conveyor belt / Banda transportadora de mesa en mal estado                  3.239e-01
# cause_descDamaged detachment plate / Placa de desprendimeinto de cabezal en mal estado       -3.368e-01
# cause_descDamaged differential feeding box / Caja reductora de alimentación en mal estado    -8.257e-02
# cause_descDamaged electrical panel cable / Cable de panel eléctrico en mal estado             8.133e-01
# cause_descDamaged electrical panel contactor / Contactor de panel eléctrico en mal estado     7.823e-01
# cause_descDamaged electrical panel drive / Variador de panel eléctrico en mal estado          1.507e+00
# cause_descDamaged electrical panel fuse / Fusible de panel eléctrico en mal estado            4.239e-01
# cause_descDamaged electrical panel terminal / Terminal de panel eléctrico en mal estado       7.816e-01
# cause_descDamaged engine bearing / Rodamiento de motor en mal estado                          4.754e-02
# cause_descDamaged engine belt guard / Protector de banda de motor en mal estado              -2.442e-02
# cause_descDamaged engine bobbin / Bobina de motor en mal estado                               7.740e-02
# cause_descDamaged engine clutch / Embrague de motor en mal estado                             1.189e+00
# cause_descDamaged Engine for trim off system / Motor corta desperdicio en mal estado          1.192e-01
# cause_descDamaged engine rotor / Rotor de motor en mal estado                                -2.682e-01
# cause_descDamaged eye guard / Protector de ojo en mal estado                                 -5.381e-01
# cause_descDamaged feeding axis / Eje de alimentación en mal estado                            1.872e-01
# cause_descDamaged feeding roll / Rodo de alimentación en mal estado                           5.216e-01
# cause_descDamaged feeding transmis. cable/Cable transmisión de alimentación en mal estado     1.497e+00
# cause_descDamaged finger guard / Protector de dedo en mal estado                             -2.169e-01
# cause_descDamaged folder guide / Guía de doblillador en mal estado                           -2.588e-01
# cause_descDamaged folder guide base / Base de doblillador en mal estado                      -1.975e-01
# cause_descDamaged lubr syst hose connector/Conector manguera de sist. lubr. en mal estado     9.711e-01
# cause_descDamaged lubr syst worm wheel/Engranaje acople de sistema de lubr en mal estado      9.730e-01
# cause_descDamaged lubr Syst. oil filter screen/Filtro retorno de sist de lubr. mal estado     1.737e-02
# cause_descDamaged lubric. syst. main filter / Filtro princ. de sist. lubr. en mal estado     -1.073e+00
# cause_descDamaged lubricant / Lubricante en mal estado                                       -2.647e-01
# cause_descDamaged lubrication system hose/Manguera sistema de lubricación en mal estado       6.775e-01
# cause_descDamaged lubrication system pump / Bomba de sistema de lubricación en mal estado     8.201e-01
# cause_descDamaged machine head axle casings / Buje de cabezal en mal estado                   7.994e-01
# cause_descDamaged machine head bearings / Rodamiento de cabezal en mal estado                 5.582e-01
# cause_descDamaged machine head cup hook / Canastilla de cabezal en mal estado                 2.192e-01
# cause_descDamaged machine head looper / Enlazador de cabezal en mal estado                   -2.815e-02
# cause_descDamaged machine head needle / Aguja de cabezal en mal estado                       -4.185e-01
# cause_descDamaged machine head painting / Pintura de cabezal en mal estado                    3.391e+00
# cause_descDamaged machine head teeth / Dientes de cabezal en mal estado                       3.827e-01
# cause_descDamaged machine head tension disc / Disco de tensión de cabezal en mal estado       4.424e-01
# cause_descDamaged machine head thread guide / Guía hilo de cabezal en mal estado             -1.495e-01
# cause_descDamaged machine head thread take up / Leva de cabezal en mal estado                -9.705e-02
# cause_descDamaged maintenance unit / Unidad de mantenimiento en mal estado                    2.003e-01
# cause_descDamaged monitor and control screen /Pantalla de monitoreo y ctrol en mal estado    -7.460e-02
# cause_descDamaged movement changer main tooth/Cambiador movimto diente princ en mal estado    3.018e-01
# cause_descDamaged movmt changer differ tooth /Cambiador de movmto diente difer. mal estado   -3.811e-01
# cause_descDamaged needle thread guide / Deflector de hilo de cabezal en mal estado            4.036e-01
# cause_descDamaged needle thread guide / Deflector de hilo en mal estado                       8.649e-01
# cause_descDamaged PLC of electrical panel / PLC de panel eléctrico en mal estado              1.030e+00
# cause_descDamaged presser foot's tin filling  /Relleno de prensatela en mal estado            1.261e+00
# cause_descDamaged proximity switch / Interruptor de proximidad en mal estado                  6.679e-01
# cause_descDamaged pulley / Polea en mal estado                                                7.367e-01
# cause_descDamaged roll holder base / Base de porta rollos en mal estado                       3.828e-01
# cause_descDamaged roll tensor / Tensor de rollos en mal estado                               -3.959e-01
# cause_descDamaged rotation detector unit /Posicionador en mal estado                          2.268e-01
# cause_descDamaged sensor  / Sensor en mal estado                                              1.209e-02
# cause_descDamaged Sensor for cloth detection / Sensor detector de tela en mal estado          2.224e-01
# cause_descDamaged servomotor bearing / Rodamiento de servomotor en mal estado                 4.586e-01
# cause_descDamaged servomotor control card / Tarjeta de control de servomotor en mal estado    3.979e-01
# cause_descDamaged servomotor rotor / Rotor de servomotor en mal estado                       -1.100e+00
# cause_descDamaged servomotor sensor / Sensor de servomotor en mal estado                     -3.641e-01
# cause_descDamaged servomotor sensor cable / Cable de sensor de servomotor en mal estado       5.324e-01
# cause_descDamaged servomotor terminal / Terminal de servomotor en mal estado                  8.616e-01
# cause_descDamaged solenoid / Solenoide en mal estado                                         -5.598e-01
# cause_descDamaged stacker cylinder / Cilindro de apilador en mal estado                      -2.230e-01
# cause_descDamaged stacker hose / Manguera de apilador en mal estado                          -8.394e-01
# cause_descDamaged stacker humphrey clevis / Horquilla de apilador en mal estado               5.120e-01
# cause_descDamaged stacker regulating valve / Válvula reguladora de apilador en mal estado     8.763e-01
# cause_descDamaged stacker solenoid valve / Electroválvula de apilador en mal estado           3.299e-01
# cause_descDamaged stitch regulator / Regulador de puntada de cabezal en mal estado           -7.491e-03
# cause_descDamaged surface of printing plate / Placa impresión con superficie en mal estado    1.622e-01
# cause_descDamaged switch box / Caja de interruptor en mal estado                              4.006e-01
# cause_descDamaged switch button / Botón de interruptor en mal estado                          1.153e-01
# cause_descDamaged switch cable / Cable de interruptor en mal estado                          -1.030e+00
# cause_descDamaged switch contact / Contacto de interruptor en mal estado                      1.468e+00
# cause_descDamaged switch terminal / Terminal de interruptor en mal estado                     1.349e+00
# cause_descDamaged table painting / coating / Pintura/revestimiento de mesa en mal estado      3.477e-02
# cause_descDamaged thread cone holder / Porta conos en mal estado                             -1.436e+00
# cause_descDamaged thread cutting knife / Cuchillas corta hilo en mal estado                   3.571e-01
# cause_descDamaged thread guide / Guía hilo en mal estado                                      6.213e-01
# cause_descDamaged thread guide base / Base de guía hilo en mal estado                        -3.896e-01
# cause_descDamaged thread length tensor / Tensor auxiliar de largo de hebra en mal estado     -8.768e-01
# cause_descDamaged thread winder tensor / Tensor del devanador en mal estado                  -6.933e-01
# cause_descDamaged thread wiper / Saca hebra en mal estado                                     2.492e-03
# cause_descDamaged timer / Temporizador en mal estado                                         -4.741e-01
# cause_descDamaged trim off engine / Motor de corta desperdicio en mal estado                 -4.653e-01
# cause_descDamaged trim off knife / Cuchilla de corta tela en mal estado                      -6.361e-01
# cause_descDamaged trim off knife ball joint / Biela de corta desperdicio en mal estado        4.107e-01
# cause_descDamaged trim off knife base /Base de cuchilla de corta desperdicio en mal estado    1.082e+00
# cause_descDamaged trim off knife cylinder / Cilindro de corta tela en mal estado             -3.588e-01
# cause_descDamaged trim off knife hose / Manguera de corta tela en mal estado                  9.836e-01
# cause_descDamaged trim off knife position sensor/Sensor posic de corta tela en mal estado     6.372e-01
# cause_descDamaged trim off knife regulat. valve/Válv. reguladora corta tela en mal estado    -1.045e-01
# cause_descDamaged trim off knife solenoid valve/Electroválvula de corta tela en mal estado   -5.378e-01
# cause_descDamaged trim off system bearing / Rodamiento de corta desperdicio en mal estado     5.082e-01
# cause_descDamaged trim off system knife / Cuchilla de corta desperdicio en mal estado         1.566e-01
# cause_descDamaged U-joint with shaft / Cardan de alimentación en mal estado                  -2.133e-02
# cause_descDeprogrammed electrical panel drive / Variador de panel eléctrico desprogramado    -1.836e-01
# cause_descDirty machine head / Cabezal sucio                                                  2.951e-01
# cause_descDirty table / Mesa sucia                                                            1.109e+00
# cause_descDoblillador desajustado / Folder out of adjustment                                 -5.438e-01
# cause_descExcess dirt in servomotor casting/ Suciedad excesiva en la carcasa de servomotor    6.565e-01
# cause_descExcessive dirt in chain cutter / Suciedad excesiva en corta cadenetas              -9.703e-01
# cause_descExcessive dirt in electrical panel / Suciedad excesiva en panel eléctrico           6.093e-01
# cause_descExcessive dirt in machine head / Suciedad excesiva en cabezal                       3.859e-01
# cause_descExcessive dirt in switch contact / Contacto de interruptor sucio                    7.565e-01
# cause_descFaulty connection in burner / Falso contacto en quemador                            3.875e-01
# cause_descFaulty connection in electrical panel / Falso contacto en panel eléctrico           3.353e-02
# cause_descFaulty connection in main switch / Falso contacto en interruptor principal         -4.967e-01
# cause_descFaulty connection in switch / Falso contacto en interruptor                         2.401e-01
# cause_descHigh air pressure in pneumatic engine / Alta presión de aire en motor neumático    -1.096e-01
# cause_descHigh air pressure in stacker / Alta presión de aire en apilador                    -1.914e-01
# cause_descHigh air pressure in trim off guide / Alta presión de aire en corta tela            8.089e-01
# cause_descIncorrdistance spindle die and cap/Dado corte&tapa sujeción a distincorrecta       -1.945e+00
# cause_descIncorrect bobbin / Bobina incorrecta                                               -1.138e+00
# cause_descIncorrect bobbin case / Caja de bobina incorrecta                                  -4.764e-01
# cause_descIncorrect ink formula / Fórmula de tinta incorrecta                                -8.231e-01
# cause_descIncorrect machine head  tension spring /Resorte de tensión de cabezal incorrecto    2.047e-01
# cause_descIncorrect machine head needle / Aguja de cabezal incorrecta                         2.683e-01
# cause_descIncorrect machine head threading / Enhebrado incorrecto en cabezal                  1.053e-01
# cause_descIncorrect size button spiral /Tamaño de espiral de botón  incorrecto                1.590e-01
# cause_descIncorrect threading / Enhebrado incorrecto                                         -2.563e-01
# cause_descIncorrectly installed guard / Protector mal instalado                              -8.880e-01
# cause_descKnife does not cut needle&looper thread/Cuchillla no corta hilo aguja/enlazador     1.826e-01
# cause_descLack of bobbin case brake / Freno de caja de bobina faltante                        6.092e-01
# cause_descLack of ventilation in Engine / Falta de ventilación en motor                       6.638e-01
# cause_descLooper with rough edges / Superficie de enlazador de cabezal con asperezas         -9.697e-02
# cause_descLoose chain cutter collar / Collarin de corta cadenetas flojo                      -3.642e+00
# cause_descLoose condense cylinder base screw/Tornillos base cilindro condensado flojos        3.400e-01
# cause_descLoose condensed plug wires /Conector de condensado suelto                          -4.389e-02
# cause_descLoose electr. devices in electr. panel / Disp. Eléctr. sueltos en panel eléctr.     1.651e-01
# cause_descLoose engine belt guard / Protector de banda de motor flojo                         1.717e-01
# cause_descLoose eye guard / Protector de ojo flojo                                            6.668e-01
# cause_descLoose finger guard / Protector de dedo flojo                                        5.771e-01
# cause_descLoose folder subjection screw  / Tornillo de sujeción de doblillador flojo          6.443e-01
# cause_descLoose lubrication system hose / Manguera de sistema de lubricación suelta          -2.585e-01
# cause_descLoose machine head Support for pedal  / Soporte de pedal de cabezal suelto          3.241e-01
# cause_descLoose machine head teeth / Soltura de dientes de cabezal                            1.167e-01
# cause_descLoose roll holder guide / Guía de porta rollos floja                               -1.212e+00
# cause_descLoose table / Mesa floja                                                           -2.391e-01
# cause_descLoose thread cone holder / Porta conos flojo                                        7.064e-01
# cause_descLow air pressure in burner / Baja presión de aire en quemador                       1.841e-01
# cause_descLow air pressure in chain cutter / Baja presión de aire en corta cadenetas         -7.223e-01
# cause_descLow air pressure in pneumatic engine / Baja presión de aire en motor neumático      1.339e-01
# cause_descLow air pressure in stacker / Baja presión de aire en apilador                      1.191e-01
# cause_descLow air pressure in trim off knife / Baja presión de aire en corta tela             1.390e+00
# cause_descLow oil level in lubr. system / Nivel de aceite bajo en sistema de lubricación      1.461e-01
# cause_descMisadjusted bobbin case thd tensor/ Tensor de hilo de caja de bobina desajustado   -1.393e-01
# cause_descMisadjusted chain cutter knife / Cuchilla de corta cadeneta desajustada             2.062e-01
# cause_descMisadjusted chain cutter moving knife/Cuchilla móvil corta cadeneta mal estado      3.856e-01
# cause_descMisadjusted compressed air pressure / Presión de aire comprimido desajustado        1.286e+00
# cause_descMisadjusted control box / Caja de control desajustada                               5.971e-02
# cause_descMisadjusted feeding and ndl movement/Movmto de alimentación y aguja desajustado    -1.467e-01
# cause_descMisadjusted feeding roll / Rodo de alimentación desajustado                         1.154e-01
# cause_descMisadjusted finger guard / Dedo posicionador de cabezal en mal ajustado            -7.164e-02
# cause_descMisadjusted finger guard / Dedo posicionador mal ajustado                          -1.599e-01
# cause_descMisadjusted folder guide / Guía de doblillador desajustadas                        -1.095e-01
# cause_descMisadjusted guide / Guía desajustada                                                2.917e+00
# cause_descMisadjusted hook set / Conjunto de el garfio mal ajustados                          2.337e-01
# cause_descMisadjusted hook set / Conjunto de garfios mal ajustados                            3.119e-01
# cause_descMisadjusted machine head chopper / Cuchilla de cabezal desajustada                  1.064e-01
# cause_descMisadjusted machine head looper / Enlazador de cabezal desajustado                  1.901e-01
# cause_descMisadjusted machine head needle bar / Barra de aguja de cabezal desajustada         2.411e-01
# cause_descMisadjusted machine head needle guard / Guarda aguja de cabezal desajustada         2.690e-01
# cause_descMisadjusted machine head presser foot / Prensatela de cabezal desajustado           2.137e-01
# cause_descMisadjusted machine head teeth / Dientes de cabezal desajustados                    1.469e-01
# cause_descMisadjusted machine head thd frame guide/ Marco guía hilo de cabezal desajustado    1.154e-01
# cause_descMisadjusted presser foot bar /Barra de prensatela desajustada                       6.636e-01
# cause_descMisadjusted printing head (switch S2-S3) / Cabezal desajustado (inter. S2-S3)      -2.376e-01
# cause_descMisadjusted roll tensor / Tensor de rollos desajustado                             -1.377e-01
# cause_descMisadjusted rotation detector unit /Posicionador desajustado                       -3.416e-01
# cause_descMisadjusted sensor / Sensor desajustado                                            -4.037e-01
# cause_descMisadjusted Sensor for cloth detection / Sensor detector de tela mal calibrado     -2.468e-01
# cause_descMisadjusted servomotor magnet brake / Imán de freno de servomotor desajustado       5.635e-01
# cause_descMisadjusted servomotor sensor / Sensor de servomotor en mal calibrado               2.516e-02
# cause_descMisadjusted servomotor thermal relay  / Relé térmico de servomotor mal calibrado    8.723e-02
# ...
# mechanicDaniel Edgardo Sandoval
# mechanicDENY RAYMUNDO PUCH POOL                                                              ***
# mechanicDIEGO CUELLAR                                                                        ***
# mechanicDouglas Alonso Bonilla Soriano                                                       ***
# mechanicDouglas del Cid                                                                      ***
# mechanicDOUGLAS LEONEL CHAVEZ                                                                ***
# mechanicDouglas Leonel Chavez Bonilla
# mechanicEdgar Arevalo                                                                        ***
# mechanicEDIL BERRIOS                                                                         **
# mechanicEDIS MAREL RODRIGUEZ                                                                 ***
# mechanicEdra Alvarado                                                                        **
# mechanicEduardo Antonio Flores Campos                                                        ***
# mechanicEDWIN ALEXANDER CAMPOS                                                               ***
# mechanicEdwin Colindres                                                                      ***
# mechanicEdwin Edgardo Castillo Giron
# mechanicEdwin Froylan Turcios                                                                ***
# mechanicEdwin Rogelio Galeas Perez                                                           ***
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                          ***
# mechanicEmilio Zeledon Lopez                                                                 ***
# mechanicEnrique Pech Canul                                                                   ***
# mechanicErick Garcia Lima                                                                    ***
# mechanicErick Salazar                                                                        ***
# mechanicErlin Sabillon                                                                       ***
# mechanicEver Alfredo Flores Molina                                                           ***
# mechanicFABIAN POSADAS                                                                       ***
# mechanicFabit Aranda                                                                         ***
# mechanicFAULO VICENTE TEC TORRES                                                             ***
# mechanicFernando Alexander Pubill Quintanilla                                                ***
# mechanicFLORES CAMPOS EDUARDO ANTONIO                                                        *
# mechanicFrancisco Antonio Hernandez                                                          ***
# mechanicFranqui Garcia                                                                       ***
# mechanicFUENTES LIMA NESTOR MAURICIO                                                         ***
# mechanicGabriel Sanchez                                                                      ***
# mechanicGARCIA GOMEZ FRANQUI ALIRIO                                                          *
# mechanicGeovanny  Felipe Rivera                                                              ***
# mechanicGerardo Arturo de la Cruz Lemus                                                      ***
# mechanicGilberto Antonio Flores                                                              ***
# mechanicGiovanny Alexander Rivas                                                             ***
# mechanicGuillermo Alfonso Ramirez Landaverde                                                 ***
# mechanicGUILLERMO CASTRO                                                                     **
# mechanicGuillermo Josue Lara Ferman                                                          ***
# mechanicHarley Antonio Valiente                                                              ***
# mechanicHector Antonio Alfaro
# mechanicHector Montoya                                                                       ***
# mechanicHenry Valdez                                                                         ***
# mechanicHerbert Amilcar Montiel Sosa                                                         ***
# mechanicHERIBERTO GARCIA                                                                     ***
# mechanicHugo Hernandez                                                                       ***
# mechanicIGNACIO COB                                                                          ***
# mechanicImmer Sanchez                                                                        ***
# mechanicIsaias Santiago Hernandez                                                            ***
# mechanicJaime Armando Campos                                                                 *
# mechanicJaime Juarez                                                                         **
# mechanicJaime Rivera                                                                         ***
# mechanicJAIRO NATAEL CALIX                                                                   ***
# mechanicJarim Martinez                                                                       ***
# mechanicJeffrey Velasquez                                                                    ***
# mechanicJERONIMO FUNEZ                                                                       ***
# mechanicJimmy Bardales                                                                       ***
# mechanicJoel Elias Chica Bran                                                                ***
# mechanicJoel Ernesto Cuellar Vanegas                                                         ***
# mechanicJonathan Ceceres
# mechanicJony Bladimir Dominguez Alvarado                                                     ***
# mechanicJordy Cedillos                                                                       ***
# mechanicJorge Lopez                                                                          **
# mechanicJorge Ramos                                                                          ***
# mechanicJOSE AGUILAR                                                                         ***
# mechanicJOSE ALVARENGA
# mechanicJose Luis Hernandez                                                                  ***
# mechanicJose Luis Rodriguez                                                                  ***
# mechanicJose Manuel Perez Zepeda                                                             ***
# mechanicJose Maria Canul Tec                                                                 ***
# mechanicJOSE MAURICIO VELASQUEZ ASCENCIO                                                     ***
# mechanicJose Max Reyes Flores                                                                ***
# mechanicJOSE MENDOZA                                                                         ***
# mechanicJOSE PEDRO DZUL PECH                                                                 ***
# mechanicJose Valencia                                                                        ***
# mechanicJosue Zalmeron                                                                       ***
# mechanicJuan Absalon Portillo Lemus                                                          ***
# mechanicJuan Antonio Leiva
# mechanicJuan Carlos Lemus
# mechanicJuan Francisco Cardona Hernandez                                                     ***
# mechanicJUAN GONZALEZ                                                                        ***
# mechanicJuan Huezo                                                                           ***
# mechanicJuan Leiva                                                                           ***
# mechanicJuan Manuel Interiano Zaldana
# mechanicJulia Margarita Chicas Diaz                                                          *
# mechanicJulio Oswaldo Rosales                                                                ***
# mechanicKenneth Emerson Clavel Flores                                                        ***
# mechanicKevin Gomez                                                                          ***
# mechanicLadislao Monterrosa Torres                                                           ***
# mechanicLeonardo Cortez                                                                      ***
# mechanicLeonardo Villanueva                                                                  ***
# mechanicLEONEL CHAVEZ                                                                        ***
# mechanicLucas Mejia                                                                          ***
# mechanicLuis Duran
# mechanicLuis Ernesto de la Rosa Garcia                                                       ***
# mechanicLuis Manuel Garcia Rosales                                                           ***
# mechanicLUIS PECH                                                                            ***
# mechanicMarco Anthonio                                                                       ***
# mechanicMarco Enmanuel Osorio Palacios
# mechanicMarcos Emmanuel Osorio Palacios                                                      ***
# mechanicMARCOS MOGUEL                                                                        ***
# mechanicMarvin Betancourth                                                                   ***
# mechanicMarvin Ernesto Melara Figueroa                                                       ***
# mechanicMarvin Pineda                                                                        ***
# mechanicMAURICIO DAVILA SANCHEZ                                                              ***
# mechanicMauricio Ernesto Valencia                                                            ***
# mechanicMelvin Galeano                                                                       ***
# mechanicMiguel Angel Fajardo Ortiz                                                           .
# mechanicMONTOYA HECTOR AMERICO                                                               ***
# mechanicNelson Amilcar Rodriguez Salazar                                                     ***
# mechanicNelson Delgado
# mechanicNELSON GUILLEN                                                                       **
# mechanicNERY MENA RODRIGUEZ                                                                  ***
# mechanicNestor Mauricio Carpio Salas                                                         ***
# mechanicNestor Mauricio Fuentes Lima                                                         *
# mechanicNoe Alexander Caballero Flores                                                       ***
# mechanicNOE CONTRERAS                                                                        ***
# mechanicOdil Alfredo Guzman Saget                                                            *
# mechanicOdil Alfredo Saget Guzman
# mechanicOmar Maldonado                                                                       ***
# mechanicOscar Argumedo                                                                       ***
# mechanicOscar Hurtado                                                                        **
# mechanicPedro Miguel Martinez Linares
# mechanicRafael Esquivel                                                                      ***
# mechanicRAMIREZ RIVERA ABEL ALBERTO
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                          ***
# mechanicRAMON VILLANUEVA                                                                     ***
# mechanicRaul Coto
# mechanicREYES JAVIER CORTEZ CANTE                                                            ***
# mechanicReynaldo Chavez Guerra
# mechanicRichard Lara                                                                         ***
# mechanicRichard Steven                                                                       ***
# mechanicRIVAS TORRES CARLOS ANTONIO
# mechanicRoberto Reyes                                                                        **
# mechanicROMAN IGNACIO AYALA PUC                                                              ***
# mechanicRonald Antonio Herrera                                                               ***
# mechanicRonald Fabricio Hernandez Rivas
# mechanicSalvador Roberto Palacios Alvarado                                                   *
# mechanicSalvador Rodriguez                                                                   ***
# mechanicSANCHEZ IMMER ALBERTO                                                                .
# mechanicSAUL ALFARO                                                                          ***
# mechanicSaul Nolberto Alfaro                                                                 **
# mechanicSolmar Elias Hernandez Mezquita                                                      ***
# mechanicSolmar Elias Mezquita                                                                ***
# mechanicVictor Alfonzo Ardon Monteros                                                        ***
# mechanicVladimir Enrique Aguilar Hernandez                                                   ***
# mechanicWalter Anibal Belloso Hernandez                                                      .
# mechanicWalter Bladimir Garcia Patino
# mechanicWalter Patino                                                                        ***
# mechanicWALTER RENE SIERRA VARGAS                                                            ***
# mechanicWilliam Alexander Arevalo Leiva                                                      ***
# mechanicWillian Tejada                                                                       ***
# mechanicWILMER CRUZ                                                                          ***
# mechanicWilmer Zamora                                                                        ***
# mechanicXavier Jose Mendoza                                                                  ***
# parts_cost                                                                                   ***
# Days_Between_Failures                                                                        ***
# Cumulative_Failure_Count                                                                     ***
# Median_Repair_Time                                                                           ***
# Cumulative_Maintenance_Cost                                                                  **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.484 on 134901 degrees of freedom
# Multiple R-squared:  0.2399,	Adjusted R-squared:  0.2345
# F-statistic: 44.44 on 958 and 134901 DF,  p-value: < 2.2e-16

# %% [markdown]
# **MODELO AGREGANDO LA VARIABLE "MACHINE AGE"**

# %%
# Renombrar la columna 'Equipment' a 'equipment' en df_age
df_age <- df_age %>% rename(equipment = Equipment)

# %%
df_merged <- df %>%
  left_join(df_age %>% select(equipment, Age), by = "equipment")

# %%
head(df_merged,3)
# Out:
#   equipment operation  base_model
# 1 1011144   HEM SLEEVE VC2700
# 2 1013453   TOP STITCH VC2713
# 3 1013453   TOP STITCH VC2713
#   problem_desc
# 1 It does not cut the trim off / No corta el desperdicio
# 2 It sews with defect / Cose con defecto
# 3 It sews with defect / Cose con defecto
#   failure_desc
# 1 Trim off device failure / Falla dispositivo corta desperdicio
# 2 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 3 Machine head failure stopping sewing  / Falla cabezal dejando de coser
#   cause_desc
# 1 Damaged trim off system knife / Cuchilla de corta desperdicio en mal estado
# 2 Misadjusted machine head needle guard / Guarda aguja de cabezal desajustada
# 3 Misadjusted machine head needle guard / Guarda aguja de cabezal desajustada
#   action_desc
# 1 Sharpen knife / Afilar cuchillas
# 2 Adjust machine head needle guard / Ajustar guarda aguja de cabezal
# 3 Adjust machine head needle guard / Ajustar guarda aguja de cabezal
#   mechanic                            date       downtime_gross parts_cost
# 1 DIEGO CUELLAR                       2023-01-03 0.1666667      51.0
# 2 Adalberto Jeremias Rodriguez Zometa 2023-01-03 1.0000000      19.2
# 3 Adalberto Jeremias Rodriguez Zometa 2023-01-03 1.0000000      19.2
#   repair_hours changed_pcs Days_Between_Failures Cumulative_Failure_Count
# 1 0.1666667    0           2                     1
# 2 1.0000000    1           2                     1
# 3 1.0000000    1           0                     2
#   Median_Repair_Time Cumulative_Maintenance_Cost Age
# 1 0.5                51.0                        26
# 2 1.0                19.2                        23
# 3 1.0                38.4                        23

# %%
# Inicializar y ajustar el modelo de regresión lineal
model3 <- lm(downtime_gross~. -equipment -downtime_gross -repair_hours -date -changed_pcs, data = df_merged)
# Resumen del modelo
summary(model3)
# Out:
# Call:
# lm(formula = downtime_gross ~ . - equipment - downtime_gross -
#     repair_hours - date - changed_pcs, data = df_merged)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -9.3915 -0.7986 -0.2544  0.2798 12.8762
#
# Coefficients: (9 not defined because of singularities)
#                                                                                                Estimate
# (Intercept)                                                                                  -1.099e+00
# operationATTACH ELASTIC                                                                       1.156e-01
# operationBARTACK                                                                              1.856e-01
# operationBIND ARM                                                                            -1.973e-01
# operationBIND ARMHOLE                                                                        -1.357e-02
# operationBIND LEG                                                                            -1.364e-02
# operationBIND NECK                                                                           -2.570e-01
# operationBUTTON                                                                               2.924e-02
# operationBUTTON HOLE                                                                          2.443e-01
# operationCLOSE CUFF                                                                           1.696e-01
# operationCLOSE INSEAM                                                                         1.118e-01
# operationCLOSE NECK                                                                           3.933e-03
# operationCLOSE POCKET                                                                         4.490e-03
# operationCLOSE SLEEVE                                                                         5.605e-01
# operationCOVER STITCH                                                                         1.017e-01
# operationCOVER STITCH WAIST                                                                   7.672e-01
# operationCUT AND CLOSE ELASTIC                                                                1.173e-01
# operationFIRST SIDE                                                                           3.098e-01
# operationFLAT LOCK                                                                           -4.099e-02
# operationFLAT SEAM                                                                            1.902e-03
# operationGROMMET                                                                              2.593e-01
# operationHEM AROUND                                                                           3.629e-01
# operationHEM BOTTOM                                                                           6.652e-02
# operationHEM HOOD                                                                            -1.296e-01
# operationHEM LEG                                                                              1.436e-01
# operationHEM POCKET                                                                          -2.014e-02
# operationHEM SLEEVE                                                                           7.850e-01
# operationHEM SLEEVE AUTO                                                                      8.905e-01
# operationHEM SLEEVE MAN                                                                       4.104e-01
# operationJOIN LEG                                                                             6.784e-04
# operationJOIN PANEL                                                                           5.982e-02
# operationJOIN SHOULDER                                                                        9.990e-02
# operationLOCK STITCH                                                                          1.752e-01
# operationP. LABEL                                                                            -1.025e+00
# operationPLACKET TOPSTITCH                                                                    3.086e-01
# operationPRECLOSE ELASTIC                                                                     3.583e-01
# operationSECOND SIDE                                                                          2.590e-01
# operationSERGE ELASTIC                                                                        4.145e-01
# operationSET BAND                                                                             2.873e-01
# operationSET COLLAR                                                                           1.429e-01
# operationSET CUFF                                                                             2.602e-01
# operationSET HOOD                                                                             1.086e-01
# operationSET POCKET                                                                           1.128e-01
# operationSET SLEEVE                                                                           1.699e-02
# operationSEW ELASTIC                                                                         -2.685e-02
# operationSEW ELASTIC WAIST                                                                   -7.706e-02
# operationSEW PANEL                                                                            2.178e-02
# operationSIDE SEAM                                                                            1.411e-01
# operationTAPE SHOULDER                                                                        7.231e-03
# operationTOP STITCH                                                                           2.465e-02
# operationTOP STITCH BAND                                                                     -4.428e-02
# operationTOP STITCH COLLAR                                                                    1.448e-01
# operationTOP STITCH HOOD                                                                     -6.858e-02
# operationTOP STITCH POCKET                                                                    2.537e-01
# operationTOP STITCH SEAM CROTCH                                                              -5.179e-02
# operationTOP STITCH SLEEVE                                                                    1.841e-01
# operationTOP STITCH SLEEVE AND BAND                                                          -8.548e-02
# operationTOP STITCH WAIST BAND                                                                7.692e-02
# operationTUBE FLY                                                                            -1.766e-01
# base_model504-E256                                                                           -3.422e-01
# base_model504-E51                                                                            -6.716e-02
# base_model504-ETS51                                                                          -4.227e-01
# base_model83SP                                                                               -1.402e-01
# base_modelA4                                                                                 -9.447e-02
# base_modelAZ8003                                                                             -1.820e-01
# base_modelAZ8203                                                                              2.566e-01
# base_modelAZ8403                                                                             -2.769e-01
# base_modelAZ8412                                                                             -5.574e-01
# base_modelAZ8420                                                                             -8.814e-02
# base_modelAZ8451                                                                             -6.242e-01
# base_modelAZF8420                                                                            -7.676e-01
# base_modelB-100                                                                              -4.262e-01
# base_modelBE-438D                                                                            -2.409e-01
# base_modelBE-438FX                                                                            2.462e-01
# base_modelC5                                                                                 -9.108e-02
# base_modelC5-3-02/233                                                                        -2.699e-01
# base_modelC5-4-M03                                                                           -1.854e-01
# base_modelC5S-4-M03                                                                          -1.974e-01
# base_modelCSA-2516D-03                                                                       -4.019e-01
# base_modelCSA-2604                                                                            6.300e-02
# base_modelCSA-2604-02                                                                        -2.127e-01
# base_modelCSC-2614                                                                           -3.264e-01
# base_modelCSC-2614-M03                                                                       -4.393e-01
# base_modelCW522AN                                                                            -8.623e-01
# base_modelDB2-B737                                                                            2.153e-01
# base_modelDDL-5550                                                                           -1.472e-01
# base_modelDDL5550                                                                            -1.788e-01
# base_modelDDL8500                                                                            -9.780e-02
# base_modelDDL8700                                                                            -2.469e-01
# base_modelDLN-5410                                                                           -1.293e-01
# base_modelDLN5410                                                                            -8.799e-02
# base_modelDT6L2512                                                                           -1.254e-01
# base_modelE256                                                                                1.423e-01
# base_modelE51-141                                                                            -1.080e-01
# base_modelEX5104                                                                             -1.368e-01
# base_modelEX5114                                                                             -3.017e-01
# base_modelEX5204                                                                             -1.913e-01
# base_modelEX5214                                                                             -1.433e-01
# base_modelEXT5114                                                                            -2.728e-01
# base_modelFD-62                                                                              -2.066e-01
# base_modelFD62                                                                                8.734e-02
# base_modelICN B-100                                                                           7.503e-01
# base_modelICN-2200                                                                            4.665e-01
# base_modelJ-261                                                                               1.053e-01
# base_modelJK-797DI                                                                           -2.905e-01
# base_modelJK-798DI                                                                           -2.409e-01
# base_modelJK-798DIII                                                                         -2.883e-01
# base_modelJK-8670BDII                                                                        -8.509e-02
# base_modelJK-SHIRLEY-IIE                                                                     -1.484e-01
# base_modelJK-T1790BK                                                                         -1.189e-01
# base_modelJK-T1790BS                                                                         -5.967e-01
# base_modelJK-T1903BR                                                                          3.499e-01
# base_modelJK-T1903GR                                                                                 NA
# base_modelJK-T1904                                                                           -3.412e-01
# base_modelJK-T1904A                                                                          -8.025e-02
# base_modelJK-T1904BS                                                                         -1.971e-01
# base_modelJKT1904A                                                                           -1.811e-01
# base_modelJS-2261                                                                             3.234e-02
# base_modelKE-430D                                                                            -2.611e-01
# base_modelKE430F                                                                             -1.126e-01
# base_modelLBH1790                                                                             2.993e-02
# base_modelLC62D                                                                               3.354e-03
# base_modelLC62D-12                                                                           -1.808e-01
# base_modelLDA-L26                                                                            -5.461e-02
# base_modelLK1900                                                                             -1.621e-01
# base_modelLK1910                                                                             -1.009e+00
# base_modelLK1920                                                                             -3.683e-01
# base_modelLT2-B842                                                                           -1.591e-01
# base_modelLT2-B872                                                                           -1.185e-01
# base_modelMH380                                                                              -2.533e-01
# base_modelMJ2600                                                                             -1.749e-02
# base_modelMJ2600SD                                                                            3.775e-01
# base_modelS7200                                                                               1.416e-01
# base_modelSP161                                                                               2.395e-01
# base_modelSP172                                                                               1.597e-02
# base_modelT-8422A                                                                            -1.304e-01
# base_modelT-8722B                                                                            -1.769e-01
# base_modelUS39500                                                                            -9.298e-02
# base_modelVC1700                                                                             -1.117e-01
# base_modelVC2700                                                                             -1.295e-01
# base_modelVC2711                                                                             -1.359e-01
# base_modelVC2713                                                                             -1.600e-01
# base_modelVC2735                                                                              2.323e-02
# base_modelVC2785                                                                             -5.907e-01
# base_modelVC3845                                                                             -1.122e-01
# base_modelVC3845P                                                                            -7.226e-02
# base_modelVE2700                                                                             -1.451e-01
# base_modelVE2711                                                                              1.175e-02
# base_modelVE2713                                                                             -1.440e-01
# base_modelVEU2703                                                                             2.036e-01
# base_modelVF2400                                                                             -1.828e-01
# base_modelVF2403                                                                              9.077e-02
# base_modelVF2439                                                                              2.806e-01
# base_modelVF2500                                                                             -2.427e-01
# base_modelVF2503                                                                              1.908e-01
# base_modelVF2529                                                                              9.420e-01
# base_modelVF2529G                                                                             4.524e-01
# base_modelVF2539                                                                              2.996e-01
# base_modelVF2560                                                                              3.104e-03
# base_modelVF64228                                                                             7.590e-02
# base_modelVFF2503                                                                             2.446e-02
# base_modelVG2700                                                                             -8.742e-02
# base_modelVG2711                                                                              1.451e-01
# base_modelVG2713                                                                             -9.589e-02
# base_modelVG2735                                                                              1.882e-03
# base_modelVM1804                                                                              2.259e-01
# base_modelW1500                                                                               3.156e-01
# base_modelW1562                                                                              -1.287e-02
# base_modelW264                                                                                1.822e-01
# base_modelW3522P                                                                             -9.174e-02
# base_modelW4-D                                                                                4.843e-01
# base_modelW500                                                                               -9.160e-02
# base_modelW542                                                                               -2.271e-01
# base_modelW562                                                                                3.197e-02
# base_modelW600                                                                               -1.442e-02
# base_modelW664                                                                               -1.601e-02
# base_modelWT500                                                                              -4.777e-01
# base_modelWT542                                                                               2.259e-02
# base_modelWT562                                                                              -5.771e-03
# problem_descFruncido/ Pucker                                                                  1.550e+00
# problem_descFuga de aire comprimido detectada/Compressed air leak detected                   -6.181e-01
# problem_descIt cuts the cloth with defect / Corta tela con defecto                            5.756e-01
# problem_descIt does not coil / No enrolla                                                     3.384e-01
# problem_descIt does not cut the cloth / No corta la tela                                      3.702e-01
# problem_descIt does not cut the thread / No corta el hilo                                     5.549e-01
# problem_descIt does not cut the trim off / No corta el desperdicio                            4.830e-01
# problem_descIt does not feed cloth / No alimenta tela                                         5.952e-01
# problem_descIt does not guarantee safety / No garantiza la seguridad                          4.801e-01
# problem_descIt does not label / No etiqueta                                                   2.501e-01
# problem_descIt does not light / No alumbra                                                    2.500e+00
# problem_descIt does not look properly / No luce adecuadamente                                 6.501e-01
# problem_descIt does not lubricate / No lubrica                                                4.386e-01
# problem_descIt does not pile up / No apila                                                    7.958e-01
# problem_descIt does not sew / No cose                                                         4.480e-01
# problem_descIt labels with defect / Etiqueta con defecto                                      8.718e-01
# problem_descIt piles up with defect / Apila con defecto                                       5.457e-01
# problem_descIt sews with defect / Cose con defecto                                            5.627e-01
# problem_descNo acciona el Rodo / Dont activate Roll                                           6.219e-01
# problem_descNo pega Grommet/Not set grommet                                                   5.645e-01
# problem_descPedal no Acciona Motor / Pedal not activates motor                                7.996e-01
# problem_descRemacha Grommet con defecto/ Rivet Grommet with defect                            3.860e-01
# problem_descSellado Debil/ Weak Sealed                                                        1.446e+00
# failure_descBurner failure / Falla quemador                                                   1.868e+00
# failure_descButton spiral failure/Falla de espiral de botón                                   1.658e+00
# failure_descChain cutter failure / Falla corta cadenetas                                      1.789e+00
# failure_descDesajuste Pattern Wheel y Circular plate / Patter Wheel misadjustment             3.807e+00
# failure_descDesgaste de Pattern Wheel / Pattern Wheel worn                                    6.623e-01
# failure_descElectric panel failure / Falla pánel eléctrico                                    1.814e+00
# failure_descEngine failure / Falla motor                                                      1.887e+00
# failure_descFalla cabezal remachando Grommet con defecto / Head failure riveting grommet wit  2.186e-01
# failure_descFalla sistema de aire comprimido / Compressed air supply system failure           1.449e+00
# failure_descFeeding device failure / Falla dispositivo de alimentación                        1.698e+00
# failure_descFolder failure / Falla doblillador                                                2.025e+00
# failure_descLighting lamp failure / Falla lámpara de iluminación                              1.928e+00
# failure_descLubrication system failure / Falla sistema de lubricación                         1.969e+00
# failure_descMachine head failure it does not look properly / Falla cabezal en su apariencia   2.341e+00
# failure_descMachine head failure it stops labeling / Falla cabezal dejando de etiquetar       1.832e+00
# failure_descMachine head failure not riveting/Falla cabezal no remachando                    -4.995e+00
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defecto      1.682e+00
# failure_descMachine head failure stopping sewing  / Falla cabezal dejando de coser            1.759e+00
# failure_descMachine head labeling with defect / Falla cabezal etiquetando con defecto         1.968e+00
# failure_descMonitoring and control failure / Falla monitoreo y control                        1.938e+00
# failure_descPneumatic engine failure / Falla motor neumático                                  1.963e+00
# failure_descRoll holder failure / Falla porta rollo                                           1.740e+00
# failure_descSafety guard failure / Falla protectores                                          1.670e+00
# failure_descServomotor failure / Falla servomotor                                             1.656e+00
# failure_descSpindle cap failure /Falla tapa de sujeción del pin                               3.451e+00
# failure_descSpindle die failure not punching out/Falla dado de corte no perforando            1.213e+00
# failure_descStacker  piling up with defect / Falla apilador dejando de apilar con defecto     2.126e+00
# failure_descStacker failure it stops piling up / Falla apilador dejando de apilar             1.575e+00
# failure_descSwitch failure / Falla interruptor                                                1.317e+00
# failure_descTable failure generating defect / Falla mesa generando defecto                    1.836e+00
# failure_descTable failure in its safety / Falla mesa en su seguridad                          1.876e+00
# failure_descTable failure it does not look properly / Falla mesa en su apariencia             1.225e+00
# failure_descThread holder failure / Falla torre de hilo                                       2.019e+00
# failure_descThread winder failure / Falla devanador de hilo                                   2.476e+00
# failure_descTrim off device cutting with defect /Dispositivo corta tela cortando con defecto  2.691e+00
# failure_descTrim off device failure / Falla dispositivo corta desperdicio                     1.561e+00
# failure_descTrim off device stops cutting/Falla dispositivo corta tela deja de cortar         1.686e+00
# cause_descBanda motor-volante de maquina Grommet dañada / Damaged Grommet machine steering    6.921e+00
# cause_descBase de quemador desajustada / Burner base out of adjustment                        1.291e-01
# cause_descBlocked button spiral /Espiral de botón obstruida                                   2.388e+00
# cause_descBlunt spindle die / Dado de corte sin filo                                         -1.230e+00
# cause_descBlunt trim off knife / Cuchilla de corta tela desafilada                           -6.845e-02
# cause_descBobbin case placed incorrectly / Caja de bobina mal colocada                       -7.786e-01
# cause_descBrazo de prensatela dañado / Damaged presser foot arm                              -4.045e-03
# cause_descBroken feeding belt / Rotura de banda de alimentación                               2.815e-01
# cause_descBroken fuse / Rotura de fusible                                                     1.140e+00
# cause_descBroken knife of machine head / Rotura de cuchilla de cabezal                        2.585e-01
# cause_descBroken lubr. system spatter  / Rotura de salpicadores en sistema de lubricación    -1.352e+00
# cause_descBroken machine head ball joint / Rotura de biela de cabezal                         6.502e-01
# cause_descBroken machine head feeding bar / Rotura de barra de alimentación de cabezal        1.141e+00
# cause_descBroken machine head looper / Rotura de enlazador de cabezal                         1.681e-01
# cause_descBroken machine head needle / Rotura de aguja de cabezal                             1.431e-01
# cause_descBroken machine head needle guard / Rotura de guarda aguja de cabezal                1.269e-01
# cause_descBroken machine head needle plate / Rotura de placa de aguja de cabezal             -8.712e-02
# cause_descBroken machine head presser foot  / Rotura de prensatela de cabezal                -6.819e-02
# cause_descBroken machine head timing belt / Rotura de banda de tiempo de cabezal             -1.106e-01
# cause_descBroken motor v-belt/Banda de motor en mal estado o rota                             1.970e-01
# cause_descBroken needle plate finger / Rotura de lengueta placa de aguja de cabezal           3.225e-01
# cause_descBroken or splintered table edges / Bordes de mesa quebrados o astillados           -1.403e-01
# cause_descBroken solenoid valve / Rotura de válvula del solenoide                             9.120e-01
# cause_descBroken teeth of machine head / Rotura de dientes de cabezal                         4.268e-01
# cause_descBurner transformer in poor condition / Transformador de quemador en mal estado      4.442e-01
# cause_descCaja de quemador dañada / Damaged burner box                                       -3.053e+00
# cause_descClogged lubrication system hose / Manguera de sistema de lubricación atascada       5.620e-01
# cause_descComponente del sistema de aire comprimido dañado / Compressed air system compone   -7.755e-01
# cause_descContamination water in pneumatic engine / Contaminación agua en motor neumático     8.117e-01
# cause_descCtrol table param out of specs/Parámetros de ctrol de mesa fuera de especif.       -3.375e-01
# cause_descCup hook in poor condition / Canastilla en mal estado                               9.290e-02
# cause_descDamaged  chain cutter fixed knife / Cuchilla fija corta cadenetas en mal estado     6.991e-01
# cause_descDamaged  moving knife shaft /Eje cuchilla móvil corta desperdicio en mal estado     2.173e-01
# cause_descDamaged bobbin / Bobina en mal estado                                               3.469e-01
# cause_descDamaged bobbin case brake / Freno de caja de bobina en mal estado                   3.118e-01
# cause_descDamaged bobbin case thd tensor / Tensor de hilo de caja de bobina en mal estado    -1.482e-02
# cause_descDamaged burner resistance / Resistencia de quemador en mal estado                   1.651e-01
# cause_descDamaged burner thermostat / Termostato de quemador en mal estado                    1.172e+00
# cause_descDamaged chain cutter collar / Collarin de corta cadenetas en mal estado            -1.826e+00
# cause_descDamaged chain cutter cylinder  / Cilindro de corta cadenetas en mal estado          5.690e-01
# cause_descDamaged chain cutter humphrey clevis /Horquilla de corta cadenetas en mal estado    2.592e-01
# cause_descDamaged chain cutter knife / Cuchilla de corta cadeneta en mal estado               6.880e-01
# cause_descDamaged chain cutter mov knife axle/Eje cuchilla móv corta cadenetas mal estado    -7.085e-01
# cause_descDamaged chain cutter screw / Tornillo de corta cadenetas en mal estado             -3.760e-01
# cause_descDamaged circuit card / Tarjeta de circuito en mal estado                            7.524e-01
# cause_descDamaged control box / Caja de control en mal estado                                 3.329e-01
# cause_descDamaged conveyor belt / Banda transportadora de mesa en mal estado                  3.289e-01
# cause_descDamaged detachment plate / Placa de desprendimeinto de cabezal en mal estado       -3.477e-01
# cause_descDamaged differential feeding box / Caja reductora de alimentación en mal estado    -6.392e-02
# cause_descDamaged electrical panel cable / Cable de panel eléctrico en mal estado             8.192e-01
# cause_descDamaged electrical panel contactor / Contactor de panel eléctrico en mal estado     7.828e-01
# cause_descDamaged electrical panel drive / Variador de panel eléctrico en mal estado          1.480e+00
# cause_descDamaged electrical panel fuse / Fusible de panel eléctrico en mal estado            4.079e-01
# cause_descDamaged electrical panel terminal / Terminal de panel eléctrico en mal estado       7.888e-01
# cause_descDamaged engine bearing / Rodamiento de motor en mal estado                          6.492e-02
# cause_descDamaged engine belt guard / Protector de banda de motor en mal estado              -1.380e-02
# cause_descDamaged engine bobbin / Bobina de motor en mal estado                               7.120e-02
# cause_descDamaged engine clutch / Embrague de motor en mal estado                             1.177e+00
# cause_descDamaged Engine for trim off system / Motor corta desperdicio en mal estado          1.195e-01
# cause_descDamaged engine rotor / Rotor de motor en mal estado                                -2.531e-01
# cause_descDamaged eye guard / Protector de ojo en mal estado                                 -5.342e-01
# cause_descDamaged feeding axis / Eje de alimentación en mal estado                            1.846e-01
# cause_descDamaged feeding roll / Rodo de alimentación en mal estado                           5.288e-01
# cause_descDamaged feeding transmis. cable/Cable transmisión de alimentación en mal estado     1.469e+00
# cause_descDamaged finger guard / Protector de dedo en mal estado                             -2.041e-01
# cause_descDamaged folder guide / Guía de doblillador en mal estado                           -2.646e-01
# cause_descDamaged folder guide base / Base de doblillador en mal estado                      -2.064e-01
# cause_descDamaged lubr syst hose connector/Conector manguera de sist. lubr. en mal estado     9.686e-01
# cause_descDamaged lubr syst worm wheel/Engranaje acople de sistema de lubr en mal estado      9.504e-01
# cause_descDamaged lubr Syst. oil filter screen/Filtro retorno de sist de lubr. mal estado     2.474e-02
# cause_descDamaged lubric. syst. main filter / Filtro princ. de sist. lubr. en mal estado     -1.067e+00
# cause_descDamaged lubricant / Lubricante en mal estado                                       -2.709e-01
# cause_descDamaged lubrication system hose/Manguera sistema de lubricación en mal estado       6.714e-01
# cause_descDamaged lubrication system pump / Bomba de sistema de lubricación en mal estado     8.207e-01
# cause_descDamaged machine head axle casings / Buje de cabezal en mal estado                   7.947e-01
# cause_descDamaged machine head bearings / Rodamiento de cabezal en mal estado                 5.627e-01
# cause_descDamaged machine head cup hook / Canastilla de cabezal en mal estado                 1.915e-01
# cause_descDamaged machine head looper / Enlazador de cabezal en mal estado                   -2.496e-02
# cause_descDamaged machine head needle / Aguja de cabezal en mal estado                       -4.231e-01
# cause_descDamaged machine head painting / Pintura de cabezal en mal estado                    3.386e+00
# cause_descDamaged machine head teeth / Dientes de cabezal en mal estado                       3.927e-01
# cause_descDamaged machine head tension disc / Disco de tensión de cabezal en mal estado       4.477e-01
# cause_descDamaged machine head thread guide / Guía hilo de cabezal en mal estado             -1.345e-01
# cause_descDamaged machine head thread take up / Leva de cabezal en mal estado                -9.205e-02
# cause_descDamaged maintenance unit / Unidad de mantenimiento en mal estado                    1.959e-01
# cause_descDamaged monitor and control screen /Pantalla de monitoreo y ctrol en mal estado    -8.461e-02
# cause_descDamaged movement changer main tooth/Cambiador movimto diente princ en mal estado    3.122e-01
# cause_descDamaged movmt changer differ tooth /Cambiador de movmto diente difer. mal estado   -3.875e-01
# cause_descDamaged needle thread guide / Deflector de hilo de cabezal en mal estado            3.992e-01
# cause_descDamaged needle thread guide / Deflector de hilo en mal estado                       8.493e-01
# cause_descDamaged PLC of electrical panel / PLC de panel eléctrico en mal estado              1.027e+00
# cause_descDamaged presser foot's tin filling  /Relleno de prensatela en mal estado            1.292e+00
# cause_descDamaged proximity switch / Interruptor de proximidad en mal estado                  6.739e-01
# cause_descDamaged pulley / Polea en mal estado                                                7.515e-01
# cause_descDamaged roll holder base / Base de porta rollos en mal estado                       4.004e-01
# cause_descDamaged roll tensor / Tensor de rollos en mal estado                               -4.046e-01
# cause_descDamaged rotation detector unit /Posicionador en mal estado                          2.367e-01
# cause_descDamaged sensor  / Sensor en mal estado                                              7.552e-03
# cause_descDamaged Sensor for cloth detection / Sensor detector de tela en mal estado          2.206e-01
# cause_descDamaged servomotor bearing / Rodamiento de servomotor en mal estado                 4.651e-01
# cause_descDamaged servomotor control card / Tarjeta de control de servomotor en mal estado    3.904e-01
# cause_descDamaged servomotor rotor / Rotor de servomotor en mal estado                       -1.106e+00
# cause_descDamaged servomotor sensor / Sensor de servomotor en mal estado                     -3.511e-01
# cause_descDamaged servomotor sensor cable / Cable de sensor de servomotor en mal estado       5.361e-01
# cause_descDamaged servomotor terminal / Terminal de servomotor en mal estado                  8.555e-01
# cause_descDamaged solenoid / Solenoide en mal estado                                         -5.518e-01
# cause_descDamaged stacker cylinder / Cilindro de apilador en mal estado                      -2.161e-01
# cause_descDamaged stacker hose / Manguera de apilador en mal estado                          -8.456e-01
# cause_descDamaged stacker humphrey clevis / Horquilla de apilador en mal estado               5.170e-01
# cause_descDamaged stacker regulating valve / Válvula reguladora de apilador en mal estado     8.755e-01
# cause_descDamaged stacker solenoid valve / Electroválvula de apilador en mal estado           3.523e-01
# cause_descDamaged stitch regulator / Regulador de puntada de cabezal en mal estado           -6.607e-03
# cause_descDamaged surface of printing plate / Placa impresión con superficie en mal estado    1.623e-01
# cause_descDamaged switch box / Caja de interruptor en mal estado                              4.188e-01
# cause_descDamaged switch button / Botón de interruptor en mal estado                          1.221e-01
# cause_descDamaged switch cable / Cable de interruptor en mal estado                          -1.006e+00
# cause_descDamaged switch contact / Contacto de interruptor en mal estado                      1.491e+00
# cause_descDamaged switch terminal / Terminal de interruptor en mal estado                     1.350e+00
# cause_descDamaged table painting / coating / Pintura/revestimiento de mesa en mal estado      5.795e-02
# cause_descDamaged thread cone holder / Porta conos en mal estado                             -1.437e+00
# cause_descDamaged thread cutting knife / Cuchillas corta hilo en mal estado                   3.548e-01
# cause_descDamaged thread guide / Guía hilo en mal estado                                      6.327e-01
# cause_descDamaged thread guide base / Base de guía hilo en mal estado                        -3.913e-01
# cause_descDamaged thread length tensor / Tensor auxiliar de largo de hebra en mal estado     -8.675e-01
# cause_descDamaged thread winder tensor / Tensor del devanador en mal estado                  -6.886e-01
# cause_descDamaged thread wiper / Saca hebra en mal estado                                     4.606e-03
# cause_descDamaged timer / Temporizador en mal estado                                         -4.562e-01
# cause_descDamaged trim off engine / Motor de corta desperdicio en mal estado                 -4.624e-01
# cause_descDamaged trim off knife / Cuchilla de corta tela en mal estado                      -6.162e-01
# cause_descDamaged trim off knife ball joint / Biela de corta desperdicio en mal estado        3.964e-01
# cause_descDamaged trim off knife base /Base de cuchilla de corta desperdicio en mal estado    1.135e+00
# cause_descDamaged trim off knife cylinder / Cilindro de corta tela en mal estado             -3.585e-01
# cause_descDamaged trim off knife hose / Manguera de corta tela en mal estado                  1.000e+00
# cause_descDamaged trim off knife position sensor/Sensor posic de corta tela en mal estado     6.229e-01
# cause_descDamaged trim off knife regulat. valve/Válv. reguladora corta tela en mal estado    -7.684e-02
# cause_descDamaged trim off knife solenoid valve/Electroválvula de corta tela en mal estado   -5.121e-01
# cause_descDamaged trim off system bearing / Rodamiento de corta desperdicio en mal estado     5.154e-01
# cause_descDamaged trim off system knife / Cuchilla de corta desperdicio en mal estado         1.551e-01
# cause_descDamaged U-joint with shaft / Cardan de alimentación en mal estado                  -2.800e-02
# cause_descDeprogrammed electrical panel drive / Variador de panel eléctrico desprogramado    -1.589e-01
# cause_descDirty machine head / Cabezal sucio                                                  2.937e-01
# cause_descDirty table / Mesa sucia                                                            1.115e+00
# cause_descDoblillador desajustado / Folder out of adjustment                                 -5.496e-01
# cause_descExcess dirt in servomotor casting/ Suciedad excesiva en la carcasa de servomotor    6.580e-01
# cause_descExcessive dirt in chain cutter / Suciedad excesiva en corta cadenetas              -9.454e-01
# cause_descExcessive dirt in electrical panel / Suciedad excesiva en panel eléctrico           6.130e-01
# cause_descExcessive dirt in machine head / Suciedad excesiva en cabezal                       3.900e-01
# cause_descExcessive dirt in switch contact / Contacto de interruptor sucio                    7.819e-01
# cause_descFaulty connection in burner / Falso contacto en quemador                            3.800e-01
# cause_descFaulty connection in electrical panel / Falso contacto en panel eléctrico           1.138e-02
# cause_descFaulty connection in main switch / Falso contacto en interruptor principal         -4.779e-01
# cause_descFaulty connection in switch / Falso contacto en interruptor                         2.233e-01
# cause_descHigh air pressure in pneumatic engine / Alta presión de aire en motor neumático    -1.065e-01
# cause_descHigh air pressure in stacker / Alta presión de aire en apilador                    -1.840e-01
# cause_descHigh air pressure in trim off guide / Alta presión de aire en corta tela            8.473e-01
# cause_descIncorrdistance spindle die and cap/Dado corte&tapa sujeción a distincorrecta       -1.968e+00
# cause_descIncorrect bobbin / Bobina incorrecta                                               -1.135e+00
# cause_descIncorrect bobbin case / Caja de bobina incorrecta                                  -4.760e-01
# cause_descIncorrect ink formula / Fórmula de tinta incorrecta                                -8.642e-01
# cause_descIncorrect machine head  tension spring /Resorte de tensión de cabezal incorrecto    1.929e-01
# cause_descIncorrect machine head needle / Aguja de cabezal incorrecta                         2.691e-01
# cause_descIncorrect machine head threading / Enhebrado incorrecto en cabezal                  9.582e-02
# cause_descIncorrect size button spiral /Tamaño de espiral de botón  incorrecto                1.649e-01
# cause_descIncorrect threading / Enhebrado incorrecto                                         -2.543e-01
# cause_descIncorrectly installed guard / Protector mal instalado                              -8.948e-01
# cause_descKnife does not cut needle&looper thread/Cuchillla no corta hilo aguja/enlazador     1.812e-01
# cause_descLack of bobbin case brake / Freno de caja de bobina faltante                        6.293e-01
# cause_descLack of ventilation in Engine / Falta de ventilación en motor                       6.900e-01
# cause_descLooper with rough edges / Superficie de enlazador de cabezal con asperezas         -9.474e-02
# cause_descLoose chain cutter collar / Collarin de corta cadenetas flojo                      -3.677e+00
# cause_descLoose condense cylinder base screw/Tornillos base cilindro condensado flojos        3.594e-01
# cause_descLoose condensed plug wires /Conector de condensado suelto                          -2.309e-02
# cause_descLoose electr. devices in electr. panel / Disp. Eléctr. sueltos en panel eléctr.     1.534e-01
# cause_descLoose engine belt guard / Protector de banda de motor flojo                         1.665e-01
# cause_descLoose eye guard / Protector de ojo flojo                                            6.928e-01
# cause_descLoose finger guard / Protector de dedo flojo                                        5.611e-01
# cause_descLoose folder subjection screw  / Tornillo de sujeción de doblillador flojo          6.402e-01
# cause_descLoose lubrication system hose / Manguera de sistema de lubricación suelta          -2.625e-01
# cause_descLoose machine head Support for pedal  / Soporte de pedal de cabezal suelto          3.270e-01
# cause_descLoose machine head teeth / Soltura de dientes de cabezal                            1.164e-01
# cause_descLoose roll holder guide / Guía de porta rollos floja                               -1.185e+00
# cause_descLoose table / Mesa floja                                                           -2.011e-01
# cause_descLoose thread cone holder / Porta conos flojo                                        7.208e-01
# cause_descLow air pressure in burner / Baja presión de aire en quemador                       1.621e-01
# cause_descLow air pressure in chain cutter / Baja presión de aire en corta cadenetas         -7.255e-01
# cause_descLow air pressure in pneumatic engine / Baja presión de aire en motor neumático      1.488e-01
# cause_descLow air pressure in stacker / Baja presión de aire en apilador                      1.206e-01
# cause_descLow air pressure in trim off knife / Baja presión de aire en corta tela             1.423e+00
# cause_descLow oil level in lubr. system / Nivel de aceite bajo en sistema de lubricación      1.455e-01
# cause_descMisadjusted bobbin case thd tensor/ Tensor de hilo de caja de bobina desajustado   -1.392e-01
# cause_descMisadjusted chain cutter knife / Cuchilla de corta cadeneta desajustada             2.059e-01
# cause_descMisadjusted chain cutter moving knife/Cuchilla móvil corta cadeneta mal estado      3.805e-01
# cause_descMisadjusted compressed air pressure / Presión de aire comprimido desajustado        1.293e+00
# cause_descMisadjusted control box / Caja de control desajustada                               6.489e-02
# cause_descMisadjusted feeding and ndl movement/Movmto de alimentación y aguja desajustado    -1.319e-01
# cause_descMisadjusted feeding roll / Rodo de alimentación desajustado                         1.160e-01
# cause_descMisadjusted finger guard / Dedo posicionador de cabezal en mal ajustado            -7.715e-02
# cause_descMisadjusted finger guard / Dedo posicionador mal ajustado                          -1.645e-01
# cause_descMisadjusted folder guide / Guía de doblillador desajustadas                        -1.081e-01
# cause_descMisadjusted guide / Guía desajustada                                                2.915e+00
# cause_descMisadjusted hook set / Conjunto de el garfio mal ajustados                          2.381e-01
# cause_descMisadjusted hook set / Conjunto de garfios mal ajustados                            3.167e-01
# cause_descMisadjusted machine head chopper / Cuchilla de cabezal desajustada                  1.059e-01
# cause_descMisadjusted machine head looper / Enlazador de cabezal desajustado                  1.912e-01
# cause_descMisadjusted machine head needle bar / Barra de aguja de cabezal desajustada         2.446e-01
# cause_descMisadjusted machine head needle guard / Guarda aguja de cabezal desajustada         2.689e-01
# cause_descMisadjusted machine head presser foot / Prensatela de cabezal desajustado           2.119e-01
# cause_descMisadjusted machine head teeth / Dientes de cabezal desajustados                    1.482e-01
# cause_descMisadjusted machine head thd frame guide/ Marco guía hilo de cabezal desajustado    1.161e-01
# cause_descMisadjusted presser foot bar /Barra de prensatela desajustada                       6.536e-01
# cause_descMisadjusted printing head (switch S2-S3) / Cabezal desajustado (inter. S2-S3)      -2.920e-01
# cause_descMisadjusted roll tensor / Tensor de rollos desajustado                             -1.251e-01
# cause_descMisadjusted rotation detector unit /Posicionador desajustado                       -3.477e-01
# cause_descMisadjusted sensor / Sensor desajustado                                            -4.298e-01
# cause_descMisadjusted Sensor for cloth detection / Sensor detector de tela mal calibrado     -2.480e-01
# cause_descMisadjusted servomotor magnet brake / Imán de freno de servomotor desajustado       5.490e-01
# cause_descMisadjusted servomotor sensor / Sensor de servomotor en mal calibrado               2.432e-02
# cause_descMisadjusted servomotor thermal relay  / Relé térmico de servomotor mal calibrado    6.946e-02
# ...
# mechanicDENY RAYMUNDO PUCH POOL                                                              ***
# mechanicDIEGO CUELLAR                                                                        ***
# mechanicDouglas Alonso Bonilla Soriano                                                       ***
# mechanicDouglas del Cid                                                                      ***
# mechanicDOUGLAS LEONEL CHAVEZ                                                                ***
# mechanicDouglas Leonel Chavez Bonilla
# mechanicEdgar Arevalo                                                                        ***
# mechanicEDIL BERRIOS                                                                         *
# mechanicEDIS MAREL RODRIGUEZ                                                                 ***
# mechanicEdra Alvarado                                                                        **
# mechanicEduardo Antonio Flores Campos                                                        ***
# mechanicEDWIN ALEXANDER CAMPOS                                                               ***
# mechanicEdwin Colindres                                                                      ***
# mechanicEdwin Edgardo Castillo Giron
# mechanicEdwin Froylan Turcios                                                                ***
# mechanicEdwin Rogelio Galeas Perez                                                           ***
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                          ***
# mechanicEmilio Zeledon Lopez                                                                 ***
# mechanicEnrique Pech Canul                                                                   ***
# mechanicErick Garcia Lima                                                                    ***
# mechanicErick Salazar                                                                        ***
# mechanicErlin Sabillon                                                                       ***
# mechanicEver Alfredo Flores Molina                                                           ***
# mechanicFABIAN POSADAS                                                                       ***
# mechanicFabit Aranda                                                                         ***
# mechanicFAULO VICENTE TEC TORRES                                                             ***
# mechanicFernando Alexander Pubill Quintanilla                                                ***
# mechanicFLORES CAMPOS EDUARDO ANTONIO                                                        *
# mechanicFrancisco Antonio Hernandez                                                          ***
# mechanicFranqui Garcia                                                                       ***
# mechanicFUENTES LIMA NESTOR MAURICIO                                                         ***
# mechanicGabriel Sanchez                                                                      ***
# mechanicGARCIA GOMEZ FRANQUI ALIRIO                                                          *
# mechanicGeovanny  Felipe Rivera                                                              ***
# mechanicGerardo Arturo de la Cruz Lemus                                                      ***
# mechanicGilberto Antonio Flores                                                              ***
# mechanicGiovanny Alexander Rivas                                                             ***
# mechanicGuillermo Alfonso Ramirez Landaverde                                                 ***
# mechanicGUILLERMO CASTRO                                                                     *
# mechanicGuillermo Josue Lara Ferman                                                          ***
# mechanicHarley Antonio Valiente                                                              ***
# mechanicHector Antonio Alfaro
# mechanicHector Montoya                                                                       ***
# mechanicHenry Valdez                                                                         ***
# mechanicHerbert Amilcar Montiel Sosa                                                         ***
# mechanicHERIBERTO GARCIA                                                                     ***
# mechanicHugo Hernandez                                                                       ***
# mechanicIGNACIO COB                                                                          ***
# mechanicImmer Sanchez                                                                        ***
# mechanicIsaias Santiago Hernandez                                                            ***
# mechanicJaime Armando Campos                                                                 *
# mechanicJaime Juarez                                                                         **
# mechanicJaime Rivera                                                                         ***
# mechanicJAIRO NATAEL CALIX                                                                   ***
# mechanicJarim Martinez                                                                       ***
# mechanicJeffrey Velasquez                                                                    ***
# mechanicJERONIMO FUNEZ                                                                       ***
# mechanicJimmy Bardales                                                                       ***
# mechanicJoel Elias Chica Bran                                                                ***
# mechanicJoel Ernesto Cuellar Vanegas                                                         ***
# mechanicJonathan Ceceres
# mechanicJony Bladimir Dominguez Alvarado                                                     ***
# mechanicJordy Cedillos                                                                       ***
# mechanicJorge Lopez                                                                          **
# mechanicJorge Ramos                                                                          ***
# mechanicJOSE AGUILAR                                                                         ***
# mechanicJOSE ALVARENGA
# mechanicJose Luis Hernandez                                                                  ***
# mechanicJose Luis Rodriguez                                                                  ***
# mechanicJose Manuel Perez Zepeda                                                             ***
# mechanicJose Maria Canul Tec                                                                 ***
# mechanicJOSE MAURICIO VELASQUEZ ASCENCIO                                                     ***
# mechanicJose Max Reyes Flores                                                                ***
# mechanicJOSE MENDOZA                                                                         **
# mechanicJOSE PEDRO DZUL PECH                                                                 ***
# mechanicJose Valencia                                                                        ***
# mechanicJosue Zalmeron                                                                       ***
# mechanicJuan Absalon Portillo Lemus                                                          ***
# mechanicJuan Antonio Leiva
# mechanicJuan Carlos Lemus
# mechanicJuan Francisco Cardona Hernandez                                                     ***
# mechanicJUAN GONZALEZ                                                                        ***
# mechanicJuan Huezo                                                                           ***
# mechanicJuan Leiva                                                                           ***
# mechanicJuan Manuel Interiano Zaldana
# mechanicJulia Margarita Chicas Diaz                                                          *
# mechanicJulio Oswaldo Rosales                                                                ***
# mechanicKenneth Emerson Clavel Flores                                                        ***
# mechanicKevin Gomez                                                                          ***
# mechanicLadislao Monterrosa Torres                                                           ***
# mechanicLeonardo Cortez                                                                      ***
# mechanicLeonardo Villanueva                                                                  ***
# mechanicLEONEL CHAVEZ                                                                        ***
# mechanicLucas Mejia                                                                          ***
# mechanicLuis Duran
# mechanicLuis Ernesto de la Rosa Garcia                                                       ***
# mechanicLuis Manuel Garcia Rosales                                                           ***
# mechanicLUIS PECH                                                                            ***
# mechanicMarco Anthonio                                                                       ***
# mechanicMarco Enmanuel Osorio Palacios
# mechanicMarcos Emmanuel Osorio Palacios                                                      ***
# mechanicMARCOS MOGUEL                                                                        ***
# mechanicMarvin Betancourth                                                                   ***
# mechanicMarvin Ernesto Melara Figueroa                                                       ***
# mechanicMarvin Pineda                                                                        ***
# mechanicMAURICIO DAVILA SANCHEZ                                                              ***
# mechanicMauricio Ernesto Valencia                                                            ***
# mechanicMelvin Galeano                                                                       ***
# mechanicMiguel Angel Fajardo Ortiz                                                           .
# mechanicMONTOYA HECTOR AMERICO                                                               ***
# mechanicNelson Amilcar Rodriguez Salazar                                                     ***
# mechanicNelson Delgado
# mechanicNELSON GUILLEN                                                                       **
# mechanicNERY MENA RODRIGUEZ                                                                  ***
# mechanicNestor Mauricio Carpio Salas                                                         ***
# mechanicNestor Mauricio Fuentes Lima                                                         **
# mechanicNoe Alexander Caballero Flores                                                       ***
# mechanicNOE CONTRERAS                                                                        ***
# mechanicOdil Alfredo Guzman Saget                                                            *
# mechanicOdil Alfredo Saget Guzman
# mechanicOmar Maldonado                                                                       ***
# mechanicOscar Argumedo                                                                       ***
# mechanicOscar Hurtado                                                                        **
# mechanicPedro Miguel Martinez Linares
# mechanicRafael Esquivel                                                                      ***
# mechanicRAMIREZ RIVERA ABEL ALBERTO
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                          ***
# mechanicRAMON VILLANUEVA                                                                     ***
# mechanicRaul Coto
# mechanicREYES JAVIER CORTEZ CANTE                                                            ***
# mechanicReynaldo Chavez Guerra
# mechanicRichard Lara                                                                         ***
# mechanicRichard Steven                                                                       ***
# mechanicRIVAS TORRES CARLOS ANTONIO
# mechanicRoberto Reyes                                                                        **
# mechanicROMAN IGNACIO AYALA PUC                                                              ***
# mechanicRonald Antonio Herrera                                                               ***
# mechanicRonald Fabricio Hernandez Rivas                                                      .
# mechanicSalvador Roberto Palacios Alvarado                                                   *
# mechanicSalvador Rodriguez                                                                   ***
# mechanicSANCHEZ IMMER ALBERTO                                                                .
# mechanicSAUL ALFARO                                                                          ***
# mechanicSaul Nolberto Alfaro                                                                 **
# mechanicSolmar Elias Hernandez Mezquita                                                      ***
# mechanicSolmar Elias Mezquita                                                                ***
# mechanicVictor Alfonzo Ardon Monteros                                                        ***
# mechanicVladimir Enrique Aguilar Hernandez                                                   ***
# mechanicWalter Anibal Belloso Hernandez                                                      .
# mechanicWalter Bladimir Garcia Patino
# mechanicWalter Patino                                                                        ***
# mechanicWALTER RENE SIERRA VARGAS                                                            ***
# mechanicWilliam Alexander Arevalo Leiva                                                      ***
# mechanicWillian Tejada                                                                       ***
# mechanicWILMER CRUZ                                                                          ***
# mechanicWilmer Zamora                                                                        ***
# mechanicXavier Jose Mendoza                                                                  ***
# parts_cost                                                                                   ***
# Days_Between_Failures                                                                        ***
# Cumulative_Failure_Count                                                                     ***
# Median_Repair_Time                                                                           ***
# Cumulative_Maintenance_Cost                                                                  **
# Age                                                                                          ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.484 on 134900 degrees of freedom
# Multiple R-squared:  0.2402,	Adjusted R-squared:  0.2348
# F-statistic: 44.47 on 959 and 134900 DF,  p-value: < 2.2e-16

# %% [markdown]
# **MODELO AGREGANDO LA VARIABLE "MECHANIC ANTIQUITY"**

# %%
df_merged2 <- df_merged %>%
  left_join(df_mechanic %>% select(mechanic, antiquity), by = "mechanic")

# %%
# Inicializar y ajustar el modelo de regresión lineal
model4 <- lm(downtime_gross~. -equipment -downtime_gross -repair_hours -date -changed_pcs, data = df_merged2)
# Resumen del modelo
summary(model4)
# Out:
# Call:
# lm(formula = downtime_gross ~ . - equipment - downtime_gross -
#     repair_hours - date - changed_pcs, data = df_merged2)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -9.3915 -0.7986 -0.2544  0.2798 12.8762
#
# Coefficients: (10 not defined because of singularities)
#                                                                                                Estimate
# (Intercept)                                                                                  -1.099e+00
# operationATTACH ELASTIC                                                                       1.156e-01
# operationBARTACK                                                                              1.856e-01
# operationBIND ARM                                                                            -1.973e-01
# operationBIND ARMHOLE                                                                        -1.357e-02
# operationBIND LEG                                                                            -1.364e-02
# operationBIND NECK                                                                           -2.570e-01
# operationBUTTON                                                                               2.924e-02
# operationBUTTON HOLE                                                                          2.443e-01
# operationCLOSE CUFF                                                                           1.696e-01
# operationCLOSE INSEAM                                                                         1.118e-01
# operationCLOSE NECK                                                                           3.933e-03
# operationCLOSE POCKET                                                                         4.490e-03
# operationCLOSE SLEEVE                                                                         5.605e-01
# operationCOVER STITCH                                                                         1.017e-01
# operationCOVER STITCH WAIST                                                                   7.672e-01
# operationCUT AND CLOSE ELASTIC                                                                1.173e-01
# operationFIRST SIDE                                                                           3.098e-01
# operationFLAT LOCK                                                                           -4.099e-02
# operationFLAT SEAM                                                                            1.902e-03
# operationGROMMET                                                                              2.593e-01
# operationHEM AROUND                                                                           3.629e-01
# operationHEM BOTTOM                                                                           6.652e-02
# operationHEM HOOD                                                                            -1.296e-01
# operationHEM LEG                                                                              1.436e-01
# operationHEM POCKET                                                                          -2.014e-02
# operationHEM SLEEVE                                                                           7.850e-01
# operationHEM SLEEVE AUTO                                                                      8.905e-01
# operationHEM SLEEVE MAN                                                                       4.104e-01
# operationJOIN LEG                                                                             6.784e-04
# operationJOIN PANEL                                                                           5.982e-02
# operationJOIN SHOULDER                                                                        9.990e-02
# operationLOCK STITCH                                                                          1.752e-01
# operationP. LABEL                                                                            -1.025e+00
# operationPLACKET TOPSTITCH                                                                    3.086e-01
# operationPRECLOSE ELASTIC                                                                     3.583e-01
# operationSECOND SIDE                                                                          2.590e-01
# operationSERGE ELASTIC                                                                        4.145e-01
# operationSET BAND                                                                             2.873e-01
# operationSET COLLAR                                                                           1.429e-01
# operationSET CUFF                                                                             2.602e-01
# operationSET HOOD                                                                             1.086e-01
# operationSET POCKET                                                                           1.128e-01
# operationSET SLEEVE                                                                           1.699e-02
# operationSEW ELASTIC                                                                         -2.685e-02
# operationSEW ELASTIC WAIST                                                                   -7.706e-02
# operationSEW PANEL                                                                            2.178e-02
# operationSIDE SEAM                                                                            1.411e-01
# operationTAPE SHOULDER                                                                        7.231e-03
# operationTOP STITCH                                                                           2.465e-02
# operationTOP STITCH BAND                                                                     -4.428e-02
# operationTOP STITCH COLLAR                                                                    1.448e-01
# operationTOP STITCH HOOD                                                                     -6.858e-02
# operationTOP STITCH POCKET                                                                    2.537e-01
# operationTOP STITCH SEAM CROTCH                                                              -5.179e-02
# operationTOP STITCH SLEEVE                                                                    1.841e-01
# operationTOP STITCH SLEEVE AND BAND                                                          -8.548e-02
# operationTOP STITCH WAIST BAND                                                                7.692e-02
# operationTUBE FLY                                                                            -1.766e-01
# base_model504-E256                                                                           -3.422e-01
# base_model504-E51                                                                            -6.716e-02
# base_model504-ETS51                                                                          -4.227e-01
# base_model83SP                                                                               -1.402e-01
# base_modelA4                                                                                 -9.447e-02
# base_modelAZ8003                                                                             -1.820e-01
# base_modelAZ8203                                                                              2.566e-01
# base_modelAZ8403                                                                             -2.769e-01
# base_modelAZ8412                                                                             -5.574e-01
# base_modelAZ8420                                                                             -8.814e-02
# base_modelAZ8451                                                                             -6.242e-01
# base_modelAZF8420                                                                            -7.676e-01
# base_modelB-100                                                                              -4.262e-01
# base_modelBE-438D                                                                            -2.409e-01
# base_modelBE-438FX                                                                            2.462e-01
# base_modelC5                                                                                 -9.108e-02
# base_modelC5-3-02/233                                                                        -2.699e-01
# base_modelC5-4-M03                                                                           -1.854e-01
# base_modelC5S-4-M03                                                                          -1.974e-01
# base_modelCSA-2516D-03                                                                       -4.019e-01
# base_modelCSA-2604                                                                            6.300e-02
# base_modelCSA-2604-02                                                                        -2.127e-01
# base_modelCSC-2614                                                                           -3.264e-01
# base_modelCSC-2614-M03                                                                       -4.393e-01
# base_modelCW522AN                                                                            -8.623e-01
# base_modelDB2-B737                                                                            2.153e-01
# base_modelDDL-5550                                                                           -1.472e-01
# base_modelDDL5550                                                                            -1.788e-01
# base_modelDDL8500                                                                            -9.780e-02
# base_modelDDL8700                                                                            -2.469e-01
# base_modelDLN-5410                                                                           -1.293e-01
# base_modelDLN5410                                                                            -8.799e-02
# base_modelDT6L2512                                                                           -1.254e-01
# base_modelE256                                                                                1.423e-01
# base_modelE51-141                                                                            -1.080e-01
# base_modelEX5104                                                                             -1.368e-01
# base_modelEX5114                                                                             -3.017e-01
# base_modelEX5204                                                                             -1.913e-01
# base_modelEX5214                                                                             -1.433e-01
# base_modelEXT5114                                                                            -2.728e-01
# base_modelFD-62                                                                              -2.066e-01
# base_modelFD62                                                                                8.734e-02
# base_modelICN B-100                                                                           7.503e-01
# base_modelICN-2200                                                                            4.665e-01
# base_modelJ-261                                                                               1.053e-01
# base_modelJK-797DI                                                                           -2.905e-01
# base_modelJK-798DI                                                                           -2.409e-01
# base_modelJK-798DIII                                                                         -2.883e-01
# base_modelJK-8670BDII                                                                        -8.509e-02
# base_modelJK-SHIRLEY-IIE                                                                     -1.484e-01
# base_modelJK-T1790BK                                                                         -1.189e-01
# base_modelJK-T1790BS                                                                         -5.967e-01
# base_modelJK-T1903BR                                                                          3.499e-01
# base_modelJK-T1903GR                                                                                 NA
# base_modelJK-T1904                                                                           -3.412e-01
# base_modelJK-T1904A                                                                          -8.025e-02
# base_modelJK-T1904BS                                                                         -1.971e-01
# base_modelJKT1904A                                                                           -1.811e-01
# base_modelJS-2261                                                                             3.234e-02
# base_modelKE-430D                                                                            -2.611e-01
# base_modelKE430F                                                                             -1.126e-01
# base_modelLBH1790                                                                             2.993e-02
# base_modelLC62D                                                                               3.354e-03
# base_modelLC62D-12                                                                           -1.808e-01
# base_modelLDA-L26                                                                            -5.461e-02
# base_modelLK1900                                                                             -1.621e-01
# base_modelLK1910                                                                             -1.009e+00
# base_modelLK1920                                                                             -3.683e-01
# base_modelLT2-B842                                                                           -1.591e-01
# base_modelLT2-B872                                                                           -1.185e-01
# base_modelMH380                                                                              -2.533e-01
# base_modelMJ2600                                                                             -1.749e-02
# base_modelMJ2600SD                                                                            3.775e-01
# base_modelS7200                                                                               1.416e-01
# base_modelSP161                                                                               2.395e-01
# base_modelSP172                                                                               1.597e-02
# base_modelT-8422A                                                                            -1.304e-01
# base_modelT-8722B                                                                            -1.769e-01
# base_modelUS39500                                                                            -9.298e-02
# base_modelVC1700                                                                             -1.117e-01
# base_modelVC2700                                                                             -1.295e-01
# base_modelVC2711                                                                             -1.359e-01
# base_modelVC2713                                                                             -1.600e-01
# base_modelVC2735                                                                              2.323e-02
# base_modelVC2785                                                                             -5.907e-01
# base_modelVC3845                                                                             -1.122e-01
# base_modelVC3845P                                                                            -7.226e-02
# base_modelVE2700                                                                             -1.451e-01
# base_modelVE2711                                                                              1.175e-02
# base_modelVE2713                                                                             -1.440e-01
# base_modelVEU2703                                                                             2.036e-01
# base_modelVF2400                                                                             -1.828e-01
# base_modelVF2403                                                                              9.077e-02
# base_modelVF2439                                                                              2.806e-01
# base_modelVF2500                                                                             -2.427e-01
# base_modelVF2503                                                                              1.908e-01
# base_modelVF2529                                                                              9.420e-01
# base_modelVF2529G                                                                             4.524e-01
# base_modelVF2539                                                                              2.996e-01
# base_modelVF2560                                                                              3.104e-03
# base_modelVF64228                                                                             7.590e-02
# base_modelVFF2503                                                                             2.446e-02
# base_modelVG2700                                                                             -8.742e-02
# base_modelVG2711                                                                              1.451e-01
# base_modelVG2713                                                                             -9.589e-02
# base_modelVG2735                                                                              1.882e-03
# base_modelVM1804                                                                              2.259e-01
# base_modelW1500                                                                               3.156e-01
# base_modelW1562                                                                              -1.287e-02
# base_modelW264                                                                                1.822e-01
# base_modelW3522P                                                                             -9.174e-02
# base_modelW4-D                                                                                4.843e-01
# base_modelW500                                                                               -9.160e-02
# base_modelW542                                                                               -2.271e-01
# base_modelW562                                                                                3.197e-02
# base_modelW600                                                                               -1.442e-02
# base_modelW664                                                                               -1.601e-02
# base_modelWT500                                                                              -4.777e-01
# base_modelWT542                                                                               2.259e-02
# base_modelWT562                                                                              -5.771e-03
# problem_descFruncido/ Pucker                                                                  1.550e+00
# problem_descFuga de aire comprimido detectada/Compressed air leak detected                   -6.181e-01
# problem_descIt cuts the cloth with defect / Corta tela con defecto                            5.756e-01
# problem_descIt does not coil / No enrolla                                                     3.384e-01
# problem_descIt does not cut the cloth / No corta la tela                                      3.702e-01
# problem_descIt does not cut the thread / No corta el hilo                                     5.549e-01
# problem_descIt does not cut the trim off / No corta el desperdicio                            4.830e-01
# problem_descIt does not feed cloth / No alimenta tela                                         5.952e-01
# problem_descIt does not guarantee safety / No garantiza la seguridad                          4.801e-01
# problem_descIt does not label / No etiqueta                                                   2.501e-01
# problem_descIt does not light / No alumbra                                                    2.500e+00
# problem_descIt does not look properly / No luce adecuadamente                                 6.501e-01
# problem_descIt does not lubricate / No lubrica                                                4.386e-01
# problem_descIt does not pile up / No apila                                                    7.958e-01
# problem_descIt does not sew / No cose                                                         4.480e-01
# problem_descIt labels with defect / Etiqueta con defecto                                      8.718e-01
# problem_descIt piles up with defect / Apila con defecto                                       5.457e-01
# problem_descIt sews with defect / Cose con defecto                                            5.627e-01
# problem_descNo acciona el Rodo / Dont activate Roll                                           6.219e-01
# problem_descNo pega Grommet/Not set grommet                                                   5.645e-01
# problem_descPedal no Acciona Motor / Pedal not activates motor                                7.996e-01
# problem_descRemacha Grommet con defecto/ Rivet Grommet with defect                            3.860e-01
# problem_descSellado Debil/ Weak Sealed                                                        1.446e+00
# failure_descBurner failure / Falla quemador                                                   1.868e+00
# failure_descButton spiral failure/Falla de espiral de botón                                   1.658e+00
# failure_descChain cutter failure / Falla corta cadenetas                                      1.789e+00
# failure_descDesajuste Pattern Wheel y Circular plate / Patter Wheel misadjustment             3.807e+00
# failure_descDesgaste de Pattern Wheel / Pattern Wheel worn                                    6.623e-01
# failure_descElectric panel failure / Falla pánel eléctrico                                    1.814e+00
# failure_descEngine failure / Falla motor                                                      1.887e+00
# failure_descFalla cabezal remachando Grommet con defecto / Head failure riveting grommet wit  2.186e-01
# failure_descFalla sistema de aire comprimido / Compressed air supply system failure           1.449e+00
# failure_descFeeding device failure / Falla dispositivo de alimentación                        1.698e+00
# failure_descFolder failure / Falla doblillador                                                2.025e+00
# failure_descLighting lamp failure / Falla lámpara de iluminación                              1.928e+00
# failure_descLubrication system failure / Falla sistema de lubricación                         1.969e+00
# failure_descMachine head failure it does not look properly / Falla cabezal en su apariencia   2.341e+00
# failure_descMachine head failure it stops labeling / Falla cabezal dejando de etiquetar       1.832e+00
# failure_descMachine head failure not riveting/Falla cabezal no remachando                    -4.995e+00
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defecto      1.682e+00
# failure_descMachine head failure stopping sewing  / Falla cabezal dejando de coser            1.759e+00
# failure_descMachine head labeling with defect / Falla cabezal etiquetando con defecto         1.968e+00
# failure_descMonitoring and control failure / Falla monitoreo y control                        1.938e+00
# failure_descPneumatic engine failure / Falla motor neumático                                  1.963e+00
# failure_descRoll holder failure / Falla porta rollo                                           1.740e+00
# failure_descSafety guard failure / Falla protectores                                          1.670e+00
# failure_descServomotor failure / Falla servomotor                                             1.656e+00
# failure_descSpindle cap failure /Falla tapa de sujeción del pin                               3.451e+00
# failure_descSpindle die failure not punching out/Falla dado de corte no perforando            1.213e+00
# failure_descStacker  piling up with defect / Falla apilador dejando de apilar con defecto     2.126e+00
# failure_descStacker failure it stops piling up / Falla apilador dejando de apilar             1.575e+00
# failure_descSwitch failure / Falla interruptor                                                1.317e+00
# failure_descTable failure generating defect / Falla mesa generando defecto                    1.836e+00
# failure_descTable failure in its safety / Falla mesa en su seguridad                          1.876e+00
# failure_descTable failure it does not look properly / Falla mesa en su apariencia             1.225e+00
# failure_descThread holder failure / Falla torre de hilo                                       2.019e+00
# failure_descThread winder failure / Falla devanador de hilo                                   2.476e+00
# failure_descTrim off device cutting with defect /Dispositivo corta tela cortando con defecto  2.691e+00
# failure_descTrim off device failure / Falla dispositivo corta desperdicio                     1.561e+00
# failure_descTrim off device stops cutting/Falla dispositivo corta tela deja de cortar         1.686e+00
# cause_descBanda motor-volante de maquina Grommet dañada / Damaged Grommet machine steering    6.921e+00
# cause_descBase de quemador desajustada / Burner base out of adjustment                        1.291e-01
# cause_descBlocked button spiral /Espiral de botón obstruida                                   2.388e+00
# cause_descBlunt spindle die / Dado de corte sin filo                                         -1.230e+00
# cause_descBlunt trim off knife / Cuchilla de corta tela desafilada                           -6.845e-02
# cause_descBobbin case placed incorrectly / Caja de bobina mal colocada                       -7.786e-01
# cause_descBrazo de prensatela dañado / Damaged presser foot arm                              -4.045e-03
# cause_descBroken feeding belt / Rotura de banda de alimentación                               2.815e-01
# cause_descBroken fuse / Rotura de fusible                                                     1.140e+00
# cause_descBroken knife of machine head / Rotura de cuchilla de cabezal                        2.585e-01
# cause_descBroken lubr. system spatter  / Rotura de salpicadores en sistema de lubricación    -1.352e+00
# cause_descBroken machine head ball joint / Rotura de biela de cabezal                         6.502e-01
# cause_descBroken machine head feeding bar / Rotura de barra de alimentación de cabezal        1.141e+00
# cause_descBroken machine head looper / Rotura de enlazador de cabezal                         1.681e-01
# cause_descBroken machine head needle / Rotura de aguja de cabezal                             1.431e-01
# cause_descBroken machine head needle guard / Rotura de guarda aguja de cabezal                1.269e-01
# cause_descBroken machine head needle plate / Rotura de placa de aguja de cabezal             -8.712e-02
# cause_descBroken machine head presser foot  / Rotura de prensatela de cabezal                -6.819e-02
# cause_descBroken machine head timing belt / Rotura de banda de tiempo de cabezal             -1.106e-01
# cause_descBroken motor v-belt/Banda de motor en mal estado o rota                             1.970e-01
# cause_descBroken needle plate finger / Rotura de lengueta placa de aguja de cabezal           3.225e-01
# cause_descBroken or splintered table edges / Bordes de mesa quebrados o astillados           -1.403e-01
# cause_descBroken solenoid valve / Rotura de válvula del solenoide                             9.120e-01
# cause_descBroken teeth of machine head / Rotura de dientes de cabezal                         4.268e-01
# cause_descBurner transformer in poor condition / Transformador de quemador en mal estado      4.442e-01
# cause_descCaja de quemador dañada / Damaged burner box                                       -3.053e+00
# cause_descClogged lubrication system hose / Manguera de sistema de lubricación atascada       5.620e-01
# cause_descComponente del sistema de aire comprimido dañado / Compressed air system compone   -7.755e-01
# cause_descContamination water in pneumatic engine / Contaminación agua en motor neumático     8.117e-01
# cause_descCtrol table param out of specs/Parámetros de ctrol de mesa fuera de especif.       -3.375e-01
# cause_descCup hook in poor condition / Canastilla en mal estado                               9.290e-02
# cause_descDamaged  chain cutter fixed knife / Cuchilla fija corta cadenetas en mal estado     6.991e-01
# cause_descDamaged  moving knife shaft /Eje cuchilla móvil corta desperdicio en mal estado     2.173e-01
# cause_descDamaged bobbin / Bobina en mal estado                                               3.469e-01
# cause_descDamaged bobbin case brake / Freno de caja de bobina en mal estado                   3.118e-01
# cause_descDamaged bobbin case thd tensor / Tensor de hilo de caja de bobina en mal estado    -1.482e-02
# cause_descDamaged burner resistance / Resistencia de quemador en mal estado                   1.651e-01
# cause_descDamaged burner thermostat / Termostato de quemador en mal estado                    1.172e+00
# cause_descDamaged chain cutter collar / Collarin de corta cadenetas en mal estado            -1.826e+00
# cause_descDamaged chain cutter cylinder  / Cilindro de corta cadenetas en mal estado          5.690e-01
# cause_descDamaged chain cutter humphrey clevis /Horquilla de corta cadenetas en mal estado    2.592e-01
# cause_descDamaged chain cutter knife / Cuchilla de corta cadeneta en mal estado               6.880e-01
# cause_descDamaged chain cutter mov knife axle/Eje cuchilla móv corta cadenetas mal estado    -7.085e-01
# cause_descDamaged chain cutter screw / Tornillo de corta cadenetas en mal estado             -3.760e-01
# cause_descDamaged circuit card / Tarjeta de circuito en mal estado                            7.524e-01
# cause_descDamaged control box / Caja de control en mal estado                                 3.329e-01
# cause_descDamaged conveyor belt / Banda transportadora de mesa en mal estado                  3.289e-01
# cause_descDamaged detachment plate / Placa de desprendimeinto de cabezal en mal estado       -3.477e-01
# cause_descDamaged differential feeding box / Caja reductora de alimentación en mal estado    -6.392e-02
# cause_descDamaged electrical panel cable / Cable de panel eléctrico en mal estado             8.192e-01
# cause_descDamaged electrical panel contactor / Contactor de panel eléctrico en mal estado     7.828e-01
# cause_descDamaged electrical panel drive / Variador de panel eléctrico en mal estado          1.480e+00
# cause_descDamaged electrical panel fuse / Fusible de panel eléctrico en mal estado            4.079e-01
# cause_descDamaged electrical panel terminal / Terminal de panel eléctrico en mal estado       7.888e-01
# cause_descDamaged engine bearing / Rodamiento de motor en mal estado                          6.492e-02
# cause_descDamaged engine belt guard / Protector de banda de motor en mal estado              -1.380e-02
# cause_descDamaged engine bobbin / Bobina de motor en mal estado                               7.120e-02
# cause_descDamaged engine clutch / Embrague de motor en mal estado                             1.177e+00
# cause_descDamaged Engine for trim off system / Motor corta desperdicio en mal estado          1.195e-01
# cause_descDamaged engine rotor / Rotor de motor en mal estado                                -2.531e-01
# cause_descDamaged eye guard / Protector de ojo en mal estado                                 -5.342e-01
# cause_descDamaged feeding axis / Eje de alimentación en mal estado                            1.846e-01
# cause_descDamaged feeding roll / Rodo de alimentación en mal estado                           5.288e-01
# cause_descDamaged feeding transmis. cable/Cable transmisión de alimentación en mal estado     1.469e+00
# cause_descDamaged finger guard / Protector de dedo en mal estado                             -2.041e-01
# cause_descDamaged folder guide / Guía de doblillador en mal estado                           -2.646e-01
# cause_descDamaged folder guide base / Base de doblillador en mal estado                      -2.064e-01
# cause_descDamaged lubr syst hose connector/Conector manguera de sist. lubr. en mal estado     9.686e-01
# cause_descDamaged lubr syst worm wheel/Engranaje acople de sistema de lubr en mal estado      9.504e-01
# cause_descDamaged lubr Syst. oil filter screen/Filtro retorno de sist de lubr. mal estado     2.474e-02
# cause_descDamaged lubric. syst. main filter / Filtro princ. de sist. lubr. en mal estado     -1.067e+00
# cause_descDamaged lubricant / Lubricante en mal estado                                       -2.709e-01
# cause_descDamaged lubrication system hose/Manguera sistema de lubricación en mal estado       6.714e-01
# cause_descDamaged lubrication system pump / Bomba de sistema de lubricación en mal estado     8.207e-01
# cause_descDamaged machine head axle casings / Buje de cabezal en mal estado                   7.947e-01
# cause_descDamaged machine head bearings / Rodamiento de cabezal en mal estado                 5.627e-01
# cause_descDamaged machine head cup hook / Canastilla de cabezal en mal estado                 1.915e-01
# cause_descDamaged machine head looper / Enlazador de cabezal en mal estado                   -2.496e-02
# cause_descDamaged machine head needle / Aguja de cabezal en mal estado                       -4.231e-01
# cause_descDamaged machine head painting / Pintura de cabezal en mal estado                    3.386e+00
# cause_descDamaged machine head teeth / Dientes de cabezal en mal estado                       3.927e-01
# cause_descDamaged machine head tension disc / Disco de tensión de cabezal en mal estado       4.477e-01
# cause_descDamaged machine head thread guide / Guía hilo de cabezal en mal estado             -1.345e-01
# cause_descDamaged machine head thread take up / Leva de cabezal en mal estado                -9.205e-02
# cause_descDamaged maintenance unit / Unidad de mantenimiento en mal estado                    1.959e-01
# cause_descDamaged monitor and control screen /Pantalla de monitoreo y ctrol en mal estado    -8.461e-02
# cause_descDamaged movement changer main tooth/Cambiador movimto diente princ en mal estado    3.122e-01
# cause_descDamaged movmt changer differ tooth /Cambiador de movmto diente difer. mal estado   -3.875e-01
# cause_descDamaged needle thread guide / Deflector de hilo de cabezal en mal estado            3.992e-01
# cause_descDamaged needle thread guide / Deflector de hilo en mal estado                       8.493e-01
# cause_descDamaged PLC of electrical panel / PLC de panel eléctrico en mal estado              1.027e+00
# cause_descDamaged presser foot's tin filling  /Relleno de prensatela en mal estado            1.292e+00
# cause_descDamaged proximity switch / Interruptor de proximidad en mal estado                  6.739e-01
# cause_descDamaged pulley / Polea en mal estado                                                7.515e-01
# cause_descDamaged roll holder base / Base de porta rollos en mal estado                       4.004e-01
# cause_descDamaged roll tensor / Tensor de rollos en mal estado                               -4.046e-01
# cause_descDamaged rotation detector unit /Posicionador en mal estado                          2.367e-01
# cause_descDamaged sensor  / Sensor en mal estado                                              7.552e-03
# cause_descDamaged Sensor for cloth detection / Sensor detector de tela en mal estado          2.206e-01
# cause_descDamaged servomotor bearing / Rodamiento de servomotor en mal estado                 4.651e-01
# cause_descDamaged servomotor control card / Tarjeta de control de servomotor en mal estado    3.904e-01
# cause_descDamaged servomotor rotor / Rotor de servomotor en mal estado                       -1.106e+00
# cause_descDamaged servomotor sensor / Sensor de servomotor en mal estado                     -3.511e-01
# cause_descDamaged servomotor sensor cable / Cable de sensor de servomotor en mal estado       5.361e-01
# cause_descDamaged servomotor terminal / Terminal de servomotor en mal estado                  8.555e-01
# cause_descDamaged solenoid / Solenoide en mal estado                                         -5.518e-01
# cause_descDamaged stacker cylinder / Cilindro de apilador en mal estado                      -2.161e-01
# cause_descDamaged stacker hose / Manguera de apilador en mal estado                          -8.456e-01
# cause_descDamaged stacker humphrey clevis / Horquilla de apilador en mal estado               5.170e-01
# cause_descDamaged stacker regulating valve / Válvula reguladora de apilador en mal estado     8.755e-01
# cause_descDamaged stacker solenoid valve / Electroválvula de apilador en mal estado           3.523e-01
# cause_descDamaged stitch regulator / Regulador de puntada de cabezal en mal estado           -6.607e-03
# cause_descDamaged surface of printing plate / Placa impresión con superficie en mal estado    1.623e-01
# cause_descDamaged switch box / Caja de interruptor en mal estado                              4.188e-01
# cause_descDamaged switch button / Botón de interruptor en mal estado                          1.221e-01
# cause_descDamaged switch cable / Cable de interruptor en mal estado                          -1.006e+00
# cause_descDamaged switch contact / Contacto de interruptor en mal estado                      1.491e+00
# cause_descDamaged switch terminal / Terminal de interruptor en mal estado                     1.350e+00
# cause_descDamaged table painting / coating / Pintura/revestimiento de mesa en mal estado      5.795e-02
# cause_descDamaged thread cone holder / Porta conos en mal estado                             -1.437e+00
# cause_descDamaged thread cutting knife / Cuchillas corta hilo en mal estado                   3.548e-01
# cause_descDamaged thread guide / Guía hilo en mal estado                                      6.327e-01
# cause_descDamaged thread guide base / Base de guía hilo en mal estado                        -3.913e-01
# cause_descDamaged thread length tensor / Tensor auxiliar de largo de hebra en mal estado     -8.675e-01
# cause_descDamaged thread winder tensor / Tensor del devanador en mal estado                  -6.886e-01
# cause_descDamaged thread wiper / Saca hebra en mal estado                                     4.606e-03
# cause_descDamaged timer / Temporizador en mal estado                                         -4.562e-01
# cause_descDamaged trim off engine / Motor de corta desperdicio en mal estado                 -4.624e-01
# cause_descDamaged trim off knife / Cuchilla de corta tela en mal estado                      -6.162e-01
# cause_descDamaged trim off knife ball joint / Biela de corta desperdicio en mal estado        3.964e-01
# cause_descDamaged trim off knife base /Base de cuchilla de corta desperdicio en mal estado    1.135e+00
# cause_descDamaged trim off knife cylinder / Cilindro de corta tela en mal estado             -3.585e-01
# cause_descDamaged trim off knife hose / Manguera de corta tela en mal estado                  1.000e+00
# cause_descDamaged trim off knife position sensor/Sensor posic de corta tela en mal estado     6.229e-01
# cause_descDamaged trim off knife regulat. valve/Válv. reguladora corta tela en mal estado    -7.684e-02
# cause_descDamaged trim off knife solenoid valve/Electroválvula de corta tela en mal estado   -5.121e-01
# cause_descDamaged trim off system bearing / Rodamiento de corta desperdicio en mal estado     5.154e-01
# cause_descDamaged trim off system knife / Cuchilla de corta desperdicio en mal estado         1.551e-01
# cause_descDamaged U-joint with shaft / Cardan de alimentación en mal estado                  -2.800e-02
# cause_descDeprogrammed electrical panel drive / Variador de panel eléctrico desprogramado    -1.589e-01
# cause_descDirty machine head / Cabezal sucio                                                  2.937e-01
# cause_descDirty table / Mesa sucia                                                            1.115e+00
# cause_descDoblillador desajustado / Folder out of adjustment                                 -5.496e-01
# cause_descExcess dirt in servomotor casting/ Suciedad excesiva en la carcasa de servomotor    6.580e-01
# cause_descExcessive dirt in chain cutter / Suciedad excesiva en corta cadenetas              -9.454e-01
# cause_descExcessive dirt in electrical panel / Suciedad excesiva en panel eléctrico           6.130e-01
# cause_descExcessive dirt in machine head / Suciedad excesiva en cabezal                       3.900e-01
# cause_descExcessive dirt in switch contact / Contacto de interruptor sucio                    7.819e-01
# cause_descFaulty connection in burner / Falso contacto en quemador                            3.800e-01
# cause_descFaulty connection in electrical panel / Falso contacto en panel eléctrico           1.138e-02
# cause_descFaulty connection in main switch / Falso contacto en interruptor principal         -4.779e-01
# cause_descFaulty connection in switch / Falso contacto en interruptor                         2.233e-01
# cause_descHigh air pressure in pneumatic engine / Alta presión de aire en motor neumático    -1.065e-01
# cause_descHigh air pressure in stacker / Alta presión de aire en apilador                    -1.840e-01
# cause_descHigh air pressure in trim off guide / Alta presión de aire en corta tela            8.473e-01
# cause_descIncorrdistance spindle die and cap/Dado corte&tapa sujeción a distincorrecta       -1.968e+00
# cause_descIncorrect bobbin / Bobina incorrecta                                               -1.135e+00
# cause_descIncorrect bobbin case / Caja de bobina incorrecta                                  -4.760e-01
# cause_descIncorrect ink formula / Fórmula de tinta incorrecta                                -8.642e-01
# cause_descIncorrect machine head  tension spring /Resorte de tensión de cabezal incorrecto    1.929e-01
# cause_descIncorrect machine head needle / Aguja de cabezal incorrecta                         2.691e-01
# cause_descIncorrect machine head threading / Enhebrado incorrecto en cabezal                  9.582e-02
# cause_descIncorrect size button spiral /Tamaño de espiral de botón  incorrecto                1.649e-01
# cause_descIncorrect threading / Enhebrado incorrecto                                         -2.543e-01
# cause_descIncorrectly installed guard / Protector mal instalado                              -8.948e-01
# cause_descKnife does not cut needle&looper thread/Cuchillla no corta hilo aguja/enlazador     1.812e-01
# cause_descLack of bobbin case brake / Freno de caja de bobina faltante                        6.293e-01
# cause_descLack of ventilation in Engine / Falta de ventilación en motor                       6.900e-01
# cause_descLooper with rough edges / Superficie de enlazador de cabezal con asperezas         -9.474e-02
# cause_descLoose chain cutter collar / Collarin de corta cadenetas flojo                      -3.677e+00
# cause_descLoose condense cylinder base screw/Tornillos base cilindro condensado flojos        3.594e-01
# cause_descLoose condensed plug wires /Conector de condensado suelto                          -2.309e-02
# cause_descLoose electr. devices in electr. panel / Disp. Eléctr. sueltos en panel eléctr.     1.534e-01
# cause_descLoose engine belt guard / Protector de banda de motor flojo                         1.665e-01
# cause_descLoose eye guard / Protector de ojo flojo                                            6.928e-01
# cause_descLoose finger guard / Protector de dedo flojo                                        5.611e-01
# cause_descLoose folder subjection screw  / Tornillo de sujeción de doblillador flojo          6.402e-01
# cause_descLoose lubrication system hose / Manguera de sistema de lubricación suelta          -2.625e-01
# cause_descLoose machine head Support for pedal  / Soporte de pedal de cabezal suelto          3.270e-01
# cause_descLoose machine head teeth / Soltura de dientes de cabezal                            1.164e-01
# cause_descLoose roll holder guide / Guía de porta rollos floja                               -1.185e+00
# cause_descLoose table / Mesa floja                                                           -2.011e-01
# cause_descLoose thread cone holder / Porta conos flojo                                        7.208e-01
# cause_descLow air pressure in burner / Baja presión de aire en quemador                       1.621e-01
# cause_descLow air pressure in chain cutter / Baja presión de aire en corta cadenetas         -7.255e-01
# cause_descLow air pressure in pneumatic engine / Baja presión de aire en motor neumático      1.488e-01
# cause_descLow air pressure in stacker / Baja presión de aire en apilador                      1.206e-01
# cause_descLow air pressure in trim off knife / Baja presión de aire en corta tela             1.423e+00
# cause_descLow oil level in lubr. system / Nivel de aceite bajo en sistema de lubricación      1.455e-01
# cause_descMisadjusted bobbin case thd tensor/ Tensor de hilo de caja de bobina desajustado   -1.392e-01
# cause_descMisadjusted chain cutter knife / Cuchilla de corta cadeneta desajustada             2.059e-01
# cause_descMisadjusted chain cutter moving knife/Cuchilla móvil corta cadeneta mal estado      3.805e-01
# cause_descMisadjusted compressed air pressure / Presión de aire comprimido desajustado        1.293e+00
# cause_descMisadjusted control box / Caja de control desajustada                               6.489e-02
# cause_descMisadjusted feeding and ndl movement/Movmto de alimentación y aguja desajustado    -1.319e-01
# cause_descMisadjusted feeding roll / Rodo de alimentación desajustado                         1.160e-01
# cause_descMisadjusted finger guard / Dedo posicionador de cabezal en mal ajustado            -7.715e-02
# cause_descMisadjusted finger guard / Dedo posicionador mal ajustado                          -1.645e-01
# cause_descMisadjusted folder guide / Guía de doblillador desajustadas                        -1.081e-01
# cause_descMisadjusted guide / Guía desajustada                                                2.915e+00
# cause_descMisadjusted hook set / Conjunto de el garfio mal ajustados                          2.381e-01
# cause_descMisadjusted hook set / Conjunto de garfios mal ajustados                            3.167e-01
# cause_descMisadjusted machine head chopper / Cuchilla de cabezal desajustada                  1.059e-01
# cause_descMisadjusted machine head looper / Enlazador de cabezal desajustado                  1.912e-01
# cause_descMisadjusted machine head needle bar / Barra de aguja de cabezal desajustada         2.446e-01
# cause_descMisadjusted machine head needle guard / Guarda aguja de cabezal desajustada         2.689e-01
# cause_descMisadjusted machine head presser foot / Prensatela de cabezal desajustado           2.119e-01
# cause_descMisadjusted machine head teeth / Dientes de cabezal desajustados                    1.482e-01
# cause_descMisadjusted machine head thd frame guide/ Marco guía hilo de cabezal desajustado    1.161e-01
# cause_descMisadjusted presser foot bar /Barra de prensatela desajustada                       6.536e-01
# cause_descMisadjusted printing head (switch S2-S3) / Cabezal desajustado (inter. S2-S3)      -2.920e-01
# cause_descMisadjusted roll tensor / Tensor de rollos desajustado                             -1.251e-01
# cause_descMisadjusted rotation detector unit /Posicionador desajustado                       -3.477e-01
# cause_descMisadjusted sensor / Sensor desajustado                                            -4.298e-01
# cause_descMisadjusted Sensor for cloth detection / Sensor detector de tela mal calibrado     -2.480e-01
# cause_descMisadjusted servomotor magnet brake / Imán de freno de servomotor desajustado       5.490e-01
# cause_descMisadjusted servomotor sensor / Sensor de servomotor en mal calibrado               2.432e-02
# cause_descMisadjusted servomotor thermal relay  / Relé térmico de servomotor mal calibrado    6.946e-02
# ...
# mechanicDIEGO CUELLAR                                                                        ***
# mechanicDouglas Alonso Bonilla Soriano                                                       ***
# mechanicDouglas del Cid                                                                      ***
# mechanicDOUGLAS LEONEL CHAVEZ                                                                ***
# mechanicDouglas Leonel Chavez Bonilla
# mechanicEdgar Arevalo                                                                        ***
# mechanicEDIL BERRIOS                                                                         *
# mechanicEDIS MAREL RODRIGUEZ                                                                 ***
# mechanicEdra Alvarado                                                                        **
# mechanicEduardo Antonio Flores Campos                                                        ***
# mechanicEDWIN ALEXANDER CAMPOS                                                               ***
# mechanicEdwin Colindres                                                                      ***
# mechanicEdwin Edgardo Castillo Giron
# mechanicEdwin Froylan Turcios                                                                ***
# mechanicEdwin Rogelio Galeas Perez                                                           ***
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                          ***
# mechanicEmilio Zeledon Lopez                                                                 ***
# mechanicEnrique Pech Canul                                                                   ***
# mechanicErick Garcia Lima                                                                    ***
# mechanicErick Salazar                                                                        ***
# mechanicErlin Sabillon                                                                       ***
# mechanicEver Alfredo Flores Molina                                                           ***
# mechanicFABIAN POSADAS                                                                       ***
# mechanicFabit Aranda                                                                         ***
# mechanicFAULO VICENTE TEC TORRES                                                             ***
# mechanicFernando Alexander Pubill Quintanilla                                                ***
# mechanicFLORES CAMPOS EDUARDO ANTONIO                                                        *
# mechanicFrancisco Antonio Hernandez                                                          ***
# mechanicFranqui Garcia                                                                       ***
# mechanicFUENTES LIMA NESTOR MAURICIO                                                         ***
# mechanicGabriel Sanchez                                                                      ***
# mechanicGARCIA GOMEZ FRANQUI ALIRIO                                                          *
# mechanicGeovanny  Felipe Rivera                                                              ***
# mechanicGerardo Arturo de la Cruz Lemus                                                      ***
# mechanicGilberto Antonio Flores                                                              ***
# mechanicGiovanny Alexander Rivas                                                             ***
# mechanicGuillermo Alfonso Ramirez Landaverde                                                 ***
# mechanicGUILLERMO CASTRO                                                                     *
# mechanicGuillermo Josue Lara Ferman                                                          ***
# mechanicHarley Antonio Valiente                                                              ***
# mechanicHector Antonio Alfaro
# mechanicHector Montoya                                                                       ***
# mechanicHenry Valdez                                                                         ***
# mechanicHerbert Amilcar Montiel Sosa                                                         ***
# mechanicHERIBERTO GARCIA                                                                     ***
# mechanicHugo Hernandez                                                                       ***
# mechanicIGNACIO COB                                                                          ***
# mechanicImmer Sanchez                                                                        ***
# mechanicIsaias Santiago Hernandez                                                            ***
# mechanicJaime Armando Campos                                                                 *
# mechanicJaime Juarez                                                                         **
# mechanicJaime Rivera                                                                         ***
# mechanicJAIRO NATAEL CALIX                                                                   ***
# mechanicJarim Martinez                                                                       ***
# mechanicJeffrey Velasquez                                                                    ***
# mechanicJERONIMO FUNEZ                                                                       ***
# mechanicJimmy Bardales                                                                       ***
# mechanicJoel Elias Chica Bran                                                                ***
# mechanicJoel Ernesto Cuellar Vanegas                                                         ***
# mechanicJonathan Ceceres
# mechanicJony Bladimir Dominguez Alvarado                                                     ***
# mechanicJordy Cedillos                                                                       ***
# mechanicJorge Lopez                                                                          **
# mechanicJorge Ramos                                                                          ***
# mechanicJOSE AGUILAR                                                                         ***
# mechanicJOSE ALVARENGA
# mechanicJose Luis Hernandez                                                                  ***
# mechanicJose Luis Rodriguez                                                                  ***
# mechanicJose Manuel Perez Zepeda                                                             ***
# mechanicJose Maria Canul Tec                                                                 ***
# mechanicJOSE MAURICIO VELASQUEZ ASCENCIO                                                     ***
# mechanicJose Max Reyes Flores                                                                ***
# mechanicJOSE MENDOZA                                                                         **
# mechanicJOSE PEDRO DZUL PECH                                                                 ***
# mechanicJose Valencia                                                                        ***
# mechanicJosue Zalmeron                                                                       ***
# mechanicJuan Absalon Portillo Lemus                                                          ***
# mechanicJuan Antonio Leiva
# mechanicJuan Carlos Lemus
# mechanicJuan Francisco Cardona Hernandez                                                     ***
# mechanicJUAN GONZALEZ                                                                        ***
# mechanicJuan Huezo                                                                           ***
# mechanicJuan Leiva                                                                           ***
# mechanicJuan Manuel Interiano Zaldana
# mechanicJulia Margarita Chicas Diaz                                                          *
# mechanicJulio Oswaldo Rosales                                                                ***
# mechanicKenneth Emerson Clavel Flores                                                        ***
# mechanicKevin Gomez                                                                          ***
# mechanicLadislao Monterrosa Torres                                                           ***
# mechanicLeonardo Cortez                                                                      ***
# mechanicLeonardo Villanueva                                                                  ***
# mechanicLEONEL CHAVEZ                                                                        ***
# mechanicLucas Mejia                                                                          ***
# mechanicLuis Duran
# mechanicLuis Ernesto de la Rosa Garcia                                                       ***
# mechanicLuis Manuel Garcia Rosales                                                           ***
# mechanicLUIS PECH                                                                            ***
# mechanicMarco Anthonio                                                                       ***
# mechanicMarco Enmanuel Osorio Palacios
# mechanicMarcos Emmanuel Osorio Palacios                                                      ***
# mechanicMARCOS MOGUEL                                                                        ***
# mechanicMarvin Betancourth                                                                   ***
# mechanicMarvin Ernesto Melara Figueroa                                                       ***
# mechanicMarvin Pineda                                                                        ***
# mechanicMAURICIO DAVILA SANCHEZ                                                              ***
# mechanicMauricio Ernesto Valencia                                                            ***
# mechanicMelvin Galeano                                                                       ***
# mechanicMiguel Angel Fajardo Ortiz                                                           .
# mechanicMONTOYA HECTOR AMERICO                                                               ***
# mechanicNelson Amilcar Rodriguez Salazar                                                     ***
# mechanicNelson Delgado
# mechanicNELSON GUILLEN                                                                       **
# mechanicNERY MENA RODRIGUEZ                                                                  ***
# mechanicNestor Mauricio Carpio Salas                                                         ***
# mechanicNestor Mauricio Fuentes Lima                                                         **
# mechanicNoe Alexander Caballero Flores                                                       ***
# mechanicNOE CONTRERAS                                                                        ***
# mechanicOdil Alfredo Guzman Saget                                                            *
# mechanicOdil Alfredo Saget Guzman
# mechanicOmar Maldonado                                                                       ***
# mechanicOscar Argumedo                                                                       ***
# mechanicOscar Hurtado                                                                        **
# mechanicPedro Miguel Martinez Linares
# mechanicRafael Esquivel                                                                      ***
# mechanicRAMIREZ RIVERA ABEL ALBERTO
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                          ***
# mechanicRAMON VILLANUEVA                                                                     ***
# mechanicRaul Coto
# mechanicREYES JAVIER CORTEZ CANTE                                                            ***
# mechanicReynaldo Chavez Guerra
# mechanicRichard Lara                                                                         ***
# mechanicRichard Steven                                                                       ***
# mechanicRIVAS TORRES CARLOS ANTONIO
# mechanicRoberto Reyes                                                                        **
# mechanicROMAN IGNACIO AYALA PUC                                                              ***
# mechanicRonald Antonio Herrera                                                               ***
# mechanicRonald Fabricio Hernandez Rivas                                                      .
# mechanicSalvador Roberto Palacios Alvarado                                                   *
# mechanicSalvador Rodriguez                                                                   ***
# mechanicSANCHEZ IMMER ALBERTO                                                                .
# mechanicSAUL ALFARO                                                                          ***
# mechanicSaul Nolberto Alfaro                                                                 **
# mechanicSolmar Elias Hernandez Mezquita                                                      ***
# mechanicSolmar Elias Mezquita                                                                ***
# mechanicVictor Alfonzo Ardon Monteros                                                        ***
# mechanicVladimir Enrique Aguilar Hernandez                                                   ***
# mechanicWalter Anibal Belloso Hernandez                                                      .
# mechanicWalter Bladimir Garcia Patino
# mechanicWalter Patino                                                                        ***
# mechanicWALTER RENE SIERRA VARGAS                                                            ***
# mechanicWilliam Alexander Arevalo Leiva                                                      ***
# mechanicWillian Tejada                                                                       ***
# mechanicWILMER CRUZ                                                                          ***
# mechanicWilmer Zamora                                                                        ***
# mechanicXavier Jose Mendoza                                                                  ***
# parts_cost                                                                                   ***
# Days_Between_Failures                                                                        ***
# Cumulative_Failure_Count                                                                     ***
# Median_Repair_Time                                                                           ***
# Cumulative_Maintenance_Cost                                                                  **
# Age                                                                                          ***
# antiquity
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.484 on 134900 degrees of freedom
# Multiple R-squared:  0.2402,	Adjusted R-squared:  0.2348
# F-statistic: 44.47 on 959 and 134900 DF,  p-value: < 2.2e-16

# %% [markdown]
# **AGREGANDO LA VARIABLE "CHANGED_PCS"**

# %%
# Inicializar y ajustar el modelo de regresión lineal
model5 <- lm(downtime_gross~. -equipment -downtime_gross -repair_hours -date, data = df_merged2)
# Resumen del modelo
summary(model5)
# Out:
# Call:
# lm(formula = downtime_gross ~ . - equipment - downtime_gross -
#     repair_hours - date, data = df_merged2)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.2982 -0.5550 -0.1515  0.2063  9.6918
#
# Coefficients: (10 not defined because of singularities)
#                                                                                                Estimate
# (Intercept)                                                                                   4.905e-01
# operationATTACH ELASTIC                                                                       1.227e-01
# operationBARTACK                                                                             -3.187e-02
# operationBIND ARM                                                                            -2.041e-01
# operationBIND ARMHOLE                                                                        -3.484e-05
# operationBIND LEG                                                                            -1.435e-01
# operationBIND NECK                                                                           -2.853e-01
# operationBUTTON                                                                              -4.490e-02
# operationBUTTON HOLE                                                                         -3.400e-02
# operationCLOSE CUFF                                                                           9.790e-02
# operationCLOSE INSEAM                                                                        -2.719e-02
# operationCLOSE NECK                                                                           3.226e-02
# operationCLOSE POCKET                                                                         1.324e-02
# operationCLOSE SLEEVE                                                                         3.936e-01
# operationCOVER STITCH                                                                        -9.357e-02
# operationCOVER STITCH WAIST                                                                   4.395e-01
# operationCUT AND CLOSE ELASTIC                                                               -8.925e-02
# operationFIRST SIDE                                                                           1.774e-01
# operationFLAT LOCK                                                                           -5.126e-02
# operationFLAT SEAM                                                                           -1.642e-02
# operationGROMMET                                                                             -4.729e-02
# operationHEM AROUND                                                                           2.300e-01
# operationHEM BOTTOM                                                                          -3.156e-02
# operationHEM HOOD                                                                            -1.191e-01
# operationHEM LEG                                                                              2.597e-02
# operationHEM POCKET                                                                          -9.474e-02
# operationHEM SLEEVE                                                                           4.087e-01
# operationHEM SLEEVE AUTO                                                                      6.511e-01
# operationHEM SLEEVE MAN                                                                       3.903e-01
# operationJOIN LEG                                                                            -4.271e-02
# operationJOIN PANEL                                                                           1.127e-02
# operationJOIN SHOULDER                                                                       -1.568e-02
# operationLOCK STITCH                                                                          1.868e-02
# operationP. LABEL                                                                            -5.935e-01
# operationPLACKET TOPSTITCH                                                                    3.757e-01
# operationPRECLOSE ELASTIC                                                                     2.021e-01
# operationSECOND SIDE                                                                          5.323e-02
# operationSERGE ELASTIC                                                                        3.644e-01
# operationSET BAND                                                                             1.731e-02
# operationSET COLLAR                                                                          -7.914e-03
# operationSET CUFF                                                                             9.384e-02
# operationSET HOOD                                                                            -4.497e-02
# operationSET POCKET                                                                           3.342e-02
# operationSET SLEEVE                                                                          -5.184e-02
# operationSEW ELASTIC                                                                         -2.045e-02
# operationSEW ELASTIC WAIST                                                                    7.797e-03
# operationSEW PANEL                                                                           -1.894e-02
# operationSIDE SEAM                                                                            1.262e-01
# operationTAPE SHOULDER                                                                       -5.471e-02
# operationTOP STITCH                                                                          -9.546e-02
# operationTOP STITCH BAND                                                                     -2.778e-02
# operationTOP STITCH COLLAR                                                                    1.895e-02
# operationTOP STITCH HOOD                                                                     -1.689e-01
# operationTOP STITCH POCKET                                                                   -5.534e-02
# operationTOP STITCH SEAM CROTCH                                                               1.101e-01
# operationTOP STITCH SLEEVE                                                                    3.586e-02
# operationTOP STITCH SLEEVE AND BAND                                                          -1.551e-01
# operationTOP STITCH WAIST BAND                                                                7.853e-03
# operationTUBE FLY                                                                            -2.079e-01
# base_model504-E256                                                                           -1.300e-01
# base_model504-E51                                                                             1.010e-01
# base_model504-ETS51                                                                          -1.123e-01
# base_model83SP                                                                                3.170e-02
# base_modelA4                                                                                  4.894e-02
# base_modelAZ8003                                                                              5.803e-02
# base_modelAZ8203                                                                              6.252e-01
# base_modelAZ8403                                                                             -2.430e-02
# base_modelAZ8412                                                                             -1.996e-01
# base_modelAZ8420                                                                              6.053e-02
# base_modelAZ8451                                                                             -1.221e-01
# base_modelAZF8420                                                                            -7.420e-02
# base_modelB-100                                                                               1.261e-01
# base_modelBE-438D                                                                             1.273e-01
# base_modelBE-438FX                                                                            3.719e-01
# base_modelC5                                                                                 -1.122e-02
# base_modelC5-3-02/233                                                                        -6.716e-02
# base_modelC5-4-M03                                                                            4.905e-02
# base_modelC5S-4-M03                                                                           5.766e-02
# base_modelCSA-2516D-03                                                                        1.463e-01
# base_modelCSA-2604                                                                            4.686e-02
# base_modelCSA-2604-02                                                                        -9.229e-02
# base_modelCSC-2614                                                                            5.506e-02
# base_modelCSC-2614-M03                                                                       -2.159e-01
# base_modelCW522AN                                                                            -1.983e-03
# base_modelDB2-B737                                                                           -1.345e-01
# base_modelDDL-5550                                                                            6.123e-02
# base_modelDDL5550                                                                            -8.585e-02
# base_modelDDL8500                                                                             8.570e-02
# base_modelDDL8700                                                                            -1.601e-01
# base_modelDLN-5410                                                                            5.855e-02
# base_modelDLN5410                                                                            -6.089e-02
# base_modelDT6L2512                                                                            7.259e-03
# base_modelE256                                                                                6.088e-02
# base_modelE51-141                                                                             1.108e-01
# base_modelEX5104                                                                              2.150e-02
# base_modelEX5114                                                                             -5.996e-02
# base_modelEX5204                                                                             -1.968e-01
# base_modelEX5214                                                                              2.121e-02
# base_modelEXT5114                                                                            -1.464e-02
# base_modelFD-62                                                                               2.102e-02
# base_modelFD62                                                                                1.063e-01
# base_modelICN B-100                                                                           6.300e-01
# base_modelICN-2200                                                                            3.817e-01
# base_modelJ-261                                                                               1.359e-01
# base_modelJK-797DI                                                                           -5.386e-02
# base_modelJK-798DI                                                                           -4.374e-02
# base_modelJK-798DIII                                                                         -3.581e-02
# base_modelJK-8670BDII                                                                        -5.431e-02
# base_modelJK-SHIRLEY-IIE                                                                      6.370e-02
# base_modelJK-T1790BK                                                                          7.117e-02
# base_modelJK-T1790BS                                                                          2.819e-01
# base_modelJK-T1903BR                                                                          4.516e-01
# base_modelJK-T1903GR                                                                                 NA
# base_modelJK-T1904                                                                            2.151e-02
# base_modelJK-T1904A                                                                          -6.476e-02
# base_modelJK-T1904BS                                                                          9.735e-03
# base_modelJKT1904A                                                                            1.354e-01
# base_modelJS-2261                                                                             1.387e-01
# base_modelKE-430D                                                                             9.018e-02
# base_modelKE430F                                                                              2.722e-02
# base_modelLBH1790                                                                            -6.535e-02
# base_modelLC62D                                                                               9.459e-02
# base_modelLC62D-12                                                                            3.768e-02
# base_modelLDA-L26                                                                             1.426e-02
# base_modelLK1900                                                                              8.572e-03
# base_modelLK1910                                                                             -6.092e-01
# base_modelLK1920                                                                             -1.984e-01
# base_modelLT2-B842                                                                            2.523e-02
# base_modelLT2-B872                                                                           -5.447e-02
# base_modelMH380                                                                              -1.236e-01
# base_modelMJ2600                                                                              7.181e-02
# base_modelMJ2600SD                                                                            5.341e-01
# base_modelS7200                                                                              -4.717e-02
# base_modelSP161                                                                               9.526e-01
# base_modelSP172                                                                              -5.081e-01
# base_modelT-8422A                                                                             1.285e-02
# base_modelT-8722B                                                                            -2.177e-02
# base_modelUS39500                                                                             6.024e-02
# base_modelVC1700                                                                              2.344e-02
# base_modelVC2700                                                                              1.270e-03
# base_modelVC2711                                                                              1.535e-03
# base_modelVC2713                                                                             -9.316e-03
# base_modelVC2735                                                                              9.330e-02
# base_modelVC2785                                                                             -3.355e-01
# base_modelVC3845                                                                             -1.712e-01
# base_modelVC3845P                                                                             2.776e-02
# base_modelVE2700                                                                              2.125e-02
# base_modelVE2711                                                                              5.335e-02
# base_modelVE2713                                                                              3.217e-03
# base_modelVEU2703                                                                             5.655e-01
# base_modelVF2400                                                                              1.309e-01
# base_modelVF2403                                                                              2.565e-01
# base_modelVF2439                                                                              1.619e-01
# base_modelVF2500                                                                              6.674e-02
# base_modelVF2503                                                                              2.768e-01
# base_modelVF2529                                                                              6.629e-01
# base_modelVF2529G                                                                             7.803e-01
# base_modelVF2539                                                                              4.639e-01
# base_modelVF2560                                                                              2.907e-01
# base_modelVF64228                                                                             3.416e-01
# base_modelVFF2503                                                                             2.200e-01
# base_modelVG2700                                                                              1.524e-02
# base_modelVG2711                                                                              1.273e-01
# base_modelVG2713                                                                              5.037e-02
# base_modelVG2735                                                                             -3.566e-03
# base_modelVM1804                                                                              5.976e-02
# base_modelW1500                                                                               1.943e-01
# base_modelW1562                                                                              -5.189e-02
# base_modelW264                                                                                3.340e-01
# base_modelW3522P                                                                             -3.646e-02
# base_modelW4-D                                                                                5.246e-01
# base_modelW500                                                                                1.776e-01
# base_modelW542                                                                               -1.046e-01
# base_modelW562                                                                                1.713e-01
# base_modelW600                                                                                6.313e-02
# base_modelW664                                                                                1.607e-02
# base_modelWT500                                                                              -3.667e-01
# base_modelWT542                                                                              -1.492e-01
# base_modelWT562                                                                              -2.779e-02
# problem_descFruncido/ Pucker                                                                  1.351e+00
# problem_descFuga de aire comprimido detectada/Compressed air leak detected                   -1.024e+00
# problem_descIt cuts the cloth with defect / Corta tela con defecto                            2.397e-01
# problem_descIt does not coil / No enrolla                                                     2.602e-01
# problem_descIt does not cut the cloth / No corta la tela                                      1.636e-02
# problem_descIt does not cut the thread / No corta el hilo                                     8.290e-02
# problem_descIt does not cut the trim off / No corta el desperdicio                            8.918e-02
# problem_descIt does not feed cloth / No alimenta tela                                         8.145e-02
# problem_descIt does not guarantee safety / No garantiza la seguridad                         -2.441e-02
# problem_descIt does not label / No etiqueta                                                  -8.237e-02
# problem_descIt does not light / No alumbra                                                    1.373e-01
# problem_descIt does not look properly / No luce adecuadamente                                 1.211e-01
# problem_descIt does not lubricate / No lubrica                                                4.913e-02
# problem_descIt does not pile up / No apila                                                    3.915e-01
# problem_descIt does not sew / No cose                                                         7.522e-02
# problem_descIt labels with defect / Etiqueta con defecto                                      5.845e-02
# problem_descIt piles up with defect / Apila con defecto                                       1.890e-01
# problem_descIt sews with defect / Cose con defecto                                            1.488e-01
# problem_descNo acciona el Rodo / Dont activate Roll                                           8.745e-02
# problem_descNo pega Grommet/Not set grommet                                                   1.328e-01
# problem_descPedal no Acciona Motor / Pedal not activates motor                               -1.469e-01
# problem_descRemacha Grommet con defecto/ Rivet Grommet with defect                           -9.410e-01
# problem_descSellado Debil/ Weak Sealed                                                        1.500e+00
# failure_descBurner failure / Falla quemador                                                   5.927e-01
# failure_descButton spiral failure/Falla de espiral de botón                                  -5.608e-02
# failure_descChain cutter failure / Falla corta cadenetas                                      5.830e-01
# failure_descDesajuste Pattern Wheel y Circular plate / Patter Wheel misadjustment             2.511e+00
# failure_descDesgaste de Pattern Wheel / Pattern Wheel worn                                   -4.004e-02
# failure_descElectric panel failure / Falla pánel eléctrico                                    5.703e-01
# failure_descEngine failure / Falla motor                                                      4.909e-01
# failure_descFalla cabezal remachando Grommet con defecto / Head failure riveting grommet wit  5.164e-01
# failure_descFalla sistema de aire comprimido / Compressed air supply system failure           1.142e+00
# failure_descFeeding device failure / Falla dispositivo de alimentación                        5.257e-01
# failure_descFolder failure / Falla doblillador                                                6.950e-01
# failure_descLighting lamp failure / Falla lámpara de iluminación                              4.646e-01
# failure_descLubrication system failure / Falla sistema de lubricación                         4.891e-01
# failure_descMachine head failure it does not look properly / Falla cabezal en su apariencia   7.149e-01
# failure_descMachine head failure it stops labeling / Falla cabezal dejando de etiquetar       4.380e-01
# failure_descMachine head failure not riveting/Falla cabezal no remachando                    -1.784e+00
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defecto      4.808e-01
# failure_descMachine head failure stopping sewing  / Falla cabezal dejando de coser            5.444e-01
# failure_descMachine head labeling with defect / Falla cabezal etiquetando con defecto         6.067e-01
# failure_descMonitoring and control failure / Falla monitoreo y control                        6.076e-01
# failure_descPneumatic engine failure / Falla motor neumático                                  7.174e-01
# failure_descRoll holder failure / Falla porta rollo                                           5.352e-01
# failure_descSafety guard failure / Falla protectores                                          3.578e-01
# failure_descServomotor failure / Falla servomotor                                             4.071e-01
# failure_descSpindle cap failure /Falla tapa de sujeción del pin                               1.146e+00
# failure_descSpindle die failure not punching out/Falla dado de corte no perforando            1.545e-02
# failure_descStacker  piling up with defect / Falla apilador dejando de apilar con defecto     4.557e-01
# failure_descStacker failure it stops piling up / Falla apilador dejando de apilar             1.048e-01
# failure_descSwitch failure / Falla interruptor                                                1.277e-02
# failure_descTable failure generating defect / Falla mesa generando defecto                    6.704e-01
# failure_descTable failure in its safety / Falla mesa en su seguridad                          5.347e-01
# failure_descTable failure it does not look properly / Falla mesa en su apariencia             3.276e-01
# failure_descThread holder failure / Falla torre de hilo                                       6.195e-01
# failure_descThread winder failure / Falla devanador de hilo                                   4.511e-01
# failure_descTrim off device cutting with defect /Dispositivo corta tela cortando con defecto  9.221e-01
# failure_descTrim off device failure / Falla dispositivo corta desperdicio                     4.317e-01
# failure_descTrim off device stops cutting/Falla dispositivo corta tela deja de cortar         4.630e-01
# cause_descBanda motor-volante de maquina Grommet dañada / Damaged Grommet machine steering    1.999e+00
# cause_descBase de quemador desajustada / Burner base out of adjustment                       -3.928e-01
# cause_descBlocked button spiral /Espiral de botón obstruida                                   1.093e+00
# cause_descBlunt spindle die / Dado de corte sin filo                                         -7.327e-01
# cause_descBlunt trim off knife / Cuchilla de corta tela desafilada                            1.282e-01
# cause_descBobbin case placed incorrectly / Caja de bobina mal colocada                       -8.738e-02
# cause_descBrazo de prensatela dañado / Damaged presser foot arm                               1.163e-01
# cause_descBroken feeding belt / Rotura de banda de alimentación                               1.297e-02
# cause_descBroken fuse / Rotura de fusible                                                     1.820e-01
# cause_descBroken knife of machine head / Rotura de cuchilla de cabezal                        1.460e-01
# cause_descBroken lubr. system spatter  / Rotura de salpicadores en sistema de lubricación    -5.241e-01
# cause_descBroken machine head ball joint / Rotura de biela de cabezal                         1.196e-01
# cause_descBroken machine head feeding bar / Rotura de barra de alimentación de cabezal        6.598e-01
# cause_descBroken machine head looper / Rotura de enlazador de cabezal                        -6.608e-02
# cause_descBroken machine head needle / Rotura de aguja de cabezal                            -4.363e-02
# cause_descBroken machine head needle guard / Rotura de guarda aguja de cabezal               -1.110e-02
# cause_descBroken machine head needle plate / Rotura de placa de aguja de cabezal             -1.277e-01
# cause_descBroken machine head presser foot  / Rotura de prensatela de cabezal                -1.824e-01
# cause_descBroken machine head timing belt / Rotura de banda de tiempo de cabezal             -2.804e-01
# cause_descBroken motor v-belt/Banda de motor en mal estado o rota                             5.879e-02
# cause_descBroken needle plate finger / Rotura de lengueta placa de aguja de cabezal           1.457e-01
# cause_descBroken or splintered table edges / Bordes de mesa quebrados o astillados           -1.888e-01
# cause_descBroken solenoid valve / Rotura de válvula del solenoide                             6.353e-01
# cause_descBroken teeth of machine head / Rotura de dientes de cabezal                         1.972e-01
# cause_descBurner transformer in poor condition / Transformador de quemador en mal estado     -9.714e-02
# cause_descCaja de quemador dañada / Damaged burner box                                       -1.502e+00
# cause_descClogged lubrication system hose / Manguera de sistema de lubricación atascada       2.901e-01
# cause_descComponente del sistema de aire comprimido dañado / Compressed air system compone   -1.982e-01
# cause_descContamination water in pneumatic engine / Contaminación agua en motor neumático     7.519e-01
# cause_descCtrol table param out of specs/Parámetros de ctrol de mesa fuera de especif.       -2.434e-01
# cause_descCup hook in poor condition / Canastilla en mal estado                               1.742e-04
# cause_descDamaged  chain cutter fixed knife / Cuchilla fija corta cadenetas en mal estado     1.348e-01
# cause_descDamaged  moving knife shaft /Eje cuchilla móvil corta desperdicio en mal estado     4.485e-02
# cause_descDamaged bobbin / Bobina en mal estado                                               1.956e-01
# cause_descDamaged bobbin case brake / Freno de caja de bobina en mal estado                  -4.356e-01
# cause_descDamaged bobbin case thd tensor / Tensor de hilo de caja de bobina en mal estado    -6.830e-02
# cause_descDamaged burner resistance / Resistencia de quemador en mal estado                   1.644e-02
# cause_descDamaged burner thermostat / Termostato de quemador en mal estado                    6.975e-01
# cause_descDamaged chain cutter collar / Collarin de corta cadenetas en mal estado            -7.851e-02
# cause_descDamaged chain cutter cylinder  / Cilindro de corta cadenetas en mal estado          1.585e-01
# cause_descDamaged chain cutter humphrey clevis /Horquilla de corta cadenetas en mal estado    2.311e-01
# cause_descDamaged chain cutter knife / Cuchilla de corta cadeneta en mal estado               2.745e-01
# cause_descDamaged chain cutter mov knife axle/Eje cuchilla móv corta cadenetas mal estado     3.911e-02
# cause_descDamaged chain cutter screw / Tornillo de corta cadenetas en mal estado             -3.709e-01
# cause_descDamaged circuit card / Tarjeta de circuito en mal estado                            1.134e-01
# cause_descDamaged control box / Caja de control en mal estado                                 1.024e-01
# cause_descDamaged conveyor belt / Banda transportadora de mesa en mal estado                  1.224e-01
# cause_descDamaged detachment plate / Placa de desprendimeinto de cabezal en mal estado       -3.865e-01
# cause_descDamaged differential feeding box / Caja reductora de alimentación en mal estado    -2.129e-01
# cause_descDamaged electrical panel cable / Cable de panel eléctrico en mal estado             9.510e-02
# cause_descDamaged electrical panel contactor / Contactor de panel eléctrico en mal estado     4.890e-01
# cause_descDamaged electrical panel drive / Variador de panel eléctrico en mal estado         -9.073e-03
# cause_descDamaged electrical panel fuse / Fusible de panel eléctrico en mal estado           -2.140e-02
# cause_descDamaged electrical panel terminal / Terminal de panel eléctrico en mal estado       3.365e-01
# cause_descDamaged engine bearing / Rodamiento de motor en mal estado                          5.590e-02
# cause_descDamaged engine belt guard / Protector de banda de motor en mal estado              -2.455e-01
# cause_descDamaged engine bobbin / Bobina de motor en mal estado                               1.882e-01
# cause_descDamaged engine clutch / Embrague de motor en mal estado                             5.957e-01
# cause_descDamaged Engine for trim off system / Motor corta desperdicio en mal estado         -6.742e-02
# cause_descDamaged engine rotor / Rotor de motor en mal estado                                 9.498e-02
# cause_descDamaged eye guard / Protector de ojo en mal estado                                  1.530e-01
# cause_descDamaged feeding axis / Eje de alimentación en mal estado                           -5.302e-02
# cause_descDamaged feeding roll / Rodo de alimentación en mal estado                           4.023e-02
# cause_descDamaged feeding transmis. cable/Cable transmisión de alimentación en mal estado     8.553e-01
# cause_descDamaged finger guard / Protector de dedo en mal estado                              9.884e-02
# cause_descDamaged folder guide / Guía de doblillador en mal estado                           -3.096e-01
# cause_descDamaged folder guide base / Base de doblillador en mal estado                      -1.529e-01
# cause_descDamaged lubr syst hose connector/Conector manguera de sist. lubr. en mal estado     1.275e+00
# cause_descDamaged lubr syst worm wheel/Engranaje acople de sistema de lubr en mal estado      4.929e-01
# cause_descDamaged lubr Syst. oil filter screen/Filtro retorno de sist de lubr. mal estado    -2.767e-01
# cause_descDamaged lubric. syst. main filter / Filtro princ. de sist. lubr. en mal estado     -3.885e-01
# cause_descDamaged lubricant / Lubricante en mal estado                                       -1.150e-01
# cause_descDamaged lubrication system hose/Manguera sistema de lubricación en mal estado       5.474e-01
# cause_descDamaged lubrication system pump / Bomba de sistema de lubricación en mal estado     1.608e-01
# cause_descDamaged machine head axle casings / Buje de cabezal en mal estado                  -1.410e-01
# cause_descDamaged machine head bearings / Rodamiento de cabezal en mal estado                 2.206e-02
# cause_descDamaged machine head cup hook / Canastilla de cabezal en mal estado                 4.529e-01
# cause_descDamaged machine head looper / Enlazador de cabezal en mal estado                   -6.481e-02
# cause_descDamaged machine head needle / Aguja de cabezal en mal estado                       -1.409e-01
# cause_descDamaged machine head painting / Pintura de cabezal en mal estado                    1.601e+00
# cause_descDamaged machine head teeth / Dientes de cabezal en mal estado                       3.333e-01
# cause_descDamaged machine head tension disc / Disco de tensión de cabezal en mal estado       1.655e-01
# cause_descDamaged machine head thread guide / Guía hilo de cabezal en mal estado              1.654e-01
# cause_descDamaged machine head thread take up / Leva de cabezal en mal estado                -1.639e-01
# cause_descDamaged maintenance unit / Unidad de mantenimiento en mal estado                    2.327e-01
# cause_descDamaged monitor and control screen /Pantalla de monitoreo y ctrol en mal estado    -1.577e-01
# cause_descDamaged movement changer main tooth/Cambiador movimto diente princ en mal estado   -1.504e-01
# cause_descDamaged movmt changer differ tooth /Cambiador de movmto diente difer. mal estado   -5.149e-01
# cause_descDamaged needle thread guide / Deflector de hilo de cabezal en mal estado            3.845e-01
# cause_descDamaged needle thread guide / Deflector de hilo en mal estado                       3.635e-01
# cause_descDamaged PLC of electrical panel / PLC de panel eléctrico en mal estado              4.020e-01
# cause_descDamaged presser foot's tin filling  /Relleno de prensatela en mal estado            1.228e+00
# cause_descDamaged proximity switch / Interruptor de proximidad en mal estado                  3.638e-02
# cause_descDamaged pulley / Polea en mal estado                                                6.634e-01
# cause_descDamaged roll holder base / Base de porta rollos en mal estado                       9.689e-02
# cause_descDamaged roll tensor / Tensor de rollos en mal estado                                9.693e-02
# cause_descDamaged rotation detector unit /Posicionador en mal estado                          1.904e-01
# cause_descDamaged sensor  / Sensor en mal estado                                             -9.585e-02
# cause_descDamaged Sensor for cloth detection / Sensor detector de tela en mal estado          2.209e-01
# cause_descDamaged servomotor bearing / Rodamiento de servomotor en mal estado                 4.305e-01
# cause_descDamaged servomotor control card / Tarjeta de control de servomotor en mal estado    4.112e-02
# cause_descDamaged servomotor rotor / Rotor de servomotor en mal estado                       -1.189e+00
# cause_descDamaged servomotor sensor / Sensor de servomotor en mal estado                     -1.043e+00
# cause_descDamaged servomotor sensor cable / Cable de sensor de servomotor en mal estado      -5.998e-02
# cause_descDamaged servomotor terminal / Terminal de servomotor en mal estado                  2.343e-01
# cause_descDamaged solenoid / Solenoide en mal estado                                         -8.347e-02
# cause_descDamaged stacker cylinder / Cilindro de apilador en mal estado                       7.732e-02
# cause_descDamaged stacker hose / Manguera de apilador en mal estado                          -3.864e-01
# cause_descDamaged stacker humphrey clevis / Horquilla de apilador en mal estado               6.747e-01
# cause_descDamaged stacker regulating valve / Válvula reguladora de apilador en mal estado     9.506e-01
# cause_descDamaged stacker solenoid valve / Electroválvula de apilador en mal estado           4.020e-01
# cause_descDamaged stitch regulator / Regulador de puntada de cabezal en mal estado           -1.427e-01
# cause_descDamaged surface of printing plate / Placa impresión con superficie en mal estado    1.092e+00
# cause_descDamaged switch box / Caja de interruptor en mal estado                             -2.313e-01
# cause_descDamaged switch button / Botón de interruptor en mal estado                          3.711e-01
# cause_descDamaged switch cable / Cable de interruptor en mal estado                          -8.187e-01
# cause_descDamaged switch contact / Contacto de interruptor en mal estado                      1.227e+00
# cause_descDamaged switch terminal / Terminal de interruptor en mal estado                     6.169e-01
# cause_descDamaged table painting / coating / Pintura/revestimiento de mesa en mal estado      3.678e-01
# cause_descDamaged thread cone holder / Porta conos en mal estado                             -5.543e-01
# cause_descDamaged thread cutting knife / Cuchillas corta hilo en mal estado                   5.432e-02
# cause_descDamaged thread guide / Guía hilo en mal estado                                      3.282e-01
# cause_descDamaged thread guide base / Base de guía hilo en mal estado                        -1.017e-01
# cause_descDamaged thread length tensor / Tensor auxiliar de largo de hebra en mal estado     -6.502e-01
# cause_descDamaged thread winder tensor / Tensor del devanador en mal estado                  -7.566e-01
# cause_descDamaged thread wiper / Saca hebra en mal estado                                     4.686e-02
# cause_descDamaged timer / Temporizador en mal estado                                         -4.128e-01
# cause_descDamaged trim off engine / Motor de corta desperdicio en mal estado                  1.926e-01
# cause_descDamaged trim off knife / Cuchilla de corta tela en mal estado                       4.399e-02
# cause_descDamaged trim off knife ball joint / Biela de corta desperdicio en mal estado        2.604e-01
# cause_descDamaged trim off knife base /Base de cuchilla de corta desperdicio en mal estado    1.339e+00
# cause_descDamaged trim off knife cylinder / Cilindro de corta tela en mal estado             -9.462e-01
# cause_descDamaged trim off knife hose / Manguera de corta tela en mal estado                  4.326e-01
# cause_descDamaged trim off knife position sensor/Sensor posic de corta tela en mal estado     1.696e-01
# cause_descDamaged trim off knife regulat. valve/Válv. reguladora corta tela en mal estado     1.455e-01
# cause_descDamaged trim off knife solenoid valve/Electroválvula de corta tela en mal estado   -1.183e+00
# cause_descDamaged trim off system bearing / Rodamiento de corta desperdicio en mal estado     4.232e-01
# cause_descDamaged trim off system knife / Cuchilla de corta desperdicio en mal estado         6.834e-03
# cause_descDamaged U-joint with shaft / Cardan de alimentación en mal estado                   1.012e+00
# cause_descDeprogrammed electrical panel drive / Variador de panel eléctrico desprogramado    -3.285e-01
# cause_descDirty machine head / Cabezal sucio                                                  3.901e-01
# cause_descDirty table / Mesa sucia                                                           -1.154e-01
# cause_descDoblillador desajustado / Folder out of adjustment                                 -4.625e-01
# cause_descExcess dirt in servomotor casting/ Suciedad excesiva en la carcasa de servomotor    8.011e-02
# cause_descExcessive dirt in chain cutter / Suciedad excesiva en corta cadenetas              -4.183e-01
# cause_descExcessive dirt in electrical panel / Suciedad excesiva en panel eléctrico           3.368e-01
# cause_descExcessive dirt in machine head / Suciedad excesiva en cabezal                       1.326e-01
# cause_descExcessive dirt in switch contact / Contacto de interruptor sucio                    2.966e-01
# cause_descFaulty connection in burner / Falso contacto en quemador                            5.285e-02
# cause_descFaulty connection in electrical panel / Falso contacto en panel eléctrico           8.933e-02
# cause_descFaulty connection in main switch / Falso contacto en interruptor principal         -2.321e-01
# cause_descFaulty connection in switch / Falso contacto en interruptor                         3.636e-01
# cause_descHigh air pressure in pneumatic engine / Alta presión de aire en motor neumático     1.265e-01
# cause_descHigh air pressure in stacker / Alta presión de aire en apilador                    -3.493e-02
# cause_descHigh air pressure in trim off guide / Alta presión de aire en corta tela            5.356e-02
# cause_descIncorrdistance spindle die and cap/Dado corte&tapa sujeción a distincorrecta       -1.239e+00
# cause_descIncorrect bobbin / Bobina incorrecta                                               -5.626e-01
# cause_descIncorrect bobbin case / Caja de bobina incorrecta                                  -4.544e-01
# cause_descIncorrect ink formula / Fórmula de tinta incorrecta                                -8.954e-01
# cause_descIncorrect machine head  tension spring /Resorte de tensión de cabezal incorrecto   -9.952e-02
# cause_descIncorrect machine head needle / Aguja de cabezal incorrecta                         1.398e-01
# cause_descIncorrect machine head threading / Enhebrado incorrecto en cabezal                 -1.972e-01
# cause_descIncorrect size button spiral /Tamaño de espiral de botón  incorrecto               -4.053e-01
# cause_descIncorrect threading / Enhebrado incorrecto                                         -1.737e-01
# cause_descIncorrectly installed guard / Protector mal instalado                              -6.140e-01
# cause_descKnife does not cut needle&looper thread/Cuchillla no corta hilo aguja/enlazador    -1.835e-01
# cause_descLack of bobbin case brake / Freno de caja de bobina faltante                        5.893e-01
# cause_descLack of ventilation in Engine / Falta de ventilación en motor                       7.069e-02
# cause_descLooper with rough edges / Superficie de enlazador de cabezal con asperezas         -1.101e-01
# cause_descLoose chain cutter collar / Collarin de corta cadenetas flojo                      -2.736e+00
# cause_descLoose condense cylinder base screw/Tornillos base cilindro condensado flojos        5.638e-01
# cause_descLoose condensed plug wires /Conector de condensado suelto                          -3.478e-02
# cause_descLoose electr. devices in electr. panel / Disp. Eléctr. sueltos en panel eléctr.     1.056e-01
# cause_descLoose engine belt guard / Protector de banda de motor flojo                         7.695e-02
# cause_descLoose eye guard / Protector de ojo flojo                                            3.129e-01
# cause_descLoose finger guard / Protector de dedo flojo                                        7.214e-01
# cause_descLoose folder subjection screw  / Tornillo de sujeción de doblillador flojo          5.357e-01
# cause_descLoose lubrication system hose / Manguera de sistema de lubricación suelta          -1.094e-01
# cause_descLoose machine head Support for pedal  / Soporte de pedal de cabezal suelto          1.660e-01
# cause_descLoose machine head teeth / Soltura de dientes de cabezal                            4.217e-02
# cause_descLoose roll holder guide / Guía de porta rollos floja                               -1.466e+00
# cause_descLoose table / Mesa floja                                                           -2.036e-01
# cause_descLoose thread cone holder / Porta conos flojo                                        1.385e+00
# cause_descLow air pressure in burner / Baja presión de aire en quemador                       3.239e-01
# cause_descLow air pressure in chain cutter / Baja presión de aire en corta cadenetas         -3.547e-01
# cause_descLow air pressure in pneumatic engine / Baja presión de aire en motor neumático     -2.354e-01
# cause_descLow air pressure in stacker / Baja presión de aire en apilador                      2.898e-01
# cause_descLow air pressure in trim off knife / Baja presión de aire en corta tela             3.125e-01
# cause_descLow oil level in lubr. system / Nivel de aceite bajo en sistema de lubricación      2.367e-01
# cause_descMisadjusted bobbin case thd tensor/ Tensor de hilo de caja de bobina desajustado    1.538e-01
# cause_descMisadjusted chain cutter knife / Cuchilla de corta cadeneta desajustada            -1.749e-01
# cause_descMisadjusted chain cutter moving knife/Cuchilla móvil corta cadeneta mal estado      2.106e-01
# cause_descMisadjusted compressed air pressure / Presión de aire comprimido desajustado        5.203e-01
# cause_descMisadjusted control box / Caja de control desajustada                               2.089e-01
# cause_descMisadjusted feeding and ndl movement/Movmto de alimentación y aguja desajustado    -3.749e-01
# cause_descMisadjusted feeding roll / Rodo de alimentación desajustado                         3.142e-02
# cause_descMisadjusted finger guard / Dedo posicionador de cabezal en mal ajustado            -1.655e-01
# cause_descMisadjusted finger guard / Dedo posicionador mal ajustado                           7.028e-02
# cause_descMisadjusted folder guide / Guía de doblillador desajustadas                        -1.526e-01
# cause_descMisadjusted guide / Guía desajustada                                                1.299e-01
# cause_descMisadjusted hook set / Conjunto de el garfio mal ajustados                         -2.171e-02
# cause_descMisadjusted hook set / Conjunto de garfios mal ajustados                            1.411e-01
# cause_descMisadjusted machine head chopper / Cuchilla de cabezal desajustada                  5.610e-02
# cause_descMisadjusted machine head looper / Enlazador de cabezal desajustado                  1.594e-02
# cause_descMisadjusted machine head needle bar / Barra de aguja de cabezal desajustada        -4.132e-02
# cause_descMisadjusted machine head needle guard / Guarda aguja de cabezal desajustada         6.830e-02
# cause_descMisadjusted machine head presser foot / Prensatela de cabezal desajustado           1.731e-02
# cause_descMisadjusted machine head teeth / Dientes de cabezal desajustados                    7.516e-03
# cause_descMisadjusted machine head thd frame guide/ Marco guía hilo de cabezal desajustado    5.585e-02
# cause_descMisadjusted presser foot bar /Barra de prensatela desajustada                      -2.431e-02
# cause_descMisadjusted printing head (switch S2-S3) / Cabezal desajustado (inter. S2-S3)      -1.716e-01
# cause_descMisadjusted roll tensor / Tensor de rollos desajustado                             -1.988e-01
# cause_descMisadjusted rotation detector unit /Posicionador desajustado                       -2.033e-01
# cause_descMisadjusted sensor / Sensor desajustado                                             5.561e-03
# cause_descMisadjusted Sensor for cloth detection / Sensor detector de tela mal calibrado     -3.231e-02
# cause_descMisadjusted servomotor magnet brake / Imán de freno de servomotor desajustado       6.794e-01
# cause_descMisadjusted servomotor sensor / Sensor de servomotor en mal calibrado              -3.355e-01
# cause_descMisadjusted servomotor thermal relay  / Relé térmico de servomotor mal calibrado    5.608e-01
# ...
# mechanicDouglas Alonso Bonilla Soriano                                                       ***
# mechanicDouglas del Cid                                                                      *
# mechanicDOUGLAS LEONEL CHAVEZ                                                                ***
# mechanicDouglas Leonel Chavez Bonilla                                                        ***
# mechanicEdgar Arevalo                                                                        ***
# mechanicEDIL BERRIOS                                                                         **
# mechanicEDIS MAREL RODRIGUEZ                                                                 ***
# mechanicEdra Alvarado                                                                        ***
# mechanicEduardo Antonio Flores Campos                                                        ***
# mechanicEDWIN ALEXANDER CAMPOS                                                               ***
# mechanicEdwin Colindres                                                                      ***
# mechanicEdwin Edgardo Castillo Giron                                                         **
# mechanicEdwin Froylan Turcios                                                                ***
# mechanicEdwin Rogelio Galeas Perez                                                           ***
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                          ***
# mechanicEmilio Zeledon Lopez                                                                 ***
# mechanicEnrique Pech Canul                                                                   ***
# mechanicErick Garcia Lima                                                                    ***
# mechanicErick Salazar                                                                        ***
# mechanicErlin Sabillon                                                                       ***
# mechanicEver Alfredo Flores Molina                                                           ***
# mechanicFABIAN POSADAS                                                                       ***
# mechanicFabit Aranda                                                                         ***
# mechanicFAULO VICENTE TEC TORRES                                                             ***
# mechanicFernando Alexander Pubill Quintanilla                                                ***
# mechanicFLORES CAMPOS EDUARDO ANTONIO
# mechanicFrancisco Antonio Hernandez                                                          **
# mechanicFranqui Garcia                                                                       *
# mechanicFUENTES LIMA NESTOR MAURICIO
# mechanicGabriel Sanchez                                                                      ***
# mechanicGARCIA GOMEZ FRANQUI ALIRIO                                                          ***
# mechanicGeovanny  Felipe Rivera                                                              ***
# mechanicGerardo Arturo de la Cruz Lemus                                                      ***
# mechanicGilberto Antonio Flores                                                              ***
# mechanicGiovanny Alexander Rivas                                                             ***
# mechanicGuillermo Alfonso Ramirez Landaverde                                                 ***
# mechanicGUILLERMO CASTRO                                                                     **
# mechanicGuillermo Josue Lara Ferman                                                          ***
# mechanicHarley Antonio Valiente                                                              ***
# mechanicHector Antonio Alfaro
# mechanicHector Montoya                                                                       ***
# mechanicHenry Valdez                                                                         ***
# mechanicHerbert Amilcar Montiel Sosa                                                         ***
# mechanicHERIBERTO GARCIA                                                                     ***
# mechanicHugo Hernandez                                                                       ***
# mechanicIGNACIO COB                                                                          ***
# mechanicImmer Sanchez                                                                        **
# mechanicIsaias Santiago Hernandez                                                            ***
# mechanicJaime Armando Campos
# mechanicJaime Juarez                                                                         ***
# mechanicJaime Rivera                                                                         ***
# mechanicJAIRO NATAEL CALIX                                                                   ***
# mechanicJarim Martinez                                                                       ***
# mechanicJeffrey Velasquez                                                                    ***
# mechanicJERONIMO FUNEZ                                                                       ***
# mechanicJimmy Bardales                                                                       ***
# mechanicJoel Elias Chica Bran                                                                ***
# mechanicJoel Ernesto Cuellar Vanegas                                                         ***
# mechanicJonathan Ceceres
# mechanicJony Bladimir Dominguez Alvarado                                                     ***
# mechanicJordy Cedillos                                                                       ***
# mechanicJorge Lopez                                                                          **
# mechanicJorge Ramos                                                                          ***
# mechanicJOSE AGUILAR                                                                         ***
# mechanicJOSE ALVARENGA
# mechanicJose Luis Hernandez                                                                  .
# mechanicJose Luis Rodriguez                                                                  ***
# mechanicJose Manuel Perez Zepeda                                                             ***
# mechanicJose Maria Canul Tec                                                                 ***
# mechanicJOSE MAURICIO VELASQUEZ ASCENCIO                                                     ***
# mechanicJose Max Reyes Flores                                                                ***
# mechanicJOSE MENDOZA                                                                         ***
# mechanicJOSE PEDRO DZUL PECH                                                                 ***
# mechanicJose Valencia                                                                        ***
# mechanicJosue Zalmeron                                                                       ***
# mechanicJuan Absalon Portillo Lemus                                                          ***
# mechanicJuan Antonio Leiva                                                                   .
# mechanicJuan Carlos Lemus
# mechanicJuan Francisco Cardona Hernandez                                                     ***
# mechanicJUAN GONZALEZ                                                                        ***
# mechanicJuan Huezo                                                                           ***
# mechanicJuan Leiva                                                                           ***
# mechanicJuan Manuel Interiano Zaldana
# mechanicJulia Margarita Chicas Diaz
# mechanicJulio Oswaldo Rosales
# mechanicKenneth Emerson Clavel Flores                                                        ***
# mechanicKevin Gomez                                                                          ***
# mechanicLadislao Monterrosa Torres                                                           ***
# mechanicLeonardo Cortez                                                                      ***
# mechanicLeonardo Villanueva                                                                  ***
# mechanicLEONEL CHAVEZ                                                                        ***
# mechanicLucas Mejia                                                                          ***
# mechanicLuis Duran                                                                           **
# mechanicLuis Ernesto de la Rosa Garcia                                                       ***
# mechanicLuis Manuel Garcia Rosales                                                           ***
# mechanicLUIS PECH                                                                            ***
# mechanicMarco Anthonio                                                                       ***
# mechanicMarco Enmanuel Osorio Palacios                                                       .
# mechanicMarcos Emmanuel Osorio Palacios                                                      ***
# mechanicMARCOS MOGUEL                                                                        ***
# mechanicMarvin Betancourth                                                                   ***
# mechanicMarvin Ernesto Melara Figueroa                                                       ***
# mechanicMarvin Pineda                                                                        ***
# mechanicMAURICIO DAVILA SANCHEZ                                                              ***
# mechanicMauricio Ernesto Valencia                                                            ***
# mechanicMelvin Galeano                                                                       ***
# mechanicMiguel Angel Fajardo Ortiz
# mechanicMONTOYA HECTOR AMERICO                                                               ***
# mechanicNelson Amilcar Rodriguez Salazar                                                     ***
# mechanicNelson Delgado
# mechanicNELSON GUILLEN                                                                       ***
# mechanicNERY MENA RODRIGUEZ                                                                  ***
# mechanicNestor Mauricio Carpio Salas                                                         ***
# mechanicNestor Mauricio Fuentes Lima                                                         .
# mechanicNoe Alexander Caballero Flores                                                       ***
# mechanicNOE CONTRERAS                                                                        ***
# mechanicOdil Alfredo Guzman Saget                                                            ***
# mechanicOdil Alfredo Saget Guzman                                                            ***
# mechanicOmar Maldonado                                                                       ***
# mechanicOscar Argumedo                                                                       **
# mechanicOscar Hurtado                                                                        ***
# mechanicPedro Miguel Martinez Linares                                                        **
# mechanicRafael Esquivel                                                                      ***
# mechanicRAMIREZ RIVERA ABEL ALBERTO
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                          ***
# mechanicRAMON VILLANUEVA                                                                     ***
# mechanicRaul Coto
# mechanicREYES JAVIER CORTEZ CANTE                                                            ***
# mechanicReynaldo Chavez Guerra                                                               **
# mechanicRichard Lara                                                                         ***
# mechanicRichard Steven                                                                       ***
# mechanicRIVAS TORRES CARLOS ANTONIO
# mechanicRoberto Reyes                                                                        ***
# mechanicROMAN IGNACIO AYALA PUC                                                              ***
# mechanicRonald Antonio Herrera                                                               ***
# mechanicRonald Fabricio Hernandez Rivas                                                      ***
# mechanicSalvador Roberto Palacios Alvarado                                                   ***
# mechanicSalvador Rodriguez                                                                   ***
# mechanicSANCHEZ IMMER ALBERTO
# mechanicSAUL ALFARO                                                                          ***
# mechanicSaul Nolberto Alfaro                                                                 ***
# mechanicSolmar Elias Hernandez Mezquita
# mechanicSolmar Elias Mezquita                                                                *
# mechanicVictor Alfonzo Ardon Monteros                                                        ***
# mechanicVladimir Enrique Aguilar Hernandez                                                   ***
# mechanicWalter Anibal Belloso Hernandez                                                      ***
# mechanicWalter Bladimir Garcia Patino
# mechanicWalter Patino                                                                        ***
# mechanicWALTER RENE SIERRA VARGAS                                                            ***
# mechanicWilliam Alexander Arevalo Leiva                                                      ***
# mechanicWillian Tejada                                                                       ***
# mechanicWILMER CRUZ                                                                          ***
# mechanicWilmer Zamora                                                                        **
# mechanicXavier Jose Mendoza
# parts_cost
# changed_pcs                                                                                  ***
# Days_Between_Failures                                                                        ***
# Cumulative_Failure_Count                                                                     ***
# Median_Repair_Time                                                                           ***
# Cumulative_Maintenance_Cost                                                                  ***
# Age                                                                                          ***
# antiquity
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.1 on 134899 degrees of freedom
# Multiple R-squared:  0.5826,	Adjusted R-squared:  0.5796
# F-statistic: 196.1 on 960 and 134899 DF,  p-value: < 2.2e-16

# %% [markdown]
# Variables no significativas hay que eliminarlas del modelo

# %% [markdown]
# **IMPLEMENTACION DE BACKWARD**

# %%
sapply(df_merged2, function(x) sum(is.na(x)))
# Out:
#                   equipment                   operation
#                           0                           0
#                  base_model                problem_desc
#                           0                           0
#                failure_desc                  cause_desc
#                           0                           0
#                 action_desc                    mechanic
#                           0                           0
#                        date              downtime_gross
#                           0                           0
#                  parts_cost                repair_hours
#                           0                           0
#                 changed_pcs       Days_Between_Failures
#                           0                           0
#    Cumulative_Failure_Count          Median_Repair_Time
#                           0                           0
# Cumulative_Maintenance_Cost                         Age
#                           0                           0
#                   antiquity
#                           0

# %%
# Realizar backward elimination
model_null <- lm(downtime_gross ~ 1, data = df_merged2)
model_forward <- step(model_null,
                      scope = list(lower = model_null, upper = model5),
                      direction = "forward")
model_forward$anova

# %%
formula = as.formula("Days_Between_Failures ~ operation + base_model + mechanic + downtime_gross +
    parts_cost + Cumulative_Failure_Count + Median_Repair_Time +
    Cumulative_Maintenance_Cost + Age")

# %%
# Inicializar y ajustar el modelo de regresión lineal
model6 <- lm(formula = formula, data = df_merged3)
# Resumen del modelo
summary(model6)

# %% [markdown]
# **Análisis de supervivencia no se incluirá en el informe de TFM**

# %% [markdown]
# **ANALISIS DE SUPERVIVENCIA PARA MAQUINARIA DE RUEDO DE MANGA**

# %%
# Cargar datos
url <- "https://raw.githubusercontent.com/cesargar1507/DatasetsUB/main/maquina2.csv"
data <- read_csv(url, show_col_types = FALSE)

# %%
head(data,5)

# %%
# Filtrar el DataFrame por 'WO Type' igual a 'Corrective Maintenance'
data <- data %>%
  filter(`WO Type` == "Corrective Maintenance")
data <- data%>%
  filter(Operation == "HEM SLEEVE")

# %%
# Convertir la columna 'Date' al formato adecuado
data$Date <- as.Date(data$Date, format="%m/%d/%Y")  # Ajusta el formato según tus datos

# Ordenar por equipo y fecha
data <- data %>% arrange(Equipment, Date)

# Calcular el tiempo entre fallas y si la falla ocurrió
data <- data %>%
  group_by(Equipment) %>%
  mutate(Previous_Failure_Date = lag(Date),
         Days_Between_Failures = as.numeric(Date - Previous_Failure_Date),
         Event_Occurred = ifelse(is.na(Previous_Failure_Date), 0, 1)) %>%
  ungroup()

# Eliminar filas con NA en 'Days_Between_Failures'
data <- data %>% filter(!is.na(Days_Between_Failures))

# %%
head(data,5)

# %%
# Convertir las variables categóricas a factores
data$Equipment <- as.factor(data$Equipment)
data$Operation <- as.factor(data$Operation)
data$Model.Base <- as.factor(data$`Model Base`)
data$Problem.Code <- as.factor(data$`Problem Code`)
data$Failure.Code <- as.factor(data$`Failure Code`)
data$Cause.Code <- as.factor(data$`Cause Code`)
data$Action.Code <- as.factor(data$`Action Code`)

# %%
cox_model <- coxph(Surv(Days_Between_Failures, Event_Occurred) ~
                  Model.Base + Problem.Code + Failure.Code + Cause.Code +
                   Action.Code + downtimeGross + partsCost +repairHours, data = data)

# %%
# Resumen del modelo
summary(cox_model)

# %%
# Curvas de supervivencia ajustadas
fit <- survfit(cox_model)
ggsurvplot(fit, data = data, risk.table = TRUE, pval = TRUE,
           title = "Curvas de Supervivencia Ajustadas",
           xlab = "Tiempo (días)", ylab = "Probabilidad de Supervivencia")

# %%
# Imprimir el resumen del ajuste para ver la mediana de supervivencia
summary_fit <- summary(fit)
print(summary_fit)

# Obtener la mediana de supervivencia
median_survival <- summary_fit$time[which.min(abs(summary_fit$surv - 0.5))]
print(paste("La mediana de supervivencia es:", median_survival, "días"))

# %%
library(ggplot2)
library(survminer)

# Graficar la curva de supervivencia con la mediana de supervivencia resaltada
plot <- ggsurvplot(fit, data = data, risk.table = TRUE, pval = TRUE,
                   title = "Curvas de Supervivencia Ajustadas",
                   xlab = "Tiempo (días)", ylab = "Probabilidad de Supervivencia",
                   conf.int = TRUE)

# Añadir línea vertical y anotación para la mediana de supervivencia
plot$plot <- plot$plot +
  geom_vline(xintercept = median_survival, linetype = "dashed", color = "red") +
  annotate("text", x = median_survival, y = 0.5, label = paste("Mediana =", median_survival, "días"), vjust = -1, color = "red")

print(plot)
