# %%
library(dplyr)
library(readr)
install.packages("caret")
library(caret)
install.packages("ggplot2")
library(ggplot2)
install.packages("randomForest")
library(randomForest)
library(lubridate)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: ggplot2
#
# Loading required package: lattice
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# randomForest 4.7-1.1
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: ‘randomForest’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
# Instalar y cargar las bibliotecas necesarias
install.packages("googledrive")
library(googledrive)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Autenticarse con Google Drive
drive_auth()
# Out:
# The googledrive package is requesting access to your Google account.
# Enter '1' to start a new auth process or select a pre-authorized account.
# 1: Send me to the browser for a new auth process.
# 2: cesar.garcia@catolica.edu.sv
# Selection: 1
# Please point your browser to the following url:
#
# https://accounts.google.com/o/oauth2/v2/auth?client_id=603366585132-frjlouoa3s2ono25d2l9ukvhlsrlnr7k.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&redirect_uri=https%3A%2F%2Fwww.tidyverse.org%2Fgoogle-callback%2F&response_type=code&state=31796c814f7ef826e3d3ad019908c7c9&access_type=offline&prompt=consent
# Enter authorization code: eyJjb2RlIjoiNC8wQVR4M0xZN3FfX2lvNWpBMlE3clg1eFRNQWxoUW5lVC1uX2R4OVFieHhGcDczb0lUcktjT0otR2lNZjNZUGdweV9SSkJkZyIsInN0YXRlIjoiMzE3OTZjODE0ZjdlZjgyNmUzZDNhZDAxOTkwOGM3YzkifQ==

# %%
# Especificar el ID del archivo y la ruta de destino
file_id <- "https://drive.google.com/file/d/1WDRKvrZrvSlQa8qNgUCoGwEyepYNm3dz/view?usp=drivesdk"  # Reemplaza este ID con el ID de tu archivo
drive_download(as_id(file_id), path = "archivo.csv", overwrite = TRUE)
# Out:
# File downloaded:
#
# • Documento de César García <id: 1WDRKvrZrvSlQa8qNgUCoGwEyepYNm3dz>
#
# Saved locally as:
#
# • archivo.csv

# %%
# Leer el archivo CSV desde la URL
urlAge <- "https://raw.githubusercontent.com/cesargar1507/DatasetsUB/main/machine_age.csv"
urlMechanic <- "https://raw.githubusercontent.com/cesargar1507/DatasetsUB/main/mechanic_antiquity.csv"
df <- read_csv("archivo.csv", show_col_types = FALSE)
df_age <- read_csv(urlAge, show_col_types = FALSE)
df_mechanic <- read_csv(urlMechanic, show_col_types = FALSE)

# %%
summary(df)
# Out:
#    equipment        operation           wo_type           base_model
#  Min.   : 100268   Length:149066      Length:149066      Length:149066
#  1st Qu.:1023935   Class :character   Class :character   Class :character
#  Median :1078773   Mode  :character   Mode  :character   Mode  :character
#  Mean   :1017279
#  3rd Qu.:1149220
#  Max.   :1169630
#  problem_code       problem_desc       failure_code       failure_desc
#  Length:149066      Length:149066      Length:149066      Length:149066
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#   cause_code         cause_desc        action_code        action_desc
#  Length:149066      Length:149066      Length:149066      Length:149066
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#    mechanic             date           downtime_gross     pit_coverage
#  Length:149066      Length:149066      Min.   :-6.3833   Min.   : 0.0000
#  Class :character   Class :character   1st Qu.: 0.4167   1st Qu.: 0.0000
#  Mode  :character   Mode  :character   Median : 0.8333   Median : 0.1700
#                                        Mean   : 1.4810   Mean   : 0.8333
#                                        3rd Qu.: 1.8333   3rd Qu.: 1.0000
#                                        Max.   :13.9167   Max.   :20.0000
#  real_downtime         parts_cost         repair_hours     waiting_hours
#  Min.   :-18.166667   Length:149066      Min.   :-7.4333   Min.   :-14.0000
#  1st Qu.:  0.003333   Class :character   1st Qu.: 0.3333   1st Qu.:  0.0000
#  Median :  0.216667   Mode  :character   Median : 0.5000   Median :  0.0000
#  Mean   :  0.647710                      Mean   : 0.9847   Mean   :  0.4963
#  3rd Qu.:  0.666667                      3rd Qu.: 1.0000   3rd Qu.:  0.3333
#  Max.   : 13.916667                      Max.   :13.9167   Max.   : 10.0000
#   changed_pcs
#  Min.   :-7.000
#  1st Qu.: 0.000
#  Median : 1.000
#  Mean   : 1.011
#  3rd Qu.: 1.000
#  Max.   :14.000

# %%
head(df,5)
# Out:
#   equipment operation wo_type                base_model problem_code
# 1 100268    BIND LEG  Calibration            VF2500     SEWP001
# 2 100268    BIND LEG  Corrective Maintenance VF2500     SEWP002
# 3 100268    BIND LEG  Corrective Maintenance VF2500     SEWP002
# 4 100268    BIND LEG  Corrective Maintenance VF2500     SEWP002
# 5 100312    BARTACK   Corrective Maintenance LT2-B872   SEWP001
#   problem_desc                           failure_code
# 1 It does not sew / No cose              SEWF001
# 2 It sews with defect / Cose con defecto SEWF001
# 3 It sews with defect / Cose con defecto SEWF001
# 4 It sews with defect / Cose con defecto SEWF001
# 5 It does not sew / No cose              SEWF001
#   failure_desc
# 1 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 2 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 3 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 4 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 5 Machine head failure stopping sewing  / Falla cabezal dejando de coser
#   cause_code
# 1 SEWC001
# 2 SEWC017
# 3 SEWC017
# 4 SEWC012
# 5 SEWC005
#   cause_desc                                                                  ⋯
# 1 Misadjusted machine head needle guard / Guarda aguja de cabezal desajustada ⋯
# 2 Misadjusted machine head teeth / Dientes de cabezal desajustados            ⋯
# 3 Misadjusted machine head teeth / Dientes de cabezal desajustados            ⋯
# 4 Misadjusted machine head needle bar / Barra de aguja de cabezal desajustada ⋯
# 5 Broken machine head ball joint / Rotura de biela de cabezal                 ⋯
#   action_desc
# 1 Adjust machine head needle guard / Ajustar guarda aguja de cabezal
# 2 Adjust machine head teeth / Ajustar dientes de cabezal
# 3 Adjust machine head teeth / Ajustar dientes de cabezal
# 4 Adjust machine head teeth / Ajustar dientes de cabezal
# 5 Replace machine head ball joint / Reemplazar biela de cabezal
#   mechanic          date      downtime_gross pit_coverage real_downtime
# 1 Erick Garcia Lima 7/14/2023 0.08333333     0.08         0.003333333
# 2 Jaime Rivera      10/3/2023 1.25000000     0.00         1.250000000
# 3 Jaime Rivera      10/3/2023 1.25000000     0.00         1.250000000
# 4 Jaime Rivera      1/17/2024 3.00000000     3.00         0.000000000
# 5 JERONIMO FUNEZ    3/18/2023 0.25000000     0.00         0.250000000
#   parts_cost repair_hours waiting_hours changed_pcs
# 1 $0.74      0.08333333   0             0
# 2 $16.81     1.25000000   0             1
# 3 $16.81     1.25000000   0             1
# 4 $12.50     2.00000000   1             2
# 5 $2.67      0.25000000   0             0

# %% [markdown]
# **LIMPIEZA DE DATOS**

# %%
sapply(df, function(x) sum(is.na(x)))
#Fiabilidad suficiente para continuar con el trabajo
# Out:
#      equipment      operation        wo_type     base_model   problem_code
#              0              0              0              0              0
#   problem_desc   failure_code   failure_desc     cause_code     cause_desc
#              0              0              0              0              0
#    action_code    action_desc       mechanic           date downtime_gross
#              0              0              0              0              0
#   pit_coverage  real_downtime     parts_cost   repair_hours  waiting_hours
#              0              0              0              0              0
#    changed_pcs
#              0

# %%
# Remover el símbolo de dólar y las comas, y convertir a float
df$parts_cost <- as.numeric(gsub("[\\$,()]", "", df$parts_cost))

# %%
# Convertir la columna 'Date' al formato adecuado
df$date <- as.Date(df$date, format="%m/%d/%Y")  # Ajusta el formato según tus datos
# Ordenar el DataFrame por fecha
df <- df %>%
  arrange(date)

# %%
mean(df$downtime_gross < 0)
# Out:
# [1] 2.683375e-05

# %%
# Filtrar registros donde downtimeGross no sea negativo
df <- df %>%
  filter(downtime_gross >= 0)

# %%
mean(df$repair_hours < 0)
# Out:
# [1] 0

# %%
#Eliminar columnas que no seran utilizadas
df <- select(df, -problem_code, -failure_code, -cause_code, -action_code, -pit_coverage, -real_downtime, -waiting_hours)
#Se han eliminado codigos y variables calculadas

# %%
# Filtrar el DataFrame por 'WO Type' igual a 'Corrective Maintenance'
df <- df %>%
  filter(`wo_type` == "Corrective Maintenance")
#Colocar comentario de por qué el filtro, colocar que tecnicas pueden aplicarse y cuales no, colocar en apartado diferente

# %%
# Calcular la diferencia en días entre fechas consecutivas
df <- df %>%
  group_by(equipment) %>%
  mutate(Days_Between_Failures = difftime(date, lag(date), units = "days"))

# Reemplazar los valores NA en Days_Between_Failures
df$Days_Between_Failures[is.na(df$Days_Between_Failures)] <- as.numeric(difftime(df$date[is.na(df$Days_Between_Failures)], as.Date("2023-01-01"), units = "days"))

# %%
# Convertir 'Days_Between_Failures' a numeric
df$Days_Between_Failures <- as.numeric(df$Days_Between_Failures, units = "days")

# %%
#Cambio de nombre de mecánico cuyo nombre está escrito de dos formas
df <- df %>%
  mutate(mechanic = ifelse(mechanic == "GALEAS PEREZ EDWIN ROGELIO", "Edwin Rogelio Galeas Perez", mechanic))

# %%
# Calcular la tabla de frecuencias de cause_desc
freq_cause_desc <- table(df$cause_desc)

# Definir umbral de baja frecuencia (por ejemplo, menos de 5 observaciones)
umbral <- 800

# Identificar categorías con baja frecuencia
categorias_baja_frecuencia <- names(freq_cause_desc)[freq_cause_desc < umbral]

# Reemplazar categorías con baja frecuencia por "Otros"
df$cause_desc[df$cause_desc %in% categorias_baja_frecuencia] <- "Otros"

# %%
# Calcular la tabla de frecuencias de action_desc
freq_action_desc <- table(df$action_desc)

# Definir umbral de baja frecuencia
umbral <- 800

# Identificar categorías con baja frecuencia
categorias_baja_frecuencia <- names(freq_action_desc)[freq_action_desc < umbral]

# Reemplazar categorías con baja frecuencia por "Otros"
df$action_desc[df$action_desc %in% categorias_baja_frecuencia] <- "Otros"

# %%
# Calcular la tabla de frecuencias de operation
freq_operation <- table(df$operation)

# Definir umbral de baja frecuencia
umbral <- 1600

# Identificar categorías con baja frecuencia
categorias_baja_frecuencia <- names(freq_operation)[freq_operation < umbral]

# Reemplazar categorías con baja frecuencia por "Otros"
df$operation[df$operation %in% categorias_baja_frecuencia] <- "Otros"

# %%
# Calcular la tabla de frecuencias de mechanic
freq_mechanic <- table(df$mechanic)

# Definir umbral de baja frecuencia
umbral <- 200

# Identificar categorías con baja frecuencia
categorias_baja_frecuencia <- names(freq_mechanic)[freq_mechanic < umbral]

# Reemplazar categorías con baja frecuencia por "Otros"
df$mechanic[df$mechanic %in% categorias_baja_frecuencia] <- "Otros"

# %%
# Calcular la tabla de frecuencias de base model
freq_base_model <- table(df$base_model)

# Definir umbral de baja frecuencia
umbral <- 657

# Identificar categorías con baja frecuencia
categorias_baja_frecuencia <- names(freq_base_model)[freq_base_model< umbral]

# Reemplazar categorías con baja frecuencia por "Otros"
df$base_model[df$base_model %in% categorias_baja_frecuencia] <- "Otros"

# %%
# Calcular la tabla de frecuencias de problem_desc
freq_problem_desc <- table(df$problem_desc)

# Definir umbral de baja frecuencia
umbral <- 1000

# Identificar categorías con baja frecuencia
categorias_baja_frecuencia <- names(freq_problem_desc)[freq_problem_desc< umbral]

# Reemplazar categorías con baja frecuencia por "Otros"
df$problem_desc[df$problem_desc %in% categorias_baja_frecuencia] <- "Otros"

# %%
# Calcular la tabla de frecuencias de failure_desc
freq_failure_desc <- table(df$failure_desc)

# Definir umbral de baja frecuencia
umbral <- 1000

# Identificar categorías con baja frecuencia
categorias_baja_frecuencia <- names(freq_failure_desc)[freq_failure_desc< umbral]

# Reemplazar categorías con baja frecuencia por "Otros"
df$failure_desc[df$failure_desc %in% categorias_baja_frecuencia] <- "Otros"

# %%
#Convertir horas a minutos
df$downtime_gross <-df$downtime_gross*60

# %% [markdown]
# **ANALISIS DE VARIABLES**

# %%
dim(df)
# Out:
# [1] 135858     15

# %% [markdown]
# **Variable "Operación"**

# %%
# Calcular la frecuencia de cada operación
operation_freq <- df %>%
  group_by(operation) %>%
  summarise(count = n()) %>%
  arrange(desc(count))

# Calcular el porcentaje acumulado
operation_freq <- operation_freq %>%
  mutate(cum_count = cumsum(count),
         cum_perc = cum_count / sum(count))

operation_freq
# Out:
#    operation         count cum_count cum_perc
# 1  HEM SLEEVE        25222  25222    0.1856497
# 2  Otros             22387  47609    0.3504321
# 3  HEM BOTTOM        15840  63449    0.4670244
# 4  JOIN PANEL         7799  71248    0.5244299
# 5  SET SLEEVE         7743  78991    0.5814233
# 6  TAPE SHOULDER      7556  86547    0.6370401
# 7  HEM AROUND         5256  91803    0.6757276
# 8  FLAT SEAM          4987  96790    0.7124350
# 9  JOIN SHOULDER      4857 101647    0.7481856
# 10 ATTACH ELASTIC     4704 106351    0.7828100
# 11 CLOSE SLEEVE       4313 110664    0.8145564
# 12 FLAT LOCK          4303 114967    0.8462292
# 13 SET COLLAR         4270 119237    0.8776590
# 14 SEW ELASTIC        4097 123334    0.9078155
# 15 BIND LEG           3690 127024    0.9349762
# 16 TOP STITCH         2886 129910    0.9562190
# 17 HEM SLEEVE MAN     2668 132578    0.9758571
# 18 SET POCKET         1655 134233    0.9880390
# 19 TOP STITCH COLLAR  1625 135858    1.0000000

# %% [markdown]
# **Variable "problem_desc"**

# %%
# Calcular la frecuencia de problemas de maquinaria
problem_freq <- df %>%
  group_by(problem_desc) %>%
  summarise(count = n()) %>%
  arrange(desc(count))

# Calcular el porcentaje acumulado
problem_freq <- problem_freq %>%
  mutate(cum_count = cumsum(count),
         cum_perc = cum_count / sum(count))
problem_freq
# Out:
#   problem_desc                                           count cum_count
# 1 It sews with defect / Cose con defecto                 95025  95025
# 2 It does not sew / No cose                              31928 126953
# 3 Otros                                                   4491 131444
# 4 It does not cut the thread / No corta el hilo           2214 133658
# 5 It does not cut the trim off / No corta el desperdicio  1177 134835
# 6 It does not cut the cloth / No corta la tela            1023 135858
#   cum_perc
# 1 0.6994435
# 2 0.9344536
# 3 0.9675102
# 4 0.9838066
# 5 0.9924701
# 6 1.0000000

# %%
# Ordenar los datos por frecuencia descendente
problem_freq <- problem_freq %>%
  arrange(desc(count))

problem_freq <- problem_freq %>%
  top_n(3, count)

options(repr.plot.width=17, repr.plot.height=6)

ggplot(problem_freq, aes(y = reorder(problem_desc, count), x = count)) +
  geom_bar(stat = "identity", fill = 'skyblue') +
  geom_text(aes(label = paste0(round(cum_perc * 100, 1), "%")), vjust = -0.5, hjust = 0) +
  labs(title = "Frecuencia acumulada Problemas de Maquinaria",
       y = "Problema",
       x = "Cantidad") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1),
        axis.text.y = element_text(size = 12))
# Out:
# plot without title

# %% [markdown]
# **Variable "failure_desc"**

# %%
# Calcular la frecuencia de fallos de maquinaria
failure_freq <- df %>%
  group_by(failure_desc) %>%
  summarise(count = n()) %>%
  arrange(desc(count))

# Calcular el porcentaje acumulado
failure_freq <- failure_freq %>%
  mutate(cum_count = cumsum(count),
         cum_perc = cum_count / sum(count))
failure_freq
# Out:
#    failure_desc
# 1  Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 2  Machine head failure sewing with defect / Falla cabezal cosiendo con defecto
# 3  Trim off device failure / Falla dispositivo corta desperdicio
# 4  Otros
# 5  Chain cutter failure / Falla corta cadenetas
# 6  Folder failure / Falla doblillador
# 7  Monitoring and control failure / Falla monitoreo y control
# 8  Engine failure / Falla motor
# 9  Lubrication system failure / Falla sistema de lubricación
# 10 Stacker failure it stops piling up / Falla apilador dejando de apilar
# 11 Electric panel failure / Falla pánel eléctrico
# 12 Trim off device stops cutting/Falla dispositivo corta tela deja de cortar
# 13 Burner failure / Falla quemador
# 14 Feeding device failure / Falla dispositivo de alimentación
#    count cum_count cum_perc
# 1  64019  64019    0.4712200
# 2  36833 100852    0.7423339
# 3  13704 114556    0.8432039
# 4   3774 118330    0.8709829
# 5   2967 121297    0.8928219
# 6   2816 124113    0.9135494
# 7   1975 126088    0.9280867
# 8   1854 127942    0.9417333
# 9   1511 129453    0.9528552
# 10  1487 130940    0.9638004
# 11  1403 132343    0.9741274
# 12  1312 133655    0.9837845
# 13  1138 134793    0.9921609
# 14  1065 135858    1.0000000

# %%
# Ordenar los datos por frecuencia descendente
failure_freq <- failure_freq %>%
  arrange(desc(count))

failure_freq <- failure_freq %>%
  top_n(3, count)

options(repr.plot.width=17, repr.plot.height=6)

ggplot(failure_freq, aes(y = reorder(failure_desc, count), x = count)) +
  geom_bar(stat = "identity", fill = 'skyblue') +
  geom_text(aes(label = paste0(round(cum_perc * 100, 1), "%")), vjust = -0.5, hjust = 0) +  # Etiquetas de porcentaje acumulado
  labs(title = "Frecuencia acumulada Fallas de Maquinaria",
       y = "Problema",
       x = "Cantidad") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1),
        axis.text.y = element_text(size = 12))
# Out:
# plot without title

# %% [markdown]
# **Variable "cause_desc"**

# %%
# Calcular la frecuencia de causas de fallo
cause_freq <- df %>%
  group_by(cause_desc) %>%
  summarise(count = n()) %>%
  arrange(desc(count))

# Calcular el porcentaje acumulado
cause_freq <- cause_freq %>%
  mutate(cum_count = cumsum(count),
         cum_perc = cum_count / sum(count))
cause_freq
# Out:
#    cause_desc
# 1  Otros
# 2  Misadjusted machine head looper / Enlazador de cabezal desajustado
# 3  Damaged trim off system knife / Cuchilla de corta desperdicio en mal estado
# 4  Misadjusted machine head needle guard / Guarda aguja de cabezal desajustada
# 5  Broken machine head ball joint / Rotura de biela de cabezal
# 6  Misadjusted machine head presser foot / Prensatela de cabezal desajustado
# 7  Misadjusted machine head teeth / Dientes de cabezal desajustados
# 8  Misadjusted machine head chopper / Cuchilla de cabezal desajustada
# 9  Misadjusted machine head needle bar / Barra de aguja de cabezal desajustada
# 10 Oil leak in machine head / Fuga de aceite lubricante en cabezal
# 11 Misadjusted hook set / Conjunto de garfios mal ajustados
# 12 Excessive dirt in machine head / Suciedad excesiva en cabezal
# 13 Broken machine head needle plate / Rotura de placa de aguja de cabezal
# 14 Misadjusted thread cutting knife / Cuchillas corta hilo mal ajustadas
# 15 Broken machine head presser foot  / Rotura de prensatela de cabezal
# 16 Worn-out machine head looper / Enlazador de cabezal desgastado
# 17 Damaged  moving knife shaft /Eje cuchilla móvil corta desperdicio en mal estado
# 18 Damaged machine head thread take up / Leva de cabezal en mal estado
# 19 Damaged machine head looper / Enlazador de cabezal en mal estado
# 20 Damaged bobbin / Bobina en mal estado
# 21 Broken knife of machine head / Rotura de cuchilla de cabezal
# 22 Misadjusted folder guide / Guía de doblillador desajustadas
# 23 Misadjusted Sensor for cloth detection / Sensor detector de tela mal calibrado
# 24 Blunt trim off knife / Cuchilla de corta tela desafilada
# 25 Damaged thread cutting knife / Cuchillas corta hilo en mal estado
# 26 Damaged burner resistance / Resistencia de quemador en mal estado
# 27 Misadjusted chain cutter knife / Cuchilla de corta cadeneta desajustada
# 28 Loose machine head teeth / Soltura de dientes de cabezal
# 29 Broken machine head looper / Rotura de enlazador de cabezal
# 30 Damaged control box / Caja de control en mal estado
#    count cum_count cum_perc
# 1  26748  26748    0.1968820
# 2  24259  51007    0.3754435
# 3  12994  64001    0.4710875
# 4  11344  75345    0.5545864
# 5   8785  84130    0.6192495
# 6   6193  90323    0.6648339
# 7   5733  96056    0.7070323
# 8   5387 101443    0.7466840
# 9   4551 105994    0.7801822
# 10  3194 109188    0.8036921
# 11  2067 111255    0.8189065
# 12  1868 113123    0.8326562
# 13  1852 114975    0.8462880
# 14  1806 116781    0.8595813
# 15  1575 118356    0.8711743
# 16  1573 119929    0.8827526
# 17  1551 121480    0.8941689
# 18  1431 122911    0.9047020
# 19  1427 124338    0.9152056
# 20  1254 125592    0.9244358
# 21  1221 126813    0.9334231
# 22  1219 128032    0.9423957
# 23  1103 129135    0.9505145
# 24  1067 130202    0.9583683
# 25  1015 131217    0.9658393
# 26   992 132209    0.9731411
# 27   979 133188    0.9803471
# 28   957 134145    0.9873912
# 29   884 135029    0.9938980
# 30   829 135858    1.0000000

# %%
# Ordenar los datos por frecuencia descendente
cause_freq <- cause_freq %>%
  arrange(desc(count))

cause_freq <- cause_freq %>%
  top_n(3, count)

options(repr.plot.width=17, repr.plot.height=6)

ggplot(cause_freq, aes(y = reorder(cause_desc, count), x = count)) +
  geom_bar(stat = "identity", fill = 'skyblue') +
  geom_text(aes(label = paste0(round(cum_perc * 100, 1), "%")), vjust = -0.5, hjust = 0) +  # Etiquetas de porcentaje acumulado
  labs(title = "Frecuencia acumulada Fallas de Maquinaria",
       y = "Problema",
       x = "Cantidad") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1),
        axis.text.y = element_text(size = 12))
# Out:
# plot without title

# %% [markdown]
# **Variable "action_desc"**

# %%
# Calcular la frecuencia de acciones correctivas
action_freq <- df %>%
  group_by(action_desc) %>%
  summarise(count = n()) %>%
  arrange(desc(count))

# Calcular el porcentaje acumulado
action_freq <- action_freq %>%
  mutate(cum_count = cumsum(count),
         cum_perc = cum_count / sum(count))
action_freq
#Grafica de distribución
# Out:
#    action_desc
# 1  Otros
# 2  Adjust machine head looper / Ajustar enlazador de cabezal
# 3  Adjust machine head needle guard / Ajustar guarda aguja de cabezal
# 4  Adjust machine head teeth / Ajustar dientes de cabezal
# 5  Sharpen knife / Afilar cuchillas
# 6  Replace machine head ball joint / Reemplazar biela de cabezal
# 7  Replace machine head looper / Reemplazar enlazador de cabezal
# 8  Adjusted machine head presser foot / Ajustar prensatela de cabezal
# 9  Replace trim off knife / Reemplazar cuchilla de corta desperdicio
# 10 Adjust machine head knife / Ajustar cuchilla de cabezal
# 11 Fix machine head oil leak / Corregir fuga de aceite en cabezal
# 12 Adjust hook set / Ajustar conjunto de el garfio
# 13 Adjust thread cutting knife / Ajustar cuchillas corta hilo
# 14 Replace machine head needle plate / Reemplazar placa de aguja de cabezal
# 15 Adjusted machine head needle bar / Ajustar barra de aguja de cabezal
# 16 Replace bobbin / Reemplazar bobina
# 17 Adjust machine head sensor / Ajustar sensor de cabezal
# 18 Adjust folder guide / Ajustar guía de doblillador
# 19 Replace machine head knife / Reemplazar cuchilla de cabezal
# 20 Polish thread take up / Pulir leva
# 21 Clean machine head / Limpiar cabezal
# 22 Fasten machine head pedal brace / Asegurar soporte de pedal de coser de cabezal
# 23 Replace machine head presser foot / Reemplazar prensatela de cabezal
# 24 Replace machine head teeth / Reemplazar dientes de cabezal
# 25 Adjust chain cutter knife / Ajustar cuchilla de corta cadenetas
# 26 Replace thread cutting knife / Reemplazar cuchillas corta hilo
# 27 Replace burner resistance / Reemplazar resistencia de quemador
# 28 Replace thread tension assembly / Reemplazar tensor auxiliar de largo de hebra
# 29 Replace machine head needle / Reemplazar aguja de cabezal
# 30 Replace machine head needle guard / Reemplazar guarda aguja de cabezal
# 31 Inspect stacker air supply / Revisar suministro de aire en apilador
#    count cum_count cum_perc
# 1  25800  25800    0.1899042
# 2  18275  44075    0.3244196
# 3  11409  55484    0.4083970
# 4   9699  65183    0.4797877
# 5   9087  74270    0.5466737
# 6   8825  83095    0.6116313
# 7   7719  90814    0.6684479
# 8   6842  97656    0.7188093
# 9   6205 103861    0.7644820
# 10  4188 108049    0.7953083
# 11  3028 111077    0.8175963
# 12  2527 113604    0.8361966
# 13  1801 115405    0.8494531
# 14  1796 117201    0.8626728
# 15  1703 118904    0.8752079
# 16  1310 120214    0.8848504
# 17  1285 121499    0.8943088
# 18  1263 122762    0.9036052
# 19  1156 123918    0.9121141
# 20  1141 125059    0.9205126
# 21  1113 126172    0.9287050
# 22  1062 127234    0.9365220
# 23  1054 128288    0.9442801
# 24  1047 129335    0.9519866
# 25  1037 130372    0.9596196
# 26   978 131350    0.9668183
# 27   968 132318    0.9739434
# 28   944 133262    0.9808918
# 29   892 134154    0.9874575
# 30   860 135014    0.9937876
# 31   844 135858    1.0000000

# %% [markdown]
# **Variable "mechanic"**

# %%
# Calcular la frecuencia de fallos resueltos por mecanicos
mechanic_freq <- df %>%
  group_by(mechanic) %>%
  summarise(count = n()) %>%
  arrange(desc(count))

# Calcular el porcentaje acumulado
mechanic_freq <- mechanic_freq %>%
  mutate(cum_count = cumsum(count),
         cum_perc = cum_count / sum(count))
mechanic_freq
# Out:
#     mechanic                            count cum_count cum_perc
# 1   Otros                               4011   4011     0.02952347
# 2   Antony Ulloa                        3226   7237     0.05326885
# 3   Jose Manuel Perez Zepeda            3034  10271     0.07560100
# 4   Omar Maldonado                      2768  13039     0.09597521
# 5   Erick Garcia Lima                   2533  15572     0.11461968
# 6   Ronald Antonio Herrera              2434  18006     0.13253544
# 7   Edwin Colindres                     2389  20395     0.15011998
# 8   DIEGO CUELLAR                       2247  22642     0.16665931
# 9   Carlos Alberto Alfaro Salamanca     2234  24876     0.18310295
# 10  DENY RAYMUNDO PUCH POOL             2104  26980     0.19858970
# 11  Kenneth Emerson Clavel Flores       2003  28983     0.21333304
# 12  Eduardo Antonio Flores Campos       1953  30936     0.22770834
# 13  Carlos De Leon                      1917  32853     0.24181866
# 14  Willian Tejada                      1840  34693     0.25536222
# 15  Immer Sanchez                       1766  36459     0.26836108
# 16  Cesar Edgardo Ruedas Mendoza        1749  38208     0.28123482
# 17  Edgar Arevalo                       1717  39925     0.29387301
# 18  NOE CONTRERAS                       1716  41641     0.30650385
# 19  Luis Ernesto de la Rosa Garcia      1704  43345     0.31904636
# 20  Juan Carlos Lemus                   1703  45048     0.33158150
# 21  JOSE PEDRO DZUL PECH                1666  46714     0.34384431
# 22  Edwin Rogelio Galeas Perez          1621  48335     0.35577588
# 23  ROMAN IGNACIO AYALA PUC             1545  49880     0.36714805
# 24  Melvin Galeano                      1509  51389     0.37825524
# 25  Edwin Edgardo Castillo Giron        1498  52887     0.38928146
# 26  EDWIN ALEXANDER CAMPOS              1492  54379     0.40026351
# 27  Cain Alfredo Ramirez                1389  55768     0.41048742
# 28  SAUL ALFARO                         1389  57157     0.42071133
# 29  Adalberto Jeremias Rodriguez Zometa 1352  58509     0.43066290
# 30  NERY MENA RODRIGUEZ                 1352  59861     0.44061447
# ⋮   ⋮                                   ⋮     ⋮         ⋮
# 114 Douglas Leonel Chavez Bonilla       388   127407    0.9377953
# 115 CASTILLO GIRON EDWIN EDGARDO        383   127790    0.9406145
# 116 LEONEL CHAVEZ                       377   128167    0.9433894
# 117 RAMON VILLANUEVA                    359   128526    0.9460319
# 118 Gerardo Arturo de la Cruz Lemus     357   128883    0.9486596
# 119 Rafael Esquivel                     356   129239    0.9512800
# 120 FUENTES LIMA NESTOR MAURICIO        353   129592    0.9538783
# 121 Marco Enmanuel Osorio Palacios      344   129936    0.9564104
# 122 Angel Mex                           338   130274    0.9588983
# 123 RAMIREZ RIVERA CAIN ALFREDO         332   130606    0.9613420
# 124 Odil Alfredo Saget Guzman           324   130930    0.9637268
# 125 Walter Patino                       312   131242    0.9660233
# 126 Herbert Amilcar Montiel Sosa        304   131546    0.9682610
# 127 Carlos Ernesto Rojas Guzman         292   131838    0.9704103
# 128 Josue Zalmeron                      292   132130    0.9725596
# 129 FABIAN POSADAS                      286   132416    0.9746647
# 130 Guillermo Josue Lara Ferman         284   132700    0.9767551
# 131 Henry Valdez                        273   132973    0.9787646
# 132 Marcos Emmanuel Osorio Palacios     270   133243    0.9807520
# 133 Carlos Rodriguez                    265   133508    0.9827025
# 134 Jeffrey Velasquez                   257   133765    0.9845942
# 135 Jimmy Bardales                      245   134010    0.9863976
# 136 Douglas Alonso Bonilla Soriano      244   134254    0.9881936
# 137 MONTOYA HECTOR AMERICO              239   134493    0.9899527
# 138 REYES JAVIER CORTEZ CANTE           238   134731    0.9917046
# 139 RIVAS TORRES CARLOS ANTONIO         238   134969    0.9934564
# 140 Carlos Rivas                        231   135200    0.9951567
# 141 Mauricio Ernesto Valencia           230   135430    0.9968497
# 142 Julia Margarita Chicas Diaz         222   135652    0.9984837
# 143 Daniel Edgardo Sandoval             206   135858    1.0000000

# %% [markdown]
# **Variable "repair_hours"**

# %%
# Crear el boxplot de repair_hours
ggplot(df, aes(y = repair_hours)) +
  geom_boxplot(fill = 'skyblue', color = 'black') +
  labs(title = 'Boxplot de repair time',
       y = 'Minutos de reparación') +
  theme_minimal()
# Out:
# plot without title

# %%
# Crear el boxplot de repair_hours
ggplot(df, aes(y = repair_hours)) +
  geom_boxplot(fill = 'skyblue', color = 'black', outlier.shape = NA) +
  labs(title = 'Boxplot de repair time',
       y = 'Minutos de reparación') +
  theme_minimal()
# Out:
# plot without title

# %%
# Calcular los outliers
outlier_threshold <- quantile(df$repair_hours, 0.95)

# Identificar outliers
df$outlier <- ifelse(df$repair_hours > outlier_threshold, TRUE, FALSE)

# Convertir Date a formato de fecha
df$date <- as.Date(df$date)

# Agrupar por mes y contar la frecuencia de outliers
df_outliers <- df %>%
  mutate(Month = month(date, label = TRUE)) %>%
  group_by(Month) %>%
  summarise(Outliers = sum(outlier))

# Crear un gráfico de barras de la frecuencia de outliers por mes
ggplot(df_outliers, aes(x = Month, y = Outliers)) +
  geom_bar(stat = "identity", fill = 'skyblue', color = 'black') +
  labs(title = 'Frecuencia de Outliers por Mes',
       x = 'Mes',
       y = 'Cantidad de Outliers') +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# **Variable "parts cost"**

# %%
ggplot(df, aes(y = repair_hours)) +
  geom_boxplot(fill = 'skyblue', color = 'black', outlier.shape = NA) +
  labs(title = 'Boxplot de repair time',
       y = 'Minutos de reparación') +
  theme_minimal() +
  ylim(0, max(df$repair_hours, na.rm = TRUE))
# Out:
# plot without title

# %%
# Crear el boxplot de repair_hours
ggplot(df, aes(y = parts_cost)) +
  geom_boxplot(fill = 'skyblue', color = 'black') +
  labs(title = 'Boxplot de parts cost',
       y = 'Costo') +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# **ANALISIS DE VARIABLE OBJETIVO "DOWNTIME GROSS"**

# %%
# Histograma de 'downtimeGross'
hist_downtimeGross <- ggplot(df, aes(x = downtime_gross)) +
  geom_histogram(binwidth = 10, fill = "green", color = "black", alpha = 0.7) +
  labs(title = "Histograma de Downtime Bruto",
       x = "Downtime Bruto (minutos)",
       y = "Frecuencia") +
  theme_minimal()

# Mostrar histogramas
print(hist_downtimeGross)
#Hacerlo más grande
# Out:
# plot without title

# %%
# Crear el boxplot de downtime gross
ggplot(df, aes(y = downtime_gross)) +
  geom_boxplot(fill = 'skyblue', color = 'black') +
  labs(title = 'Boxplot de downtime gross',
       y = 'Minutos') +
  theme_minimal()
# Out:
# plot without title

# %%
# Crear el boxplot de downtime gross
ggplot(df, aes(y = downtime_gross)) +
  geom_boxplot(fill = 'skyblue', color = 'black', outlier.shape = NA) +
  labs(title = 'Boxplot de downtime gross',
       y = 'Minutos') +
  theme_minimal()
# Out:
# plot without title

# %%
outlier_threshold <- quantile(df$downtime_gross, 0.95)

# Identificar outliers
df$outlier <- ifelse(df$downtime_gross > outlier_threshold, TRUE, FALSE)

# Convertir Date a formato de fecha
df$date <- as.Date(df$date)

# Agrupar por mes y contar la frecuencia de outliers
df_outliers <- df %>%
  mutate(Month = month(date, label = TRUE)) %>%
  group_by(Month) %>%
  summarise(Outliers = sum(outlier))

# Crear un gráfico de barras de la frecuencia de outliers por mes
ggplot(df_outliers, aes(x = Month, y = Outliers)) +
  geom_bar(stat = "identity", fill = 'skyblue', color = 'black') +
  labs(title = 'Frecuencia de Outliers de Downtime Gross por Mes',
       x = 'Mes',
       y = 'Cantidad de Outliers') +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# **GLM INICIAL PARA PREDECIR DOWNTIME**

# %%
df <- select(df, -wo_type)
#Comparar con un glm

# %%
head(df,5)
# Out:
#   equipment operation  base_model
# 1 1011144   HEM SLEEVE VC2700
# 2 1013453   TOP STITCH VC2713
# 3 1013453   TOP STITCH VC2713
# 4 1027243   SET SLEEVE VC2700
# 5 1027243   SET SLEEVE VC2700
#   problem_desc
# 1 It does not cut the trim off / No corta el desperdicio
# 2 It sews with defect / Cose con defecto
# 3 It sews with defect / Cose con defecto
# 4 It sews with defect / Cose con defecto
# 5 It sews with defect / Cose con defecto
#   failure_desc
# 1 Trim off device failure / Falla dispositivo corta desperdicio
# 2 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 3 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 4 Machine head failure sewing with defect / Falla cabezal cosiendo con defecto
# 5 Machine head failure sewing with defect / Falla cabezal cosiendo con defecto
#   cause_desc
# 1 Damaged trim off system knife / Cuchilla de corta desperdicio en mal estado
# 2 Misadjusted machine head needle guard / Guarda aguja de cabezal desajustada
# 3 Misadjusted machine head needle guard / Guarda aguja de cabezal desajustada
# 4 Oil leak in machine head / Fuga de aceite lubricante en cabezal
# 5 Oil leak in machine head / Fuga de aceite lubricante en cabezal
#   action_desc
# 1 Sharpen knife / Afilar cuchillas
# 2 Adjust machine head needle guard / Ajustar guarda aguja de cabezal
# 3 Adjust machine head needle guard / Ajustar guarda aguja de cabezal
# 4 Fix machine head oil leak / Corregir fuga de aceite en cabezal
# 5 Fix machine head oil leak / Corregir fuga de aceite en cabezal
#   mechanic                            date       downtime_gross parts_cost
# 1 DIEGO CUELLAR                       2023-01-03 10             51.00
# 2 Adalberto Jeremias Rodriguez Zometa 2023-01-03 60             19.20
# 3 Adalberto Jeremias Rodriguez Zometa 2023-01-03 60             19.20
# 4 RAMON VILLANUEVA                    2023-01-03 30             60.69
# 5 RAMON VILLANUEVA                    2023-01-03 30             60.69
#   repair_hours changed_pcs Days_Between_Failures outlier
# 1 0.1666667    0           2                     FALSE
# 2 1.0000000    1           2                     FALSE
# 3 1.0000000    1           0                     FALSE
# 4 0.5000000    1           2                     FALSE
# 5 0.5000000    1           0                     FALSE

# %%
# Establecer una semilla para reproducibilidad
set.seed(123)

# Definir la proporción de entrenamiento
train_proportion <- 0.70

# Crear índices de muestreo para el conjunto de entrenamiento
trainIndex <- createDataPartition(df$downtime_gross, p = train_proportion, list = FALSE)

# Crear conjunto de entrenamiento
train_data1 <- df[trainIndex,]

# Crear conjunto de prueba
test_data1 <- df[-trainIndex,]

# Comprobar las dimensiones de cada conjunto
cat("Dimensiones del conjunto de entrenamiento: ", dim(train_data1), "\n")
cat("Dimensiones del conjunto de prueba: ", dim(test_data1), "\n")
# Out:
# Dimensiones del conjunto de entrenamiento:  95102 15
# Dimensiones del conjunto de prueba:  40756 15

# %%
# Inicializar y ajustar el modelo de regresión lineal
#Dividir en entrenamiento, test, validación por ejemplo 70,20,10
model1 <- glm(downtime_gross~. -equipment -downtime_gross -repair_hours -Days_Between_Failures -date -changed_pcs, data = train_data1)
# Resumen del modelo
summary(model1)
# Out:
# Call:
# glm(formula = downtime_gross ~ . - equipment - downtime_gross -
#     repair_hours - Days_Between_Failures - date - changed_pcs,
#     data = train_data1)
#
# Coefficients:
#                                                                                              Estimate
# (Intercept)                                                                                 61.329194
# operationBIND LEG                                                                            0.313122
# operationCLOSE SLEEVE                                                                        8.364028
# operationFLAT LOCK                                                                         -12.731265
# operationFLAT SEAM                                                                          -5.081947
# operationHEM AROUND                                                                          2.245936
# operationHEM BOTTOM                                                                         -5.605522
# operationHEM SLEEVE                                                                         13.423195
# operationHEM SLEEVE MAN                                                                     10.182662
# operationJOIN PANEL                                                                         -4.217026
# operationJOIN SHOULDER                                                                      -7.909187
# operationOtros                                                                              -3.916325
# operationSET COLLAR                                                                        -10.546928
# operationSET POCKET                                                                         -7.766456
# operationSET SLEEVE                                                                        -10.506088
# operationSEW ELASTIC                                                                        -4.900111
# operationTAPE SHOULDER                                                                      -6.228555
# operationTOP STITCH                                                                         -5.337086
# operationTOP STITCH COLLAR                                                                  -5.120216
# base_modelC5                                                                                 0.338251
# base_modelC5-3-02/233                                                                        2.236918
# base_modelC5-4-M03                                                                           1.987406
# base_modelC5S-4-M03                                                                         -3.087987
# base_modelDDL5550                                                                            1.485185
# base_modelDT6L2512                                                                           2.371360
# base_modelEX5214                                                                             1.955457
# base_modelFD-62                                                                             -1.023714
# base_modelFD62                                                                              10.393007
# base_modelJ-261                                                                              9.726203
# base_modelJK-797DI                                                                           1.395011
# base_modelJK-798DIII                                                                        -2.546971
# base_modelJK-T1904                                                                           1.969721
# base_modelJK-T1904BS                                                                         4.666307
# base_modelJS-2261                                                                            8.880277
# base_modelLC62D                                                                              6.572760
# base_modelLC62D-12                                                                          -4.974858
# base_modelLDA-L26                                                                            2.260647
# base_modelOtros                                                                              4.961405
# base_modelT-8722B                                                                            2.917898
# base_modelUS39500                                                                           11.169320
# base_modelVC1700                                                                             5.114441
# base_modelVC2700                                                                             2.828148
# base_modelVC2711                                                                             2.184742
# base_modelVC2713                                                                             7.008646
# base_modelVC3845P                                                                            2.321114
# base_modelVE2700                                                                             2.945130
# base_modelVF2400                                                                            -6.623393
# base_modelVF2403                                                                             2.805173
# base_modelVF2500                                                                            -1.986274
# base_modelVF2560                                                                             7.940965
# base_modelVG2700                                                                             4.989623
# base_modelVG2713                                                                             9.502582
# base_modelVG2735                                                                             5.158525
# base_modelW600                                                                              -7.569596
# base_modelW664                                                                               6.958935
# base_modelWT542                                                                             10.108169
# base_modelWT562                                                                              8.401111
# problem_descIt does not cut the thread / No corta el hilo                                    0.760851
# problem_descIt does not cut the trim off / No corta el desperdicio                          -7.851302
# problem_descIt does not sew / No cose                                                       -5.706530
# problem_descIt sews with defect / Cose con defecto                                           1.648044
# problem_descOtros                                                                            3.119225
# failure_descChain cutter failure / Falla corta cadenetas                                     7.626323
# failure_descElectric panel failure / Falla pánel eléctrico                                   7.258850
# failure_descEngine failure / Falla motor                                                     6.630320
# failure_descFeeding device failure / Falla dispositivo de alimentación                       3.675571
# failure_descFolder failure / Falla doblillador                                              10.571200
# failure_descLubrication system failure / Falla sistema de lubricación                       29.007247
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defecto     2.372966
# failure_descMachine head failure stopping sewing  / Falla cabezal dejando de coser           6.062646
# failure_descMonitoring and control failure / Falla monitoreo y control                       9.107844
# failure_descOtros                                                                            4.243465
# failure_descStacker failure it stops piling up / Falla apilador dejando de apilar            6.355508
# failure_descTrim off device failure / Falla dispositivo corta desperdicio                   -2.415445
# failure_descTrim off device stops cutting/Falla dispositivo corta tela deja de cortar        0.578700
# cause_descBroken knife of machine head / Rotura de cuchilla de cabezal                      -6.149985
# cause_descBroken machine head ball joint / Rotura de biela de cabezal                       19.531163
# cause_descBroken machine head looper / Rotura de enlazador de cabezal                       -2.507058
# cause_descBroken machine head needle plate / Rotura de placa de aguja de cabezal            -6.264543
# cause_descBroken machine head presser foot  / Rotura de prensatela de cabezal               -4.569887
# cause_descDamaged  moving knife shaft /Eje cuchilla móvil corta desperdicio en mal estado    0.126037
# cause_descDamaged bobbin / Bobina en mal estado                                             16.007140
# cause_descDamaged burner resistance / Resistencia de quemador en mal estado                 -2.006390
# cause_descDamaged control box / Caja de control en mal estado                               14.683905
# cause_descDamaged machine head looper / Enlazador de cabezal en mal estado                  -7.522418
# cause_descDamaged machine head thread take up / Leva de cabezal en mal estado               -3.595649
# cause_descDamaged thread cutting knife / Cuchillas corta hilo en mal estado                  9.761866
# cause_descDamaged trim off system knife / Cuchilla de corta desperdicio en mal estado       -3.715270
# cause_descExcessive dirt in machine head / Suciedad excesiva en cabezal                     -4.329249
# cause_descLoose machine head teeth / Soltura de dientes de cabezal                          -1.653547
# cause_descMisadjusted chain cutter knife / Cuchilla de corta cadeneta desajustada            9.404373
# cause_descMisadjusted folder guide / Guía de doblillador desajustadas                       -9.072089
# cause_descMisadjusted hook set / Conjunto de garfios mal ajustados                          -3.869021
# cause_descMisadjusted machine head chopper / Cuchilla de cabezal desajustada                -6.117798
# cause_descMisadjusted machine head looper / Enlazador de cabezal desajustado                 1.646137
# cause_descMisadjusted machine head needle bar / Barra de aguja de cabezal desajustada        2.739680
# cause_descMisadjusted machine head needle guard / Guarda aguja de cabezal desajustada        5.356532
# cause_descMisadjusted machine head presser foot / Prensatela de cabezal desajustado          0.578483
# cause_descMisadjusted machine head teeth / Dientes de cabezal desajustados                   0.155504
# cause_descMisadjusted Sensor for cloth detection / Sensor detector de tela mal calibrado   -23.884843
# cause_descMisadjusted thread cutting knife / Cuchillas corta hilo mal ajustadas              5.665093
# cause_descOil leak in machine head / Fuga de aceite lubricante en cabezal                   12.445861
# cause_descOtros                                                                             -1.827573
# cause_descWorn-out machine head looper / Enlazador de cabezal desgastado                    -1.983074
# action_descAdjust folder guide / Ajustar guía de doblillador                                21.996818
# action_descAdjust hook set / Ajustar conjunto de el garfio                                  30.698680
# action_descAdjust machine head knife / Ajustar cuchilla de cabezal                          22.988120
# action_descAdjust machine head looper / Ajustar enlazador de cabezal                        27.878246
# action_descAdjust machine head needle guard / Ajustar guarda aguja de cabezal               21.737862
# action_descAdjust machine head sensor / Ajustar sensor de cabezal                           27.533227
# action_descAdjust machine head teeth / Ajustar dientes de cabezal                           25.704545
# action_descAdjust thread cutting knife / Ajustar cuchillas corta hilo                       28.090684
# action_descAdjusted machine head needle bar / Ajustar barra de aguja de cabezal             27.071583
# action_descAdjusted machine head presser foot / Ajustar prensatela de cabezal               23.204122
# action_descClean machine head / Limpiar cabezal                                             23.850383
# action_descFasten machine head pedal brace / Asegurar soporte de pedal de coser de cabezal  22.669850
# action_descFix machine head oil leak / Corregir fuga de aceite en cabezal                   30.470116
# action_descInspect stacker air supply / Revisar suministro de aire en apilador              13.086366
# action_descOtros                                                                            21.253547
# action_descPolish thread take up / Pulir leva                                                9.187921
# action_descReplace bobbin / Reemplazar bobina                                                8.019935
# action_descReplace burner resistance / Reemplazar resistencia de quemador                   16.907429
# action_descReplace machine head ball joint / Reemplazar biela de cabezal                    14.425777
# action_descReplace machine head knife / Reemplazar cuchilla de cabezal                      25.688574
# action_descReplace machine head looper / Reemplazar enlazador de cabezal                    37.019933
# action_descReplace machine head needle / Reemplazar aguja de cabezal                        20.336113
# action_descReplace machine head needle guard / Reemplazar guarda aguja de cabezal           22.857995
# action_descReplace machine head needle plate / Reemplazar placa de aguja de cabezal         30.526754
# action_descReplace machine head presser foot / Reemplazar prensatela de cabezal             21.624168
# action_descReplace machine head teeth / Reemplazar dientes de cabezal                       32.146584
# action_descReplace thread cutting knife / Reemplazar cuchillas corta hilo                   15.671476
# action_descReplace thread tension assembly / Reemplazar tensor auxiliar de largo de hebra   33.387628
# action_descReplace trim off knife / Reemplazar cuchilla de corta desperdicio                22.189094
# action_descSharpen knife / Afilar cuchillas                                                 21.783373
# mechanicAdalberto Jeremias Rodriguez Zometa                                                -41.532197
# mechanicAlfonso Escobar                                                                     -8.992408
# mechanicAngel Mex                                                                          -48.252286
# mechanicAnthony Murillo                                                                    -66.568027
# mechanicAntony Ulloa                                                                       -67.738949
# mechanicCain Alfredo Ramirez                                                               -11.093639
# mechanicCarlos Alberto Alfaro Salamanca                                                      0.033188
# mechanicCARLOS CARRANZA LOBO                                                                 1.794749
# mechanicCarlos De Leon                                                                     -61.251591
# mechanicCarlos Ernesto Rojas Guzman                                                        -44.414844
# mechanicCarlos Galo                                                                        -51.608403
# mechanicCarlos Israel Linares                                                               -7.317928
# mechanicCarlos Montoya                                                                     -22.271010
# mechanicCarlos Oswaldo Rodriguez Sabala                                                      5.577286
# mechanicCarlos Rivas                                                                       -10.165117
# mechanicCarlos Rodriguez                                                                   -42.419558
# mechanicCASTILLO GIRON EDWIN EDGARDO                                                         2.505021
# mechanicCesar Edgardo Ruedas Mendoza                                                        -7.300124
# mechanicCesar Edwin Maradiaga                                                              -26.480339
# mechanicCristian Vladimir Cartagena Ortiz                                                    6.227874
# mechanicDaniel Arevalo                                                                       2.439611
# mechanicDaniel Edgardo Sandoval                                                              4.673022
# mechanicDENY RAYMUNDO PUCH POOL                                                            -44.840089
# mechanicDIEGO CUELLAR                                                                       -4.702263
# mechanicWalter Anibal Belloso Hernandez                                                      6.594875
# mechanicWalter Patino                                                                      -52.668431
# mechanicWALTER RENE SIERRA VARGAS                                                          -22.928308
# mechanicWilliam Alexander Arevalo Leiva                                                    -17.525882
# mechanicWillian Tejada                                                                      15.043669
# mechanicWILMER CRUZ                                                                        -72.458717
# parts_cost                                                                                   0.106514
# outlierTRUE                                                                                333.296609
#                                                                                            Std. Error
# (Intercept)                                                                                  9.507309
# operationBIND LEG                                                                            2.820861
# operationCLOSE SLEEVE                                                                        2.971883
# operationFLAT LOCK                                                                           3.349043
# operationFLAT SEAM                                                                           3.202599
# operationHEM AROUND                                                                          2.585103
# operationHEM BOTTOM                                                                          2.459127
# operationHEM SLEEVE                                                                          2.621009
# operationHEM SLEEVE MAN                                                                      3.880380
# operationJOIN PANEL                                                                          3.205512
# operationJOIN SHOULDER                                                                       2.940162
# operationOtros                                                                               2.337989
# operationSET COLLAR                                                                          2.908610
# operationSET POCKET                                                                          3.240200
# operationSET SLEEVE                                                                          2.710541
# operationSEW ELASTIC                                                                         2.003893
# operationTAPE SHOULDER                                                                       5.622386
# operationTOP STITCH                                                                          2.752050
# operationTOP STITCH COLLAR                                                                   2.992730
# base_modelC5                                                                                 2.904142
# base_modelC5-3-02/233                                                                        3.490252
# base_modelC5-4-M03                                                                           3.078632
# base_modelC5S-4-M03                                                                          2.935002
# base_modelDDL5550                                                                            3.986060
# base_modelDT6L2512                                                                           5.962799
# base_modelEX5214                                                                             3.111875
# base_modelFD-62                                                                              3.994151
# base_modelFD62                                                                               3.805485
# base_modelJ-261                                                                              6.027226
# base_modelJK-797DI                                                                           3.343834
# base_modelJK-798DIII                                                                         3.839771
# base_modelJK-T1904                                                                           3.727497
# base_modelJK-T1904BS                                                                         3.969241
# base_modelJS-2261                                                                            6.218738
# base_modelLC62D                                                                              3.969317
# base_modelLC62D-12                                                                           3.911324
# base_modelLDA-L26                                                                            5.867209
# base_modelOtros                                                                              2.874392
# base_modelT-8722B                                                                            4.417628
# base_modelUS39500                                                                            3.545452
# base_modelVC1700                                                                             3.130779
# base_modelVC2700                                                                             2.989152
# base_modelVC2711                                                                             3.126996
# base_modelVC2713                                                                             3.080568
# base_modelVC3845P                                                                            3.378314
# base_modelVE2700                                                                             4.034935
# base_modelVF2400                                                                             3.904563
# base_modelVF2403                                                                             3.258588
# base_modelVF2500                                                                             4.143389
# base_modelVF2560                                                                             3.792633
# base_modelVG2700                                                                             3.007532
# base_modelVG2713                                                                             3.646407
# base_modelVG2735                                                                             3.609036
# base_modelW600                                                                               3.734149
# base_modelW664                                                                               3.229375
# base_modelWT542                                                                              4.656955
# base_modelWT562                                                                              4.507925
# problem_descIt does not cut the thread / No corta el hilo                                    3.451553
# problem_descIt does not cut the trim off / No corta el desperdicio                           4.058794
# problem_descIt does not sew / No cose                                                        3.100604
# problem_descIt sews with defect / Cose con defecto                                           3.064139
# problem_descOtros                                                                            3.280659
# failure_descChain cutter failure / Falla corta cadenetas                                     4.145868
# failure_descElectric panel failure / Falla pánel eléctrico                                   4.545678
# failure_descEngine failure / Falla motor                                                     4.204350
# failure_descFeeding device failure / Falla dispositivo de alimentación                       4.444889
# failure_descFolder failure / Falla doblillador                                               4.197097
# failure_descLubrication system failure / Falla sistema de lubricación                        4.279824
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defec
# action_descReplace trim off knife / Reemplazar cuchilla de corta desperdicio               ***
# action_descSharpen knife / Afilar cuchillas                                                ***
# mechanicAdalberto Jeremias Rodriguez Zometa                                                ***
# mechanicAlfonso Escobar                                                                    *
# mechanicAngel Mex                                                                          ***
# mechanicAnthony Murillo                                                                    ***
# mechanicAntony Ulloa                                                                       ***
# mechanicCain Alfredo Ramirez                                                               ***
# mechanicCarlos Alberto Alfaro Salamanca
# mechanicCARLOS CARRANZA LOBO
# mechanicCarlos De Leon                                                                     ***
# mechanicCarlos Ernesto Rojas Guzman                                                        ***
# mechanicCarlos Galo                                                                        ***
# mechanicCarlos Israel Linares                                                              *
# mechanicCarlos Montoya                                                                     ***
# mechanicCarlos Oswaldo Rodriguez Sabala
# mechanicCarlos Rivas                                                                       *
# mechanicCarlos Rodriguez                                                                   ***
# mechanicCASTILLO GIRON EDWIN EDGARDO
# mechanicCesar Edgardo Ruedas Mendoza                                                       *
# mechanicCesar Edwin Maradiaga                                                              ***
# mechanicCristian Vladimir Cartagena Ortiz                                                  .
# mechanicDaniel Arevalo
# mechanicDaniel Edgardo Sandoval
# mechanicDENY RAYMUNDO PUCH POOL                                                            ***
# mechanicDIEGO CUELLAR
# mechanicDouglas Alonso Bonilla Soriano                                                     ***
# mechanicDouglas del Cid
# mechanicDOUGLAS LEONEL CHAVEZ                                                              ***
# mechanicDouglas Leonel Chavez Bonilla
# mechanicEdgar Arevalo                                                                      ***
# mechanicEDIS MAREL RODRIGUEZ                                                               ***
# mechanicEduardo Antonio Flores Campos                                                      ***
# mechanicEDWIN ALEXANDER CAMPOS                                                             ***
# mechanicEdwin Colindres                                                                    ***
# mechanicEdwin Edgardo Castillo Giron
# mechanicEdwin Froylan Turcios                                                              ***
# mechanicEdwin Rogelio Galeas Perez                                                         ***
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                        ***
# mechanicEmilio Zeledon Lopez                                                               ***
# mechanicEnrique Pech Canul                                                                 ***
# mechanicErick Garcia Lima                                                                  ***
# mechanicErick Salazar                                                                      ***
# mechanicEver Alfredo Flores Molina                                                         ***
# mechanicFABIAN POSADAS                                                                     ***
# mechanicFAULO VICENTE TEC TORRES                                                           ***
# mechanicFernando Alexander Pubill Quintanilla                                              **
# mechanicFLORES CAMPOS EDUARDO ANTONIO
# mechanicFrancisco Antonio Hernandez                                                        ***
# mechanicFranqui Garcia                                                                     ***
# mechanicFUENTES LIMA NESTOR MAURICIO                                                       ***
# mechanicGabriel Sanchez                                                                    ***
# mechanicGeovanny  Felipe Rivera                                                            ***
# mechanicGerardo Arturo de la Cruz Lemus                                                    ***
# mechanicGilberto Antonio Flores                                                            ***
# mechanicGiovanny Alexander Rivas                                                           ***
# mechanicGuillermo Alfonso Ramirez Landaverde                                               ***
# mechanicGuillermo Josue Lara Ferman                                                        ***
# mechanicHarley Antonio Valiente                                                            *
# mechanicHector Antonio Alfaro
# mechanicHector Montoya                                                                     ***
# mechanicHenry Valdez                                                                       ***
# mechanicHerbert Amilcar Montiel Sosa                                                       ***
# mechanicHugo Hernandez                                                                     ***
# mechanicIGNACIO COB                                                                        ***
# mechanicImmer Sanchez                                                                      ***
# mechanicIsaias Santiago Hernandez                                                          ***
# mechanicJaime Juarez
# mechanicJaime Rivera                                                                       ***
# mechanicJAIRO NATAEL CALIX                                                                 ***
# mechanicJarim Martinez                                                                     ***
# mechanicJeffrey Velasquez                                                                  ***
# mechanicJERONIMO FUNEZ                                                                     ***
# mechanicJimmy Bardales                                                                     ***
# mechanicJoel Elias Chica Bran                                                              ***
# mechanicJoel Ernesto Cuellar Vanegas                                                       ***
# mechanicJose Manuel Perez Zepeda
# mechanicJose Maria Canul Tec                                                               ***
# mechanicJOSE MAURICIO VELASQUEZ ASCENCIO                                                   ***
# mechanicJose Max Reyes Flores                                                              ***
# mechanicJOSE PEDRO DZUL PECH                                                               ***
# mechanicJose Valencia                                                                      ***
# mechanicJosue Zalmeron                                                                     ***
# mechanicJuan Absalon Portillo Lemus                                                        ***
# mechanicJuan Carlos Lemus                                                                  *
# mechanicJuan Francisco Cardona Hernandez
# mechanicJuan Leiva                                                                         ***
# mechanicJuan Manuel Interiano Zaldana
# mechanicJulia Margarita Chicas Diaz
# mechanicKenneth Emerson Clavel Flores                                                      ***
# mechanicLadislao Monterrosa Torres                                                         ***
# mechanicLeonardo Cortez                                                                    ***
# mechanicLeonardo Villanueva                                                                ***
# mechanicLEONEL CHAVEZ                                                                      ***
# mechanicLuis Duran
# mechanicLuis Ernesto de la Rosa Garcia                                                     ***
# mechanicLuis Manuel Garcia Rosales
# mechanicLUIS PECH                                                                          ***
# mechanicMarco Enmanuel Osorio Palacios
# mechanicMarcos Emmanuel Osorio Palacios                                                    ***
# mechanicMARCOS MOGUEL                                                                      ***
# mechanicMAURICIO DAVILA SANCHEZ                                                            ***
# mechanicMauricio Ernesto Valencia                                                          ***
# mechanicMelvin Galeano                                                                     ***
# mechanicMiguel Angel Fajardo Ortiz
# mechanicMONTOYA HECTOR AMERICO                                                             ***
# mechanicNelson Amilcar Rodriguez Salazar                                                   ***
# mechanicNERY MENA RODRIGUEZ                                                                ***
# mechanicNestor Mauricio Carpio Salas                                                       ***
# mechanicNestor Mauricio Fuentes Lima                                                       *
# mechanicNoe Alexander Caballero Flores                                                     ***
# mechanicNOE CONTRERAS                                                                      ***
# mechanicOdil Alfredo Guzman Saget
# mechanicOdil Alfredo Saget Guzman                                                          *
# mechanicOmar Maldonado                                                                     ***
# mechanicOscar Argumedo                                                                     ***
# mechanicOscar Hurtado                                                                      ***
# mechanicOtros                                                                              ***
# mechanicPedro Miguel Martinez Linares                                                      **
# mechanicRafael Esquivel                                                                    ***
# mechanicRAMIREZ RIVERA ABEL ALBERTO
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                        ***
# mechanicRAMON VILLANUEVA                                                                   ***
# mechanicRaul Coto
# mechanicREYES JAVIER CORTEZ CANTE                                                          ***
# mechanicReynaldo Chavez Guerra
# mechanicRichard Lara                                                                       ***
# mechanicRIVAS TORRES CARLOS ANTONIO                                                        **
# mechanicRoberto Reyes
# mechanicROMAN IGNACIO AYALA PUC                                                            ***
# mechanicRonald Antonio Herrera                                                             ***
# mechanicSalvador Roberto Palacios Alvarado                                                 **
# mechanicSalvador Rodriguez                                                                 ***
# mechanicSANCHEZ IMMER ALBERTO                                                              *
# mechanicSAUL ALFARO                                                                        ***
# mechanicSaul Nolberto Alfaro                                                               ***
# mechanicVictor Alfonzo Ardon Monteros                                                      ***
# mechanicVladimir Enrique Aguilar Hernandez                                                 ***
# mechanicWalter Anibal Belloso Hernandez                                                    .
# mechanicWalter Patino                                                                      ***
# mechanicWALTER RENE SIERRA VARGAS                                                          ***
# mechanicWilliam Alexander Arevalo Leiva                                                    ***
# mechanicWillian Tejada                                                                     ***
# mechanicWILMER CRUZ                                                                        ***
# parts_cost                                                                                 ***
# outlierTRUE                                                                                ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 3592.422)
#
#     Null deviance: 989661669  on 95101  degrees of freedom
# Residual deviance: 340647797  on 94824  degrees of freedom
# AIC: 1048728
#
# Number of Fisher Scoring iterations: 2

# %%
# Predecir con el conjunto de prueba
test_predictions <- predict(model1, newdata = test_data1)

# Calcular métricas de rendimiento para el conjunto de prueba
test_actuals <- test_data1$downtime_gross
test_rmse <- sqrt(mean((test_predictions - test_actuals)^2))
test_mae <- mean(abs(test_predictions - test_actuals))
test_r2 <- 1 - (sum((test_predictions - test_actuals)^2) / sum((test_actuals - mean(test_actuals))^2))

cat("Test RMSE: ", test_rmse, "\n")
cat("Test MAE: ", test_mae, "\n")
cat("Test R-squared: ", test_r2, "\n")
# Out:
# Test RMSE:  59.58153
# Test MAE:  43.31577
# Test R-squared:  0.653424

# %% [markdown]
# **CALCULO DE VARIABLES PARA MEJORA DEL AJUSTE**

# %%
#Calcular los fallos acumulativos
df <- df %>%
  group_by(equipment) %>%
  mutate(Cumulative_Failure_Count = row_number())

# %%
# Calcular la mediana de tiempo de reparación
df <- df %>%
  group_by(equipment) %>%
  mutate(Median_Repair_Time = median(repair_hours, na.rm = TRUE))

# %%
# Calcular el costo acumulado de mantenimiento
df <- df %>%
  group_by(equipment) %>%
  mutate(Cumulative_Maintenance_Cost = cumsum(parts_cost))

# %%
# Establecer una semilla para reproducibilidad
set.seed(123)

# Definir la proporción de entrenamiento
train_proportion <- 0.70

# Crear índices de muestreo para el conjunto de entrenamiento
trainIndex <- createDataPartition(df$downtime_gross, p = train_proportion, list = FALSE)

# Crear conjunto de entrenamiento
train_data2 <- df[trainIndex,]

# Crear conjunto de prueba
test_data2 <- df[-trainIndex,]

# Comprobar las dimensiones de cada conjunto
cat("Dimensiones del conjunto de entrenamiento: ", dim(train_data2), "\n")
cat("Dimensiones del conjunto de prueba: ", dim(test_data2), "\n")
# Out:
# Dimensiones del conjunto de entrenamiento:  95102 18
# Dimensiones del conjunto de prueba:  40756 18

# %% [markdown]
# **GLM PARA PREDECIR DOWNTIME CON MAS VARIABLES**

# %%
# Inicializar y ajustar el modelo de regresión lineal
model2 <- glm(downtime_gross~. -equipment -downtime_gross -repair_hours -date -changed_pcs, data = train_data2)
# Resumen del modelo
summary(model2)
# Out:
# Call:
# glm(formula = downtime_gross ~ . - equipment - downtime_gross -
#     repair_hours - date - changed_pcs, data = train_data2)
#
# Coefficients:
#                                                                                              Estimate
# (Intercept)                                                                                 4.242e+01
# operationBIND LEG                                                                          -1.737e+00
# operationCLOSE SLEEVE                                                                       7.763e+00
# operationFLAT LOCK                                                                         -1.185e+01
# operationFLAT SEAM                                                                         -7.374e+00
# operationHEM AROUND                                                                         2.939e+00
# operationHEM BOTTOM                                                                        -6.079e+00
# operationHEM SLEEVE                                                                         8.474e+00
# operationHEM SLEEVE MAN                                                                     1.397e+00
# operationJOIN PANEL                                                                        -6.188e+00
# operationJOIN SHOULDER                                                                     -8.220e+00
# operationOtros                                                                             -4.398e+00
# operationSET COLLAR                                                                        -9.200e+00
# operationSET POCKET                                                                        -6.048e+00
# operationSET SLEEVE                                                                        -9.497e+00
# operationSEW ELASTIC                                                                       -6.885e+00
# operationTAPE SHOULDER                                                                     -7.397e+00
# operationTOP STITCH                                                                        -7.524e+00
# operationTOP STITCH COLLAR                                                                 -5.655e+00
# base_modelC5                                                                                1.208e-01
# base_modelC5-3-02/233                                                                       2.572e+00
# base_modelC5-4-M03                                                                          2.995e+00
# base_modelC5S-4-M03                                                                        -6.151e-01
# base_modelDDL5550                                                                           5.386e-01
# base_modelDT6L2512                                                                          7.569e-01
# base_modelEX5214                                                                            1.177e+00
# base_modelFD-62                                                                            -5.068e+00
# base_modelFD62                                                                              9.638e+00
# base_modelJ-261                                                                             6.098e+00
# base_modelJK-797DI                                                                          7.055e-02
# base_modelJK-798DIII                                                                       -2.239e+00
# base_modelJK-T1904                                                                         -2.820e+00
# base_modelJK-T1904BS                                                                        1.618e+00
# base_modelJS-2261                                                                           7.247e+00
# base_modelLC62D                                                                             7.272e+00
# base_modelLC62D-12                                                                         -5.456e+00
# base_modelLDA-L26                                                                           1.204e+00
# base_modelOtros                                                                             1.048e+00
# base_modelT-8722B                                                                          -6.093e-02
# base_modelUS39500                                                                           1.169e+01
# base_modelVC1700                                                                            5.026e+00
# base_modelVC2700                                                                            2.436e+00
# base_modelVC2711                                                                            1.089e+00
# base_modelVC2713                                                                            5.101e+00
# base_modelVC3845P                                                                          -6.020e-01
# base_modelVE2700                                                                           -5.456e-01
# base_modelVF2400                                                                           -8.954e+00
# base_modelVF2403                                                                            1.847e+00
# base_modelVF2500                                                                           -6.019e+00
# base_modelVF2560                                                                            8.859e-01
# base_modelVG2700                                                                            2.836e+00
# base_modelVG2713                                                                            5.859e+00
# base_modelVG2735                                                                            3.657e+00
# base_modelW600                                                                             -6.965e+00
# base_modelW664                                                                              4.422e+00
# base_modelWT542                                                                             6.726e+00
# base_modelWT562                                                                             2.553e+00
# problem_descIt does not cut the thread / No corta el hilo                                   2.342e+00
# problem_descIt does not cut the trim off / No corta el desperdicio                         -6.771e+00
# problem_descIt does not sew / No cose                                                      -3.819e+00
# problem_descIt sews with defect / Cose con defecto                                          2.646e+00
# problem_descOtros                                                                           4.937e+00
# failure_descChain cutter failure / Falla corta cadenetas                                    6.348e+00
# failure_descElectric panel failure / Falla pánel eléctrico                                  5.899e+00
# failure_descEngine failure / Falla motor                                                    4.767e+00
# failure_descFeeding device failure / Falla dispositivo de alimentación                      3.198e+00
# failure_descFolder failure / Falla doblillador                                              7.998e+00
# failure_descLubrication system failure / Falla sistema de lubricación                       2.484e+01
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defec
# mechanicOdil Alfredo Guzman Saget                                                          -1.783e+01
# mechanicOdil Alfredo Saget Guzman                                                          -1.451e+01
# mechanicOmar Maldonado                                                                     -3.145e+01
# mechanicOscar Argumedo                                                                      7.303e+00
# mechanicOscar Hurtado                                                                      -1.073e+01
# mechanicOtros                                                                              -2.017e+01
# mechanicPedro Miguel Martinez Linares                                                       5.142e+00
# mechanicRafael Esquivel                                                                    -3.459e+01
# mechanicRAMIREZ RIVERA ABEL ALBERTO                                                         9.778e-01
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                        -1.375e+01
# mechanicRAMON VILLANUEVA                                                                   -5.630e+01
# mechanicRaul Coto                                                                          -1.820e+00
# mechanicREYES JAVIER CORTEZ CANTE                                                          -4.356e+01
# mechanicReynaldo Chavez Guerra                                                              3.869e+00
# mechanicRichard Lara                                                                       -3.905e+01
# mechanicRIVAS TORRES CARLOS ANTONIO                                                        -7.855e+00
# mechanicRoberto Reyes                                                                      -8.940e+00
# mechanicROMAN IGNACIO AYALA PUC                                                            -3.015e+01
# mechanicRonald Antonio Herrera                                                             -2.351e+01
# mechanicSalvador Roberto Palacios Alvarado                                                  1.032e+01
# mechanicSalvador Rodriguez                                                                 -3.541e+01
# mechanicSANCHEZ IMMER ALBERTO                                                              -3.135e+00
# mechanicSAUL ALFARO                                                                        -2.278e+01
# mechanicSaul Nolberto Alfaro                                                               -2.639e+01
# mechanicVictor Alfonzo Ardon Monteros                                                      -2.629e+01
# mechanicVladimir Enrique Aguilar Hernandez                                                 -1.950e+01
# mechanicWalter Anibal Belloso Hernandez                                                    -3.085e+00
# mechanicWalter Patino                                                                      -4.534e+01
# mechanicWALTER RENE SIERRA VARGAS                                                          -2.610e+01
# mechanicWilliam Alexander Arevalo Leiva                                                    -1.531e+01
# mechanicWillian Tejada                                                                      4.520e+00
# mechanicWILMER CRUZ                                                                        -5.734e+01
# parts_cost                                                                                  1.038e-01
# Days_Between_Failures                                                                      -4.174e-02
# outlierTRUE                                                                                 3.279e+02
# Cumulative_Failure_Count                                                                   -3.804e-03
# Median_Repair_Time                                                                          3.321e+01
# Cumulative_Maintenance_Cost                                                                -9.049e-04
#                                                                                            Std. Error
# (Intercept)                                                                                 9.374e+00
# operationBIND LEG                                                                           2.780e+00
# operationCLOSE SLEEVE                                                                       2.930e+00
# operationFLAT LOCK                                                                          3.300e+00
# operationFLAT SEAM                                                                          3.157e+00
# operationHEM AROUND                                                                         2.548e+00
# operationHEM BOTTOM                                                                         2.426e+00
# operationHEM SLEEVE                                                                         2.593e+00
# operationHEM SLEEVE MAN                                                                     3.829e+00
# operationJOIN PANEL                                                                         3.158e+00
# operationJOIN SHOULDER                                                                      2.898e+00
# operationOtros                                                                              2.305e+00
# operationSET COLLAR                                                                         2.867e+00
# operationSET POCKET                                                                         3.194e+00
# operationSET SLEEVE                                                                         2.673e+00
# operationSEW ELASTIC                                                                        1.975e+00
# operationTAPE SHOULDER                                                                      5.539e+00
# operationTOP STITCH                                                                         2.715e+00
# operationTOP STITCH COLLAR                                                                  2.949e+00
# base_modelC5                                                                                2.862e+00
# mechanicCASTILLO GIRON EDWIN EDGARDO                                                        4.245e+00
# mechanicCesar Edgardo Ruedas Mendoza                                                        2.891e+00
# mechanicCesar Edwin Maradiaga                                                               3.775e+00
# mechanicCristian Vladimir Cartagena Ortiz                                                   3.328e+00
# mechanicDaniel Arevalo                                                                      3.455e+00
# mechanicDaniel Edgardo Sandoval                                                             5.530e+00
# mechanicDENY RAYMUNDO PUCH POOL                                                             3.020e+00
# mechanicDIEGO CUELLAR                                                                       2.865e+00
# mechanicDouglas Alonso Bonilla Soriano                                                      5.042e+00
# mechanicDouglas del Cid                                                                     3.500e+00
# mechanicDOUGLAS LEONEL CHAVEZ                                                               3.805e+00
# mechanicDouglas Leonel Chavez Bonilla                                                       4.361e+00
# mechanicEdgar Arevalo                                                                       2.991e+00
# mechanicEDIS MAREL RODRIGUEZ                                                                3.326e+00
# mechanicEduardo Antonio Flores Campos                                                       2.677e+00
# mechanicEDWIN ALEXANDER CAMPOS                                                              2.984e+00
# mechanicEdwin Colindres                                                                     2.977e+00
# mechanicEdwin Edgardo Castillo Giron                                                        2.840e+00
# mechanicEdwin Froylan Turcios                                                               3.389e+00
# mechanicEdwin Rogelio Galeas Perez                                                          2.724e+00
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                         3.448e+00
# mechanicEmilio Zeledon Lopez                                                                3.359e+00
# mechanicEnrique Pech Canul                                                                  3.704e+00
# mechanicErick Garcia Lima                                                                   2.817e+00
# mechanicErick Salazar                                                                       3.187e+00
# mechanicEver Alfredo Flores Molina                                                          3.538e+00
# mechanicFABIAN POSADAS                                                                      4.818e+00
# mechanicFAULO VICENTE TEC TORRES                                                            2.939e+00
# mechanicFernando Alexander Pubill Quintanilla                                               3.192e+00
# mechanicFLORES CAMPOS EDUARDO ANTONIO                                                       3.732e+00
# mechanicFrancisco Antonio Hernandez                                                         3.597e+00
# mechanicFranqui Garcia                                                                      4.769e+00
# mechanicFUENTES LIMA NESTOR MAURICIO                                                        4.461e+00
# mechanicGabriel Sanchez                                                                     3.818e+00
# mechanicGeovanny  Felipe Rivera                                                             3.510e+00
# ...
# action_descInspect stacker air supply / Revisar suministro de aire en apilador             .
# action_descOtros                                                                           ***
# action_descPolish thread take up / Pulir leva
# action_descReplace bobbin / Reemplazar bobina
# action_descReplace burner resistance / Reemplazar resistencia de quemador                  .
# action_descReplace machine head ball joint / Reemplazar biela de cabezal
# action_descReplace machine head knife / Reemplazar cuchilla de cabezal                     **
# action_descReplace machine head looper / Reemplazar enlazador de cabezal                   ***
# action_descReplace machine head needle / Reemplazar aguja de cabezal                       **
# action_descReplace machine head needle guard / Reemplazar guarda aguja de cabezal          **
# action_descReplace machine head needle plate / Reemplazar placa de aguja de cabezal        ***
# action_descReplace machine head presser foot / Reemplazar prensatela de cabezal            **
# action_descReplace machine head teeth / Reemplazar dientes de cabezal                      ***
# action_descReplace thread cutting knife / Reemplazar cuchillas corta hilo                  .
# action_descReplace thread tension assembly / Reemplazar tensor auxiliar de largo de hebra  ***
# action_descReplace trim off knife / Reemplazar cuchilla de corta desperdicio               **
# action_descSharpen knife / Afilar cuchillas                                                **
# mechanicAdalberto Jeremias Rodriguez Zometa                                                ***
# mechanicAlfonso Escobar                                                                    .
# mechanicAngel Mex                                                                          ***
# mechanicAnthony Murillo                                                                    ***
# mechanicAntony Ulloa                                                                       ***
# mechanicCain Alfredo Ramirez                                                               .
# mechanicCarlos Alberto Alfaro Salamanca
# mechanicCARLOS CARRANZA LOBO
# mechanicCarlos De Leon                                                                     ***
# mechanicCarlos Ernesto Rojas Guzman                                                        ***
# mechanicCarlos Galo                                                                        ***
# mechanicCarlos Israel Linares                                                              **
# mechanicCarlos Montoya                                                                     ***
# mechanicCarlos Oswaldo Rodriguez Sabala
# mechanicCarlos Rivas
# mechanicCarlos Rodriguez                                                                   ***
# mechanicCASTILLO GIRON EDWIN EDGARDO                                                       .
# mechanicCesar Edgardo Ruedas Mendoza                                                       .
# mechanicCesar Edwin Maradiaga                                                              ***
# mechanicCristian Vladimir Cartagena Ortiz
# mechanicDaniel Arevalo
# mechanicDaniel Edgardo Sandoval
# mechanicDENY RAYMUNDO PUCH POOL                                                            ***
# mechanicDIEGO CUELLAR
# mechanicDouglas Alonso Bonilla Soriano                                                     ***
# mechanicDouglas del Cid
# mechanicDOUGLAS LEONEL CHAVEZ                                                              ***
# mechanicDouglas Leonel Chavez Bonilla
# mechanicEdgar Arevalo                                                                      ***
# mechanicEDIS MAREL RODRIGUEZ                                                               ***
# mechanicEduardo Antonio Flores Campos                                                      ***
# mechanicEDWIN ALEXANDER CAMPOS                                                             ***
# mechanicEdwin Colindres                                                                    ***
# mechanicEdwin Edgardo Castillo Giron
# mechanicEdwin Froylan Turcios                                                              ***
# mechanicEdwin Rogelio Galeas Perez                                                         ***
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                        ***
# mechanicEmilio Zeledon Lopez                                                               ***
# mechanicEnrique Pech Canul                                                                 ***
# mechanicErick Garcia Lima                                                                  ***
# mechanicErick Salazar                                                                      ***
# mechanicEver Alfredo Flores Molina                                                         ***
# mechanicFABIAN POSADAS                                                                     ***
# mechanicFAULO VICENTE TEC TORRES                                                           ***
# mechanicFernando Alexander Pubill Quintanilla                                              ***
# mechanicFLORES CAMPOS EDUARDO ANTONIO                                                      **
# mechanicFrancisco Antonio Hernandez                                                        ***
# mechanicFranqui Garcia                                                                     ***
# mechanicFUENTES LIMA NESTOR MAURICIO                                                       .
# mechanicGabriel Sanchez                                                                    ***
# mechanicGeovanny  Felipe Rivera                                                            ***
# mechanicGerardo Arturo de la Cruz Lemus                                                    ***
# mechanicGilberto Antonio Flores                                                            ***
# mechanicGiovanny Alexander Rivas                                                           ***
# mechanicGuillermo Alfonso Ramirez Landaverde                                               ***
# mechanicGuillermo Josue Lara Ferman                                                        ***
# mechanicHarley Antonio Valiente                                                            ***
# mechanicHector Antonio Alfaro
# mechanicHector Montoya                                                                     ***
# mechanicHenry Valdez                                                                       ***
# mechanicHerbert Amilcar Montiel Sosa                                                       ***
# mechanicHugo Hernandez                                                                     ***
# mechanicIGNACIO COB                                                                        ***
# mechanicImmer Sanchez                                                                      ***
# mechanicIsaias Santiago Hernandez                                                          ***
# mechanicJaime Juarez
# mechanicJaime Rivera                                                                       ***
# mechanicJAIRO NATAEL CALIX                                                                 ***
# mechanicJarim Martinez                                                                     ***
# mechanicJeffrey Velasquez                                                                  ***
# mechanicJERONIMO FUNEZ                                                                     ***
# mechanicJimmy Bardales                                                                     ***
# mechanicJoel Elias Chica Bran                                                              ***
# mechanicJoel Ernesto Cuellar Vanegas                                                       ***
# mechanicJose Manuel Perez Zepeda
# mechanicJose Maria Canul Tec                                                               ***
# mechanicJOSE MAURICIO VELASQUEZ ASCENCIO                                                   ***
# mechanicJose Max Reyes Flores                                                              ***
# mechanicJOSE PEDRO DZUL PECH                                                               ***
# mechanicJose Valencia                                                                      ***
# mechanicJosue Zalmeron                                                                     ***
# mechanicJuan Absalon Portillo Lemus                                                        ***
# mechanicJuan Carlos Lemus
# mechanicJuan Francisco Cardona Hernandez
# mechanicJuan Leiva                                                                         ***
# mechanicJuan Manuel Interiano Zaldana
# mechanicJulia Margarita Chicas Diaz                                                        .
# mechanicKenneth Emerson Clavel Flores                                                      ***
# mechanicLadislao Monterrosa Torres                                                         ***
# mechanicLeonardo Cortez                                                                    ***
# mechanicLeonardo Villanueva                                                                ***
# mechanicLEONEL CHAVEZ                                                                      ***
# mechanicLuis Duran
# mechanicLuis Ernesto de la Rosa Garcia                                                     ***
# mechanicLuis Manuel Garcia Rosales
# mechanicLUIS PECH                                                                          ***
# mechanicMarco Enmanuel Osorio Palacios
# mechanicMarcos Emmanuel Osorio Palacios                                                    ***
# mechanicMARCOS MOGUEL                                                                      ***
# mechanicMAURICIO DAVILA SANCHEZ                                                            ***
# mechanicMauricio Ernesto Valencia                                                          ***
# mechanicMelvin Galeano                                                                     ***
# mechanicMiguel Angel Fajardo Ortiz
# mechanicMONTOYA HECTOR AMERICO                                                             ***
# mechanicNelson Amilcar Rodriguez Salazar                                                   ***
# mechanicNERY MENA RODRIGUEZ                                                                ***
# mechanicNestor Mauricio Carpio Salas                                                       ***
# mechanicNestor Mauricio Fuentes Lima
# mechanicNoe Alexander Caballero Flores                                                     ***
# mechanicNOE CONTRERAS                                                                      ***
# mechanicOdil Alfredo Guzman Saget                                                          ***
# mechanicOdil Alfredo Saget Guzman                                                          **
# mechanicOmar Maldonado                                                                     ***
# mechanicOscar Argumedo                                                                     *
# mechanicOscar Hurtado                                                                      *
# mechanicOtros                                                                              ***
# mechanicPedro Miguel Martinez Linares
# mechanicRafael Esquivel                                                                    ***
# mechanicRAMIREZ RIVERA ABEL ALBERTO
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                        **
# mechanicRAMON VILLANUEVA                                                                   ***
# mechanicRaul Coto
# mechanicREYES JAVIER CORTEZ CANTE                                                          ***
# mechanicReynaldo Chavez Guerra
# mechanicRichard Lara                                                                       ***
# mechanicRIVAS TORRES CARLOS ANTONIO
# mechanicRoberto Reyes
# mechanicROMAN IGNACIO AYALA PUC                                                            ***
# mechanicRonald Antonio Herrera                                                             ***
# mechanicSalvador Roberto Palacios Alvarado                                                 **
# mechanicSalvador Rodriguez                                                                 ***
# mechanicSANCHEZ IMMER ALBERTO
# mechanicSAUL ALFARO                                                                        ***
# mechanicSaul Nolberto Alfaro                                                               ***
# mechanicVictor Alfonzo Ardon Monteros                                                      ***
# mechanicVladimir Enrique Aguilar Hernandez                                                 ***
# mechanicWalter Anibal Belloso Hernandez
# mechanicWalter Patino                                                                      ***
# mechanicWALTER RENE SIERRA VARGAS                                                          ***
# mechanicWilliam Alexander Arevalo Leiva                                                    ***
# mechanicWillian Tejada
# mechanicWILMER CRUZ                                                                        ***
# parts_cost                                                                                 ***
# Days_Between_Failures                                                                      ***
# outlierTRUE                                                                                ***
# Cumulative_Failure_Count
# Median_Repair_Time                                                                         ***
# Cumulative_Maintenance_Cost                                                                *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 3485.826)
#
#     Null deviance: 989661669  on 95101  degrees of freedom
# Residual deviance: 330526051  on 94820  degrees of freedom
# AIC: 1045867
#
# Number of Fisher Scoring iterations: 2

# %%
# Predecir con el conjunto de prueba
test_predictions <- predict(model2, newdata = test_data2)

# Calcular métricas de rendimiento para el conjunto de prueba
test_actuals <- test_data2$downtime_gross
test_rmse <- sqrt(mean((test_predictions - test_actuals)^2))
test_mae <- mean(abs(test_predictions - test_actuals))
test_r2 <- 1 - (sum((test_predictions - test_actuals)^2) / sum((test_actuals - mean(test_actuals))^2))

cat("Test RMSE: ", test_rmse, "\n")
cat("Test MAE: ", test_mae, "\n")
cat("Test R-squared: ", test_r2, "\n")
# Out:
# Test RMSE:  58.7193
# Test MAE:  42.40528
# Test R-squared:  0.6633823

# %% [markdown]
# **MODELO AGREGANDO LA VARIABLE "MACHINE AGE"**

# %%
# Renombrar la columna 'Equipment' a 'equipment' en df_age
df_age <- df_age %>% rename(equipment = Equipment)

# %%
df_merged <- df %>%
  left_join(df_age %>% select(equipment, Age), by = "equipment")

# %%
head(df_merged,3)
# Out:
#   equipment operation  base_model
# 1 1011144   HEM SLEEVE VC2700
# 2 1013453   TOP STITCH VC2713
# 3 1013453   TOP STITCH VC2713
#   problem_desc
# 1 It does not cut the trim off / No corta el desperdicio
# 2 It sews with defect / Cose con defecto
# 3 It sews with defect / Cose con defecto
#   failure_desc
# 1 Trim off device failure / Falla dispositivo corta desperdicio
# 2 Machine head failure stopping sewing  / Falla cabezal dejando de coser
# 3 Machine head failure stopping sewing  / Falla cabezal dejando de coser
#   cause_desc
# 1 Damaged trim off system knife / Cuchilla de corta desperdicio en mal estado
# 2 Misadjusted machine head needle guard / Guarda aguja de cabezal desajustada
# 3 Misadjusted machine head needle guard / Guarda aguja de cabezal desajustada
#   action_desc
# 1 Sharpen knife / Afilar cuchillas
# 2 Adjust machine head needle guard / Ajustar guarda aguja de cabezal
# 3 Adjust machine head needle guard / Ajustar guarda aguja de cabezal
#   mechanic                            date       downtime_gross parts_cost
# 1 DIEGO CUELLAR                       2023-01-03 10             51.0
# 2 Adalberto Jeremias Rodriguez Zometa 2023-01-03 60             19.2
# 3 Adalberto Jeremias Rodriguez Zometa 2023-01-03 60             19.2
#   repair_hours changed_pcs Days_Between_Failures outlier
# 1 0.1666667    0           2                     FALSE
# 2 1.0000000    1           2                     FALSE
# 3 1.0000000    1           0                     FALSE
#   Cumulative_Failure_Count Median_Repair_Time Cumulative_Maintenance_Cost Age
# 1 1                        0.5                51.0                        26
# 2 1                        1.0                19.2                        23
# 3 2                        1.0                38.4                        23

# %%
# Establecer una semilla para reproducibilidad
set.seed(123)

# Definir la proporción de entrenamiento
train_proportion <- 0.70

# Crear índices de muestreo para el conjunto de entrenamiento
trainIndex <- createDataPartition(df_merged$downtime_gross, p = train_proportion, list = FALSE)

# Crear conjunto de entrenamiento
train_data3 <- df_merged[trainIndex,]

# Crear conjunto de prueba
test_data3 <- df_merged[-trainIndex,]

# Comprobar las dimensiones de cada conjunto
cat("Dimensiones del conjunto de entrenamiento: ", dim(train_data3), "\n")
cat("Dimensiones del conjunto de prueba: ", dim(test_data3), "\n")
# Out:
# Dimensiones del conjunto de entrenamiento:  95102 19
# Dimensiones del conjunto de prueba:  40756 19

# %%
# Inicializar y ajustar el modelo de regresión lineal
model3 <- glm(downtime_gross~. -equipment -downtime_gross -repair_hours -date -changed_pcs, data = train_data3)
# Resumen del modelo
summary(model3)
# Out:
# Call:
# glm(formula = downtime_gross ~ . - equipment - downtime_gross -
#     repair_hours - date - changed_pcs, data = train_data3)
#
# Coefficients:
#                                                                                              Estimate
# (Intercept)                                                                                 3.639e+01
# operationBIND LEG                                                                          -1.426e+00
# operationCLOSE SLEEVE                                                                       8.282e+00
# operationFLAT LOCK                                                                         -1.093e+01
# operationFLAT SEAM                                                                         -6.661e+00
# operationHEM AROUND                                                                         2.975e+00
# operationHEM BOTTOM                                                                        -5.900e+00
# operationHEM SLEEVE                                                                         8.602e+00
# operationHEM SLEEVE MAN                                                                     1.129e+00
# operationJOIN PANEL                                                                        -5.593e+00
# operationJOIN SHOULDER                                                                     -7.185e+00
# operationOtros                                                                             -3.754e+00
# operationSET COLLAR                                                                        -8.490e+00
# operationSET POCKET                                                                        -5.180e+00
# operationSET SLEEVE                                                                        -8.387e+00
# operationSEW ELASTIC                                                                       -6.561e+00
# operationTAPE SHOULDER                                                                     -7.286e+00
# operationTOP STITCH                                                                        -7.227e+00
# operationTOP STITCH COLLAR                                                                 -5.462e+00
# base_modelC5                                                                                1.051e+00
# base_modelC5-3-02/233                                                                       3.065e+00
# base_modelC5-4-M03                                                                          3.534e+00
# base_modelC5S-4-M03                                                                         2.261e-01
# base_modelDDL5550                                                                           8.849e-01
# base_modelDT6L2512                                                                          1.403e+00
# base_modelEX5214                                                                            1.753e+00
# base_modelFD-62                                                                            -4.739e+00
# base_modelFD62                                                                              9.112e+00
# base_modelJ-261                                                                             6.580e+00
# base_modelJK-797DI                                                                          1.035e+00
# base_modelJK-798DIII                                                                       -1.325e+00
# base_modelJK-T1904                                                                         -2.602e+00
# base_modelJK-T1904BS                                                                        3.011e+00
# base_modelJS-2261                                                                           7.523e+00
# base_modelLC62D                                                                             6.905e+00
# base_modelLC62D-12                                                                         -5.440e+00
# base_modelLDA-L26                                                                           1.755e+00
# base_modelOtros                                                                             1.672e+00
# base_modelT-8722B                                                                          -3.157e-01
# base_modelUS39500                                                                           1.107e+01
# base_modelVC1700                                                                            4.884e+00
# base_modelVC2700                                                                            2.540e+00
# base_modelVC2711                                                                            1.199e+00
# base_modelVC2713                                                                            5.051e+00
# base_modelVC3845P                                                                          -3.314e-01
# base_modelVE2700                                                                           -4.506e-02
# base_modelVF2400                                                                           -8.134e+00
# base_modelVF2403                                                                            2.126e+00
# base_modelVF2500                                                                           -5.707e+00
# base_modelVF2560                                                                            1.547e+00
# base_modelVG2700                                                                            3.184e+00
# base_modelVG2713                                                                            5.813e+00
# base_modelVG2735                                                                            3.804e+00
# base_modelW600                                                                             -5.677e+00
# base_modelW664                                                                              4.253e+00
# base_modelWT542                                                                             7.066e+00
# base_modelWT562                                                                             3.336e+00
# problem_descIt does not cut the thread / No corta el hilo                                   2.438e+00
# problem_descIt does not cut the trim off / No corta el desperdicio                         -6.656e+00
# problem_descIt does not sew / No cose                                                      -3.728e+00
# problem_descIt sews with defect / Cose con defecto                                          2.698e+00
# problem_descOtros                                                                           5.024e+00
# failure_descChain cutter failure / Falla corta cadenetas                                    6.242e+00
# failure_descElectric panel failure / Falla pánel eléctrico                                  5.866e+00
# failure_descEngine failure / Falla motor                                                    4.694e+00
# failure_descFeeding device failure / Falla dispositivo de alimentación                      3.252e+00
# failure_descFolder failure / Falla doblillador                                              7.975e+00
# failure_descLubrication system failure / Falla sistema de lubricación                       2.481e+01
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defecto    5.974e-01
# failure_descMachine head failure stopping sewing  / Falla cabezal dejando de coser          4.358e+00
# failure_descMonitoring and control failure / Falla monitoreo y control                      8.300e+00
# failure_descOtros                                                                           2.717e+00
# failure_descStacker failure it stops piling up / Falla apilador dejando de apilar           5.041e+00
# failure_descTrim off device failure / Falla dispositivo corta desperdicio                  -3.663e+00
# failure_descTrim off device stops cutting/Falla dispositivo corta tela deja de cortar       1.260e+00
# cause_descBroken knife of machine head / Rotura de cuchilla de cabezal                     -4.174e+00
# cause_descBroken machine head ball joint / Rotura de biela de cabezal                       1.949e+01
# cause_descBroken machine head looper / Rotura de enlazador de cabezal                      -1.817e+00
# cause_descBroken machine head needle plate / Rotura de placa de aguja de cabezal           -6.412e+00
# cause_descBroken machine head presser foot  / Rotura de prensatela de cabezal              -4.194e+00
# cause_descDamaged  moving knife shaft /Eje cuchilla móvil corta desperdicio en mal estado   2.795e-01
# cause_descDamaged bobbin / Bobina en mal estado                                             1.656e+01
# cause_descDamaged burner resistance / Resistencia de quemador en mal estado                -3.516e+00
# cause_descDamaged control box / Caja de control en mal estado                               1.430e+01
# cause_descDamaged machine head looper / Enlazador de cabezal en mal estado                 -6.021e+00
# cause_descDamaged machine head thread take up / Leva de cabezal en mal estado              -2.952e+00
# cause_descDamaged thread cutting knife / Cuchillas corta hilo en mal estado                 8.826e+00
# cause_descDamaged trim off system knife / Cuchilla de corta desperdicio en mal estado      -2.639e+00
# cause_descExcessive dirt in machine head / Suciedad excesiva en cabezal                    -2.964e+00
# cause_descLoose machine head teeth / Soltura de dientes de cabezal                         -7.561e-01
# cause_descMisadjusted chain cutter knife / Cuchilla de corta cadeneta desajustada           9.157e+00
# cause_descMisadjusted folder guide / Guía de doblillador desajustadas                      -5.998e+00
# cause_descMisadjusted hook set / Conjunto de garfios mal ajustados                         -1.311e+00
# cause_descMisadjusted machine head chopper / Cuchilla de cabezal desajustada               -4.949e+00
# cause_descMisadjusted machine head looper / Enlazador de cabezal desajustado                1.883e+00
# cause_descMisadjusted machine head needle bar / Barra de aguja de cabezal desajustada       3.164e+00
# cause_descMisadjusted machine head needle guard / Guarda aguja de cabezal desajustada       4.449e+00
# cause_descMisadjusted machine head presser foot / Prensatela de cabezal desajustado         1.071e+00
# cause_descMisadjusted machine head teeth / Dientes de cabezal desajustados                  1.160e+00
# cause_descMisadjusted Sensor for cloth detection / Sensor detector de tela mal calibrado   -2.121e+01
# cause_descMisadjusted thread cutting knife / Cuchillas corta hilo mal ajustadas             6.085e+00
# cause_descOil leak in machine head / Fuga de aceite lubricante en cabezal                   1.055e+01
# cause_descOtros                                                                            -1.693e+00
# cause_descWorn-out machine head looper / Enlazador de cabezal desgastado                   -1.471e+00
# action_descAdjust folder guide / Ajustar guía de doblillador                                2.002e+01
# action_descAdjust hook set / Ajustar conjunto de el garfio                                  2.813e+01
# action_descAdjust machine head knife / Ajustar cuchilla de cabezal                          2.228e+01
# action_descAdjust machine head looper / Ajustar enlazador de cabezal                        2.695e+01
# action_descAdjust machine head needle guard / Ajustar guarda aguja de cabezal               2.117e+01
# action_descAdjust machine head sensor / Ajustar sensor de cabezal                           2.524e+01
# action_descAdjust machine head teeth / Ajustar dientes de cabezal                           2.427e+01
# action_descAdjust thread cutting knife / Ajustar cuchillas corta hilo                       2.652e+01
# action_descAdjusted machine head needle bar / Ajustar barra de aguja de cabezal             2.599e+01
# action_descAdjusted machine head presser foot / Ajustar prensatela de cabezal               2.230e+01
# action_descClean machine head / Limpiar cabezal                                             2.376e+01
# action_descFasten machine head pedal brace / Asegurar soporte de pedal de coser de cabezal  2.306e+01
# action_descFix machine head oil leak / Corregir fuga de aceite en cabezal                   3.063e+01
# action_descInspect stacker air supply / Revisar suministro de aire en apilador              1.168e+01
# action_descOtros                                                                            2.034e+01
# action_descPolish thread take up / Pulir leva                                               9.201e+00
# action_descReplace bobbin / Reemplazar bobina                                               8.550e+00
# action_descReplace burner resistance / Reemplazar resistencia de quemador                   1.663e+01
# action_descReplace machine head ball joint / Reemplazar biela de cabezal                    1.349e+01
# action_descReplace machine head knife / Reemplazar cuchilla de cabezal                      2.525e+01
# action_descReplace machine head looper / Reemplazar enlazador de cabezal                    3.511e+01
# action_descReplace machine head needle / Reemplazar aguja de cabezal                        2.308e+01
# action_descReplace machine head needle guard / Reemplazar guarda aguja de cabezal           2.159e+01
# action_descReplace machine head needle plate / Reemplazar placa de aguja de cabezal         2.953e+01
# action_descReplace machine head presser foot / Reemplazar prensatela de cabezal             2.107e+01
# action_descReplace machine head teeth / Reemplazar dientes de cabezal                       3.117e+01
# action_descReplace thread cutting knife / Reemplazar cuchillas corta hilo                   1.568e+01
# action_descReplace thread tension assembly / Reemplazar tensor auxiliar de largo de hebra   3.444e+01
# action_descReplace trim off knife / Reemplazar cuchilla de corta desperdic
# mechanicNoe Alexander Caballero Flores                                                     -2.805e+01
# mechanicNOE CONTRERAS                                                                      -4.528e+01
# mechanicOdil Alfredo Guzman Saget                                                          -1.813e+01
# mechanicOdil Alfredo Saget Guzman                                                          -1.479e+01
# mechanicOmar Maldonado                                                                     -3.225e+01
# mechanicOscar Argumedo                                                                      6.909e+00
# mechanicOscar Hurtado                                                                      -1.083e+01
# mechanicOtros                                                                              -2.016e+01
# mechanicPedro Miguel Martinez Linares                                                       4.955e+00
# mechanicRafael Esquivel                                                                    -3.520e+01
# mechanicRAMIREZ RIVERA ABEL ALBERTO                                                         7.204e-01
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                        -1.373e+01
# mechanicRAMON VILLANUEVA                                                                   -5.715e+01
# mechanicRaul Coto                                                                          -1.884e+00
# mechanicREYES JAVIER CORTEZ CANTE                                                          -4.301e+01
# mechanicReynaldo Chavez Guerra                                                              3.605e+00
# mechanicRichard Lara                                                                       -3.914e+01
# mechanicRIVAS TORRES CARLOS ANTONIO                                                        -7.723e+00
# mechanicRoberto Reyes                                                                      -9.501e+00
# mechanicROMAN IGNACIO AYALA PUC                                                            -3.038e+01
# mechanicRonald Antonio Herrera                                                             -2.390e+01
# mechanicSalvador Roberto Palacios Alvarado                                                  1.004e+01
# mechanicSalvador Rodriguez                                                                 -3.489e+01
# mechanicSANCHEZ IMMER ALBERTO                                                              -3.178e+00
# mechanicSAUL ALFARO                                                                        -2.278e+01
# mechanicSaul Nolberto Alfaro                                                               -2.656e+01
# mechanicVictor Alfonzo Ardon Monteros                                                      -2.596e+01
# mechanicVladimir Enrique Aguilar Hernandez                                                 -1.965e+01
# mechanicWalter Anibal Belloso Hernandez                                                    -3.324e+00
# mechanicWalter Patino                                                                      -4.540e+01
# mechanicWALTER RENE SIERRA VARGAS                                                          -2.501e+01
# mechanicWilliam Alexander Arevalo Leiva                                                    -1.559e+01
# mechanicWillian Tejada                                                                      3.710e+00
# mechanicWILMER CRUZ                                                                        -5.637e+01
# parts_cost                                                                                  1.043e-01
# Days_Between_Failures                                                                      -3.466e-02
# outlierTRUE                                                                                 3.278e+02
# Cumulative_Failure_Count                                                                   -6.521e-03
# Median_Repair_Time                                                                          3.326e+01
# Cumulative_Maintenance_Cost                                                                -8.855e-04
# Age                                                                                         2.557e-01
#                                                                                            Std. Error
# (Intercept)                                                                                 9.416e+00
# operationBIND LEG                                                                           2.780e+00
# operationCLOSE SLEEVE                                                                       2.931e+00
# operationFLAT LOCK                                                                          3.302e+00
# operationFLAT SEAM                                                                          3.158e+00
# operationHEM AROUND                                                                         2.548e+00
# operationHEM BOTTOM                                                                         2.426e+00
# operationHEM SLEEVE                                                                         2.593e+00
# operationHEM SLEEVE MAN                                                                     3.828e+00
# operationJOIN PANEL                                                                         3.159e+00
# operationJOIN SHOULDER                                                                      2.902e+00
# operationOtros                                                                              2.306e+00
# operationSET COLLAR                                                                         2.868e+00
# operationSET POCKET                                                                         3.196e+00
# operationSET SLEEVE                                                                         2.677e+00
# operationSEW ELASTIC                                                                        1.975e+00
# operationTAPE SHOULDER                                                                      5.538e+00
# operationTOP STITCH                                                                         2.715e+00
# operationTOP STITCH COLLAR                                                                  2.949e+00
# base_modelC5                                                                                2.865e+00
# base_modelC5-3-02/233                                                                       3.439e+00
# base_modelC5-4-M03                                                                          3.034e+00
# base_modelC5S-4-M03                                                                         2.895e+00
# base_modelDDL5550                                                                           3.926e+00
# base_modelDT6L2512                                                                          5.874e+00
# base_modelEX5214                                                                            3.066e+00
# base_modelFD-62                                                                             3.935e+00
# base_modelFD62                                                                              3.749e+00
# base_modelJ-261                                                                             5.937e+00
# base_modelJK-797DI                                                                          3.297e+00
# base_modelJK-798DIII                                                                        3.786e+00
# base_modelJK-T1904                                                                          3.672e+00
# base_modelJK-T1904BS                                                                        3.917e+00
# base_modelJS-2261                                                                           6.125e+00
# base_modelLC62D                                                                             3.910e+00
# base_modelLC62D-12                                                                          3.860e+00
# base_modelLDA-L26                                                                           5.779e+00
# base_modelOtros                                                                             2.834e+00
# base_modelT-8722B                                                                           4.352e+00
# base_modelUS39500                                                                           3.493e+00
# base_modelVC1700                                                                            3.085e+00
# base_modelVC2700                                                                            2.946e+00
# base_modelVC2711                                                                            3.081e+00
# base_modelVC2713                                                                            3.035e+00
# base_modelVC3845P                                                                           3.329e+00
# base_modelVE2700                                                                            3.976e+00
# base_modelVF2400                                                                            3.848e+00
# base_modelVF2403                                                                            3.210e+00
# base_modelVF2500                                                                            4.082e+00
# base_modelVF2560                                                                            3.740e+00
# base_modelVG2700                                                                            2.964e+00
# base_modelVG2713                                                                            3.592e+00
# base_modelVG2735                                                                            3.555e+00
# base_modelW600                                                                              3.684e+00
# base_modelW664                                                                              3.181e+00
# base_modelWT542                                                                             4.588e+00
# base_modelWT562                                                                             4.443e+00
# problem_descIt does not cut the thread / No corta el hilo                                   3.399e+00
# problem_descIt does not cut the trim off / No corta el desperdicio                          3.997e+00
# problem_descIt does not sew / No cose                                                       3.054e+00
# problem_descIt sews with defect / Cose con defecto                                          3.018e+00
# problem_descOtros                                                                           3.231e+00
# failure_descChain cutter failure / Falla corta cadenetas                                    4.083e+00
# failure_descElectric panel failure / Falla pánel eléctrico                                  4.477e+00
# failure_descEngine failure / Falla motor                                                    4.141e+00
# failure_descFeeding device failure / Falla dispositivo de alimentación                      4.378e+00
# failure_descFolder failure / Falla doblillador                                              4.134e+00
# failure_descLubrication system failure / Falla sistema de lubricación                       4.216e+00
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defecto    3.851e+00
# failure_descMachine head failure stopping sewing  / Falla cabezal dejando de coser          3.847e+00
# failure_descMonitoring and control failure / Falla monitoreo y control                      4.199e+00
# failure_descOtros                                                                           3.978e+00
# failure_descStacker failure it stops piling up / Falla apilador dejando de apilar           4.273e+00
# failure_descTrim off device failure / Falla dispositivo corta desperdicio                   3.966e+00
# failure_descTrim off device stops cutting/Falla dispositivo corta tela deja de cortar       5.202e+00
# cause_descBroken knife of machine head / Rotura de cuchilla de cabezal                      6.375e+00
# cause_descBroken machine head ball joint / Rotura de biela de cabezal                       6.676e+00
# cause_descBroken machine head looper / Rotura de enlazador de cabezal                       4.919e+00
# cause_descBroken machine head needle plate / Rotura de placa de aguja de cabezal            7.110e+00
# cause_descBroken machine head presser foot  / Rotura de prensatela de cabezal               5.114e+00
# cause_descDamaged  moving knife shaft /Eje cuchilla móvil corta desperdicio en mal estado   4.694e+00
# cause_descDamaged bobbin / Bobina en mal estado                                             7.627e+00
# cause_descDamaged burner resistance / Resistencia de quemador en mal estado                 7.951e+00
# cause_descDamaged control box / Caja de control en mal estado                               4.934e+00
# cause_descDamaged machine head looper / Enlazador de cabezal en mal estado                  4.727e+00
# cause_descDamaged machine head thread take up / Leva de cabezal en mal estado               5.341e+00
# cause_descDamaged thread cutting knife / Cuchillas corta hilo en mal estado                 7.216e+00
# cause_descDamaged trim off system knife / Cuchilla de corta desperdicio en mal estado       4.652e+00
# cause_descExcessive dirt in machine head / Suciedad excesiva en cabezal                     6.709e+00
# cause_descLoose machine head teeth / Soltura de dientes de cabezal                          4.678e+00
# cause_descMisadjusted chain cutter knife / Cuchilla de corta cadeneta desajust
# mechanicCASTILLO GIRON EDWIN EDGARDO                                                       .
# mechanicCesar Edgardo Ruedas Mendoza                                                       *
# mechanicCesar Edwin Maradiaga                                                              ***
# mechanicCristian Vladimir Cartagena Ortiz
# mechanicDaniel Arevalo
# mechanicDaniel Edgardo Sandoval
# mechanicDENY RAYMUNDO PUCH POOL                                                            ***
# mechanicDIEGO CUELLAR
# mechanicDouglas Alonso Bonilla Soriano                                                     ***
# mechanicDouglas del Cid
# mechanicDOUGLAS LEONEL CHAVEZ                                                              ***
# mechanicDouglas Leonel Chavez Bonilla
# mechanicEdgar Arevalo                                                                      ***
# mechanicEDIS MAREL RODRIGUEZ                                                               ***
# mechanicEduardo Antonio Flores Campos                                                      ***
# mechanicEDWIN ALEXANDER CAMPOS                                                             ***
# mechanicEdwin Colindres                                                                    ***
# mechanicEdwin Edgardo Castillo Giron
# mechanicEdwin Froylan Turcios                                                              ***
# mechanicEdwin Rogelio Galeas Perez                                                         ***
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                        ***
# mechanicEmilio Zeledon Lopez                                                               ***
# mechanicEnrique Pech Canul                                                                 ***
# mechanicErick Garcia Lima                                                                  ***
# mechanicErick Salazar                                                                      ***
# mechanicEver Alfredo Flores Molina                                                         ***
# mechanicFABIAN POSADAS                                                                     ***
# mechanicFAULO VICENTE TEC TORRES                                                           ***
# mechanicFernando Alexander Pubill Quintanilla                                              ***
# mechanicFLORES CAMPOS EDUARDO ANTONIO                                                      **
# mechanicFrancisco Antonio Hernandez                                                        ***
# mechanicFranqui Garcia                                                                     ***
# mechanicFUENTES LIMA NESTOR MAURICIO                                                       *
# mechanicGabriel Sanchez                                                                    ***
# mechanicGeovanny  Felipe Rivera                                                            ***
# mechanicGerardo Arturo de la Cruz Lemus                                                    ***
# mechanicGilberto Antonio Flores                                                            ***
# mechanicGiovanny Alexander Rivas                                                           ***
# mechanicGuillermo Alfonso Ramirez Landaverde                                               ***
# mechanicGuillermo Josue Lara Ferman                                                        ***
# mechanicHarley Antonio Valiente                                                            ***
# mechanicHector Antonio Alfaro
# mechanicHector Montoya                                                                     ***
# mechanicHenry Valdez                                                                       ***
# mechanicHerbert Amilcar Montiel Sosa                                                       ***
# mechanicHugo Hernandez                                                                     ***
# mechanicIGNACIO COB                                                                        ***
# mechanicImmer Sanchez                                                                      ***
# mechanicIsaias Santiago Hernandez                                                          ***
# mechanicJaime Juarez
# mechanicJaime Rivera                                                                       ***
# mechanicJAIRO NATAEL CALIX                                                                 ***
# mechanicJarim Martinez                                                                     ***
# mechanicJeffrey Velasquez                                                                  ***
# mechanicJERONIMO FUNEZ                                                                     ***
# mechanicJimmy Bardales                                                                     ***
# mechanicJoel Elias Chica Bran                                                              ***
# mechanicJoel Ernesto Cuellar Vanegas                                                       ***
# mechanicJose Manuel Perez Zepeda
# mechanicJose Maria Canul Tec                                                               ***
# mechanicJOSE MAURICIO VELASQUEZ ASCENCIO                                                   ***
# mechanicJose Max Reyes Flores                                                              ***
# mechanicJOSE PEDRO DZUL PECH                                                               ***
# mechanicJose Valencia                                                                      ***
# mechanicJosue Zalmeron                                                                     ***
# mechanicJuan Absalon Portillo Lemus                                                        ***
# mechanicJuan Carlos Lemus
# mechanicJuan Francisco Cardona Hernandez
# mechanicJuan Leiva                                                                         ***
# mechanicJuan Manuel Interiano Zaldana
# mechanicJulia Margarita Chicas Diaz                                                        .
# mechanicKenneth Emerson Clavel Flores                                                      ***
# mechanicLadislao Monterrosa Torres                                                         ***
# mechanicLeonardo Cortez                                                                    ***
# mechanicLeonardo Villanueva                                                                ***
# mechanicLEONEL CHAVEZ                                                                      ***
# mechanicLuis Duran
# mechanicLuis Ernesto de la Rosa Garcia                                                     ***
# mechanicLuis Manuel Garcia Rosales
# mechanicLUIS PECH                                                                          ***
# mechanicMarco Enmanuel Osorio Palacios
# mechanicMarcos Emmanuel Osorio Palacios                                                    ***
# mechanicMARCOS MOGUEL                                                                      ***
# mechanicMAURICIO DAVILA SANCHEZ                                                            ***
# mechanicMauricio Ernesto Valencia                                                          ***
# mechanicMelvin Galeano                                                                     ***
# mechanicMiguel Angel Fajardo Ortiz
# mechanicMONTOYA HECTOR AMERICO                                                             ***
# mechanicNelson Amilcar Rodriguez Salazar                                                   ***
# mechanicNERY MENA RODRIGUEZ                                                                ***
# mechanicNestor Mauricio Carpio Salas                                                       ***
# mechanicNestor Mauricio Fuentes Lima
# mechanicNoe Alexander Caballero Flores                                                     ***
# mechanicNOE CONTRERAS                                                                      ***
# mechanicOdil Alfredo Guzman Saget                                                          ***
# mechanicOdil Alfredo Saget Guzman                                                          **
# mechanicOmar Maldonado                                                                     ***
# mechanicOscar Argumedo                                                                     *
# mechanicOscar Hurtado                                                                      **
# mechanicOtros                                                                              ***
# mechanicPedro Miguel Martinez Linares
# mechanicRafael Esquivel                                                                    ***
# mechanicRAMIREZ RIVERA ABEL ALBERTO
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                        **
# mechanicRAMON VILLANUEVA                                                                   ***
# mechanicRaul Coto
# mechanicREYES JAVIER CORTEZ CANTE                                                          ***
# mechanicReynaldo Chavez Guerra
# mechanicRichard Lara                                                                       ***
# mechanicRIVAS TORRES CARLOS ANTONIO
# mechanicRoberto Reyes
# mechanicROMAN IGNACIO AYALA PUC                                                            ***
# mechanicRonald Antonio Herrera                                                             ***
# mechanicSalvador Roberto Palacios Alvarado                                                 **
# mechanicSalvador Rodriguez                                                                 ***
# mechanicSANCHEZ IMMER ALBERTO
# mechanicSAUL ALFARO                                                                        ***
# mechanicSaul Nolberto Alfaro                                                               ***
# mechanicVictor Alfonzo Ardon Monteros                                                      ***
# mechanicVladimir Enrique Aguilar Hernandez                                                 ***
# mechanicWalter Anibal Belloso Hernandez
# mechanicWalter Patino                                                                      ***
# mechanicWALTER RENE SIERRA VARGAS                                                          ***
# mechanicWilliam Alexander Arevalo Leiva                                                    ***
# mechanicWillian Tejada
# mechanicWILMER CRUZ                                                                        ***
# parts_cost                                                                                 ***
# Days_Between_Failures                                                                      ***
# outlierTRUE                                                                                ***
# Cumulative_Failure_Count
# Median_Repair_Time                                                                         ***
# Cumulative_Maintenance_Cost                                                                *
# Age                                                                                        ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 3484.247)
#
#     Null deviance: 989661669  on 95101  degrees of freedom
# Residual deviance: 330372770  on 94819  degrees of freedom
# AIC: 1045825
#
# Number of Fisher Scoring iterations: 2

# %%
# Predecir con el conjunto de prueba
test_predictions <- predict(model3, newdata = test_data3)

# Calcular métricas de rendimiento para el conjunto de prueba
test_actuals <- test_data3$downtime_gross
test_rmse <- sqrt(mean((test_predictions - test_actuals)^2))
test_mae <- mean(abs(test_predictions - test_actuals))
test_r2 <- 1 - (sum((test_predictions - test_actuals)^2) / sum((test_actuals - mean(test_actuals))^2))

cat("Test RMSE: ", test_rmse, "\n")
cat("Test MAE: ", test_mae, "\n")
cat("Test R-squared: ", test_r2, "\n")
# Out:
# Test RMSE:  58.70829
# Test MAE:  42.40129
# Test R-squared:  0.6635085

# %% [markdown]
# **MODELO AGREGANDO LA VARIABLE "MECHANIC ANTIQUITY"**

# %%
# Primero, calcula la media de antiquity
mean_antiquity <- mean(df_mechanic$antiquity, na.rm = TRUE)

# Realiza el left join y luego reemplaza los NA en antiquity con la media calculada
df_merged2 <- df_merged %>%
  left_join(df_mechanic %>% select(mechanic, antiquity), by = "mechanic") %>%
  mutate(antiquity = ifelse(is.na(antiquity), mean_antiquity, antiquity))

# %%
# Establecer una semilla para reproducibilidad
set.seed(123)

# Definir la proporción de entrenamiento
train_proportion <- 0.70

# Crear índices de muestreo para el conjunto de entrenamiento
trainIndex <- createDataPartition(df_merged2$downtime_gross, p = train_proportion, list = FALSE)

# Crear conjunto de entrenamiento
train_data4 <- df_merged2[trainIndex,]

# Crear conjunto de prueba
test_data4 <- df_merged2[-trainIndex,]

# Comprobar las dimensiones de cada conjunto
cat("Dimensiones del conjunto de entrenamiento: ", dim(train_data4), "\n")
cat("Dimensiones del conjunto de prueba: ", dim(test_data4), "\n")
# Out:
# Dimensiones del conjunto de entrenamiento:  95102 20
# Dimensiones del conjunto de prueba:  40756 20

# %%
# Inicializar y ajustar el modelo de regresión lineal
model4 <- glm(downtime_gross~. -equipment -downtime_gross -repair_hours -date -changed_pcs, data = train_data4)
# Resumen del modelo
summary(model4)
# Out:
# Call:
# glm(formula = downtime_gross ~ . - equipment - downtime_gross -
#     repair_hours - date - changed_pcs, data = train_data4)
#
# Coefficients: (1 not defined because of singularities)
#                                                                                              Estimate
# (Intercept)                                                                                 3.639e+01
# operationBIND LEG                                                                          -1.426e+00
# operationCLOSE SLEEVE                                                                       8.282e+00
# operationFLAT LOCK                                                                         -1.093e+01
# operationFLAT SEAM                                                                         -6.661e+00
# operationHEM AROUND                                                                         2.975e+00
# operationHEM BOTTOM                                                                        -5.900e+00
# operationHEM SLEEVE                                                                         8.602e+00
# operationHEM SLEEVE MAN                                                                     1.129e+00
# operationJOIN PANEL                                                                        -5.593e+00
# operationJOIN SHOULDER                                                                     -7.185e+00
# operationOtros                                                                             -3.754e+00
# operationSET COLLAR                                                                        -8.490e+00
# operationSET POCKET                                                                        -5.180e+00
# operationSET SLEEVE                                                                        -8.387e+00
# operationSEW ELASTIC                                                                       -6.561e+00
# operationTAPE SHOULDER                                                                     -7.286e+00
# operationTOP STITCH                                                                        -7.227e+00
# operationTOP STITCH COLLAR                                                                 -5.462e+00
# base_modelC5                                                                                1.051e+00
# base_modelC5-3-02/233                                                                       3.065e+00
# base_modelC5-4-M03                                                                          3.534e+00
justed thread cutting knife / Cuchillas corta hilo mal ajustadas             6.085e+00
# cause_descOil leak in machine head / Fuga de aceite lubricante en cabezal                   1.055e+01
# cause_descOtros                                                                            -1.693e+00
# cause_descWorn-out machine head looper / Enlazador de cabezal desgastado                   -1.471e+00
# action_descAdjust folder guide / Ajustar guía de doblillador                                2.002e+01
# action_descAdjust hook set / Ajustar conjunto de el garfio                                  2.813e+01
# action_descAdjust machine head knife / Ajustar cuchilla de cabezal                          2.228e+01
# action_descAdjust machine head looper / Ajustar enlazador de cabezal                        2.695e+01
# action_descAdjust machine head needle guard / Ajustar guarda aguja de cabezal               2.117e+01
# action_descAdjust machine head sensor / Ajustar sensor de cabezal                           2.524e+01
# action_descAdjust machine head teeth / Ajustar dientes de cabezal                           2.427e+01
# action_descAdjust thread cutting knife / Ajustar cuchillas corta hilo                       2.652e+01
# action_descAdjusted machine head needle bar / Ajustar barra de aguja de cabezal             2.599e+01
# action_descAdjusted machine head presser foot / Ajustar prensatela de cabezal               2.230e+01
# action_descClean machine head / Limpiar cabezal                                             2.376e+01
# action_descFasten machine head pedal brace / Asegurar soporte de pedal de coser de cabezal  2.306e+01
# action_descFix machine head oil leak / Corregir fuga de aceite en cabezal                   3.063e+01
# action_descInspect stacker air supply / Revisar suministro de aire en apilador              1.168e+01
# action_descOtros                                                                            2.034e+01
# action_descPolish thread take up / Pulir leva                                               9.201e+00
# action_descReplace bobbin / Reemplazar bobina                                               8.550e+00
# action_descReplace burner resistance / Reemplazar resistencia de quemador                   1.663e+01
# action_descReplace machine head ball joint / Reemplazar biela de cabezal                    1.349e+01
# action_descReplace machine head knife / Reemplazar cuchilla de cabezal                      2.525e+01
# action_descReplace machine head looper / Reemplazar enlazador de cabezal                    3.511e+01
# action_descReplace machine head needle / Reemplazar aguja de cabezal                        2.308e+01
# action_descReplace machine head needle guard / Reemplazar guarda aguja de cabezal           2.159e+01
# action_descReplace machine head needle plate / Reemplazar placa de aguja de cabezal         2.953e+01
# action_descReplace machine head presser foot / Reemplazar prensatela de cabezal             2.107e+01
# action_descReplace machine head teeth / Reemplazar dientes de cabezal                       3.117e+01
# action_descReplace thread cutting knife / Reemplazar cuchillas corta hilo                   1.568e+01
# action_descReplace thread tension assembly / Reemplazar tensor auxiliar de largo de hebra   3.444e+01
# action_descReplace trim off knife / Reemplazar cuchilla de corta desperdicio                2.140e+01
# action_descSharpen knife / Afilar cuchillas                                                 2.073e+01
# mechanicAdalberto Jeremias Rodriguez Zometa                                                -3.474e+01
# mechanicAlfonso Escobar                                                                    -7.290e+00
# mechanicAngel Mex                                                                          -4.037e+01
# mechanicAnthony Murillo                                                                    -6.049e+01
# mechanicAntony Ulloa                                                                       -5.622e+01
# mechanicCain Alfredo Ramirez                                                               -5.203e+00
# mechanicCarlos Alberto Alfaro Salamanca                                                    -4.803e+00
# mechanicCARLOS CARRANZA LOBO                                                               -2.750e+00
# mechanicCarlos De Leon                                                                     -5.197e+01
# mechanicCarlos Ernesto Rojas Guzman                                                        -3.552e+01
# mechanicCarlos Galo                                                                        -5.731e+01
# mechanicCarlos Israel Linares                                                              -8.845e+00
# mechanicCarlos Montoya                                                                     -2.080e+01
# mechanicCarlos Oswaldo Rodriguez Sabala                                                    -6.511e-01
# mechanicCarlos Rivas                                                                       -4.965e+00
# mechanicCarlos Rodriguez                                                                   -4.120e+01
# mechanicCASTILLO GIRON EDWIN EDGARDO                                
# mechanicRonald Antonio Herrera                                                             -2.390e+01
# mechanicSalvador Roberto Palacios Alvarado                                                  1.004e+01
# mechanicSalvador Rodriguez                                                                 -3.489e+01
# mechanicSANCHEZ IMMER ALBERTO                                                              -3.178e+00
# mechanicSAUL ALFARO                                                                        -2.278e+01
# mechanicSaul Nolberto Alfaro                                                               -2.656e+01
# mechanicVictor Alfonzo Ardon Monteros                                                      -2.596e+01
# mechanicVladimir Enrique Aguilar Hernandez                                                 -1.965e+01
# mechanicWalter Anibal Belloso Hernandez                                                    -3.324e+00
# mechanicWalter Patino                                                                      -4.540e+01
# mechanicWALTER RENE SIERRA VARGAS                                                          -2.501e+01
# mechanicWilliam Alexander Arevalo Leiva                                                    -1.559e+01
# mechanicWillian Tejada                                                                      3.710e+00
# mechanicWILMER CRUZ                                                                        -5.637e+01
# parts_cost                                                                                  1.043e-01
# Days_Between_Failures                                                                      -3.466e-02
# outlierTRUE                                                                                 3.278e+02
# Cumulative_Failure_Count                                                                   -6.521e-03
# Median_Repair_Time                                                                          3.326e+01
# Cumulative_Maintenance_Cost                                                                -8.855e-04
# Age                                                                                         2.557e-01
# antiquity                                                                                          NA
#                                                                                            Std. Error
# (Intercept)                                                                                 9.416e+00
# operationBIND LEG                                                                           2.780e+00
# operationCLOSE SLEEVE                                                                       2.931e+00
# operationFLAT LOCK                                                                          3.302e+00
# operationFLAT SEAM                                                                          3.158e+00
# operationHEM AROUND                                                                         2.548e+00
# operationHEM BOTTOM                                                                         2.426e+00
# operationHEM SLEEVE                                                                         2.593e+00
# operationHEM SLEEVE MAN                                                                     3.828e+00
# operationJOIN PANEL                                                                         3.159e+00
# operationJOIN SHOULDER                                                                      2.902e+00
# operationOtros                                                                              2.306e+00
# operationSET COLLAR                                                                         2.868e+00
# operationSET POCKET                                                                         3.196e+00
# operationSET SLEEVE                                                                         2.677e+00
# operationSEW ELASTIC                                                                        1.975e+00
# operationTAPE SHOULDER                                                                      5.538e+00
# operationTOP STITCH                                                                         2.715e+00
# operationTOP STITCH COLLAR                                                                  2.949e+00
# base_modelC5                                                                                2.865e+00
# base_modelC5-3-02/233                                                                       3.439e+00
# base_modelC5-4-M03                                                                          3.034e+00
# base_modelC5S-4-M03                                                                         2.895e+00
# base_modelDDL5550                                                                           3.926e+00
# base_modelDT6L2512                                                                          5.874e+00
# base_modelEX5214                                                                            3.066e+00
# base_modelFD-62                                                                             3.935e+00
# base_modelFD62                                                                              3.749e+00
# base_modelJ-261                                                                             5.937e+00
# base_modelJK-797DI                                                                          3.297e+00
# base_modelJK-798DIII                                                                        3.786e+00
# base_modelJK-T1904                                                                          3.672e+00
# base_modelJK-T1904BS                                                                        3.917e+00
# base_modelJS-2261                                                                           6.125e+00
# base_modelLC62D                                                                             3.910e+00
# base_modelLC62D-12                                                                          3.860e+00
# base_modelLDA-L26                                                                           5.779e+00
# base_modelOtros                                                                             2.834e+00
# base_modelT-8722B                                                                           4.352e+00
# base_modelUS39500                                                                           3.493e+00
# base_modelVC1700                                                                            3.085e+00
# base_modelVC2700                                                                            2.946e+00
# base_modelVC2711                                                                            3.081e+00
# base_modelVC2713                                                                            3.035e+00
# base_modelVC3845P                                                                           3.329e+00
# base_modelVE2700                                                                            3.976e+00
# base_modelVF2400                                                                            3.848e+00
# base_modelVF2403                                                                            3.210e+00
# base_modelVF2500                                                                            4.082e+00
# base_modelVF2560                                                                            3.740e+00
# base_modelVG2700                                                                            2.964e+00
# base_modelVG2713                                                                            3.592e+00
# base_modelVG2735                                                                            3.555e+00
# base_modelW600                                                                              3.684e+00
# base_modelW664                                                                              3.181e+00
# base_modelWT542                                                                             4.588e+00
# base_modelWT562                                                                             4.443e+00
# problem_descIt does not cut the thread / No corta el hilo                                   3.399e+00
# problem_descIt does not cut the trim off / No corta el desperdicio                          3.997e+00
# problem_descIt does not sew / No cose                                                       3.054e+00
# problem_descIt sews with defect / Cose con defecto                                          3.018e+00
# problem_descOtros                                                                           3.231e+00
# failure_descChain cutter failure / Falla corta cadenetas                                    4.083e+00
# failure_descElectric panel failure / Falla pánel eléctrico                                  4.477e+00
# failure_descEngine failure / Falla motor                                                    4.141e+00
# failure_descFeeding device failure / Falla dispositivo de alimentación                      4.378e+00
# failure_descFolder failure / Falla doblillador                                              4.134e+00
# failure_descLubrication system failure / Falla sistema de lubricación                       4.216e+00
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defecto    3.851e+00
# failure_descMachine head failure stopping sewing  / Falla cabezal dejando de coser          3.847e+00
# failure_descMonitoring and control failure / Falla monitoreo y control                      4.199e+00
# failure_descOtros                                                                           3.978e+00
# failure_descStacker failure it stops piling up / Falla apilador dejando de apilar           4.273e+00
# failure_descTrim off device failure / Falla dispositivo corta desperdicio                   3.966e+00
# failure_descTrim off device stops cutting/Falla dispositivo corta tela deja de cortar       5.202e+00
# cause_descBroken knife of machine head / Rotura de cuchilla de cabezal                      6.375e+00
# cause_descBroken machine head ball joint / Rotura de biela de cabezal                       6.676e+00
# cause_descBroken machine head looper / Rotura de enlazador de cabezal                       4.919e+00
# cause_descBroken machine head needle plate / Rotura de placa de aguja de cabezal            7.110e+00
# cause_descBroken machine head presser foot  / Rotura de prensatela de cabezal               5.114e+00
# cause_descDamaged  moving knife shaft /Eje cuchilla móvil corta desperdicio en mal estado   4.694e+00
# cause_descDamaged bobbin / Bobina en mal estado                                             7.627e+00
# cause_descDamaged burner resistance / Resistencia de quemador en mal estado                 7.951e+00
# cause_descDamaged control box / Caja de control en mal estado                               4.934e+00
# cause_descDamaged machine head looper / Enlazador de cabezal en mal estado                  4.727e+00
# cause_descDamaged machine head thread take up / Leva de cabezal en mal estado               5.341e+00
# cause_descDamaged thread cutting knife / Cuchillas corta hilo en mal estado                 7.216e+00
# cause_descDamaged trim off system knife / Cuchilla de corta desperdicio en mal estado       4.652e+00
# cause_descExcessive dirt in machine head / Suciedad excesiva en cabezal                     6.709e+00
# cause_descLoose machine head teeth / Soltura de dientes de cabezal                          4.678e+00
# cause_descMisadjusted chain cutter knife / Cuchilla de corta cadeneta desajustada           7.358e+00
# cause_descMisadjusted folder guide / Guía de doblillador desajustadas                       6.704e+00
# cause_descMisadjusted hook set / Conjunto de garfios mal ajustados                          5.259e+00
# cause_descMisadjusted machine head chopper / Cuchilla de cabezal desajustada                4.555e+00
# cause_descMisadjusted machine head looper / Enlazador de cabezal desajustado                4.274e+00
# cause_descMisadjusted machine head needle bar / Barra de aguja de cabezal desajustada       4.398e+00
# cause_descMisadjusted machine head needle guard / Guarda aguja de cabezal desajustada       5.111e+00
# cause_descMisadjusted machine head presser foot / Prensatela de cabezal desajustado         4.636e+00
# cause_descMisadjusted machine head teeth / Dientes de cabezal desajustados                  4.390e+00
# cause_descMisadjusted Sensor for cloth detection / Sensor detector de tela mal calibrado    5.904e+00
# cause_descMisadjusted thread cutting knife / Cuchillas corta hilo mal ajustadas             5.955e+00
# cause_descOil leak in machine head / Fuga de aceite lubricante en cabezal                   6.110e+00
# cause_descOtros                                                                             3.955e+00
# cause_descWorn-out machine head looper / Enlazador de cabezal desgastado                    4.734e+00
# action_descAdjust folder guide / Ajustar guía de doblillador                                8.073e+00
# action_descAdjust hook set / Ajustar conjunto de el garfio                                  6.857e+00
# action_descAdjust machine head knife / Ajustar cuchilla de cabezal                          6.457e+00
# action_descAdjust machine head looper / Ajustar enlazador de cabezal                        6.294e+00
# action_descAdjust machine head needle guard / Ajustar guarda aguja de cabezal               6.885e+00
# action_descAdjust machine head sensor / Ajustar sensor de cabezal                           7.262e+00
# action_descAdjust machine head teeth / Ajustar dientes de cabezal                           6.304e+00
# action_descAdjust thread cutting knife / Ajustar cuchillas corta hilo                       7.545e+00
# action_descAdjusted machine head needle bar / Ajustar barra de aguja de cabezal             6.593e+00
# action_descAdjusted machine head presser foot / Ajustar prensatela de cabezal               6.506e+00
# action_descClean machine head / Limpiar cabezal                                             7.892e+00
# action_descFasten machine head pedal brace / Asegurar soporte de pedal de coser de cabez
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                         3.447e+00
# mechanicEmilio Zeledon Lopez                                                                3.358e+00
# mechanicEnrique Pech Canul                                                                  3.705e+00
# mechanicErick Garcia Lima                                                                   2.817e+00
# mechanicErick Salazar                                                                       3.187e+00
# mechanicEver Alfredo Flores Molina                                                          3.538e+00
# mechanicFABIAN POSADAS                                                                      4.818e+00
# mechanicFAULO VICENTE TEC TORRES                                                            2.939e+00
# mechanicFernando Alexander Pubill Quintanilla                                               3.191e+00
# mechanicFLORES CAMPOS EDUARDO ANTONIO                                                       3.732e+00
# mechanicFrancisco Antonio Hernandez                                                         3.596e+00
# mechanicFranqui Garcia                                                                      4.768e+00
# ...
# action_descPolish thread take up / Pulir leva
# action_descReplace bobbin / Reemplazar bobina
# action_descReplace burner resistance / Reemplazar resistencia de quemador                  .
# action_descReplace machine head ball joint / Reemplazar biela de cabezal                   .
# action_descReplace machine head knife / Reemplazar cuchilla de cabezal                     **
# action_descReplace machine head looper / Reemplazar enlazador de cabezal                   ***
# action_descReplace machine head needle / Reemplazar aguja de cabezal                       ***
# action_descReplace machine head needle guard / Reemplazar guarda aguja de cabezal          **
# action_descReplace machine head needle plate / Reemplazar placa de aguja de cabezal        ***
# action_descReplace machine head presser foot / Reemplazar prensatela de cabezal            **
# action_descReplace machine head teeth / Reemplazar dientes de cabezal                      ***
# action_descReplace thread cutting knife / Reemplazar cuchillas corta hilo                  .
# action_descReplace thread tension assembly / Reemplazar tensor auxiliar de largo de hebra  ***
# action_descReplace trim off knife / Reemplazar cuchilla de corta desperdicio               **
# action_descSharpen knife / Afilar cuchillas                                                **
# mechanicAdalberto Jeremias Rodriguez Zometa                                                ***
# mechanicAlfonso Escobar                                                                    *
# mechanicAngel Mex                                                                          ***
# mechanicAnthony Murillo                                                                    ***
# mechanicAntony Ulloa                                                                       ***
# mechanicCain Alfredo Ramirez                                                               .
# mechanicCarlos Alberto Alfaro Salamanca                                                    .
# mechanicCARLOS CARRANZA LOBO
# mechanicCarlos De Leon                                                                     ***
# mechanicCarlos Ernesto Rojas Guzman                                                        ***
# mechanicCarlos Galo                                                                        ***
# mechanicCarlos Israel Linares                                                              **
# mechanicCarlos Montoya                                                                     ***
# mechanicCarlos Oswaldo Rodriguez Sabala
# mechanicCarlos Rivas
# mechanicCarlos Rodriguez                                                                   ***
# mechanicCASTILLO GIRON EDWIN EDGARDO                                                       .
# mechanicCesar Edgardo Ruedas Mendoza                                                       *
# mechanicCesar Edwin Maradiaga                                                              ***
# mechanicCristian Vladimir Cartagena Ortiz
# mechanicDaniel Arevalo
# mechanicDaniel Edgardo Sandoval
# mechanicDENY RAYMUNDO PUCH POOL                                                            ***
# mechanicDIEGO CUELLAR
# mechanicDouglas Alonso Bonilla Soriano                                                     ***
# mechanicDouglas del Cid
# mechanicDOUGLAS LEONEL CHAVEZ                                                              ***
# mechanicDouglas Leonel Chavez Bonilla
# mechanicEdgar Arevalo                                                                      ***
# mechanicEDIS MAREL RODRIGUEZ                                                               ***
# mechanicEduardo Antonio Flores Campos                                                      ***
# mechanicEDWIN ALEXANDER CAMPOS                                                             ***
# mechanicEdwin Colindres                                                                    ***
# mechanicEdwin Edgardo Castillo Giron
# mechanicEdwin Froylan Turcios                                                              ***
# mechanicEdwin Rogelio Galeas Perez                                                         ***
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                        ***
# mechanicEmilio Zeledon Lopez                                                               ***
# mechanicEnrique Pech Canul                                                                 ***
# mechanicErick Garcia Lima                                                                  ***
# mechanicErick Salazar                                                                      ***
# mechanicEver Alfredo Flores Molina                                                         ***
# mechanicFABIAN POSADAS                                                                     ***
# mechanicFAULO VICENTE TEC TORRES                                                           ***
# mechanicFernando Alexander Pubill Quintanilla                                              ***
# mechanicFLORES CAMPOS EDUARDO ANTONIO                                                      **
# mechanicFrancisco Antonio Hernandez                                                        ***
# mechanicFranqui Garcia                                                                     ***
# mechanicFUENTES LIMA NESTOR MAURICIO                                                       *
# mechanicGabriel Sanchez                                                                    ***
# mechanicGeovanny  Felipe Rivera                                                            ***
# mechanicGerardo Arturo de la Cruz Lemus                                                    ***
# mechanicGilberto Antonio Flores                                                            ***
# mechanicGiovanny Alexander Rivas                                                           ***
# mechanicGuillermo Alfonso Ramirez Landaverde                                               ***
# mechanicGuillermo Josue Lara Ferman                                                        ***
# mechanicHarley Antonio Valiente                                                            ***
# mechanicHector Antonio Alfaro
# mechanicHector Montoya                                                                     ***
# mechanicHenry Valdez                                                                       ***
# mechanicHerbert Amilcar Montiel Sosa                                                       ***
# mechanicHugo Hernandez                                                                     ***
# mechanicIGNACIO COB                                                                        ***
# mechanicImmer Sanchez                                                                      ***
# mechanicIsaias Santiago Hernandez                                                          ***
# mechanicJaime Juarez
# mechanicJaime Rivera                                                                       ***
# mechanicJAIRO NATAEL CALIX                                                                 ***
# mechanicJarim Martinez                                                                     ***
# mechanicJeffrey Velasquez                                                                  ***
# mechanicJERONIMO FUNEZ                                                                     ***
# mechanicJimmy Bardales                                                                     ***
# mechanicJoel Elias Chica Bran                                                              ***
# mechanicJoel Ernesto Cuellar Vanegas                                                       ***
# mechanicJose Manuel Perez Zepeda
# mechanicJose Maria Canul Tec                                                               ***
# mechanicJOSE MAURICIO VELASQUEZ ASCENCIO                                                   ***
# mechanicJose Max Reyes Flores                                                              ***
# mechanicJOSE PEDRO DZUL PECH                                                               ***
# mechanicJose Valencia                                                                      ***
# mechanicJosue Zalmeron                                                                     ***
# mechanicJuan Absalon Portillo Lemus                                                        ***
# mechanicJuan Carlos Lemus
# mechanicJuan Francisco Cardona Hernandez
# mechanicJuan Leiva                                                                         ***
# mechanicJuan Manuel Interiano Zaldana
# mechanicJulia Margarita Chicas Diaz                                                        .
# mechanicKenneth Emerson Clavel Flores                                                      ***
# mechanicLadislao Monterrosa Torres                                                         ***
# mechanicLeonardo Cortez                                                                    ***
# mechanicLeonardo Villanueva                                                                ***
# mechanicLEONEL CHAVEZ                                                                      ***
# mechanicLuis Duran
# mechanicLuis Ernesto de la Rosa Garcia                                                     ***
# mechanicLuis Manuel Garcia Rosales
# mechanicLUIS PECH                                                                          ***
# mechanicMarco Enmanuel Osorio Palacios
# mechanicMarcos Emmanuel Osorio Palacios                                                    ***
# mechanicMARCOS MOGUEL                                                                      ***
# mechanicMAURICIO DAVILA SANCHEZ                                                            ***
# mechanicMauricio Ernesto Valencia                                                          ***
# mechanicMelvin Galeano                                                                     ***
# mechanicMiguel Angel Fajardo Ortiz
# mechanicMONTOYA HECTOR AMERICO                                                             ***
# mechanicNelson Amilcar Rodriguez Salazar                                                   ***
# mechanicNERY MENA RODRIGUEZ                                                                ***
# mechanicNestor Mauricio Carpio Salas                                                       ***
# mechanicNestor Mauricio Fuentes Lima
# mechanicNoe Alexander Caballero Flores                                                     ***
# mechanicNOE CONTRERAS                                                                      ***
# mechanicOdil Alfredo Guzman Saget                                                          ***
# mechanicOdil Alfredo Saget Guzman                                                          **
# mechanicOmar Maldonado                                                                     ***
# mechanicOscar Argumedo                                                                     *
# mechanicOscar Hurtado                                                                      **
# mechanicOtros                                                                              ***
# mechanicPedro Miguel Martinez Linares
# mechanicRafael Esquivel                                                                    ***
# mechanicRAMIREZ RIVERA ABEL ALBERTO
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                        **
# mechanicRAMON VILLANUEVA                                                                   ***
# mechanicRaul Coto
# mechanicREYES JAVIER CORTEZ CANTE                                                          ***
# mechanicReynaldo Chavez Guerra
# mechanicRichard Lara                                                                       ***
# mechanicRIVAS TORRES CARLOS ANTONIO
# mechanicRoberto Reyes
# mechanicROMAN IGNACIO AYALA PUC                                                            ***
# mechanicRonald Antonio Herrera                                                             ***
# mechanicSalvador Roberto Palacios Alvarado                                                 **
# mechanicSalvador Rodriguez                                                                 ***
# mechanicSANCHEZ IMMER ALBERTO
# mechanicSAUL ALFARO                                                                        ***
# mechanicSaul Nolberto Alfaro                                                               ***
# mechanicVictor Alfonzo Ardon Monteros                                                      ***
# mechanicVladimir Enrique Aguilar Hernandez                                                 ***
# mechanicWalter Anibal Belloso Hernandez
# mechanicWalter Patino                                                                      ***
# mechanicWALTER RENE SIERRA VARGAS                                                          ***
# mechanicWilliam Alexander Arevalo Leiva                                                    ***
# mechanicWillian Tejada
# mechanicWILMER CRUZ                                                                        ***
# parts_cost                                                                                 ***
# Days_Between_Failures                                                                      ***
# outlierTRUE                                                                                ***
# Cumulative_Failure_Count
# Median_Repair_Time                                                                         ***
# Cumulative_Maintenance_Cost                                                                *
# Age                                                                                        ***
# antiquity
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 3484.247)
#
#     Null deviance: 989661669  on 95101  degrees of freedom
# Residual deviance: 330372770  on 94819  degrees of freedom
# AIC: 1045825
#
# Number of Fisher Scoring iterations: 2

# %%
# Predecir con el conjunto de prueba
test_predictions <- predict(model4, newdata = test_data4)

# Calcular métricas de rendimiento para el conjunto de prueba
test_actuals <- test_data4$downtime_gross
test_rmse <- sqrt(mean((test_predictions - test_actuals)^2))
test_mae <- mean(abs(test_predictions - test_actuals))
test_r2 <- 1 - (sum((test_predictions - test_actuals)^2) / sum((test_actuals - mean(test_actuals))^2))

cat("Test RMSE: ", test_rmse, "\n")
cat("Test MAE: ", test_mae, "\n")
cat("Test R-squared: ", test_r2, "\n")
# Out:
# Test RMSE:  58.70829
# Test MAE:  42.40129
# Test R-squared:  0.6635085

# %% [markdown]
# **AGREGANDO LA VARIABLE "CHANGED_PCS"**

# %%
# Inicializar y ajustar el modelo de regresión lineal
model5 <- glm(downtime_gross~. -equipment -downtime_gross -repair_hours -date -antiquity, data = train_data4)
# Resumen del modelo
summary(model5)
# Out:
# Call:
# glm(formula = downtime_gross ~ . - equipment - downtime_gross -
#     repair_hours - date - antiquity, data = train_data4)
#
# Coefficients:
#                                                                                              Estimate
# (Intercept)                                                                                 5.169e+01
# operationBIND LEG                                                                          -6.864e+00
# operationCLOSE SLEEVE                                                                       6.208e+00
# operationFLAT LOCK                                                                         -1.187e+01
# operationFLAT SEAM                                                                         -7.831e+00
# operationHEM AROUND                                                                        -3.214e-01
# operationHEM BOTTOM                                                                        -1.018e+01
# operationHEM SLEEVE                                                                         8.310e-01
# operationHEM SLEEVE MAN                                                                     5.973e+00
# operationJOIN PANEL                                                                        -7.142e+00
# operationJOIN SHOULDER                                                                     -1.136e+01
# operationOtros                                                                             -6.962e+00
# operationSET COLLAR                                                                        -1.201e+01
# operationSET POCKET                                                                        -6.184e+00
# operationSET SLEEVE                                                                        -1.158e+01
# operationSEW ELASTIC                                                                       -7.682e+00
# operationTAPE SHOULDER                                                                     -1.020e+01
# operationTOP STITCH                                                                        -1.290e+01
# operationTOP STITCH COLLAR                                                                 -1.070e+01
# base_modelC5                                                                               -2.212e+00
# base_modelC5-3-02/233                                                                       1.209e+00
# base_modelC5-4-M03                                                                          2.853e+00
# base_modelC5S-4-M03                                                                         1.416e+00
# base_modelDDL5550                                                                          -1.087e+00
# base_modelDT6L2512                                                                         -5.575e-01
# base_modelEX5214                                                                            2.670e-01
# base_modelFD-62                                                                            -3.951e+00
# base_modelFD62                                                                              3.187e+00
# base_modelJ-261                                                                             3.308e+00
# base_modelJK-797DI                                                                         -5.804e-01
# base_modelJK-798DIII                                                                       -6.615e-01
# base_modelJK-T1904                                                                         -3.175e+00
# base_modelJK-T1904BS                                                                        2.147e+00
# base_modelJS-2261                                                                           4.205e+00
# base_modelLC62D                                                                             3.126e+00
# base_modelLC62D-12                                                                         -4.791e+00
# base_modelLDA-L26                                                                          -1.928e+00
# base_modelOtros                                                                            -1.035e+00
# base_modelT-8722B                                                                          -4.686e+00
# base_modelUS39500                                                                           7.870e+00
# base_modelVC1700                                                                            2.939e+00
# base_modelVC2700                                                                            5.826e-01
# base_modelVC2711                                                                           -4.001e-01
# base_modelVC2713                                                                            2.647e+00
# base_modelVC3845P                                                                          -2.839e+00
# base_modelVE2700                                                                           -1.043e+00
# base_modelVF2400                                                                           -4.846e+00
# base_modelVF2403                                                                            1.822e+00
# base_modelVF2500                                                                           -3.178e+00
# base_modelVF2560                                                                            4.467e+00
# base_modelVG2700                                                                           -4.791e-01
# base_modelVG2713                                                                            3.507e+00
# base_modelVG2735                                                                           -2.268e+00
# base_modelW600                                                                             -5.379e+00
# base_modelW664                                                                             -8.140e-01
# base_modelWT542                                                                            -7.472e+00
# base_modelWT562                                                                            -5.101e+00
# problem_descIt does not cut the thread / No corta el hilo                                   2.263e+00
# problem_descIt does not cut the trim off / No corta el desperdicio                         -2.809e+00
# problem_descIt does not sew / No cose                                                      -4.521e-01
# problem_descIt sews with defect / Cose con defecto                                          4.230e+00
# problem_descOtros                                                                           6.298e+00
# failure_descChain cutter failure / Falla corta cadenetas                                    3.162e+00
# failure_descElectric panel failure / Falla pánel eléctrico                                  2.442e+00
# failure_descEngine failure / Falla motor                                                    3.821e-01
# failure_descFeeding device failure / Falla dispositivo de alimentación                      1.650e+00
# failure_descFolder failure / Falla doblillador                                              8.290e+00
# failure_descLubrication system failure / Falla sistema de lubricación                       3.246e+00
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defecto    2.207e-01
# failure_descMachine head failure stopping sewing  / Falla cabezal dejando de coser          3.440e+00
# failure_descMonitoring and control failure / Falla monitoreo y control                      4.527e+00
# failure_descOtros                                                                           1.390e+00
# failure_descStacker failure it stops piling up / Falla apilador dejando de apil
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                        -1.508e+01
# mechanicRAMON VILLANUEVA                                                                   -4.639e+01
# mechanicRaul Coto                                                                          -1.243e+00
# mechanicREYES JAVIER CORTEZ CANTE                                                          -4.137e+01
# mechanicReynaldo Chavez Guerra                                                             -5.758e+00
# mechanicRichard Lara                                                                       -3.913e+01
# mechanicRIVAS TORRES CARLOS ANTONIO                                                        -8.958e+00
# mechanicRoberto Reyes                                                                      -1.116e+01
# mechanicROMAN IGNACIO AYALA PUC                                                            -3.218e+01
# mechanicRonald Antonio Herrera                                                             -2.239e+01
# mechanicSalvador Roberto Palacios Alvarado                                                 -7.322e+00
# mechanicSalvador Rodriguez                                                                 -3.207e+01
# mechanicSANCHEZ IMMER ALBERTO                                                              -1.084e-01
# mechanicSAUL ALFARO                                                                        -2.251e+01
# mechanicSaul Nolberto Alfaro                                                               -3.205e+01
# mechanicVictor Alfonzo Ardon Monteros                                                      -3.181e+01
# mechanicVladimir Enrique Aguilar Hernandez                                                 -1.871e+01
# mechanicWalter Anibal Belloso Hernandez                                                    -2.333e+01
# mechanicWalter Patino                                                                      -4.059e+01
# mechanicWALTER RENE SIERRA VARGAS                                                          -3.132e+01
# mechanicWilliam Alexander Arevalo Leiva                                                    -2.389e+01
# mechanicWillian Tejada                                                                     -2.300e+01
# mechanicWILMER CRUZ                                                                        -4.271e+01
# parts_cost                                                                                  6.361e-03
# changed_pcs                                                                                 3.293e+01
# Days_Between_Failures                                                                      -2.068e-02
# outlierTRUE                                                                                 2.445e+02
# Cumulative_Failure_Count                                                                   -1.659e-03
# Median_Repair_Time                                                                          1.093e+01
# Cumulative_Maintenance_Cost                                                                -1.327e-03
# Age                                                                                         1.434e-01
#                                                                                            Std. Error
# (Intercept)                                                                                 7.809e+00
# operationBIND LEG                                                                           2.305e+00
# operationCLOSE SLEEVE                                                                       2.430e+00
# operationFLAT LOCK                                                                          2.738e+00
# operationFLAT SEAM                                                                          2.619e+00
# operationHEM AROUND                                                                         2.113e+00
# operationHEM BOTTOM                                                                         2.012e+00
# operationHEM SLEEVE                                                                         2.150e+00
# operationHEM SLEEVE MAN                                                                     3.174e+00
# operationJOIN PANEL                                                                         2.619e+00
# operationJOIN SHOULDER                                                                      2.406e+00
# operationOtros                                                                              1.913e+00
# operationSET COLLAR                                                                         2.378e+00
# operationSET POCKET                                                                         2.650e+00
# operationSET SLEEVE                                                                         2.220e+00
# operationSEW ELASTIC                                                                        1.638e+00
# operationTAPE SHOULDER                                                                      4.593e+00
# operationTOP STITCH                                                                         2.252e+00
# operationTOP STITCH COLLAR                                                                  2.445e+00
# base_modelC5                                                                                2.376e+00
# base_modelC5-3-02/233                                                                       2.852e+00
# base_modelC5-4-M03                                                                          2.516e+00
# base_modelC5S-4-M03                                                                         2.400e+00
# base_modelDDL5550                                                                           3.256e+00
# base_modelDT6L2512                                                                          4.871e+00
# base_modelEX5214                                                                            2.543e+00
# base_modelFD-62                                                                             3.263e+00
# base_modelFD62                                                                              3.109e+00
# base_modelJ-261                                                                             4.923e+00
# base_modelJK-797DI                                                                          2.734e+00
# base_modelJK-798DIII                                                                        3.139e+00
# base_modelJK-T1904                                                                          3.045e+00
# base_modelJK-T1904BS                                                                        3.248e+00
# base_modelJS-2261                                                                           5.079e+00
# base_modelLC62D                                                                             3.243e+00
# base_modelLC62D-12                                                                          3.201e+00
# base_modelLDA-L26                                                                           4.792e+00
# base_modelOtros                                                                             2.350e+00
# base_modelT-8722B                                                                           3.609e+00
# base_modelUS39500                                                                           2.897e+00
# base_modelVC1700                                                                            2.558e+00
# base_modelVC2700                                                                            2.443e+00
# base_modelVC2711                                                                            2.555e+00
# base_modelVC2713                                                                            2.517e+00
# base_modelVC3845P                                                                           2.761e+00
# base_modelVE2700                                                                            3.297e+00
# base_modelVF2400                                                                            3.191e+00
# base_modelVF2403                                                                            2.662e+00
# base_modelVF2500                                                                            3.385e+00
# base_modelVF2560                                                                            3.101e+00
# base_modelVG2700                                                                            2.458e+00
# base_modelVG2713                                                                            2.979e+00
# base_modelVG2735                                                                            2.948e+00
# base_modelW600                                                                              3.055e+00
# base_modelW664                                                                              2.638e+00
# base_modelWT542                                                                             3.805e+00
# base_modelWT562                                                                             3.685e+00
# problem_descIt does not cut the thread / No corta el hilo                                   2.819e+00
# problem_descIt does not cut the trim off / No corta el desperdicio                          3.315e+00
# problem_descIt does not sew / No cose                                                       2.532e+00
# problem_descIt sews with defect / Cose con defecto                                          2.502e+00
# problem_descOtros                                                                           2.680e+00
# failure_descChain cutter failure / Falla corta cadenetas                                    3.386e+00
# failure_descElectric panel failure / Falla pánel eléctrico                                  3.713e+00
# failure_descEngine failure / Falla motor                                                    3.434e+00
# failure_descFeeding device failure / Falla dispositivo de alimentación                      3.630e+00
# failure_descFolder failure / Falla doblillador                                              3.428e+00
# failure_descLubrication system failure / Falla sistema de lubricación                       3.497e+00
# failure_descMachine head failure sewing with defect / Falla cabezal cosiendo con defecto    3.193e+00
# failure_descMachine head failure stopping sewing  / Falla cabezal dejando de coser          3.190e+00
# failure_descMonitoring and control failure / Falla monitoreo y control                      3.482e+00
# failure_descOtros                                                                           3.299e+00
# failure_descStacker failure it stops piling up / Falla apilador dejando de apilar           3.543e+00
# failure_descTrim off device failure / Falla dispositivo corta desperdicio                   3.289e+00
# failure_descTrim off device stops cutting/Falla dispositivo corta tela deja de cortar       4.314e+00
# cause_descBroken knife of machine head / Rotura de cuchilla de cabezal                      5.287e+00
# cause_descBroken machine head ball joint / Rotura de biela de cabezal                       5.536e+00
# cause_descBroken machine head looper / Rotura de enlazador de cabezal                       4.079e+00
# cause_descBroken machine head needle plate / Rotura de placa de aguja de cabezal            5.896e+00
# cause_descBroken machine head presser foot  / Rotura de prensatela de cabezal               4.241e+00
# cause_descDamaged  moving knife shaft /Eje cuchilla móvil corta desperdicio en mal estado   3.893e+00
# cause_descDamaged bobbin / Bobina en mal estado                                             6.325e+00
# cause_descDamaged burner resistance / Resistencia de quemador en mal estado                 6.594e+00
# cause_descDamaged control box / Caja de control en mal estado                               4.092e+00
# cause_descDamaged machine head looper / Enlazador de cabezal en mal estado                  3.920e+00
# cause_descDamaged machine head thread take up / Leva de cabezal en mal estado               4.429e+00
# cause_descDamaged thread cutting knife / Cuchillas corta hilo en mal estado                 5.984e+00
# cause_descDamaged trim off system knife / Cuchilla de corta desperdicio en mal estado       3.858e+00
# cause_descExcessive dirt in machine head / Suciedad excesiva en cabezal                     5.563e+00
# cause_descLoose machine head teeth / Soltura de dientes de cabezal                          3.879e+00
# cause_descMisadjusted chain cutter knife / Cuchilla de corta cadeneta desajustada           6.102e+00
# cause_descMisadjusted folder guide / Guía de doblillador desajustadas                       5.559e+00
# cause_descMisadjusted hook set / Conjunto de garfios mal ajustados                          4.361e+00
# cause_descMisadjusted machine head chopper / Cuchilla de cabezal desajustada                3.777e+00
# cause_descMisadjusted machine head looper / Enlazador de cabezal desajustado                3.544e+00
# cause_descMisadjusted machine head needle bar / Barra de aguja de cabezal desajustada       3.647e+00
# cause_descMisadjusted machine head needle guard / Guarda aguja de cabezal desajustada       4.238e+00
# cause_descMisadjusted machine head presser foot / Prensatela de cabezal desajustado         3.845e+00
# cause_descMisadjusted machine head teeth / Dientes de cabezal desajustados                  3.640e+00
# cause_descMisadjusted Sensor for cloth detection / Sensor detector de tela mal calibrado    4.896e+00
# cause_descMisadjusted thread cutting knife / Cuchillas corta hilo mal ajustadas             4.938e+00
# cause_descOil leak in machine head / Fuga de aceite lubricante en cabezal                   5.067e+00
# cause_descOtros                                                                             3.280e+00
# cause_descWorn-out machine head looper / Enlazador de cabezal desgastado                    3.926e+00
# action_descAdjust folder guide / Ajustar guía de doblillador                                6.695e+00
# action_descAdjust hook set / Ajustar conjunto de el garfio                                  5.687e+00
# action_descAdjust machine head knife / Ajustar cuchilla de cabezal                          5.355e+00
# action_descAdjust machine head looper / Ajustar enlazador de cabezal                        5.220e+00
# action_descAdjust machine head needle guard / Ajustar guarda aguja de cabezal               5.710e+00
# action_descAdjust machine head sensor / Ajustar sensor de cabezal                           6.022e+00
# action_descAdjust machine head teeth / Ajustar dientes de cabezal                           5.228e+00
# action_descAdjust thread cutting knife / Ajustar cuchillas corta hilo                       6.257e+00
# action_descAdjusted machine head needle bar / Ajustar barra de aguja de cabezal             5.468e+00
# action_descAdjusted machine head presser foot / Ajustar prensatela de cabezal               5.395e+00
# action_descClean machine head / Limpiar cabezal                                             6.545e+00
# action_descFasten machine head pedal brace / Asegurar soporte de pedal de coser de cabezal  5.446e+00
# action_descFix machine head oil leak / Corregir fuga de aceite en cabezal                   6.384e+00
# action_descInspect stacker air supply / Revisar suministro de aire en apilador              5.526e+00
# action_descOtros                                                                            5.027e+00
# action_descPolish thread take up / Pulir leva                                               6.032e+00
# action_descReplace bobbin / Reemplazar bobina                                               7.212e+00
# action_descReplace burner resistance / Reemplazar resistencia de quemador                   7.654e+00
# action_descReplace machine head ball joint / Reemplazar biela de cabezal                    6.732e+00
# action_descReplace machine head knife / Reemplazar cuchilla de cabezal                      6.601e+00
# action_descReplace machine head looper / Reemplazar enlazador de cabezal                    5.221e+00
# action_descReplace machine head needle / Reemplazar aguja de cabezal                        5.810e+00
# action_descReplace machine head needle guard / Reemplazar guarda aguja de cabezal           5.500e+00
# action_descReplace machine head needle plate / Reemplazar placa de aguja de cabezal         7.082e+00
# action_descReplace machine head presser foot / Reemplazar prensatela de cabezal             5.959e+00
# action_descReplace machine head teeth / Reemplazar dientes de cabezal                       5.394e+00
# action_descReplace thread cutting knife / Reemplazar cuchillas corta hilo                   7.169e+00
# action_descReplace thread tension assembly / Reemplazar tensor auxiliar de largo de hebra   7.665e+00
# action_descReplace trim off knife / Reemplazar cuchilla de corta desperdicio                5.456e+00
# action_descSharpen knife / Afilar cuchillas                                                 5.388e+00
# mechanicAdalberto Jeremias Rodriguez Zometa                                                 2.508e+00
# mechanicAlfonso Escobar                                                                     2.905e+00
# mechanicAngel Mex                                                                           3.683e+00
# mechanicAnthony Murillo                                                                     2.951e+00
# mechanicAntony Ulloa                                                                        2.228e+00
# mechanicCain Alfredo Ramirez                                                                2.327e+00
# mechanicCarlos Alberto Alfaro Salamanca                                                     2.280e+00
# mechanicCARLOS CARRANZA LOBO                                                                2.633e+00
# mechanicCarlos De Leon                                                                      2.446e+00
# mechanicCarlos Ernesto Rojas Guzman                                                         3.974e+00
# mechanicCarlos Galo                                                                         3.516e+00
# mechanicCarlos Israel Linares                                                               2.576e+00
# mechanicCarlos Montoya                                                                      2.921e+00
# mechanicCarlos Oswaldo Rodriguez Sabala                                                     3.242e+00
# mechanicCarlos Rivas                                                                        4.225e+00
# mechanicCarlos Rodriguez                                                                    4.124e+00
# mechanicCASTILLO GIRON EDWIN EDGARDO                                                        3.519e+00
# mechanicCesar Edgardo Ruedas Mendoza                                                        2.399e+00
# mechanicCesar Edwin Maradiaga                                                               3.130e+00
# mechanicCristian Vladimir Cartagena Ortiz                                                   2.761e+00
# mechanicDaniel Arevalo                                                                      2.864e+00
# mechanicDaniel Edgardo Sandoval                                                             4.585e+00
# mechanicDENY RAYMUNDO PUCH POOL                                                             2.504e+00
# mechanicDIEGO CUELLAR                                                                       2.376e+00
# mechanicDouglas Alonso Bonilla Soriano                                                      4.180e+00
# mechanicDouglas del Cid                                                                     2.902e+00
# mechanicDOUGLAS LEONEL CHAVEZ                                                               3.155e+00
# mechanicDouglas Leonel Chavez Bonilla                                                       3.616e+00
# mechanicEdgar Arevalo                                                                       2.480e+00
# mechanicEDIS MAREL RODRIGUEZ                                                                2.761e+00
# mechanicEduardo Antonio Flores Campos                                                       2.220e+00
# mechanicEDWIN ALEXANDER CAMPOS                                                              2.474e+00
# mechanicEdwin Colindres                                                                     2.470e+00
# mechanicEdwin Edgardo Castillo Giron                                                        2.355e+00
# mechanicEdwin Froylan Turcios                                                               2.812e+00
# mechanicEdwin Rogelio Galeas Perez                                                          2.259e+00
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                         2.859e+00
# mechanicEmilio Zeledon Lopez                                                                2.785e+00
# mechanicEnrique Pech Canul                                                                  3.073e+00
# mechanicErick Garcia Lima                                                                   2.336e+00
# mechanicErick Salazar                                                                       2.643e+00
# mechanicEver Alfredo Flores Molina                                                          2.934e+00
# mechanicFABIAN POSADAS                                                                      3.995e+00
# mechanicFAULO VICENTE TEC TORRES                                                            2.437e+00
# mechanicFernando Alexander Pubill Quintanilla                                               2.646e+00
# mechanicFLORES CAMPOS EDUARDO ANTONIO                                                       3.095e+00
# mechanicFrancisco Antonio Hernandez                                                         2.984e+00
# mechanicFranqui Garcia                                                                      3.954e+00
# mechanicFUENTES LIMA NESTOR MAURICIO                                                        3.700e+00
# ...
# action_descPolish thread take up / Pulir leva
# action_descReplace bobbin / Reemplazar bobina
# action_descReplace burner resistance / Reemplazar resistencia de quemador
# action_descReplace machine head ball joint / Reemplazar biela de cabezal
# action_descReplace machine head knife / Reemplazar cuchilla de cabezal
# action_descReplace machine head looper / Reemplazar enlazador de cabezal                   *
# action_descReplace machine head needle / Reemplazar aguja de cabezal                       .
# action_descReplace machine head needle guard / Reemplazar guarda aguja de cabezal
# action_descReplace machine head needle plate / Reemplazar placa de aguja de cabezal
# action_descReplace machine head presser foot / Reemplazar prensatela de cabezal
# action_descReplace machine head teeth / Reemplazar dientes de cabezal
# action_descReplace thread cutting knife / Reemplazar cuchillas corta hilo
# action_descReplace thread tension assembly / Reemplazar tensor auxiliar de largo de hebra  **
# action_descReplace trim off knife / Reemplazar cuchilla de corta desperdicio
# action_descSharpen knife / Afilar cuchillas
# mechanicAdalberto Jeremias Rodriguez Zometa                                                ***
# mechanicAlfonso Escobar                                                                    ***
# mechanicAngel Mex                                                                          ***
# mechanicAnthony Murillo                                                                    ***
# mechanicAntony Ulloa                                                                       ***
# mechanicCain Alfredo Ramirez
# mechanicCarlos Alberto Alfaro Salamanca
# mechanicCARLOS CARRANZA LOBO
# mechanicCarlos De Leon                                                                     ***
# mechanicCarlos Ernesto Rojas Guzman                                                        ***
# mechanicCarlos Galo                                                                        ***
# mechanicCarlos Israel Linares                                                              ***
# mechanicCarlos Montoya                                                                     ***
# mechanicCarlos Oswaldo Rodriguez Sabala                                                    **
# mechanicCarlos Rivas                                                                       *
# mechanicCarlos Rodriguez                                                                   ***
# mechanicCASTILLO GIRON EDWIN EDGARDO
# mechanicCesar Edgardo Ruedas Mendoza
# mechanicCesar Edwin Maradiaga                                                              ***
# mechanicCristian Vladimir Cartagena Ortiz                                                  ***
# mechanicDaniel Arevalo
# mechanicDaniel Edgardo Sandoval                                                            **
# mechanicDENY RAYMUNDO PUCH POOL                                                            ***
# mechanicDIEGO CUELLAR                                                                      **
# mechanicDouglas Alonso Bonilla Soriano                                                     ***
# mechanicDouglas del Cid
# mechanicDOUGLAS LEONEL CHAVEZ                                                              ***
# mechanicDouglas Leonel Chavez Bonilla                                                      ***
# mechanicEdgar Arevalo                                                                      ***
# mechanicEDIS MAREL RODRIGUEZ                                                               ***
# mechanicEduardo Antonio Flores Campos                                                      ***
# mechanicEDWIN ALEXANDER CAMPOS                                                             ***
# mechanicEdwin Colindres                                                                    ***
# mechanicEdwin Edgardo Castillo Giron
# mechanicEdwin Froylan Turcios                                                              ***
# mechanicEdwin Rogelio Galeas Perez                                                         ***
# mechanicEFRAIN ALEJANDRO CIME CANUL                                                        ***
# mechanicEmilio Zeledon Lopez                                                               ***
# mechanicEnrique Pech Canul                                                                 ***
# mechanicErick Garcia Lima                                                                  ***
# mechanicErick Salazar                                                                      ***
# mechanicEver Alfredo Flores Molina                                                         ***
# mechanicFABIAN POSADAS                                                                     ***
# mechanicFAULO VICENTE TEC TORRES                                                           ***
# mechanicFernando Alexander Pubill Quintanilla                                              ***
# mechanicFLORES CAMPOS EDUARDO ANTONIO
# mechanicFrancisco Antonio Hernandez                                                        **
# mechanicFranqui Garcia                                                                     ***
# mechanicFUENTES LIMA NESTOR MAURICIO
# mechanicGabriel Sanchez                                                                    ***
# mechanicGeovanny  Felipe Rivera                                                            ***
# mechanicGerardo Arturo de la Cruz Lemus                                                    ***
# mechanicGilberto Antonio Flores                                                            ***
# mechanicGiovanny Alexander Rivas                                                           ***
# mechanicGuillermo Alfonso Ramirez Landaverde                                               ***
# mechanicGuillermo Josue Lara Ferman                                                        ***
# mechanicHarley Antonio Valiente                                                            ***
# mechanicHector Antonio Alfaro
# mechanicHector Montoya                                                                     ***
# mechanicHenry Valdez                                                                       ***
# mechanicHerbert Amilcar Montiel Sosa                                                       ***
# mechanicHugo Hernandez                                                                     ***
# mechanicIGNACIO COB                                                                        ***
# mechanicImmer Sanchez                                                                      ***
# mechanicIsaias Santiago Hernandez                                                          ***
# mechanicJaime Juarez                                                                       ***
# mechanicJaime Rivera                                                                       ***
# mechanicJAIRO NATAEL CALIX                                                                 ***
# mechanicJarim Martinez                                                                     ***
# mechanicJeffrey Velasquez                                                                  ***
# mechanicJERONIMO FUNEZ                                                                     ***
# mechanicJimmy Bardales                                                                     ***
# mechanicJoel Elias Chica Bran                                                              ***
# mechanicJoel Ernesto Cuellar Vanegas                                                       ***
# mechanicJose Manuel Perez Zepeda                                                           *
# mechanicJose Maria Canul Tec                                                               ***
# mechanicJOSE MAURICIO VELASQUEZ ASCENCIO                                                   ***
# mechanicJose Max Reyes Flores                                                              ***
# mechanicJOSE PEDRO DZUL PECH                                                               ***
# mechanicJose Valencia                                                                      ***
# mechanicJosue Zalmeron                                                                     ***
# mechanicJuan Absalon Portillo Lemus                                                        ***
# mechanicJuan Carlos Lemus
# mechanicJuan Francisco Cardona Hernandez
# mechanicJuan Leiva                                                                         ***
# mechanicJuan Manuel Interiano Zaldana
# mechanicJulia Margarita Chicas Diaz
# mechanicKenneth Emerson Clavel Flores                                                      ***
# mechanicLadislao Monterrosa Torres                                                         *
# mechanicLeonardo Cortez                                                                    ***
# mechanicLeonardo Villanueva                                                                ***
# mechanicLEONEL CHAVEZ                                                                      ***
# mechanicLuis Duran
# mechanicLuis Ernesto de la Rosa Garcia                                                     ***
# mechanicLuis Manuel Garcia Rosales                                                         *
# mechanicLUIS PECH                                                                          ***
# mechanicMarco Enmanuel Osorio Palacios                                                     .
# mechanicMarcos Emmanuel Osorio Palacios                                                    ***
# mechanicMARCOS MOGUEL                                                                      ***
# mechanicMAURICIO DAVILA SANCHEZ                                                            ***
# mechanicMauricio Ernesto Valencia                                                          ***
# mechanicMelvin Galeano                                                                     ***
# mechanicMiguel Angel Fajardo Ortiz
# mechanicMONTOYA HECTOR AMERICO                                                             ***
# mechanicNelson Amilcar Rodriguez Salazar                                                   ***
# mechanicNERY MENA RODRIGUEZ                                                                ***
# mechanicNestor Mauricio Carpio Salas                                                       ***
# mechanicNestor Mauricio Fuentes Lima
# mechanicNoe Alexander Caballero Flores                                                     ***
# mechanicNOE CONTRERAS                                                                      ***
# mechanicOdil Alfredo Guzman Saget                                                          ***
# mechanicOdil Alfredo Saget Guzman                                                          ***
# mechanicOmar Maldonado                                                                     ***
# mechanicOscar Argumedo
# mechanicOscar Hurtado                                                                      ***
# mechanicOtros                                                                              ***
# mechanicPedro Miguel Martinez Linares
# mechanicRafael Esquivel                                                                    ***
# mechanicRAMIREZ RIVERA ABEL ALBERTO
# mechanicRAMIREZ RIVERA CAIN ALFREDO                                                        ***
# mechanicRAMON VILLANUEVA                                                                   ***
# mechanicRaul Coto
# mechanicREYES JAVIER CORTEZ CANTE                                                          ***
# mechanicReynaldo Chavez Guerra                                                             *
# mechanicRichard Lara                                                                       ***
# mechanicRIVAS TORRES CARLOS ANTONIO                                                        *
# mechanicRoberto Reyes                                                                      *
# mechanicROMAN IGNACIO AYALA PUC                                                            ***
# mechanicRonald Antonio Herrera                                                             ***
# mechanicSalvador Roberto Palacios Alvarado                                                 *
# mechanicSalvador Rodriguez                                                                 ***
# mechanicSANCHEZ IMMER ALBERTO
# mechanicSAUL ALFARO                                                                        ***
# mechanicSaul Nolberto Alfaro                                                               ***
# mechanicVictor Alfonzo Ardon Monteros                                                      ***
# mechanicVladimir Enrique Aguilar Hernandez                                                 ***
# mechanicWalter Anibal Belloso Hernandez                                                    ***
# mechanicWalter Patino                                                                      ***
# mechanicWALTER RENE SIERRA VARGAS                                                          ***
# mechanicWilliam Alexander Arevalo Leiva                                                    ***
# mechanicWillian Tejada                                                                     ***
# mechanicWILMER CRUZ                                                                        ***
# parts_cost
# changed_pcs                                                                                ***
# Days_Between_Failures                                                                      ***
# outlierTRUE                                                                                ***
# Cumulative_Failure_Count
# Median_Repair_Time                                                                         ***
# Cumulative_Maintenance_Cost                                                                ***
# Age                                                                                        ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 2395.894)
#
#     Null deviance: 989661669  on 95101  degrees of freedom
# Residual deviance: 227173833  on 94818  degrees of freedom
# AIC: 1010211
#
# Number of Fisher Scoring iterations: 2

# %%
# Predecir con el conjunto de prueba
test_predictions <- predict(model5, newdata = test_data4)

# Calcular métricas de rendimiento para el conjunto de prueba
test_actuals <- test_data4$downtime_gross
test_rmse <- sqrt(mean((test_predictions - test_actuals)^2))
test_mae <- mean(abs(test_predictions - test_actuals))
test_r2 <- 1 - (sum((test_predictions - test_actuals)^2) / sum((test_actuals - mean(test_actuals))^2))

cat("Test RMSE: ", test_rmse, "\n")
cat("Test MAE: ", test_mae, "\n")
cat("Test R-squared: ", test_r2, "\n")
# Out:
# Test RMSE:  48.54344
# Test MAE:  32.60229
# Test R-squared:  0.7699426

# %% [markdown]
# **IMPLEMENTACION DE FRONTWARD**

# %%
sapply(df_merged2, function(x) sum(is.na(x)))
# Out:
#                   equipment                   operation
#                           0                           0
#                  base_model                problem_desc
#                           0                           0
#                failure_desc                  cause_desc
#                           0                           0
#                 action_desc                    mechanic
#                           0                           0
#                        date              downtime_gross
#                           0                           0
#                  parts_cost                repair_hours
#                           0                           0
#                 changed_pcs       Days_Between_Failures
#                           0                           0
#                     outlier    Cumulative_Failure_Count
#                           0                           0
#          Median_Repair_Time Cumulative_Maintenance_Cost
#                           0                           0
#                         Age                   antiquity
#                           0                           0

# %%
# Realizar backward elimination
model_null <- lm(downtime_gross ~ 1, data = train_data4)
model_forward <- step(model_null,
                      scope = list(lower = model_null, upper = model5),
                      direction = "forward")
model_forward$anova

# %%
formula = as.formula("downtime_gross ~ changed_pcs + mechanic + operation + Median_Repair_Time +
    cause_desc + Cumulative_Maintenance_Cost + problem_desc +
    failure_desc + base_model + action_desc + Days_Between_Failures +
    Age + Cumulative_Failure_Count")

# %%
# Inicializar y ajustar el modelo de regresión lineal
model6 <- glm(formula = formula, data = train_data4)
# Resumen del modelo
summary(model6)

# %% [markdown]
# **MODELO RANDOM FOREST**

# %%
# Entrenar el modelo de Random Forest
model_rf <- randomForest(downtime_gross~. -equipment -downtime_gross -repair_hours -date -antiquity, data = train_data4, importance = TRUE)

# Ver el resumen del modelo
print(model_rf)

# %%
# Hacer predicciones en el conjunto de prueba
predictions <- predict(model_rf, newdata = test_data4)

# Calcular el Error Cuadrático Medio (MSE)
mse <- mean((test_data4$downtime_gross - predictions)^2)
print(paste("MSE:", mse))

# Calcular el Coeficiente de Determinación (R^2)
r_squared <- 1 - (sum((test_data4$downtime_gross - predictions)^2) / sum((test_data4$downtime_gross - mean(test_data4$downtime_gross))^2))
print(paste("R^2:", r_squared))

# %%
residuals <- test_data4$downtime_gross - predictions

# %%
# Crear el histograma de los residuales
hist(residuals,
     main = "Histogram of Residuals",
     xlab = "Residuals",
     breaks = 30,
     col = "gray")

# %%
# Ver la importancia de las variables
importance(model_rf)
varImpPlot(model_rf)
